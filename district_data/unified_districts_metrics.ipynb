# %%
#!pip install wget
#!pip install urllib3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from subprocess import call
from scipy.stats.distributions import gamma,lognorm
import json 
import wget
import os
import os.path
from datetime import datetime
import pytz 
from collections import OrderedDict
#from google.colab import drive
import math

from datetime import datetime,timedelta
from urllib.request import urlopen
import collections
import copy
#os.chdir('/content/gdrive/My Drive')
#drive.mount('/content/gdrive')

# %%
if os.path.exists("test.json"):
  os.remove("test.json")
wget.download('https://api.covid19india.org/v4/data-all.json', os.path.join(os.getcwd(),"test.json"))
# Out:
# 100% [....................................................] 28864158 / 28864158
# 'C:\\Users\\asus\\Documents\\GitHub\\CovidToday_Website\\district_data\\test.json'

# %%
def convert(dat): 
    return datetime.strptime(dat, '%Y-%m-%d').strftime('%d %B')

# %%
dataset=pd.read_csv('population_districts.csv')
population=pd.DataFrame()
population["District"]=dataset['District']
population["Population"]=dataset['Population']
population = population.set_index('District')
population
# Out:
#                      Population
# District
# Anantapur               4081148
# Chittoor                4174064
# East Godavari           5154296
# Guntur                  4887813
# Kurnool                 4053463
# Prakasam                3397448
# Srikakulam              2703114
# Visakhapatnam           4290589
# Vizianagaram            2344474
# West Godavari           3936966
# Kamrup Metropolitan     1253938
# Begusarai               2970541
# Patna                   5838465
# Ahmedabad               7214225
# Rajkot                  3804558
# Surat                   6081322
# Vadodara                4165626
# Faridabad               1809733
# Gurugram                1514432
# Bengaluru Urban         9621551
# Aurangabad              3701282
# Jalgaon                 4229917
# Kolhapur                3876001
# Mumbai                 12442373
# Nagpur                  4653570
# Nashik                  6107187
# Palghar                 2990116
# Pune                    9429408
# Raigad                  2634200
# Solapur                 4317756
# Thane                   8070032
# Bhopal                  2371061
# Indore                  3276697
# Ganjam                  3529031
# Ludhiana                3498739
# Hyderabad               3943323
# Medchal Malkajgiri      2440073
# Ranga Reddy             2446265
# Chengalpattu            2556423
# Chennai                 4646732
# Kancheepuram            3998252
# Madurai                 3038252
# Thiruvallur             3728104
# Tiruvannamalai          2464875
# Vellore                 3936331
# Aligarh                 3673889
# Bareilly                4448359
# Gautam Buddha Nagar     1648115
# Ghaziabad               4681645
# Kanpur Nagar            4581268
# Lucknow                 4589838
# Varanasi                3676841
# Kolkata                 4496694
# North 24 Parganas      10009781

# %%
d={}
for i in dataset['State_Code'].unique():
    d[i] = [dataset['District'][j] for j in dataset[dataset['State_Code']==i].index]

# %%
state_id = d
x=datetime.now(pytz.timezone('Asia/Kolkata')).date()
dd=pd.date_range(start="2020-01-30",end=x)
dates=[]
for i in range(len(dd)):
  dates.append((str(dd[i])[:10]))
#dates
dates1=[]
for w in range (len(dates)):
  if len(dates[w]):
    dates1.append(convert(dates[w]))

# %%
{
  "MH":["Mumbai", "Thane", "Pune", "Palghar", "Aurangabad"],
  "TN":["Chennai", "Chengalpattu"],
  "KA":["Bengaluru Urban"],
  "GJ":["Ahmedabad", "Surat"],
  "WB":["Kolkata"],
  "HR":["Gurugram"],
  "TG":["Hyderabad"],
}
# Out:
# {'MH': ['Mumbai', 'Thane', 'Pune', 'Palghar', 'Aurangabad'],
#  'TN': ['Chennai', 'Chengalpattu'],
#  'KA': ['Bengaluru Urban'],
#  'GJ': ['Ahmedabad', 'Surat'],
#  'WB': ['Kolkata'],
#  'HR': ['Gurugram'],
#  'TG': ['Hyderabad']}

# %%
'''
from datetime import timedelta
start=datetime.now()
x1=datetime.now(pytz.timezone('Asia/Kolkata')).date()
#x1 = datetime.today()
#y1 = timedelta(days=7)
y1=[]
x1=str(x1)[:10]
for i in range(7,0,-1):
  y1.append(str(datetime.today()-timedelta(days=i))[:10])
#print(y1)
##y1=str(y1)[:10]
t=y1
t
'''
def dates_gen(periods=7):
  t = pd.Series(pd.date_range(end = datetime.now(pytz.timezone('Asia/Kolkata'))-timedelta(1), periods = periods)).dt.strftime('%Y-%m-%d').tolist()

  return t

# %%
t = dates_gen()

# %% [markdown]
# # Positivity Rate (All metrics)

# %% [markdown]
# ## From the begining

# %%
start=datetime.now()
states={}
csv_dates=[]
csv_states=[]
csv_total_cases=[]
csv_cum_recovered=[]
csv_daily_recovered=[]
csv_cum_deceased=[]
csv_daily_deceased=[]
csv_positivity_rate_cumulative=[]
csv_daily_positive_cases=[]
csv_daily_positivity_rate=[]
csv_daily_positive_cases_ma=[]
csv_daily_positivity_rate_ma=[]
csv_test_per_million=[]
csv_daily_tested=[]
csv_cum_tested=[]

csv_daily_case_per_million = []
csv_daily_test_per_million = []
csv_daily_test_ma = []
csv_daily_deceased_ma = []

test=json.load(open('test.json'))


for j in state_id.keys():
  for k in state_id[j]:   
    test_per_million = ['']*len(dates)
    pos_cum = ['']*len(dates)
    pos_rate_cum = ['']*len(dates)
    daily_pos = ['']*len(dates)
    daily_pos_ma = ['']*len(dates)
    daily_tested = ['']*len(dates)
    daily_pos_rate = ['']*len(dates)
    daily_pos_rate_ma = ['']*len(dates)
    tested_cum = ['']*len(dates)
    tested_daily = ['']*len(dates)
    deceased_cum = ['']*len(dates)
    daily_deceased = ['']*len(dates)
    recovered_cum = ['']*len(dates)
    daily_recovered = ['']*len(dates)


    daily_case_per_million = ['']*len(dates)
    daily_test_per_million = ['']*len(dates)
    daily_test_ma = ['']*len(dates)
    daily_deceased_ma = ['']*len(dates)
    
    for i in range(len(dates)):
      
      if dates[i] in test.keys():
          temp=test[dates[i]] 
          if j in temp.keys():
            
            if 'districts' in temp[j].keys():
          
              if k in temp[j]['districts']:
               
                if 'total' in temp[j]['districts'][k].keys():
                  
                  if 'confirmed' in temp[j]['districts'][k]['total'].keys():
                  
                    pos_cum[i]=temp[j]['districts'][k]['total']['confirmed']

                  if 'tested' in temp[j]['districts'][k]['total'].keys():
                    tested_cum[i]=abs(temp[j]['districts'][k]['total']['tested'])
                    test_per_million[i]=temp[j]['districts'][k]['total']['tested']*1000000/int(population["Population"][k])
                      
                  if 'deceased' in temp[j]['districts'][k]['total'].keys():
                    deceased_cum[i]=temp[j]['districts'][k]['total']['deceased']
                  
                  if 'recovered' in temp[j]['districts'][k]['total'].keys():
                    recovered_cum[i]=temp[j]['districts'][k]['total']['recovered']
                  
                  if len(str(pos_cum[i])) and len(str(tested_cum[i])):
                    pos_rate_cum[i]= pos_cum[i]*100/tested_cum[i]


                if 'delta' in temp[j]['districts'][k].keys():
                  if 'confirmed' in temp[j]['districts'][k]['delta'].keys():
                    daily_pos[i]=temp[j]['districts'][k]['delta']['confirmed']
                    try:
                      daily_case_per_million[i] =temp[j]['delta']['confirmed']*1000000/int(population["Population"][k])   #New
                    except:
                      daily_case_per_million[i]= ''
                  if 'tested' in temp[j]['districts'][k]['delta'].keys():
                    daily_tested[i]=abs(temp[j]['districts'][k]['delta']['tested'])
                    try:
                      daily_test_per_million[i] = temp[j]['delta']['tested']*1000000/int(population["Population"][k])    #New
                    except:
                      daily_test_per_million[i] = ''
                  if 'deceased' in temp[j]['districts'][k]['delta'].keys():
                    daily_deceased[i]=temp[j]['districts'][k]['delta']['deceased']
                  
                  if 'recovered' in temp[j]['districts'][k]['delta'].keys():
                    daily_recovered[i]=temp[j]['districts'][k]['delta']['recovered']
                  
                  if len(str(daily_pos[i])) and len(str(daily_tested[i])):
                    daily_pos_rate[i]=int(daily_pos[i])*100/int(daily_tested[i])

      

    for w in range(7,len(daily_pos)):
                  sum1=0
                  sum2=0
                  for s in range(7):
                    if (len(str(daily_pos[w-s]))!=0 and len(str(daily_tested[w-s]))!=0):
                      sum1+=int(daily_pos[w-s])
                      sum2+=int(daily_tested[w-s])
                  if (sum2!=0):
                    daily_pos_rate_ma[w]=sum1*100/abs(sum2)
                
    for w in range(7,len(daily_pos)):
                  sum1=0
                  count=0
                  for s in range(7):
                    if (len(str(daily_pos[w-s]))!=0):
                      sum1+=int(daily_pos[w-s])
                      count+=1
                  if count!=0:
                    daily_pos_ma[w]=sum1/count

 
    for w in range(7,len(daily_tested)):
      sum1=0
      count=0
      for s in range(7):
        if (len(str(daily_tested[w-s]))!=0):
          sum1+=int(daily_tested[w-s])
        
          count+=1
      if count!=0:
        daily_test_ma[w]=sum1/count
        

    for w in range(7,len(daily_deceased)):
      sum1=0
      count=0
      for s in range(7):
        if (len(str(daily_deceased[w-s]))!=0):
          sum1+=int(daily_deceased[w-s])
          count+=1
      if count!=0:
        daily_deceased_ma[w]=sum1/count



    #print(daily_pos_rate[-15:],k)

    for i in range(len(dates)-1):
                  csv_dates.append(dates1[i])
                  csv_states.append(k)
                  csv_total_cases.append(pos_cum[i])
                  csv_positivity_rate_cumulative.append(pos_rate_cum[i])
                  csv_daily_positive_cases.append(daily_pos[i])
                  csv_cum_recovered.append(recovered_cum[i])
                  csv_daily_recovered.append(daily_recovered[i])
                  csv_cum_deceased.append(deceased_cum[i])
                  csv_daily_deceased.append(daily_deceased[i])
                  csv_daily_positivity_rate.append(daily_pos_rate[i])
                  csv_daily_positive_cases_ma.append(daily_pos_ma[i])
                  csv_daily_positivity_rate_ma.append(daily_pos_rate_ma[i])
                  csv_daily_tested.append(daily_tested[i])
                  csv_cum_tested.append(tested_cum[i])
                  csv_test_per_million.append(test_per_million[i])

                 
                  csv_daily_case_per_million.append(daily_case_per_million[i])
                  csv_daily_test_per_million.append(daily_test_per_million[i])
                  csv_daily_test_ma.append(daily_test_ma[i])
                  csv_daily_deceased_ma.append(daily_deceased_ma[i])
      
    states[k]={
                                  'dates':dates1[:-1],
                                  'cum_positive_cases':pos_cum[:-1],
                                  'cum_positivity_rate':pos_rate_cum[:-1],
                                  'daily_positive_cases':daily_pos[:-1],
                                  'cum_recovered':recovered_cum[:-1],
                                  'daily_recovered':daily_recovered[:-1],
                                  'cum_deceased':deceased_cum[:-1],
                                  'daily_deceased':daily_deceased[:-1],
                                  'daily_positivity_rate':daily_pos_rate[:-1],
                                  'daily_positive_cases_ma': daily_pos_ma[:-1],
                                  'daily_positivity_rate_ma':daily_pos_rate_ma[:-1] , 
                                  'daily_tests': daily_tested[:-1],
                                  'cum_tests': tested_cum[:-1],
                                  'test_per_million':test_per_million[:-1],
                                  'daily_cases_per_million':daily_case_per_million[:-1],
                                  'daily_tests_per_million':daily_test_per_million[:-1],
                                  'daily_tests_ma':daily_test_ma[:-1],
                                  'daily_deceased_ma':daily_deceased_ma[:-1]
                            }
end=datetime.now()
print(end-start)
# Out:
# 0:00:01.533085

# %%
dates1
# Out:
# ['30 January',
#  '31 January',
#  '01 February',
#  '02 February',
#  '03 February',
#  '04 February',
#  '05 February',
#  '06 February',
#  '07 February',
#  '08 February',
#  '09 February',
#  '10 February',
#  '11 February',
#  '12 February',
#  '13 February',
#  '14 February',
#  '15 February',
#  '16 February',
#  '17 February',
#  '18 February',
#  '19 February',
#  '20 February',
#  '21 February',
#  '22 February',
#  '23 February',
#  '24 February',
#  '25 February',
#  '26 February',
#  '27 February',
#  '28 February',
#  '29 February',
#  '01 March',
#  '02 March',
#  '03 March',
#  '04 March',
#  '05 March',
#  '06 March',
#  '07 March',
#  '08 March',
#  '09 March',
#  '10 March',
#  '11 March',
#  '12 March',
#  '13 March',
#  '14 March',
#  '15 March',
#  '16 March',
#  '17 March',
#  '18 March',
#  '19 March',
#  '20 March',
#  '21 March',
#  '22 March',
#  '23 March',
#  '24 March',
#  '25 March',
#  '26 March',
#  '27 March',
#  '28 March',
#  '29 March',
#  '30 March',
#  '31 March',
#  '01 April',
#  '02 April',
#  '03 April',
#  '04 April',
#  '05 April',
#  '06 April',
#  '07 April',
#  '08 April',
#  '09 April',
#  '10 April',
#  '11 April',
#  '12 April',
#  '13 April',
#  '14 April',
#  '15 April',
#  '16 April',
#  '17 April',
#  '18 April',
#  '19 April',
#  '20 April',
#  '21 April',
#  '22 April',
#  '23 April',
#  '24 April',
#  '25 April',
#  '26 April',
#  '27 April',
#  '28 April',
#  '29 April',
#  '30 April',
#  '01 May',
#  '02 May',
#  '03 May',
#  '04 May',
#  '05 May',
#  '06 May',
#  '07 May',
#  '08 May',
#  '09 May',
#  '10 May',
#  '11 May',
#  '12 May',
#  '13 May',
#  '14 May',
#  '15 May',
#  '16 May',
#  '17 May',
#  '18 May',
#  '19 May',
#  '20 May',
#  '21 May',
#  '22 May',
#  '23 May',
#  '24 May',
#  '25 May',
#  '26 May',
#  '27 May',
#  '28 May',
#  '29 May',
#  '30 May',
#  '31 May',
#  '01 June',
#  '02 June',
#  '03 June',
#  '04 June',
#  '05 June',
#  '06 June',
#  '07 June',
#  '08 June',
#  '09 June',
#  '10 June',
#  '11 June',
#  '12 June',
#  '13 June',
#  '14 June',
#  '15 June',
#  '16 June',
#  '17 June',
#  '18 June',
#  '19 June',
#  '20 June',
#  '21 June',
#  '22 June',
#  '23 June',
#  '24 June',
#  '25 June',
#  '26 June',
#  '27 June',
#  '28 June',
#  '29 June',
#  '30 June',
#  '01 July',
#  '02 July',
#  '03 July',
#  '04 July',
#  '05 July',
#  '06 July',
#  '07 July',
#  '08 July',
#  '09 July',
#  '10 July',
#  '11 July',
#  '12 July',
#  '13 July',
#  '14 July',
#  '15 July',
#  '16 July',
#  '17 July',
#  '18 July',
#  '19 July',
#  '20 July',
#  '21 July',
#  '22 July',
#  '23 July',
#  '24 July',
#  '25 July',
#  '26 July',
#  '27 July',
#  '28 July',
#  '29 July',
#  '30 July',
#  '31 July',
#  '01 August',
#  '02 August',
#  '03 August',
#  '04 August',
#  '05 August',
#  '06 August',
#  '07 August',
#  '08 August',
#  '09 August',
#  '10 August',
#  '11 August',
#  '12 August',
#  '13 August',
#  '14 August',
#  '15 August',
#  '16 August',
#  '17 August',
#  '18 August',
#  '19 August',
#  '20 August',
#  '21 August',
#  '22 August',
#  '23 August',
#  '24 August',
#  '25 August']

# %% [markdown]
# ## Append Method

# %%
'''
csv_dates=[]
csv_states=[]
csv_total_cases=[]
csv_cum_recovered=[]
csv_daily_recovered=[]
csv_cum_deceased=[]
csv_daily_deceased=[]
csv_positivity_rate_cumulative=[]
csv_daily_positive_cases=[]
csv_daily_positivity_rate=[]
csv_daily_positive_cases_ma=[]
csv_daily_positivity_rate_ma=[]
csv_test_per_million=[]
csv_daily_tested=[]
csv_cum_tested=[]

#New
csv_daily_case_per_million = []
csv_daily_test_per_million = []
csv_daily_test_ma = []
csv_daily_deceased_ma = []

temp1 = json.load(open('positivity_Rate_dist.json'))

test_json_url = 'https://api.covid19india.org/v3/data-all.json'
test_json = json.loads(urlopen(test_json_url).read())
test= test_json


for x in t:
  temp = test[x]
  
  states={}
  for j in state_id.keys():
    for k in state_id[j]:
    
      test_per_million = temp1[k]['test_per_million']
      pos_cum = temp1[k]['cum_positive_cases']
      pos_rate_cum = temp1[k]['cum_positivity_rate']
      daily_pos = temp1[k]['daily_positive_cases']
      daily_pos_ma = temp1[k]['daily_positive_cases_ma']
      daily_pos_rate = temp1[k]['daily_positivity_rate']
      daily_pos_rate_ma = temp1[k]['daily_positivity_rate_ma']
      tested_cum = temp1[k]['cum_tests']
      daily_tested = temp1[k]['daily_tests']
      deceased_cum = temp1[k]['cum_deceased']
      daily_deceased = temp1[k]['daily_deceased']
      recovered_cum = temp1[k]['cum_recovered']
      daily_recovered = temp1[k]['daily_recovered'] 

      #New added
      daily_case_per_million  = temp1[k]['daily_cases_per_million']
      daily_test_per_million  = temp1[k]['daily_tests_per_million']
      daily_test_ma  = temp1[k]['daily_tests_ma']
      daily_deceased_ma  = temp1[k]['daily_deceased_ma']
      
      dates=temp1[k]['dates']
      if convert(x) not in dates :
        print(1)
        dates.append(convert(x))
        test_per_million.append('')
        pos_cum.append('')
        pos_rate_cum.append('')
        daily_pos.append('')
        daily_pos_ma.append('')
        daily_pos_rate.append('')
        daily_pos_rate_ma.append('')
        tested_cum.append('')
        daily_tested.append('')
        deceased_cum.append('')
        daily_deceased.append('')
        recovered_cum.append('')
        daily_recovered.append('')
        i=len(dates)-1

      for l in range(len(dates)):
        if convert(x)==dates[l]:
          i=l
          break
      
      if dates[i] in test.keys():
          temp=test[dates[i]] #New
          # Previoustemp=json.load(open('test.json'))[dates[i]]
          if j in temp.keys():
            if 'districts' in temp[j].keys():
              if k in temp1.keys():
                  if 'total' in temp[j]['districts'][k].keys():
                    if 'confirmed' in temp[j]['districts'][k]['total'].keys():
                      pos_cum[i]=temp[j]['districts'][k]['total']['confirmed']

                    if 'tested' in temp[j]['districts'][k]['total'].keys():
                      tested_cum[i]=abs(temp[j]['districts'][k]['total']['tested'])
                      test_per_million[i]=temp[j]['districts'][k]['total']['tested']*1000000/int(population["Population"][k])
                        
                    if 'deceased' in temp[j]['districts'][k]['total'].keys():
                      deceased_cum[i]=temp[j]['districts'][k]['total']['deceased']
                    
                    if 'recovered' in temp[j]['districts'][k]['total'].keys():
                      recovered_cum[i]=temp[j]['districts'][k]['total']['recovered']
                    
                    if len(str(pos_cum[i])) and len(str(tested_cum[i])):
                      pos_rate_cum[i]= pos_cum[i]*100/tested_cum[i]

                  if 'delta' in temp[j].keys():
                    if 'confirmed' in temp[j]['districts'][k]['delta'].keys():
                      daily_pos[i]=temp[j]['districts'][k]['delta']['confirmed']
                      try:
                        daily_case_per_million[i] =temp[j]['delta']['confirmed']*1000000/int(population["Population"][k])   #New
                      except:
                        daily_case_per_million[i]= ''

                    if 'tested' in temp[j]['districts'][k]['delta'].keys():
                      daily_tested[i]=abs(temp[j]['districts'][k]['delta']['tested'])
                      try:
                        daily_test_per_million[i] = temp[j]['delta']['tested']*1000000/int(population["Population"][k])    #New
                      except:
                        daily_test_per_million[i] = ''

                    if 'deceased' in temp[j]['districts'][k]['delta'].keys():
                      daily_deceased[i]=temp[j]['districts'][k]['delta']['deceased']
                    
                    if 'recovered' in temp[j]['districts'][k]['delta'].keys():
                      daily_recovered[i]=temp[j]['districts'][k]['delta']['recovered']
                    
                    if len(str(daily_pos[i])) and len(str(daily_tested[i])):
                      daily_pos_rate[i]=int(daily_pos[i])*100/int(daily_tested[i])

      for w in range(7,len(daily_pos)):
        sum1=0
        sum2=0
        for s in range(7):
          if (len(str(daily_pos[w-s]))!=0 and len(str(daily_tested[w-s]))!=0):
            sum1+=int(daily_pos[w-s])
            sum2+=int(daily_tested[w-s])
        if (sum2!=0):
          daily_pos_rate_ma[w]=sum1*100/abs(sum2)
      
      for w in range(7,len(daily_pos)):
        sum1=0
        count=0
        for s in range(7):
          if (len(str(daily_pos[w-s]))!=0):
            sum1+=int(daily_pos[w-s])
            count+=1
        if count!=0:
          daily_pos_ma[w]=sum1/count

      #New
      for w in range(7,len(daily_tested)):
        sum1=0
        count=0
        for s in range(7):
          if (len(str(daily_tested[w-s]))!=0):
            sum1+=int(daily_tested[w-s])
          
            count+=1
        if count!=0:
          daily_test_ma[w]=sum1/count
          
      #New
      for w in range(7,len(daily_deceased)):
        sum1=0
        count=0
        for s in range(7):
          if (len(str(daily_deceased[w-s]))!=0):
            sum1+=int(daily_deceased[w-s])
            count+=1
        if count!=0:
          daily_deceased_ma[w]=sum1/count


      st=k
      for i in range(len(dates)):
          
          csv_dates.append(dates[i])
          csv_states.append(st)
          csv_total_cases.append(pos_cum[i])
          csv_positivity_rate_cumulative.append(pos_rate_cum[i])
          csv_daily_positive_cases.append(daily_pos[i])
          csv_cum_recovered.append(recovered_cum[i])
          csv_daily_recovered.append(daily_recovered[i])
          csv_cum_deceased.append(deceased_cum[i])
          csv_daily_deceased.append(daily_deceased[i])
          csv_daily_positivity_rate.append(daily_pos_rate[i])
          csv_daily_positive_cases_ma.append(daily_pos_ma[i])
          csv_daily_positivity_rate_ma.append(daily_pos_rate_ma[i])
          csv_daily_tested.append(daily_tested[i])
          csv_cum_tested.append(tested_cum[i])
          csv_test_per_million.append(test_per_million[i])
          
          #New
          csv_daily_case_per_million.append(daily_case_per_million[i])
          csv_daily_test_per_million.append(daily_test_per_million[i])
          csv_daily_test_ma.append(daily_test_ma[i])
          csv_daily_deceased_ma.append(daily_deceased_ma[i])
      #print(st)
      
      states[st]={
                      'dates':dates,
                      'cum_positive_cases':pos_cum,
                      'cum_positivity_rate':pos_rate_cum,
                      'daily_positive_cases':daily_pos,
                      'cum_recovered':recovered_cum,
                      'daily_recovered':daily_recovered,
                      'cum_deceased':deceased_cum,
                      'daily_deceased':daily_deceased,
                      'daily_positivity_rate':daily_pos_rate,
                      'daily_positive_cases_ma': daily_pos_ma,
                      'daily_positivity_rate_ma':daily_pos_rate_ma , 
                      'daily_tests': daily_tested,
                      'cum_tests': tested_cum,
                      'test_per_million':test_per_million,   

                      #New
                      'daily_cases_per_million':daily_case_per_million,
                      'daily_tests_per_million':daily_test_per_million,
                      'daily_tests_ma':daily_test_ma,
                      'daily_deceased_ma':daily_deceased_ma 
                }

    

states['datetime']=str(datetime.now(pytz.timezone('Asia/Kolkata')))
with open('positivity_Rate_dist.json', 'w') as outfile:
    json.dump(states, outfile,indent=4)'''
# Out:
# '\ncsv_dates=[]\ncsv_states=[]\ncsv_total_cases=[]\ncsv_cum_recovered=[]\ncsv_daily_recovered=[]\ncsv_cum_deceased=[]\ncsv_daily_deceased=[]\ncsv_positivity_rate_cumulative=[]\ncsv_daily_positive_cases=[]\ncsv_daily_positivity_rate=[]\ncsv_daily_positive_cases_ma=[]\ncsv_daily_positivity_rate_ma=[]\ncsv_test_per_million=[]\ncsv_daily_tested=[]\ncsv_cum_tested=[]\n\n#New\ncsv_daily_case_per_million = []\ncsv_daily_test_per_million = []\ncsv_daily_test_ma = []\ncsv_daily_deceased_ma = []\n\ntemp1 = json.load(open(\'positivity_Rate_dist.json\'))\n\ntest_json_url = \'https://api.covid19india.org/v3/data-all.json\'\ntest_json = json.loads(urlopen(test_json_url).read())\ntest= test_json\n\n\nfor x in t:\n  temp = test[x]\n  \n  states={}\n  for j in state_id.keys():\n    for k in state_id[j]:\n    \n      test_per_million = temp1[k][\'test_per_million\']\n      pos_cum = temp1[k][\'cum_positive_cases\']\n      pos_rate_cum = temp1[k][\'cum_positivity_rate\']\n      daily_pos = temp1[k][\'daily_positive_cases\']\n      daily_pos_ma = temp1[k][\'daily_positive_cases_ma\']\n      daily_pos_rate = temp1[k][\'daily_positivity_rate\']\n      daily_pos_rate_ma = temp1[k][\'daily_positivity_rate_ma\']\n      tested_cum = temp1[k][\'cum_tests\']\n      daily_tested = temp1[k][\'daily_tests\']\n      deceased_cum = temp1[k][\'cum_deceased\']\n      daily_deceased = temp1[k][\'daily_deceased\']\n      recovered_cum = temp1[k][\'cum_recovered\']\n      daily_recovered = temp1[k][\'daily_recovered\'] \n\n      #New added\n      daily_case_per_million  = temp1[k][\'daily_cases_per_million\']\n      daily_test_per_million  = temp1[k][\'daily_tests_per_million\']\n      daily_test_ma  = temp1[k][\'daily_tests_ma\']\n      daily_deceased_ma  = temp1[k][\'daily_deceased_ma\']\n      \n      dates=temp1[k][\'dates\']\n      if convert(x) not in dates :\n        print(1)\n        dates.append(convert(x))\n        test_per_million.append(\'\')\n        pos_cum.append(\'\')\n        pos_rate_cum.append(\'\')\n        daily_pos.append(\'\')\n        daily_pos_ma.append(\'\')\n        daily_pos_rate.append(\'\')\n        daily_pos_rate_ma.append(\'\')\n        tested_cum.append(\'\')\n        daily_tested.append(\'\')\n        deceased_cum.append(\'\')\n        daily_deceased.append(\'\')\n        recovered_cum.append(\'\')\n        daily_recovered.append(\'\')\n        i=len(dates)-1\n\n      for l in range(len(dates)):\n        if convert(x)==dates[l]:\n          i=l\n          break\n      \n      if dates[i] in test.keys():\n          temp=test[dates[i]] #New\n          # Previoustemp=json.load(open(\'test.json\'))[dates[i]]\n          if j in temp.keys():\n            if \'districts\' in temp[j].keys():\n              if k in temp1.keys():\n                  if \'total\' in temp[j][\'districts\'][k].keys():\n                    if \'confirmed\' in temp[j][\'districts\'][k][\'total\'].keys():\n                      pos_cum[i]=temp[j][\'districts\'][k][\'total\'][\'confirmed\']\n\n                    if \'tested\' in temp[j][\'districts\'][k][\'total\'].keys():\n                      tested_cum[i]=abs(temp[j][\'districts\'][k][\'total\'][\'tested\'])\n                      test_per_million[i]=temp[j][\'districts\'][k][\'total\'][\'tested\']*1000000/int(population["Population"][k])\n                        \n                    if \'deceased\' in temp[j][\'districts\'][k][\'total\'].keys():\n                      deceased_cum[i]=temp[j][\'districts\'][k][\'total\'][\'deceased\']\n                    \n                    if \'recovered\' in temp[j][\'districts\'][k][\'total\'].keys():\n                      recovered_cum[i]=temp[j][\'districts\'][k][\'total\'][\'recovered\']\n                    \n                    if len(str(pos_cum[i])) and len(str(tested_cum[i])):\n                      pos_rate_cum[i]= pos_cum[i]*100/tested_cum[i]\n\n                  if \'delta\' in temp[j].keys():\n                    if \'confirmed\' in temp[j][\'districts\'][k] ...

# %%
states['datetime']=str(datetime.now(pytz.timezone('Asia/Kolkata')))
with open('positivity_Rate_dist.json', 'w') as outfile:
    json.dump(states, outfile,indent=4)

# %%
n_states=0
for i in state_id.values():
  for k in i:
    n_states+=1

n_dates = len(list(test.keys()))

rows = n_states*n_dates

# %%
rows/36
# Out:
# 271.5

# %%
csv_dates[-1]
# Out:
# '24 August'

# %%
df=pd.DataFrame()

df['dates']=csv_dates[:rows]
df['state']=csv_states[:rows]
df['cum_positive_cases']=csv_total_cases[:rows]
df['cum_positivity_rate']=csv_positivity_rate_cumulative[:rows]
df['cum_recovered']=csv_cum_recovered[:rows]
df['daily_recovered']:csv_daily_recovered[:rows]
df['cum_deceased']=csv_cum_deceased[:rows]
df['daily_deceased']:daily_deceased[:rows]
df['daily_positive_cases']=csv_daily_positive_cases[:rows]
df['daily_positivity_rate']=csv_daily_positivity_rate[:rows]
df['daily_positive_cases_ma']=csv_daily_positive_cases_ma[:rows]
df['daily_positivity_rate_ma']=    csv_daily_positivity_rate_ma[:rows]
df['daily_tests']=csv_daily_tested[:rows]
df['cum_tested']=csv_cum_tested[:rows]
df['test_per_million']=csv_test_per_million[:rows]

#New
df['daily_cases_per_million'] = csv_daily_case_per_million[:rows]
df['daily_tests_per_million'] = csv_daily_test_per_million[:rows]
df['daily_tests_ma'] = csv_daily_test_ma[:rows]
df['daily_deceased_ma'] = csv_daily_deceased_ma[:rows]

df.to_csv('positivity_Rate_dist.csv',index=False)

# %%
df_to_concat = copy.deepcopy(df)

# %%
data_recovered = pd.DataFrame()
districts=[]
data_deceased = pd.DataFrame()
data_confirmed = pd.DataFrame()
for s in state_id.keys():
    st=state_id[s]
    districts+=st
    print(st)
    for k in st:
      data_confirmed[k] = np.array(states[k]['daily_positive_cases'])
      data_deceased[k] = np.array(states[k]['daily_deceased'])
      data_recovered[k] = np.array(states[k]['daily_recovered'])
# Out:
# ['Anantapur', 'Chittoor', 'East Godavari', 'Guntur', 'Kurnool', 'Prakasam', 'Srikakulam', 'Visakhapatnam', 'Vizianagaram', 'West Godavari']
# ['Kamrup Metropolitan']
# ['Begusarai', 'Patna']
# ['Ahmedabad', 'Rajkot', 'Surat', 'Vadodara']
# ['Faridabad', 'Gurugram']
# ['Bengaluru Urban']
# ['Aurangabad', 'Jalgaon', 'Kolhapur', 'Mumbai', 'Nagpur', 'Nashik', 'Palghar', 'Pune', 'Raigad', 'Solapur', 'Thane']
# ['Bhopal', 'Indore']
# ['Ganjam']
# ['Ludhiana']
# ['Hyderabad', 'Medchal Malkajgiri', 'Ranga Reddy']
# ['Chengalpattu', 'Chennai', 'Kancheepuram', 'Madurai', 'Thiruvallur', 'Tiruvannamalai', 'Vellore']
# ['Aligarh', 'Bareilly', 'Gautam Buddha Nagar', 'Ghaziabad', 'Kanpur Nagar', 'Lucknow', 'Varanasi']
# ['Kolkata', 'North 24 Parganas']

# %% [markdown]
# # CFR

# %%
def n2z(x):
    x[np.logical_or(np.isnan(x),np.isinf(x))] = 0
    return x

# %%
len(dates)
# Out:
# 209

# %%
data_recovered = data_recovered.replace(r'^\s*$', np.NaN, regex=True).fillna(0)
data_recovered = data_recovered.astype(np.int32)
data_confirmed = data_confirmed.replace(r'^\s*$', np.NaN, regex=True).fillna(0)
data_confirmed = data_confirmed.astype(np.int32)
data_deceased = data_deceased.replace(r'^\s*$', np.NaN, regex=True).fillna(0)
data_deceased = data_deceased.astype(np.int32)
data_deceased['date'] = dates[:-1]
data_recovered['date'] = dates[:-1]
data_confirmed['date'] = dates[:-1]

# %%
json_data={}
cfr = pd.DataFrame()
final=pd.DataFrame()
plt.figure(1, figsize=(15, 7))
for st in districts:
    print("cfr() -- Working : ",st)
    
    state=st
    boots = 100
    conf = []
    for n in range(boots):
        #print("Iteration: ",n+1,end='\r')
        if n  == boots//4:
          print("Progress : 25%")
        if n  == boots//2:
          print("Progress : 50%")
        if n  == (boots*3)//4:
          print("Progress : 75%")  
        if n  == boots-1:
          print("Progress : 100%")

        dataset = np.copy(data_confirmed[state].values)
        mean = 13.0+(20.9-8.7)/4*np.random.normal()
        sd = 12.7+(26.0-6.4)/4*np.random.normal()
        phi = np.sqrt(sd**2 + mean**2)
        mu = np.log(mean**2/phi)
        sigma = np.sqrt(np.log(phi**2/mean**2))
        L = lognorm(s=sigma,scale=np.exp(mu))
        for i in range(len(dataset)-1,-1,-1):
            send_forward = np.round(L.rvs(np.max([dataset[i],0])))
            send_forward = send_forward[i+send_forward<len(dataset)]
            dataset[i] = 0
            for j in np.unique(np.int32(send_forward)):
                dataset[i+j] += np.sum(send_forward==j)
        conf.append(dataset)
    CFR = np.cumsum(data_deceased[state].values)/np.cumsum(conf,axis=1)
    col_mean = np.nanmean(CFR, axis=0)
    inds = np.where(np.isnan(CFR))
    CFR[inds] = np.take(col_mean, inds[1])
    #temp1=list(pd.Series(dates).dt.strftime('%m-%d-%Y'))
    #print(temp1[0])
    temp={}
    temp = {
        'dates':dates1[:-1],
        'cfr1_point':list(n2z(100*np.cumsum(data_deceased[state].values)/np.cumsum(data_confirmed[state].values))),
        'cfr2_point':list(n2z(100*np.cumsum(data_deceased[state].values)/(np.cumsum(data_deceased[state].values)+np.cumsum(data_recovered[state].values)))),
        'cfr3_point':list(n2z(100*np.median(CFR,axis=0))),
        'cfr3_l95':list(n2z(100*np.quantile(CFR,0.025,axis=0))),
        'cfr3_u95':list(n2z(100*np.quantile(CFR,0.975,axis=0))),
        'cfr3_l50':list(n2z(100*np.quantile(CFR,0.25,axis=0))),
        'cfr3_u50':list(n2z(100*np.quantile(CFR,0.75,axis=0))),
        }
    a=st
    #print(a)
    states[state].update(temp)
    json_data[state] = temp
    cfr_state=pd.DataFrame()
    cfr_state['state']=([str(a)]*(len(dates)))[:-1]   #Reminder this method has to change when append method is implemented
    cfr_state['dates']=dates1[:-1]                     #Remove [1:] when append method
    cfr_state['cfr1_point']=(list(100*n2z(np.cumsum(data_deceased[state].values)/np.cumsum(data_confirmed[state].values))))
    cfr_state['cfr2_point']=(list(100*n2z(np.cumsum(data_deceased[state].values)/(np.cumsum(data_deceased[state].values)+np.cumsum(data_recovered[state].values)))))
    cfr_state['cfr3_point']=(list(100*n2z(np.median(CFR,axis=0))))
    cfr_state['cfr3_l95']=(list(100*n2z(np.quantile(CFR,0.025,axis=0))))
    cfr_state['cfr3_u95']=(list(100*n2z(np.quantile(CFR,0.975,axis=0))))
    cfr_state['cfr3_l50']=(list(100*n2z(np.quantile(CFR,0.25,axis=0))))
    cfr_state['cfr3_u50']=(list(100*n2z(np.quantile(CFR,0.75,axis=0))))
    cfr=pd.concat([cfr, cfr_state])
      
    plt.plot(temp['cfr3_point'],label=state)
    plt.legend()
    plt.ylim(0,10)
# Out:
# cfr() -- Working :  Anantapur
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Chittoor
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  East Godavari
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Guntur
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Kurnool
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Prakasam
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Srikakulam
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Visakhapatnam
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Vizianagaram
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  West Godavari
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Kamrup Metropolitan
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Begusarai
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Patna
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Ahmedabad
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Rajkot
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Surat
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Vadodara
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Faridabad
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Gurugram
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Bengaluru Urban
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Aurangabad
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Jalgaon
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Kolhapur
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Mumbai
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Nagpur
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Nashik
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Palghar
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Pune
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Raigad
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Solapur
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Thane
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Bhopal
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Indore
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Ganjam
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Ludhiana
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Hyderabad
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Medchal Malkajgiri
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Ranga Reddy
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Chengalpattu
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Chennai
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
#  Kancheepuram
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Madurai
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Thiruvallur
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Tiruvannamalai
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Vellore
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Aligarh
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Bareilly
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Gautam Buddha Nagar
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Ghaziabad
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Kanpur Nagar
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Lucknow
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Varanasi
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Kolkata
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  North 24 Parganas
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide

# %%
cfr.to_csv('cfr_district.csv',index=False)
from datetime import datetime
json_data['datetime']=str(datetime.now())

# %%
json_data_indented = json.dumps(json_data, indent = 4)
with open("cfr_district.json", "w") as outfile: 
    outfile.write(json_data_indented)

# %%
def calc_doublingtimes(x):
    vals = []
    for i in range(x.shape[0]):
        for j in range(i+1,x.shape[0]):
            if len(str(x[j])) and len(str(x[i])):
                vals.append(np.log(2)*(j-i)/np.log(int(x[j])/int(x[i])))
    return np.mean(vals),np.mean(vals)-1.96*np.std(vals),np.mean(vals)+1.96*np.std(vals)

# %%
start=datetime.now()
x=datetime.now(pytz.timezone('Asia/Kolkata')).date()
dd=pd.date_range(start="2020-01-30",end=x)
dd = dd [:-1]
datess=[]
for i in range(len(dd)):
  datess.append((str(dd[i])[:10]))

# %%
stt=states

# %%
dates1 = dates[:-1]
json_data={}
test=json.load(open('test.json'))
for j in state_id.keys():
    cumul=['']*len(dates)
    #st=state_id[j]
    for st in state_id[j]:
        #print(st)
        cumul=states[st]['cum_positive_cases']
        cumul_cases=np.array(cumul)
        dbt = np.zeros((3,cumul_cases.shape[0]))
        for i in range(cumul_cases.shape[0]):
            dbt[:,i] = calc_doublingtimes(cumul_cases[i-7:i])
        #st=state_id[j]
        #temp={}
        temp1 = {'dates':dates1,'dbt_point':pd.Series((list(dbt[0,:]))).fillna('').tolist(),'dbt_l95':pd.Series((list(dbt[1,:]))).fillna('').tolist(),'dbt_u95':pd.Series((list(dbt[2,:]))).fillna('').tolist()}
        states[st].update(temp1)
        json_data[st] = temp1
# Out:
# F:\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3335: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# F:\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# F:\Anaconda3\lib\site-packages\numpy\core\_methods.py:217: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# F:\Anaconda3\lib\site-packages\numpy\core\_methods.py:186: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# F:\Anaconda3\lib\site-packages\numpy\core\_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in double_scalars
#
# F:\Anaconda3\lib\site-packages\numpy\core\_methods.py:193: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)

# %%
json_data_indented = json.dumps(json_data, indent = 4)
with open("doubling_rate_dist.json", "w") as outfile: 
    outfile.write(json_data_indented)

# %% [markdown]
# # RT

# %%
rt_json = {}

rt = pd.DataFrame()
# plt.figure(1, figsize=(15, 7))
for j in state_id.keys():
  for st in state_id[j]:
    state=st
    print("Working : ",state)
    
    temp = pd.DataFrame()
    #temp["active"] = data_confirmed[state]
    temp["active"] = np.array(data_confirmed[state]).clip(0).tolist()

    temp.to_csv('confirmed.csv')
    call(['RScript.exe','scripts/Rt_analysis_newGT_TJ.R'])
    
    values = {
            'rt_point':[],
            'rt_sd':[],
            'rt_l95':[],
            'rt_u95':[],
            'rt_l50':[],
            'rt_u50':[],
            't_end':[]
            }

    for df in [pd.read_csv('rt_temp/'+temp) for temp in os.listdir('rt_temp/')]:
        values['rt_point'].append(df['Mean(R)'])
        values['rt_sd'].append(df['Std(R)'])
        values['rt_l95'].append(df['Quantile.0.025(R)'])
        values['rt_u95'].append(df['Quantile.0.975(R)'])
        values['rt_l50'].append(df['Quantile.0.25(R)'])
        values['rt_u50'].append(df['Quantile.0.75(R)'])
        values['t_end'].append(df['t_end']-1)
    for i in values:
        values[i] = np.median(values[i],axis=0)
    values['dates'] = list(data_confirmed['date'][values['t_end']-1])
    rt_state=pd.DataFrame()
    rt_state['state']=[str(state)]*len(values['dates'])
    rt_state['dates']= values['dates']
    rt_state['rt_point'] = values['rt_point']
    rt_state['rt_sd'] = values['rt_sd']    
    rt_state['rt_l95'] = values['rt_l95']    
    rt_state['rt_u95'] = values['rt_u95']    
    rt_state['rt_l50'] = values['rt_l50']
    rt_state['rt_u50'] = values['rt_u50']
    rt=pd.concat([rt, rt_state])
  
    rt_json[st] = values
    
    plt.plot(range(len(values['rt_point'])),values['rt_point'],label=state)
    plt.fill_between(range(len(values['rt_point'])),values['rt_l95'],values['rt_u95'],alpha=0.5)
    plt.ylim(0,4)
    plt.legend()
    plt.show()
# Out:
# Working :  Anantapur
# Working :  Chittoor
# Working :  East Godavari
# Working :  Guntur
# Working :  Kurnool
# Working :  Prakasam
# Working :  Srikakulam
# Working :  Visakhapatnam
# Working :  Vizianagaram
# Working :  West Godavari
# Working :  Kamrup Metropolitan
# Working :  Begusarai
# Working :  Patna
# Working :  Ahmedabad
# Working :  Rajkot
# Working :  Surat
# Working :  Vadodara
# Working :  Faridabad
# Working :  Gurugram
# Working :  Bengaluru Urban
# Working :  Aurangabad
# Working :  Jalgaon
# Working :  Kolhapur
# Working :  Mumbai
# Working :  Nagpur
# Working :  Nashik
# Working :  Palghar
# Working :  Pune
# Working :  Raigad
# Working :  Solapur
# Working :  Thane
# Working :  Bhopal
# Working :  Indore
# Working :  Ganjam
# Working :  Ludhiana
# Working :  Hyderabad
# Working :  Medchal Malkajgiri
# Working :  Ranga Reddy
# Working :  Chengalpattu
# Working :  Chennai
# Working :  Kancheepuram
# Working :  Madurai
# Working :  Thiruvallur
# Working :  Tiruvannamalai
# Working :  Vellore
# Working :  Aligarh
# Working :  Bareilly
# Working :  Gautam Buddha Nagar
# Working :  Ghaziabad
# Working :  Kanpur Nagar
# Working :  Lucknow
# Working :  Varanasi
# Working :  Kolkata
# Working :  North 24 Parganas

# %%
for st in state_id.keys():
    dist = state_id[st]
    for district in dist:
        states[district].update(rt_json[district])

# %%
rt.to_csv('rt.csv',index=False)

# %% [markdown]
# ## Rt shifting

# %%
def shift_rt_metrics(dict,key,days):
  values_shifted = collections.deque(dict[key])
  values_shifted.rotate(-1*days)

  new_val = list(values_shifted)

  size = len(dict['dates'])
  
  for i in range(days):
    new_val[size-1-i]=''

  return new_val

# %%
rt_json_shifted = copy.deepcopy(rt_json)
days = 2
for sta in state_id.keys():
    for st in state_id[sta]:
        rt_json_shifted[st]['rt_point'] = shift_rt_metrics(rt_json[st],'rt_point',days)
        rt_json_shifted[st]['rt_sd'] = shift_rt_metrics(rt_json[st],'rt_sd',days)
        rt_json_shifted[st]['rt_l95'] = shift_rt_metrics(rt_json[st],'rt_l95',days)
        rt_json_shifted[st]['rt_u95'] = shift_rt_metrics(rt_json[st],'rt_u95',days)
        rt_json_shifted[st]['rt_l50'] = shift_rt_metrics(rt_json[st],'rt_l50',days)
        rt_json_shifted[st]['rt_u50'] = shift_rt_metrics(rt_json[st],'rt_u50',days)
        rt_json_shifted[st]['t_end'] = shift_rt_metrics(rt_json[st],'t_end',days)

# %%
for st in state_id.keys():
    dist = state_id[st]
    leng = len(dates[:-1])
    
    #states[state]['dates'] =  temp1['India']['dates']
    for state in dist:
        for keys in list(rt_json_shifted[state].keys())[:-1]:
            if len(rt_json_shifted[state][keys])<leng:
                rt_json_shifted[state][keys].extend(['' for i in range(leng-len(rt_json_shifted[state][keys]))]) 
                
        rt_json_shifted[state]['dates'] = dates[:-1]

# %%
states_shifted = copy.deepcopy(states)

for sta in state_id.keys():
    for st in state_id[sta]:
        states_shifted[st].update(rt_json_shifted[st])

# %%
for sta in state_id.keys():
    for state in state_id[sta]:
        for key in rt_json[state].keys():
          try:
            rt_json[state][key]=rt_json[state][key].tolist()
          except:
            pass

# %%
for sta in state_id.keys():
    for state in state_id[sta]:
        for key in states[state].keys():
          try:
            states[state][key]=states[state][key].tolist()
          except:
            pass

# %%
for st in state_id.keys():
    dist = state_id[st]
        
    leng = len(dates[:-1])

        #states[state]['dates'] =  temp1['India']['dates']
    for state in dist:
        for keys in list(states[state].keys())[1:]:
            if len(states[state][keys])<leng:
                states[state][keys].extend(['' for i in range(leng-len(states[state][keys]))])

# %%
for st in state_id.keys():
    dist = state_id[st]
    leng = len(dates[:-1])
    
    #states[state]['dates'] =  temp1['India']['dates']
    for state in dist:
         for keys in list(states_shifted[state].keys())[1:]:
            if len(states_shifted[state][keys])<leng:
                states_shifted[state][keys].extend(['' for i in range(leng-len(states_shifted[state][keys]))])

# %%
for sta in state_id.keys():
    for st in state_id[sta]:
        states[st]['dates'] = dates[:-1]
        states_shifted[st]['dates'] = dates[:-1]

# %% [markdown]
# ## Rt changes for review

# %%
with open('rt_shifted.json', 'w') as outfile:
  json.dump(rt_json_shifted, outfile,indent=4)

# %%
with open('rt.json', 'w') as outfile:
  json.dump(rt_json, outfile,indent=4)

# %%
'''
df_list = [df,cfr,rt]
all_dataframes = pd.concat(df_list)
all_dataframes.to_csv('complete_districts_all_metrics.csv',index=False)'''
# Out:
# "\ndf_list = [df,cfr,rt]\nall_dataframes = pd.concat(df_list)\nall_dataframes.to_csv('complete_districts_all_metrics.csv',index=False)"

# %%
len(dates)
# Out:
# 209

# %%
rt_graph = copy.deepcopy(rt_json_shifted)

de =10

for s in state_id.keys():
    for st in state_id[s]:
        for k in rt_json_shifted[st].keys():
            rt_graph[st][k] = rt_json_shifted[st][k][:-10]

# %%
with open('rt_graph.json', 'w') as outfile:
  json.dump(rt_graph, outfile,indent=4)

# %% [markdown]
# # Complete

# %%
cols=list(states['Mumbai'].keys())
q=['state']
complete=pd.DataFrame(columns=q+cols)
keys=list(states.keys())[:-1]
for i in keys:
  temp=pd.DataFrame()
  d=len(states['Mumbai']['dates'])

  temp['state']=[str(i)]*d
  
  for j in cols:
    print(i,j)
    temp[j]=list(states[i][j])[:d]
  complete = pd.concat([complete,temp])
# Out:
# Anantapur dates
# Anantapur cum_positive_cases
# Anantapur cum_positivity_rate
# Anantapur daily_positive_cases
# Anantapur cum_recovered
# Anantapur daily_recovered
# Anantapur cum_deceased
# Anantapur daily_deceased
# Anantapur daily_positivity_rate
# Anantapur daily_positive_cases_ma
# Anantapur daily_positivity_rate_ma
# Anantapur daily_tests
# Anantapur cum_tests
# Anantapur test_per_million
# Anantapur daily_cases_per_million
# Anantapur daily_tests_per_million
# Anantapur daily_tests_ma
# Anantapur daily_deceased_ma
# Anantapur cfr1_point
# Anantapur cfr2_point
# Anantapur cfr3_point
# Anantapur cfr3_l95
# Anantapur cfr3_u95
# Anantapur cfr3_l50
# Anantapur cfr3_u50
# Anantapur dbt_point
# Anantapur dbt_l95
# Anantapur dbt_u95
# Anantapur rt_point
# Anantapur rt_sd
# Anantapur rt_l95
# Anantapur rt_u95
# Anantapur rt_l50
# Anantapur rt_u50
# Anantapur t_end
# Chittoor dates
# Chittoor cum_positive_cases
# Chittoor cum_positivity_rate
# Chittoor daily_positive_cases
# Chittoor cum_recovered
# Chittoor daily_recovered
# Chittoor cum_deceased
# Chittoor daily_deceased
# Chittoor daily_positivity_rate
# Chittoor daily_positive_cases_ma
# Chittoor daily_positivity_rate_ma
# Chittoor daily_tests
# Chittoor cum_tests
# Chittoor test_per_million
# Chittoor daily_cases_per_million
# Chittoor daily_tests_per_million
# Chittoor daily_tests_ma
# Chittoor daily_deceased_ma
# Chittoor cfr1_point
# Chittoor cfr2_point
# Chittoor cfr3_point
# Chittoor cfr3_l95
# Chittoor cfr3_u95
# Chittoor cfr3_l50
# Chittoor cfr3_u50
# Chittoor dbt_point
# Chittoor dbt_l95
# Chittoor dbt_u95
# Chittoor rt_point
# Chittoor rt_sd
# Chittoor rt_l95
# Chittoor rt_u95
# Chittoor rt_l50
# Chittoor rt_u50
# Chittoor t_end
# East Godavari dates
# East Godavari cum_positive_cases
# East Godavari cum_positivity_rate
# East Godavari daily_positive_cases
# East Godavari cum_recovered
# East Godavari daily_recovered
# East Godavari cum_deceased
# East Godavari daily_deceased
# East Godavari daily_positivity_rate
# East Godavari daily_positive_cases_ma
# East Godavari daily_positivity_rate_ma
# East Godavari daily_tests
# East Godavari cum_tests
# East Godavari test_per_million
# East Godavari daily_cases_per_million
# East Godavari daily_tests_per_million
# East Godavari daily_tests_ma
# East Godavari daily_deceased_ma
# East Godavari cfr1_point
# East Godavari cfr2_point
# East Godavari cfr3_point
# East Godavari cfr3_l95
# East Godavari cfr3_u95
# East Godavari cfr3_l50
# East Godavari cfr3_u50
# East Godavari dbt_point
# East Godavari dbt_l95
# East Godavari dbt_u95
# East Godavari rt_point
# East Godavari rt_sd
# East Godavari rt_l95
# East Godavari rt_u95
# East Godavari rt_l50
# East Godavari rt_u50
# East Godavari t_end
# Guntur dates
# Guntur cum_positive_cases
# Guntur cum_positivity_rate
# Guntur daily_positive_cases
# Guntur cum_recovered
# Guntur daily_recovered
# Guntur cum_deceased
# Guntur daily_deceased
# Guntur daily_positivity_rate
# Guntur daily_positive_cases_ma
# Guntur daily_positivity_rate_ma
# Guntur daily_tests
# Guntur cum_tests
# Guntur test_per_million
# Guntur daily_cases_per_million
# Guntur daily_tests_per_million
# Guntur daily_tests_ma
# Guntur daily_deceased_ma
# Guntur cfr1_point
# Guntur cfr2_point
# Guntur cfr3_point
# Guntur cfr3_l95
# Guntur cfr3_u95
# Guntur cfr3_l50
# Guntur cfr3_u50
# Guntur dbt_point
# Guntur dbt_l95
# Guntur dbt_u95
# Guntur rt_point
# Guntur rt_sd
# Guntur rt_l95
# Guntur rt_u95
# Guntur rt_l50
# Guntur rt_u50
# Guntur t_end
# Kurnool dates
# Kurnool cum_positive_cases
# Kurnool cum_positivity_rate
# Kurnool daily_positive_cases
# Kurnool cum_recovered
# Kurnool daily_recovered
# Kurnool cum_deceased
# Kurnool daily_deceased
# Kurnool daily_positivity_rate
# Kurnool daily_positive_cases_ma
# Kurnool daily_positivity_rate_ma
# Kurnool daily_tests
# Kurnool cum_tests
# Kurnool test_per_million
# Kurnool daily_cases_per_million
# Kurnool daily_tests_per_million
# Kurnool daily_tests_ma
# Kurnool daily_deceased_ma
# Kurnool cfr1_point
# Kurnool cfr2_point
# Kurnool cfr3_point
# Kurnool cfr3_l95
# Kurnool cfr3_u95
# Kurnool cfr3_l50
# Kurnool cfr3_u50
# Kurnool dbt_point
# Kurnool dbt_l95
# Kurnool dbt_u95
# Kurnool rt_point
# Kurnool rt_sd
# Kurnool rt_l95
# Kurnool rt_u95
# Kurnool rt_l50
# Kurnool rt_u50
# Kurnool t_end
# Prakasam dates
# Prakasam cum_positive_cases
# Prakasam cum_positivity_rate
# Prakasam daily_positive_cases
# Prakasam cum_recovered
# Prakasam daily_recovered
# Prakasam cum_deceased
# Prakasam daily_deceased
# Prakasam daily_positivity_rate
# Prakasam daily_positive_cases_ma
# Prakasam daily_positivity_rate_ma
# Prakasam daily_tests
# Prakasam cum_tests
# Prakasam test_per_million
# Prakasam daily_cases_per_million
# Prakasam daily_tests_per_million
# Prakasam daily_tests_ma
# Prakasam daily_deceased_ma
# Prakasam cfr1_point
# Prakasam cfr2_point
# Prakasam cfr3_point
# Prakasam cfr3_l95
# Prakasam cfr3_u95
# Prakasam cfr3_l50
# Prakasam cfr3_u50
# Prakasam dbt_point
# Prakasam dbt_l95
# Prakasam dbt_u95
# Prakasam rt_point
# Prakasam rt_sd
# Prakasam rt_l95
# Prakasam rt_u95
# Prakasam rt_l50
# Prakasam rt_u50
# Prakasam t_end
# Srikakulam dates
# Srikakulam cum_positive_cases
# Srikakulam cum_positivity_rate
# Srikakulam daily_positive_cases
# Srikakulam cum_recovered
# Srikakulam daily_recovered
# Srikakulam cum_deceased
# Srikakulam daily_deceased
# Srikakulam daily_positivity_rate
# Srikakulam daily_positive_cases_ma
# Srikakulam daily_positivity_rate_ma
# Srikakulam daily_tests
# Srikakulam cum_tests
# Srikakulam test_per_million
# Srikakulam daily_cases_per_million
# Srikakulam daily_tests_per_million
# Srikakulam daily_tests_ma
# Srikakulam daily_deceased_ma
# Srikakulam cfr1_point
# Srikakulam cfr2_point
# Srikakulam cfr3_point
# Srikakulam cfr3_l95
# Srikakulam cfr3_u95
# Srikakulam cfr3_l50
# Srikakulam cfr3_u50
# Srikakulam dbt_point
# Srikakulam dbt_l95
# Srikakulam dbt_u95
# Srikakulam rt_point
# Srikakulam rt_sd
# Srikakulam rt_l95
# Srikakulam rt_u95
# Srikakulam rt_l50
# Srikakulam rt_u50
# Srikakulam t_end
# Visakhapatnam dates
# Visakhapatnam cum_positive_cases
# Visakhapatnam cum_positivity_rate
# Visakhapatnam daily_positive_cases
# Visakhapatnam cum_recovered
# Visakhapatnam daily_recovered
# Visakhapatnam cum_deceased
# Visakhapatnam daily_deceased
# Visakhapatnam daily_positivity_rate
# Visakhapatnam daily_positive_cases_ma
# Visakhapatnam daily_positivity_rate_ma
# Visakhapatnam daily_tests
# Visakhapatnam cum_tests
# Visakhapatnam test_per_million
# Visakhapatnam daily_cases_per_million
# Visakhapatnam daily_tests_per_million
# Visakhapatnam daily_tests_ma
# Visakhapatnam daily_deceased_ma
# Visakhapatnam cfr1_point
# Visakhapatnam cfr2_point
# Visakhapatnam cfr3_point
# Visakhapatnam cfr3_l95
# Visakhapatnam cfr3_u95
# Visakhapatnam cfr3_l50
# Visakhapatnam cfr3_u50
# Visakhapatnam dbt_point
# Visakhapatnam dbt_l95
# Visakhapatnam dbt_u95
# Visakhapatnam rt_point
# Visakhapatnam rt_sd
# Visakhapatnam rt_l95
# Visakhapatnam rt_u95
# Visakhapatnam rt_l50
# Visakhapatnam rt_u50
# Visakhapatnam t_end
# Vizianagaram dates
# Vizianagaram cum_positive_cases
# Vizianagaram cum_positivity_rate
# Vizianagaram daily_positive_cases
# Vizianagaram cum_recovered
# Vizianagaram daily_recovered
# Vizianagaram cum_deceased
# Vizianagaram daily_deceased
# Vizianagaram daily_positivity_rate
# Vizianagaram daily_positive_cases_ma
# Vizianagaram daily_positivity_rate_ma
# Vizianagaram daily_tests
# Vizianagaram cum_tests
# Vizianagaram test_per_million
# Vizianagaram daily_cases_per_million
# Vizianagaram daily_tests_per_million
# Vizianagaram daily_tests_ma
# Vizianagaram daily_deceased_ma
# Vizianagaram cfr1_point
# Vizianagaram cfr2_point
# Vizianagaram cfr3_point
# Vizianagaram cfr3_l95
# Vizianagaram cfr3_u95
# Vizianagaram cfr3_l50
# Vizianagaram cfr3_u50
# Vizianagaram dbt_point
# Vizianagaram dbt_l95
# Vizianagaram dbt_u95
# Vizianagaram rt_point
# Vizianagaram rt_sd
# Vizianagaram rt_l95
# Vizianagaram rt_u95
# Vizianagaram rt_l50
# Vizianagaram rt_u50
# Vizianagaram t_end
# West Godavari dates
# West Godavari cum_positive_cases
# West Godavari cum_positivity_rate
# West Godavari daily_positive_cases
# West Godavari cum_recovered
# West Godavari daily_recovered
# West Godavari cum_deceased
# West Godavari daily_deceased
# West Godavari daily_positivity_rate
# West Godavari daily_positive_cases_ma
# West Godavari daily_positivity_rate_ma
# West Godavari daily_tests
# West Godavari cum_tests
# West Godavari test_per_million
# West Godavari daily_cases_per_million
# West Godavari daily_tests_per_million
# West Godavari daily_tests_ma
# West Godavari daily_deceased_ma
# West Godavari cfr1_point
# West Godavari cfr2_point
# West Godavari cfr3_point
# West Godavari cfr3_l95
# West Godavari cfr3_u95
# West Godavari cfr3_l50
# West Godavari cfr3_u50
# West Godavari dbt_point
# West Godavari dbt_l95
# West Godavari dbt_u95
# West Godavari rt_point
# West Godavari rt_sd
# West Godavari rt_l95
# West Godavari rt_u95
# West Godavari rt_l50
# West Godavari rt_u50
# West Godavari t_end
# Kamrup Metropolitan dates
# Kamrup Metropolitan cum_positive_cases
# Kamrup Metropolitan cum_positivity_rate
# Kamrup Metropolitan daily_positive_cases
# Kamrup Metropolitan cum_recovered
# Kamrup Metropolitan daily_recovered
# Kamrup Metropolitan cum_deceased
# Kamrup Metropolitan daily_deceased
# Kamrup Metropolitan daily_positivity_rate
# Kamrup Metropolitan daily_positive_cases_ma
# Kamrup Metropolitan daily_positivity_rate_ma
# Kamrup Metropolitan daily_tests
# Kamrup Metropolitan cum_tests
# Kamrup Metropolitan test_per_million
# Kamrup Metropolitan daily_cases_per_million
# Kamrup Metropolitan daily_tests_per_million
# Kamrup Metropolitan daily_tests_ma
# Kamrup Metropolitan daily_deceased_ma
# Kamrup Metropolitan cfr1_point
# Kamrup Metropolitan cfr2_point
# Kamrup Metropolitan cfr3_point
# Kamrup Metropolitan cfr3_l95
# Kamrup Metropolitan cfr3_u95
# Kamrup Metropolitan cfr3_l50
# Kamrup Metropolitan cfr3_u50
# Kamrup Metropolitan dbt_point
# Kamrup Metropolitan dbt_l95
# Kamrup Metropolitan dbt_u95
# Kamrup Metropolitan rt_point
# Kamrup Metropolitan rt_sd
# Kamrup Metropolitan rt_l95
# Kamrup Metropolitan rt_u95
# Kamrup Metropolitan rt_l50
# Kamrup Metropolitan rt_u50
# Kamrup Metropolitan t_end
# Begusarai dates
# Begusarai cum_positive_cases
# Begusarai cum_positivity_rate
# Begusarai daily_positive_cases
# Begusarai cum_recovered
# Begusarai daily_recovered
# Begusarai cum_deceased
# Begusarai daily_deceased
# Begusarai daily_positivity_rate
# Begusarai daily_positive_cases_ma
# Begusarai daily_positivity_rate_ma
# Begusarai daily_tests
# Begusarai cum_tests
# Begusarai test_per_million
# Begusarai daily_cases_per_million
# Begusarai daily_tests_per_million
# Begusarai daily_tests_ma
# Begusarai daily_deceased_ma
# Begusarai cfr1_point
# Begusarai cfr2_point
# Begusarai cfr3_point
# Begusarai cfr3_l95
# Begusarai cfr3_u95
# Begusarai cfr3_l50
# Begusarai cfr3_u50
# Begusarai dbt_point
# Begusarai dbt_l95
# Begusarai dbt_u95
# Begusarai rt_point
# Begusarai rt_sd
# Begusarai rt_l95
# Begusarai rt_u95
# Begusarai rt_l50
# Begusarai rt_u50
# Begusarai t_end
# Patna dates
# Patna cum_positive_cases
# Patna cum_positivity_rate
# Patna daily_positive_cases
# Patna cum_recovered
# Patna daily_recovered
# Patna cum_deceased
# Patna daily_deceased
# Patna daily_positivity_rate
# Patna daily_positive_cases_ma
# Patna daily_positivity_rate_ma
# Patna daily_tests
# Patna cum_tests
# Patna test_per_million
# Patna daily_cases_per_million
# Patna daily_tests_per_million
# Patna daily_tests_ma
# Patna daily_deceased_ma
# Patna cfr1_point
# Patna cfr2_point
# Patna cfr3_point
# Patna cfr3_l95
# Patna cfr3_u95
# Patna cfr3_l50
# Patna cfr3_u50
# Patna dbt_point
# Patna dbt_l95
# Patna dbt_u95
# Patna rt_point
# Patna rt_sd
# Patna rt_l95
# Patna rt_u95
# Patna rt_l50
# Patna rt_u50
# Patna t_end
# Ahmedabad dates
# Ahmedabad cum_positive_cases
# Ahmedabad cum_positivity_rate
# Ahmedabad daily_positive_cases
# Ahmedabad cum_recovered
# Ahmedabad daily_recovered
# Ahmedabad cum_deceased
# Ahmedabad daily_deceased
# Ahmedabad daily_positivity_rate
# Ahmedabad daily_positive_cases_ma
# Ahmedabad daily_positivity_rate_ma
# Ahmedabad daily_tests
# Ahmedabad cum_tests
# Ahmedabad test_per_million
# Ahmedabad daily_cases_per_million
# Ahmedabad daily_tests_per_million
# Ahmedabad daily_tests_ma
# Ahmedabad daily_deceased_ma
# Ahmedabad cfr1_point
# Ahmedabad cfr2_point
# Ahmedabad cfr3_point
# Ahmedabad cfr3_l95
# Ahmedabad cfr3_u95
# Ahmedabad cfr3_l50
# Ahmedabad cfr3_u50
# Ahmedabad dbt_point
# Ahmedabad dbt_l95
# Ahmedabad dbt_u95
# Ahmedabad rt_point
# Ahmedabad rt_sd
# Ahmedabad rt_l95
# Ahmedabad rt_u95
# Ahmedabad rt_l50
# Ahmedabad rt_u50
# Ahmedabad t_end
# Rajkot dates
# Rajkot cum_positive_cases
# Rajkot cum_positivity_rate
# Rajkot daily_positive_cases
# Rajkot cum_recovered
# Rajkot daily_recovered
# Rajkot cum_deceased
# Rajkot daily_deceased
# Rajkot daily_positivity_rate
# Rajkot daily_positive_cases_ma
# Rajkot daily_positivity_rate_ma
# Rajkot daily_tests
# Rajkot cum_tests
# Rajkot test_per_million
# Rajkot daily_cases_per_million
# Rajkot daily_tests_per_million
# Rajkot daily_tests_ma
# Rajkot daily_deceased_ma
# Rajkot cfr1_point
# Rajkot cfr2_point
# Rajkot cfr3_point
# Rajkot cfr3_l95
# Rajkot cfr3_u95
# Rajkot cfr3_l50
# Rajkot cfr3_u50
# Rajkot dbt_point
# Rajkot dbt_l95
# Rajkot dbt_u95
# Rajkot rt_point
# Rajkot rt_sd
# Rajkot rt_l95
# Rajkot rt_u95
# Rajkot rt_l50
# Rajkot rt_u50
# Rajkot t_end
# Surat dates
# Surat cum_positive_cases
# Surat cum_positivity_rate
# Surat daily_positive_cases
# Surat cum_recovered
# Surat daily_recovered
# Surat cum_deceased
# Surat daily_deceased
# Surat daily_positivity_rate
# Surat daily_positive_cases_ma
# Surat daily_positivity_rate_ma
# Surat daily_tests
# Surat cum_tests
# Surat test_per_million
# Surat daily_cases_per_million
# Surat daily_tests_per_million
# Surat daily_tests_ma
# Surat daily_deceased_ma
# Surat cfr1_point
# Surat cfr2_point
# Surat cfr3_point
# Surat cfr3_l95
# Surat cfr3_u95
# Surat cfr3_l50
# Surat cfr3_u50
# Surat dbt_point
# Surat dbt_l95
# Surat dbt_u95
# Surat rt_point
# Surat rt_sd
# Surat rt_l95
# Surat rt_u95
# Surat rt_l50
# Surat rt_u50
# Surat t_end
# Vadodara dates
# Vadodara cum_positive_cases
# Vadodara cum_positivity_rate
# Vadodara daily_positive_cases
# Vadodara cum_recovered
# Vadodara daily_recovered
# Vadodara cum_deceased
# Vadodara daily_deceased
# Vadodara daily_positivity_rate
# Vadodara daily_positive_cases_ma
# Vadodara daily_positivity_rate_ma
# Vadodara daily_tests
# Vadodara cum_tests
# Vadodara test_per_million
# Vadodara daily_cases_per_million
# Vadodara daily_tests_per_million
# Vadodara daily_tests_ma
# Vadodara daily_deceased_ma
# Vadodara cfr1_point
# Vadodara cfr2_point
# Vadodara cfr3_point
# Vadodara cfr3_l95
# Vadodara cfr3_u95
# Vadodara cfr3_l50
# Vadodara cfr3_u50
# Vadodara dbt_point
# Vadodara dbt_l95
# Vadodara dbt_u95
# Vadodara rt_point
# Vadodara rt_sd
# Vadodara rt_l95
# Vadodara rt_u95
# Vadodara rt_l50
# Vadodara rt_u50
# Vadodara t_end
# Faridabad dates
# Faridabad cum_positive_cases
# Faridabad cum_positivity_rate
# Faridabad daily_positive_cases
# Faridabad cum_recovered
# Faridabad daily_recovered
# Faridabad cum_deceased
# Faridabad daily_deceased
# Faridabad daily_positivity_rate
# Faridabad daily_positive_cases_ma
# Faridabad daily_positivity_rate_ma
# Faridabad daily_tests
# Faridabad cum_tests
# Faridabad test_per_million
# Faridabad daily_cases_per_million
# Faridabad daily_tests_per_million
# Faridabad daily_tests_ma
# Faridabad daily_deceased_ma
# Faridabad cfr1_point
# Faridabad cfr2_point
# Faridabad cfr3_point
# Faridabad cfr3_l95
# Faridabad cfr3_u95
# Faridabad cfr3_l50
# Faridabad cfr3_u50
# Faridabad dbt_point
# Faridabad dbt_l95
# Faridabad dbt_u95
# Faridabad rt_point
# Faridabad rt_sd
# Faridabad rt_l95
# Faridabad rt_u95
# Faridabad rt_l50
# Faridabad rt_u50
# Faridabad t_end
# Gurugram dates
# Gurugram cum_positive_cases
# Gurugram cum_positivity_rate
# Gurugram daily_positive_cases
# Gurugram cum_recovered
# Gurugram daily_recovered
# Gurugram cum_deceased
# Gurugram daily_deceased
# Gurugram daily_positivity_rate
# Gurugram daily_positive_cases_ma
# Gurugram daily_positivity_rate_ma
# Gurugram daily_tests
# Gurugram cum_tests
# Gurugram test_per_million
# Gurugram daily_cases_per_million
# Gurugram daily_tests_per_million
# Gurugram daily_tests_ma
# Gurugram daily_deceased_ma
# Gurugram cfr1_point
# Gurugram cfr2_point
# Gurugram cfr3_point
# Gurugram cfr3_l95
# Gurugram cfr3_u95
# Gurugram cfr3_l50
# Gurugram cfr3_u50
# Gurugram dbt_point
# Gurugram dbt_l95
# Gurugram dbt_u95
# Gurugram rt_point
# Gurugram rt_sd
# Gurugram rt_l95
# Gurugram rt_u95
# Gurugram rt_l50
# Gurugram rt_u50
# Gurugram t_end
# Bengaluru Urban dates
# Bengaluru Urban cum_positive_cases
# Bengaluru Urban cum_positivity_rate
# Bengaluru Urban daily_positive_cases
# Bengaluru Urban cum_recovered
# Bengaluru Urban daily_recovered
# Bengaluru Urban cum_deceased
# Bengaluru Urban daily_deceased
# Bengaluru Urban daily_positivity_rate
# Bengaluru Urban daily_positive_cases_ma
# Bengaluru Urban daily_positivity_rate_ma
# Bengaluru Urban daily_tests
# Bengaluru Urban cum_tests
# Bengaluru Urban test_per_million
# Bengaluru Urban daily_cases_per_million
# Bengaluru Urban daily_tests_per_million
# Bengaluru Urban daily_tests_ma
# Bengaluru Urban daily_deceased_ma
# Bengaluru Urban cfr1_point
# Bengaluru Urban cfr2_point
# Bengaluru Urban cfr3_point
# Bengaluru Urban cfr3_l95
# Bengaluru Urban cfr3_u95
# Bengaluru Urban cfr3_l50
# Bengaluru Urban cfr3_u50
# Bengaluru Urban dbt_point
# Bengaluru Urban dbt_l95
# Bengaluru Urban dbt_u95
# Bengaluru Urban rt_point
# Bengaluru Urban rt_sd
# Bengaluru Urban rt_l95
# Bengaluru Urban rt_u95
# Bengaluru Urban rt_l50
# Bengaluru Urban rt_u50
# Bengaluru Urban t_end
# Aurangabad dates
# Aurangabad cum_positive_cases
# Aurangabad cum_positivity_rate
# Aurangabad daily_positive_cases
# Aurangabad cum_recovered
# Aurangabad daily_recovered
# Aurangabad cum_deceased
# Aurangabad daily_deceased
# Aurangabad daily_positivity_rate
# Aurangabad daily_positive_cases_ma
# Aurangabad daily_positivity_rate_ma
# Aurangabad daily_tests
# Aurangabad cum_tests
# Aurangabad test_per_million
# Aurangabad daily_cases_per_million
# Aurangabad daily_tests_per_million
# Aurangabad daily_tests_ma
# Aurangabad daily_deceased_ma
# Aurangabad cfr1_point
# Aurangabad cfr2_point
# Aurangabad cfr3_point
# Aurangabad cfr3_l95
# Aurangabad cfr3_u95
# Aurangabad cfr3_l50
# Aurangabad cfr3_u50
# Aurangabad dbt_point
# Aurangabad dbt_l95
# Aurangabad dbt_u95
# Aurangabad rt_point
# Aurangabad rt_sd
# Aurangabad rt_l95
# Aurangabad rt_u95
# Aurangabad rt_l50
# Aurangabad rt_u50
# Aurangabad t_end
# Jalgaon dates
# Jalgaon cum_positive_cases
# Jalgaon cum_positivity_rate
# Jalgaon daily_positive_cases
# Jalgaon cum_recovered
# Jalgaon daily_recovered
# Jalgaon cum_deceased
# Jalgaon daily_deceased
# Jalgaon daily_positivity_rate
# Jalgaon daily_positive_cases_ma
# Jalgaon daily_positivity_rate_ma
# Jalgaon daily_tests
# Jalgaon cum_tests
# Jalgaon test_per_million
# Jalgaon daily_cases_per_million
# Jalgaon daily_tests_per_million
# Jalgaon daily_tests_ma
# Jalgaon daily_deceased_ma
# Jalgaon cfr1_point
# Jalgaon cfr2_point
# Jalgaon cfr3_point
# Jalgaon cfr3_l95
# Jalgaon cfr3_u95
# Jalgaon cfr3_l50
# Jalgaon cfr3_u50
# Jalgaon dbt_point
# Jalgaon dbt_l95
# Jalgaon dbt_u95
# Jalgaon rt_point
# Jalgaon rt_sd
# Jalgaon rt_l95
# Jalgaon rt_u95
# Jalgaon rt_l50
# Jalgaon rt_u50
# Jalgaon t_end
# Kolhapur dates
# Kolhapur cum_positive_cases
# Kolhapur cum_positivity_rate
# Kolhapur daily_positive_cases
# Kolhapur cum_recovered
# Kolhapur daily_recovered
# Kolhapur cum_deceased
# Kolhapur daily_deceased
# Kolhapur daily_positivity_rate
# Kolhapur daily_positive_cases_ma
# Kolhapur daily_positivity_rate_ma
# Kolhapur daily_tests
# Kolhapur cum_tests
# Kolhapur test_per_million
# Kolhapur daily_cases_per_million
# Kolhapur daily_tests_per_million
# Kolhapur daily_tests_ma
# Kolhapur daily_deceased_ma
# Kolhapur cfr1_point
# Kolhapur cfr2_point
# Kolhapur cfr3_point
# Kolhapur cfr3_l95
# Kolhapur cfr3_u95
# Kolhapur cfr3_l50
# Kolhapur cfr3_u50
# Kolhapur dbt_point
# Kolhapur dbt_l95
# Kolhapur dbt_u95
# Kolhapur rt_point
# Kolhapur rt_sd
# Kolhapur rt_l95
# Kolhapur rt_u95
# Kolhapur rt_l50
# Kolhapur rt_u50
# Kolhapur t_end
# Mumbai dates
# Mumbai cum_positive_cases
# Mumbai cum_positivity_rate
# Mumbai daily_positive_cases
# Mumbai cum_recovered
# Mumbai daily_recovered
# Mumbai cum_deceased
# Mumbai daily_deceased
# Mumbai daily_positivity_rate
# Mumbai daily_positive_cases_ma
# Mumbai daily_positivity_rate_ma
# Mumbai daily_tests
# Mumbai cum_tests
# Mumbai test_per_million
# Mumbai daily_cases_per_million
# Mumbai daily_tests_per_million
# Mumbai daily_tests_ma
# Mumbai daily_deceased_ma
# Mumbai cfr1_point
# Mumbai cfr2_point
# Mumbai cfr3_point
# Mumbai cfr3_l95
# Mumbai cfr3_u95
# Mumbai cfr3_l50
# Mumbai cfr3_u50
# Mumbai dbt_point
# Mumbai dbt_l95
# Mumbai dbt_u95
# Mumbai rt_point
# Mumbai rt_sd
# Mumbai rt_l95
# Mumbai rt_u95
# Mumbai rt_l50
# Mumbai rt_u50
# Mumbai t_end
# Nagpur dates
# Nagpur cum_positive_cases
# Nagpur cum_positivity_rate
# Nagpur daily_positive_cases
# Nagpur cum_recovered
# Nagpur daily_recovered
# Nagpur cum_deceased
# Nagpur daily_deceased
# Nagpur daily_positivity_rate
# Nagpur daily_positive_cases_ma
# Nagpur daily_positivity_rate_ma
# Nagpur daily_tests
# Nagpur cum_tests
# Nagpur test_per_million
# Nagpur daily_cases_per_million
# Nagpur daily_tests_per_million
# Nagpur daily_tests_ma
# Nagpur daily_deceased_ma
# Nagpur cfr1_point
# Nagpur cfr2_point
# Nagpur cfr3_point
# Nagpur cfr3_l95
# Nagpur cfr3_u95
# Nagpur cfr3_l50
# Nagpur cfr3_u50
# Nagpur dbt_point
# Nagpur dbt_l95
# Nagpur dbt_u95
# Nagpur rt_point
# Nagpur rt_sd
# Nagpur rt_l95
# Nagpur rt_u95
# Nagpur rt_l50
# Nagpur rt_u50
# Nagpur t_end
# Nashik dates
# Nashik cum_positive_cases
# Nashik cum_positivity_rate
# Nashik daily_positive_cases
# Nashik cum_recovered
# Nashik daily_recovered
# Nashik cum_deceased
# Nashik daily_deceased
# Nashik daily_positivity_rate
# Nashik daily_positive_cases_ma
# Nashik daily_positivity_rate_ma
# Nashik daily_tests
# Nashik cum_tests
# Nashik test_per_million
# Nashik daily_cases_per_million
# Nashik daily_tests_per_million
# Nashik daily_tests_ma
# Nashik daily_deceased_ma
# Nashik cfr1_point
# Nashik cfr2_point
# Nashik cfr3_point
# Nashik cfr3_l95
# Nashik cfr3_u95
# Nashik cfr3_l50
# Nashik cfr3_u50
# Nashik dbt_point
# Nashik dbt_l95
# Nashik dbt_u95
# Nashik rt_point
# Nashik rt_sd
# Nashik rt_l95
# Nashik rt_u95
# Nashik rt_l50
# Nashik rt_u50
# Nashik t_end
# Palghar dates
# Palghar cum_positive_cases
# Palghar cum_positivity_rate
# Palghar daily_positive_cases
# Palghar cum_recovered
# Palghar daily_recovered
# Palghar cum_deceased
# Palghar daily_deceased
# Palghar daily_positivity_rate
# Palghar daily_positive_cases_ma
# Palghar daily_positivity_rate_ma
# Palghar daily_tests
# Palghar cum_tests
# Palghar test_per_million
# Palghar daily_cases_per_million
# Palghar daily_tests_per_million
# Palghar daily_tests_ma
# Palghar daily_deceased_ma
# Palghar cfr1_point
# Palghar cfr2_point
# Palghar cfr3_point
# Palghar cfr3_l95
# Palghar cfr3_u95
# Palghar cfr3_l50
# Palghar cfr3_u50
# Palghar dbt_point
# Palghar dbt_l95
# Palghar dbt_u95
# Palghar rt_point
# Palghar rt_sd
# Palghar rt_l95
# Palghar rt_u95
# Palghar rt_l50
# Palghar rt_u50
# Palghar t_end
# Pune dates
# Pune cum_positive_cases
# Pune cum_positivity_rate
# Pune daily_positive_cases
# Pune cum_recovered
# Pune daily_recovered
# Pune cum_deceased
# Pune daily_deceased
# Pune daily_positivity_rate
# Pune daily_positive_cases_ma
# Pune daily_positivity_rate_ma
# Pune daily_tests
# Pune cum_tests
# Pune test_per_million
# Pune daily_cases_per_million
# Pune daily_tests_per_million
# Pune daily_tests_ma
# Pune daily_deceased_ma
# Pune cfr1_point
# Pune cfr2_point
# Pune cfr3_point
# Pune cfr3_l95
# Pune cfr3_u95
# Pune cfr3_l50
# Pune cfr3_u50
# Pune dbt_point
# Pune dbt_l95
# Pune dbt_u95
# Pune rt_point
# Pune rt_sd
# Pune rt_l95
# Pune rt_u95
# Pune rt_l50
# Pune rt_u50
# Pune t_end
# Raigad dates
# Raigad cum_positive_cases
# Raigad cum_positivity_rate
# Raigad daily_positive_cases
# Raigad cum_recovered
# Raigad daily_recovered
# Raigad cum_deceased
# Raigad daily_deceased
# Raigad daily_positivity_rate
# Raigad daily_positive_cases_ma
# Raigad daily_positivity_rate_ma
# Raigad daily_tests
# Raigad cum_tests
# Raigad test_per_million
# Raigad daily_cases_per_million
# Raigad daily_tests_per_million
# Raigad daily_tests_ma
# Raigad daily_deceased_ma
# Raigad cfr1_point
# Raigad cfr2_point
# Raigad cfr3_point
# Raigad cfr3_l95
# Raigad cfr3_u95
# Raigad cfr3_l50
# Raigad cfr3_u50
# Raigad dbt_point
# Raigad dbt_l95
# Raigad dbt_u95
# Raigad rt_point
# Raigad rt_sd
# Raigad rt_l95
# Raigad rt_u95
# Raigad rt_l50
# Raigad rt_u50
# Raigad t_end
# Solapur dates
# Solapur cum_positive_cases
# Solapur cum_positivity_rate
# Solapur daily_positive_cases
# Solapur cum_recovered
# Solapur daily_recovered
# Solapur cum_deceased
# Solapur daily_deceased
# Solapur daily_positivity_rate
# Solapur daily_positive_cases_ma
# Solapur daily_positivity_rate_ma
# Solapur daily_tests
# Solapur cum_tests
# Solapur test_per_million
# Solapur daily_cases_per_million
# Solapur daily_tests_per_million
# Solapur daily_tests_ma
# Solapur daily_deceased_ma
# Solapur cfr1_point
# Solapur cfr2_point
# Solapur cfr3_point
# Solapur cfr3_l95
# Solapur cfr3_u95
# Solapur cfr3_l50
# Solapur cfr3_u50
# Solapur dbt_point
# Solapur dbt_l95
# Solapur dbt_u95
# Solapur rt_point
# Solapur rt_sd
# Solapur rt_l95
# Solapur rt_u95
# Solapur rt_l50
# Solapur rt_u50
# Solapur t_end
# Thane dates
# Thane cum_positive_cases
# Thane cum_positivity_rate
# Thane daily_positive_cases
# Thane cum_recovered
# Thane daily_recovered
# Thane cum_deceased
# Thane daily_deceased
# Thane daily_positivity_rate
# Thane daily_positive_cases_ma
# Thane daily_positivity_rate_ma
# Thane daily_tests
# Thane cum_tests
# Thane test_per_million
# Thane daily_cases_per_million
# Thane daily_tests_per_million
# Thane daily_tests_ma
# Thane daily_deceased_ma
# Thane cfr1_point
# Thane cfr2_point
# Thane cfr3_point
# Thane cfr3_l95
# Thane cfr3_u95
# Thane cfr3_l50
# Thane cfr3_u50
# Thane dbt_point
# Thane dbt_l95
# Thane dbt_u95
# Thane rt_point
# Thane rt_sd
# Thane rt_l95
# Thane rt_u95
# Thane rt_l50
# Thane rt_u50
# Thane t_end
# Bhopal dates
# Bhopal cum_positive_cases
# Bhopal cum_positivity_rate
# Bhopal daily_positive_cases
# Bhopal cum_recovered
# Bhopal daily_recovered
# Bhopal cum_deceased
# Bhopal daily_deceased
# Bhopal daily_positivity_rate
# Bhopal daily_positive_cases_ma
# Bhopal daily_positivity_rate_ma
# Bhopal daily_tests
# Bhopal cum_tests
# Bhopal test_per_million
# Bhopal daily_cases_per_million
# Bhopal daily_tests_per_million
# Bhopal daily_tests_ma
# Bhopal daily_deceased_ma
# Bhopal cfr1_point
# Bhopal cfr2_point
# Bhopal cfr3_point
# Bhopal cfr3_l95
# Bhopal cfr3_u95
# Bhopal cfr3_l50
# Bhopal cfr3_u50
# Bhopal dbt_point
# Bhopal dbt_l95
# Bhopal dbt_u95
# Bhopal rt_point
# Bhopal rt_sd
# Bhopal rt_l95
# Bhopal rt_u95
# Bhopal rt_l50
# Bhopal rt_u50
# Bhopal t_end
# Indore dates
# Indore cum_positive_cases
# Indore cum_positivity_rate
# Indore daily_positive_cases
# Indore cum_recovered
# Indore daily_recovered
# Indore cum_deceased
# Indore daily_deceased
# Indore daily_positivity_rate
# Indore daily_positive_cases_ma
# Indore daily_positivity_rate_ma
# Indore daily_tests
# Indore cum_tests
# Indore test_per_million
# Indore daily_cases_per_million
# Indore daily_tests_per_million
# Indore daily_tests_ma
# Indore daily_deceased_ma
# Indore cfr1_point
# Indore cfr2_point
# Indore cfr3_point
# Indore cfr3_l95
# Indore cfr3_u95
# Indore cfr3_l50
# Indore cfr3_u50
# Indore dbt_point
# Indore dbt_l95
# Indore dbt_u95
# Indore rt_point
# Indore rt_sd
# Indore rt_l95
# Indore rt_u95
# Indore rt_l50
# Indore rt_u50
# Indore t_end
# Ganjam dates
# Ganjam cum_positive_cases
# Ganjam cum_positivity_rate
# Ganjam daily_positive_cases
# Ganjam cum_recovered
# Ganjam daily_recovered
# Ganjam cum_deceased
# Ganjam daily_deceased
# Ganjam daily_positivity_rate
# Ganjam daily_positive_cases_ma
# Ganjam daily_positivity_rate_ma
# Ganjam daily_tests
# Ganjam cum_tests
# Ganjam test_per_million
# Ganjam daily_cases_per_million
# Ganjam daily_tests_per_million
# Ganjam daily_tests_ma
# Ganjam daily_deceased_ma
# Ganjam cfr1_point
# Ganjam cfr2_point
# Ganjam cfr3_point
# Ganjam cfr3_l95
# Ganjam cfr3_u95
# Ganjam cfr3_l50
# Ganjam cfr3_u50
# Ganjam dbt_point
# Ganjam dbt_l95
# Ganjam dbt_u95
# Ganjam rt_point
# Ganjam rt_sd
# Ganjam rt_l95
# Ganjam rt_u95
# Ganjam rt_l50
# Ganjam rt_u50
# Ganjam t_end
# Ludhiana dates
# Ludhiana cum_positive_cases
# Ludhiana cum_positivity_rate
# Ludhiana daily_positive_cases
# Ludhiana cum_recovered
# Ludhiana daily_recovered
# Ludhiana cum_deceased
# Ludhiana daily_deceased
# Ludhiana daily_positivity_rate
# Ludhiana daily_positive_cases_ma
# Ludhiana daily_positivity_rate_ma
# Ludhiana daily_tests
# Ludhiana cum_tests
# Ludhiana test_per_million
# Ludhiana daily_cases_per_million
# Ludhiana daily_tests_per_million
# Ludhiana daily_tests_ma
# Ludhiana daily_deceased_ma
# Ludhiana cfr1_point
# Ludhiana cfr2_point
# Ludhiana cfr3_point
# Ludhiana cfr3_l95
# Ludhiana cfr3_u95
# Ludhiana cfr3_l50
# Ludhiana cfr3_u50
# Ludhiana dbt_point
# Ludhiana dbt_l95
# Ludhiana dbt_u95
# Ludhiana rt_point
# Ludhiana rt_sd
# Ludhiana rt_l95
# Ludhiana rt_u95
# Ludhiana rt_l50
# Ludhiana rt_u50
# Ludhiana t_end
# Hyderabad dates
# Hyderabad cum_positive_cases
# Hyderabad cum_positivity_rate
# Hyderabad daily_positive_cases
# Hyderabad cum_recovered
# Hyderabad daily_recovered
# Hyderabad cum_deceased
# Hyderabad daily_deceased
# Hyderabad daily_positivity_rate
# Hyderabad daily_positive_cases_ma
# Hyderabad daily_positivity_rate_ma
# Hyderabad daily_tests
# Hyderabad cum_tests
# Hyderabad test_per_million
# Hyderabad daily_cases_per_million
# Hyderabad daily_tests_per_million
# Hyderabad daily_tests_ma
# Hyderabad daily_deceased_ma
# Hyderabad cfr1_point
# Hyderabad cfr2_point
# Hyderabad cfr3_point
# Hyderabad cfr3_l95
# Hyderabad cfr3_u95
# Hyderabad cfr3_l50
# Hyderabad cfr3_u50
# Hyderabad dbt_point
# Hyderabad dbt_l95
# Hyderabad dbt_u95
# Hyderabad rt_point
# Hyderabad rt_sd
# Hyderabad rt_l95
# Hyderabad rt_u95
# Hyderabad rt_l50
# Hyderabad rt_u50
# Hyderabad t_end
# Medchal Malkajgiri dates
# Medchal Malkajgiri cum_positive_cases
# Medchal Malkajgiri cum_positivity_rate
# Medchal Malkajgiri daily_positive_cases
# Medchal Malkajgiri cum_recovered
# Medchal Malkajgiri daily_recovered
# Medchal Malkajgiri cum_deceased
# Medchal Malkajgiri daily_deceased
# Medchal Malkajgiri daily_positivity_rate
# Medchal Malkajgiri daily_positive_cases_ma
# Medchal Malkajgiri daily_positivity_rate_ma
# Medchal Malkajgiri daily_tests
# Medchal Malkajgiri cum_tests
# Medchal Malkajgiri test_per_million
# Medchal Malkajgiri daily_cases_per_million
# Medchal Malkajgiri daily_tests_per_million
# Medchal Malkajgiri daily_tests_ma
# Medchal Malkajgiri daily_deceased_ma
# Medchal Malkajgiri cfr1_point
# Medchal Malkajgiri cfr2_point
# Medchal Malkajgiri cfr3_point
# Medchal Malkajgiri cfr3_l95
# Medchal Malkajgiri cfr3_u95
# Medchal Malkajgiri cfr3_l50
# Medchal Malkajgiri cfr3_u50
# Medchal Malkajgiri dbt_point
# Medchal Malkajgiri dbt_l95
# Medchal Malkajgiri dbt_u95
# Medchal Malkajgiri rt_point
# Medchal Malkajgiri rt_sd
# Medchal Malkajgiri rt_l95
# Medchal Malkajgiri rt_u95
# Medchal Malkajgiri rt_l50
# Medchal Malkajgiri rt_u50
# Medchal Malkajgiri t_end
# Ranga Reddy dates
# Ranga Reddy cum_positive_cases
# Ranga Reddy cum_positivity_rate
# Ranga Reddy daily_positive_cases
# Ranga Reddy cum_recovered
# Ranga Reddy daily_recovered
# Ranga Reddy cum_deceased
# Ranga Reddy daily_deceased
# Ranga Reddy daily_positivity_rate
# Ranga Reddy daily_positive_cases_ma
# Ranga Reddy daily_positivity_rate_ma
# Ranga Reddy daily_tests
# Ranga Reddy cum_tests
# Ranga Reddy test_per_million
# Ranga Reddy daily_cases_per_million
# Ranga Reddy daily_tests_per_million
# Ranga Reddy daily_tests_ma
# Ranga Reddy daily_deceased_ma
# Ranga Reddy cfr1_point
# Ranga Reddy cfr2_point
# Ranga Reddy cfr3_point
# Ranga Reddy cfr3_l95
# Ranga Reddy cfr3_u95
# Ranga Reddy cfr3_l50
# Ranga Reddy cfr3_u50
# Ranga Reddy dbt_point
# Ranga Reddy dbt_l95
# Ranga Reddy dbt_u95
# Ranga Reddy rt_point
# Ranga Reddy rt_sd
# Ranga Reddy rt_l95
# Ranga Reddy rt_u95
# Ranga Reddy rt_l50
# Ranga Reddy rt_u50
# Ranga Reddy t_end
# Chengalpattu dates
# Chengalpattu cum_positive_cases
# Chengalpattu cum_positivity_rate
# Chengalpattu daily_positive_cases
# Chengalpattu cum_recovered
# Chengalpattu daily_recovered
# Chengalpattu cum_deceased
# Chengalpattu daily_deceased
# Chengalpattu daily_positivity_rate
# Chengalpattu daily_positive_cases_ma
# Chengalpattu daily_positivity_rate_ma
# Chengalpattu daily_tests
# Chengalpattu cum_tests
# Chengalpattu test_per_million
# Chengalpattu daily_cases_per_million
# Chengalpattu daily_tests_per_million
# Chengalpattu daily_tests_ma
# Chengalpattu daily_deceased_ma
# Chengalpattu cfr1_point
# Chengalpattu cfr2_point
# Chengalpattu cfr3_point
# Chengalpattu cfr3_l95
# Chengalpattu cfr3_u95
# Chengalpattu cfr3_l50
# Chengalpattu cfr3_u50
# Chengalpattu dbt_point
# Chengalpattu dbt_l95
# Chengalpattu dbt_u95
# Chengalpattu rt_point
# Chengalpattu rt_sd
# Chengalpattu rt_l95
# Chengalpattu rt_u95
# Chengalpattu rt_l50
# Chengalpattu rt_u50
# Chengalpattu t_end
# Chennai dates
# Chennai cum_positive_cases
# Chennai cum_positivity_rate
# Chennai daily_positive_cases
# Chennai cum_recovered
# Chennai daily_recovered
# Chennai cum_deceased
# Chennai daily_deceased
# Chennai daily_positivity_rate
# Chennai daily_positive_cases_ma
# Chennai daily_positivity_rate_ma
# Chennai daily_tests
# Chennai cum_tests
# Chennai test_per_million
# Chennai daily_cases_per_million
# Chennai daily_tests_per_million
# Chennai daily_tests_ma
# Chennai daily_deceased_ma
# Chennai cfr1_point
# Chennai cfr2_point
# Chennai cfr3_point
# Chennai cfr3_l95
# Chennai cfr3_u95
# Chennai cfr3_l50
# Chennai cfr3_u50
# Chennai dbt_point
# Chennai dbt_l95
# Chennai dbt_u95
# Chennai rt_point
# Chennai rt_sd
# Chennai rt_l95
# Chennai rt_u95
# Chennai rt_l50
# Chennai rt_u50
# Chennai t_end
# Kancheepuram dates
# Kancheepuram cum_positive_cases
# Kancheepuram cum_positivity_rate
# Kancheepuram daily_positive_cases
# Kancheepuram cum_recovered
# Kancheepuram daily_recovered
# Kancheepuram cum_deceased
# Kancheepuram daily_deceased
# Kancheepuram daily_positivity_rate
# Kancheepuram daily_positive_cases_ma
# Kancheepuram daily_positivity_rate_ma
# Kancheepuram daily_tests
# Kancheepuram cum_tests
# Kancheepuram test_per_million
# Kancheepuram daily_cases_per_million
# Kancheepuram daily_tests_per_million
# Kancheepuram daily_tests_ma
# Kancheepuram daily_deceased_ma
# Kancheepuram cfr1_point
# Kancheepuram cfr2_point
# Kancheepuram cfr3_point
# Kancheepuram cfr3_l95
# Kancheepuram cfr3_u95
# Kancheepuram cfr3_l50
# Kancheepuram cfr3_u50
# Kancheepuram dbt_point
# Kancheepuram dbt_l95
# Kancheepuram dbt_u95
# Kancheepuram rt_point
# Kancheepuram rt_sd
# Kancheepuram rt_l95
# Kancheepuram rt_u95
# Kancheepuram rt_l50
# Kancheepuram rt_u50
# Kancheepuram t_end
# Madurai dates
# Madurai cum_positive_cases
# Madurai cum_positivity_rate
# Madurai daily_positive_cases
# Madurai cum_recovered
# Madurai daily_recovered
# Madurai cum_deceased
# Madurai daily_deceased
# Madurai daily_positivity_rate
# Madurai daily_positive_cases_ma
# Madurai daily_positivity_rate_ma
# Madurai daily_tests
# Madurai cum_tests
# Madurai test_per_million
# Madurai daily_cases_per_million
# Madurai daily_tests_per_million
# Madurai daily_tests_ma
# Madurai daily_deceased_ma
# Madurai cfr1_point
# Madurai cfr2_point
# Madurai cfr3_point
# Madurai cfr3_l95
# Madurai cfr3_u95
# Madurai cfr3_l50
# Madurai cfr3_u50
# Madurai dbt_point
# Madurai dbt_l95
# Madurai dbt_u95
# Madurai rt_point
# Madurai rt_sd
# Madurai rt_l95
# Madurai rt_u95
# Madurai rt_l50
# Madurai rt_u50
# Madurai t_end
# Thiruvallur dates
# Thiruvallur cum_positive_cases
# Thiruvallur cum_positivity_rate
# Thiruvallur daily_positive_cases
# Thiruvallur cum_recovered
# Thiruvallur daily_recovered
# Thiruvallur cum_deceased
# Thiruvallur daily_deceased
# Thiruvallur daily_positivity_rate
# Thiruvallur daily_positive_cases_ma
# Thiruvallur daily_positivity_rate_ma
# Thiruvallur daily_tests
# Thiruvallur cum_tests
# Thiruvallur test_per_million
# Thiruvallur daily_cases_per_million
# Thiruvallur daily_tests_per_million
# Thiruvallur daily_tests_ma
# Thiruvallur daily_deceased_ma
# Thiruvallur cfr1_point
# Thiruvallur cfr2_point
# Thiruvallur cfr3_point
# Thiruvallur cfr3_l95
# Thiruvallur cfr3_u95
# Thiruvallur cfr3_l50
# Thiruvallur cfr3_u50
# Thiruvallur dbt_point
# Thiruvallur dbt_l95
# Thiruvallur dbt_u95
# Thiruvallur rt_point
# Thiruvallur rt_sd
# Thiruvallur rt_l95
# Thiruvallur rt_u95
# Thiruvallur rt_l50
# Thiruvallur rt_u50
# Thiruvallur t_end
# Tiruvannamalai dates
# Tiruvannamalai cum_positive_cases
# Tiruvannamalai cum_positivity_rate
# Tiruvannamalai daily_positive_cases
# Tiruvannamalai cum_recovered
# Tiruvannamalai daily_recovered
# Tiruvannamalai cum_deceased
# Tiruvannamalai daily_deceased
# Tiruvannamalai daily_positivity_rate
# Tiruvannamalai daily_positive_cases_ma
# Tiruvannamalai daily_positivity_rate_ma
# Tiruvannamalai daily_tests
# Tiruvannamalai cum_tests
# Tiruvannamalai test_per_million
# Tiruvannamalai daily_cases_per_million
# Tiruvannamalai daily_tests_per_million
# Tiruvannamalai daily_tests_ma
# Tiruvannamalai daily_deceased_ma
# Tiruvannamalai cfr1_point
# Tiruvannamalai cfr2_point
# Tiruvannamalai cfr3_point
# Tiruvannamalai cfr3_l95
# Tiruvannamalai cfr3_u95
# Tiruvannamalai cfr3_l50
# Tiruvannamalai cfr3_u50
# Tiruvannamalai dbt_point
# Tiruvannamalai dbt_l95
# Tiruvannamalai dbt_u95
# Tiruvannamalai rt_point
# Tiruvannamalai rt_sd
# Tiruvannamalai rt_l95
# Tiruvannamalai rt_u95
# Tiruvannamalai rt_l50
# Tiruvannamalai rt_u50
# Tiruvannamalai t_end
# Vellore dates
# Vellore cum_positive_cases
# Vellore cum_positivity_rate
# Vellore daily_positive_cases
# Vellore cum_recovered
# Vellore daily_recovered
# Vellore cum_deceased
# Vellore daily_deceased
# Vellore daily_positivity_rate
# Vellore daily_positive_cases_ma
# Vellore daily_positivity_rate_ma
# Vellore daily_tests
# Vellore cum_tests
# Vellore test_per_million
# Vellore daily_cases_per_million
# Vellore daily_tests_per_million
# Vellore daily_tests_ma
# Vellore daily_deceased_ma
# Vellore cfr1_point
# Vellore cfr2_point
# Vellore cfr3_point
# Vellore cfr3_l95
# Vellore cfr3_u95
# Vellore cfr3_l50
# Vellore cfr3_u50
# Vellore dbt_point
# Vellore dbt_l95
# Vellore dbt_u95
# Vellore rt_point
# Vellore rt_sd
# Vellore rt_l95
# Vellore rt_u95
# Vellore rt_l50
# Vellore rt_u50
# Vellore t_end
# Aligarh dates
# Aligarh cum_positive_cases
# Aligarh cum_positivity_rate
# Aligarh daily_positive_cases
# Aligarh cum_recovered
# Aligarh daily_recovered
# Aligarh cum_deceased
# Aligarh daily_deceased
# Aligarh daily_positivity_rate
# Aligarh daily_positive_cases_ma
# Aligarh daily_positivity_rate_ma
# Aligarh daily_tests
# Aligarh cum_tests
# Aligarh test_per_million
# Aligarh daily_cases_per_million
# Aligarh daily_tests_per_million
# Aligarh daily_tests_ma
# Aligarh daily_deceased_ma
# Aligarh cfr1_point
# Aligarh cfr2_point
# Aligarh cfr3_point
# Aligarh cfr3_l95
# Aligarh cfr3_u95
# Aligarh cfr3_l50
# Aligarh cfr3_u50
# Aligarh dbt_point
# Aligarh dbt_l95
# Aligarh dbt_u95
# Aligarh rt_point
# Aligarh rt_sd
# Aligarh rt_l95
# Aligarh rt_u95
# Aligarh rt_l50
# Aligarh rt_u50
# Aligarh t_end
# Bareilly dates
# Bareilly cum_positive_cases
# Bareilly cum_positivity_rate
# Bareilly daily_positive_cases
# Bareilly cum_recovered
# Bareilly daily_recovered
# Bareilly cum_deceased
# Bareilly daily_deceased
# Bareilly daily_positivity_rate
# Bareilly daily_positive_cases_ma
# Bareilly daily_positivity_rate_ma
# Bareilly daily_tests
# Bareilly cum_tests
# Bareilly test_per_million
# Bareilly daily_cases_per_million
# Bareilly daily_tests_per_million
# Bareilly daily_tests_ma
# Bareilly daily_deceased_ma
# Bareilly cfr1_point
# Bareilly cfr2_point
# Bareilly cfr3_point
# Bareilly cfr3_l95
# Bareilly cfr3_u95
# Bareilly cfr3_l50
# Bareilly cfr3_u50
# Bareilly dbt_point
# Bareilly dbt_l95
# Bareilly dbt_u95
# Bareilly rt_point
# Bareilly rt_sd
# Bareilly rt_l95
# Bareilly rt_u95
# Bareilly rt_l50
# Bareilly rt_u50
# Bareilly t_end
# Gautam Buddha Nagar dates
# Gautam Buddha Nagar cum_positive_cases
# Gautam Buddha Nagar cum_positivity_rate
# Gautam Buddha Nagar daily_positive_cases
# Gautam Buddha Nagar cum_recovered
# Gautam Buddha Nagar daily_recovered
# Gautam Buddha Nagar cum_deceased
# Gautam Buddha Nagar daily_deceased
# Gautam Buddha Nagar daily_positivity_rate
# Gautam Buddha Nagar daily_positive_cases_ma
# Gautam Buddha Nagar daily_positivity_rate_ma
# Gautam Buddha Nagar daily_tests
# Gautam Buddha Nagar cum_tests
# Gautam Buddha Nagar test_per_million
# Gautam Buddha Nagar daily_cases_per_million
# Gautam Buddha Nagar daily_tests_per_million
# Gautam Buddha Nagar daily_tests_ma
# Gautam Buddha Nagar daily_deceased_ma
# Gautam Buddha Nagar cfr1_point
# Gautam Buddha Nagar cfr2_point
# Gautam Buddha Nagar cfr3_point
# Gautam Buddha Nagar cfr3_l95
# Gautam Buddha Nagar cfr3_u95
# Gautam Buddha Nagar cfr3_l50
# Gautam Buddha Nagar cfr3_u50
# Gautam Buddha Nagar dbt_point
# Gautam Buddha Nagar dbt_l95
# Gautam Buddha Nagar dbt_u95
# Gautam Buddha Nagar rt_point
# Gautam Buddha Nagar rt_sd
# Gautam Buddha Nagar rt_l95
# Gautam Buddha Nagar rt_u95
# Gautam Buddha Nagar rt_l50
# Gautam Buddha Nagar rt_u50
# Gautam Buddha Nagar t_end
# Ghaziabad dates
# Ghaziabad cum_positive_cases
# Ghaziabad cum_positivity_rate
# Ghaziabad daily_positive_cases
# Ghaziabad cum_recovered
# Ghaziabad daily_recovered
# Ghaziabad cum_deceased
# Ghaziabad daily_deceased
# Ghaziabad daily_positivity_rate
# Ghaziabad daily_positive_cases_ma
# Ghaziabad daily_positivity_rate_ma
# Ghaziabad daily_tests
# Ghaziabad cum_tests
# Ghaziabad test_per_million
# Ghaziabad daily_cases_per_million
# Ghaziabad daily_tests_per_million
# Ghaziabad daily_tests_ma
# Ghaziabad daily_deceased_ma
# Ghaziabad cfr1_point
# Ghaziabad cfr2_point
# Ghaziabad cfr3_point
# Ghaziabad cfr3_l95
# Ghaziabad cfr3_u95
# Ghaziabad cfr3_l50
# Ghaziabad cfr3_u50
# Ghaziabad dbt_point
# Ghaziabad dbt_l95
# Ghaziabad dbt_u95
# Ghaziabad rt_point
# Ghaziabad rt_sd
# Ghaziabad rt_l95
# Ghaziabad rt_u95
# Ghaziabad rt_l50
# Ghaziabad rt_u50
# Ghaziabad t_end
# Kanpur Nagar dates
# Kanpur Nagar cum_positive_cases
# Kanpur Nagar cum_positivity_rate
# Kanpur Nagar daily_positive_cases
# Kanpur Nagar cum_recovered
# Kanpur Nagar daily_recovered
# Kanpur Nagar cum_deceased
# Kanpur Nagar daily_deceased
# Kanpur Nagar daily_positivity_rate
# Kanpur Nagar daily_positive_cases_ma
# Kanpur Nagar daily_positivity_rate_ma
# Kanpur Nagar daily_tests
# Kanpur Nagar cum_tests
# Kanpur Nagar test_per_million
# Kanpur Nagar daily_cases_per_million
# Kanpur Nagar daily_tests_per_million
# Kanpur Nagar daily_tests_ma
# Kanpur Nagar daily_deceased_ma
# Kanpur Nagar cfr1_point
# Kanpur Nagar cfr2_point
# Kanpur Nagar cfr3_point
# Kanpur Nagar cfr3_l95
# Kanpur Nagar cfr3_u95
# Kanpur Nagar cfr3_l50
# Kanpur Nagar cfr3_u50
# Kanpur Nagar dbt_point
# Kanpur Nagar dbt_l95
# Kanpur Nagar dbt_u95
# Kanpur Nagar rt_point
# Kanpur Nagar rt_sd
# Kanpur Nagar rt_l95
# Kanpur Nagar rt_u95
# Kanpur Nagar rt_l50
# Kanpur Nagar rt_u50
# Kanpur Nagar t_end
# Lucknow dates
# Lucknow cum_positive_cases
# Lucknow cum_positivity_rate
# Lucknow daily_positive_cases
# Lucknow cum_recovered
# Lucknow daily_recovered
# Lucknow cum_deceased
# Lucknow daily_deceased
# Lucknow daily_positivity_rate
# Lucknow daily_positive_cases_ma
# Lucknow daily_positivity_rate_ma
# Lucknow daily_tests
# Lucknow cum_tests
# Lucknow test_per_million
# Lucknow daily_cases_per_million
# Lucknow daily_tests_per_million
# Lucknow daily_tests_ma
# Lucknow daily_deceased_ma
# Lucknow cfr1_point
# Lucknow cfr2_point
# Lucknow cfr3_point
# Lucknow cfr3_l95
# Lucknow cfr3_u95
# Lucknow cfr3_l50
# Lucknow cfr3_u50
# Lucknow dbt_point
# Lucknow dbt_l95
# Lucknow dbt_u95
# Lucknow rt_point
# Lucknow rt_sd
# Lucknow rt_l95
# Lucknow rt_u95
# Lucknow rt_l50
# Lucknow rt_u50
# Lucknow t_end
# Varanasi dates
# Varanasi cum_positive_cases
# Varanasi cum_positivity_rate
# Varanasi daily_positive_cases
# Varanasi cum_recovered
# Varanasi daily_recovered
# Varanasi cum_deceased
# Varanasi daily_deceased
# Varanasi daily_positivity_rate
# Varanasi daily_positive_cases_ma
# Varanasi daily_positivity_rate_ma
# Varanasi daily_tests
# Varanasi cum_tests
# Varanasi test_per_million
# Varanasi daily_cases_per_million
# Varanasi daily_tests_per_million
# Varanasi daily_tests_ma
# Varanasi daily_deceased_ma
# Varanasi cfr1_point
# Varanasi cfr2_point
# Varanasi cfr3_point
# Varanasi cfr3_l95
# Varanasi cfr3_u95
# Varanasi cfr3_l50
# Varanasi cfr3_u50
# Varanasi dbt_point
# Varanasi dbt_l95
# Varanasi dbt_u95
# Varanasi rt_point
# Varanasi rt_sd
# Varanasi rt_l95
# Varanasi rt_u95
# Varanasi rt_l50
# Varanasi rt_u50
# Varanasi t_end
# Kolkata dates
# Kolkata cum_positive_cases
# Kolkata cum_positivity_rate
# Kolkata daily_positive_cases
# Kolkata cum_recovered
# Kolkata daily_recovered
# Kolkata cum_deceased
# Kolkata daily_deceased
# Kolkata daily_positivity_rate
# Kolkata daily_positive_cases_ma
# Kolkata daily_positivity_rate_ma
# Kolkata daily_tests
# Kolkata cum_tests
# Kolkata test_per_million
# Kolkata daily_cases_per_million
# Kolkata daily_tests_per_million
# Kolkata daily_tests_ma
# Kolkata daily_deceased_ma
# Kolkata cfr1_point
# Kolkata cfr2_point
# Kolkata cfr3_point
# Kolkata cfr3_l95
# Kolkata cfr3_u95
# Kolkata cfr3_l50
# Kolkata cfr3_u50
# Kolkata dbt_point
# Kolkata dbt_l95
# Kolkata dbt_u95
# Kolkata rt_point
# Kolkata rt_sd
# Kolkata rt_l95
# Kolkata rt_u95
# Kolkata rt_l50
# Kolkata rt_u50
# Kolkata t_end
# North 24 Parganas dates
# North 24 Parganas cum_positive_cases
# North 24 Parganas cum_positivity_rate
# North 24 Parganas daily_positive_cases
# North 24 Parganas cum_recovered
# North 24 Parganas daily_recovered
# North 24 Parganas cum_deceased
# North 24 Parganas daily_deceased
# North 24 Parganas daily_positivity_rate
# North 24 Parganas daily_positive_cases_ma
# North 24 Parganas daily_positivity_rate_ma
# North 24 Parganas daily_tests
# North 24 Parganas cum_tests
# North 24 Parganas test_per_million
# North 24 Parganas daily_cases_per_million
# North 24 Parganas daily_tests_per_million
# North 24 Parganas daily_tests_ma
# North 24 Parganas daily_deceased_ma
# North 24 Parganas cfr1_point
# North 24 Parganas cfr2_point
# North 24 Parganas cfr3_point
# North 24 Parganas cfr3_l95
# North 24 Parganas cfr3_u95
# North 24 Parganas cfr3_l50
# North 24 Parganas cfr3_u50
# North 24 Parganas dbt_point
# North 24 Parganas dbt_l95
# North 24 Parganas dbt_u95
# North 24 Parganas rt_point
# North 24 Parganas rt_sd
# North 24 Parganas rt_l95
# North 24 Parganas rt_u95
# North 24 Parganas rt_l50
# North 24 Parganas rt_u50
# North 24 Parganas t_end

# %%
cols=list(states_shifted['Mumbai'].keys())
q=['state']

complete_shifted=pd.DataFrame(columns=q+cols)

keys=list(states_shifted.keys())[:-1]

for i in keys:
  temp=pd.DataFrame()
  d=len(states_shifted['Mumbai']['dates'])
  temp['state']=[str(i)]*d
  
  for j in cols:
    print(i,j)
    temp[j]=list(states_shifted[i][j])
  
  complete_shifted = pd.concat([complete_shifted,temp])
# Out:
# Anantapur dates
# Anantapur cum_positive_cases
# Anantapur cum_positivity_rate
# Anantapur daily_positive_cases
# Anantapur cum_recovered
# Anantapur daily_recovered
# Anantapur cum_deceased
# Anantapur daily_deceased
# Anantapur daily_positivity_rate
# Anantapur daily_positive_cases_ma
# Anantapur daily_positivity_rate_ma
# Anantapur daily_tests
# Anantapur cum_tests
# Anantapur test_per_million
# Anantapur daily_cases_per_million
# Anantapur daily_tests_per_million
# Anantapur daily_tests_ma
# Anantapur daily_deceased_ma
# Anantapur cfr1_point
# Anantapur cfr2_point
# Anantapur cfr3_point
# Anantapur cfr3_l95
# Anantapur cfr3_u95
# Anantapur cfr3_l50
# Anantapur cfr3_u50
# Anantapur dbt_point
# Anantapur dbt_l95
# Anantapur dbt_u95
# Anantapur rt_point
# Anantapur rt_sd
# Anantapur rt_l95
# Anantapur rt_u95
# Anantapur rt_l50
# Anantapur rt_u50
# Anantapur t_end
# Chittoor dates
# Chittoor cum_positive_cases
# Chittoor cum_positivity_rate
# Chittoor daily_positive_cases
# Chittoor cum_recovered
# Chittoor daily_recovered
# Chittoor cum_deceased
# Chittoor daily_deceased
# Chittoor daily_positivity_rate
# Chittoor daily_positive_cases_ma
# Chittoor daily_positivity_rate_ma
# Chittoor daily_tests
# Chittoor cum_tests
# Chittoor test_per_million
# Chittoor daily_cases_per_million
# Chittoor daily_tests_per_million
# Chittoor daily_tests_ma
# Chittoor daily_deceased_ma
# Chittoor cfr1_point
# Chittoor cfr2_point
# Chittoor cfr3_point
# Chittoor cfr3_l95
# Chittoor cfr3_u95
# Chittoor cfr3_l50
# Chittoor cfr3_u50
# Chittoor dbt_point
# Chittoor dbt_l95
# Chittoor dbt_u95
# Chittoor rt_point
# Chittoor rt_sd
# Chittoor rt_l95
# Chittoor rt_u95
# Chittoor rt_l50
# Chittoor rt_u50
# Chittoor t_end
# East Godavari dates
# East Godavari cum_positive_cases
# East Godavari cum_positivity_rate
# East Godavari daily_positive_cases
# East Godavari cum_recovered
# East Godavari daily_recovered
# East Godavari cum_deceased
# East Godavari daily_deceased
# East Godavari daily_positivity_rate
# East Godavari daily_positive_cases_ma
# East Godavari daily_positivity_rate_ma
# East Godavari daily_tests
# East Godavari cum_tests
# East Godavari test_per_million
# East Godavari daily_cases_per_million
# East Godavari daily_tests_per_million
# East Godavari daily_tests_ma
# East Godavari daily_deceased_ma
# East Godavari cfr1_point
# East Godavari cfr2_point
# East Godavari cfr3_point
# East Godavari cfr3_l95
# East Godavari cfr3_u95
# East Godavari cfr3_l50
# East Godavari cfr3_u50
# East Godavari dbt_point
# East Godavari dbt_l95
# East Godavari dbt_u95
# East Godavari rt_point
# East Godavari rt_sd
# East Godavari rt_l95
# East Godavari rt_u95
# East Godavari rt_l50
# East Godavari rt_u50
# East Godavari t_end
# Guntur dates
# Guntur cum_positive_cases
# Guntur cum_positivity_rate
# Guntur daily_positive_cases
# Guntur cum_recovered
# Guntur daily_recovered
# Guntur cum_deceased
# Guntur daily_deceased
# Guntur daily_positivity_rate
# Guntur daily_positive_cases_ma
# Guntur daily_positivity_rate_ma
# Guntur daily_tests
# Guntur cum_tests
# Guntur test_per_million
# Guntur daily_cases_per_million
# Guntur daily_tests_per_million
# Guntur daily_tests_ma
# Guntur daily_deceased_ma
# Guntur cfr1_point
# Guntur cfr2_point
# Guntur cfr3_point
# Guntur cfr3_l95
# Guntur cfr3_u95
# Guntur cfr3_l50
# Guntur cfr3_u50
# Guntur dbt_point
# Guntur dbt_l95
# Guntur dbt_u95
# Guntur rt_point
# Guntur rt_sd
# Guntur rt_l95
# Guntur rt_u95
# Guntur rt_l50
# Guntur rt_u50
# Guntur t_end
# Kurnool dates
# Kurnool cum_positive_cases
# Kurnool cum_positivity_rate
# Kurnool daily_positive_cases
# Kurnool cum_recovered
# Kurnool daily_recovered
# Kurnool cum_deceased
# Kurnool daily_deceased
# Kurnool daily_positivity_rate
# Kurnool daily_positive_cases_ma
# Kurnool daily_positivity_rate_ma
# Kurnool daily_tests
# Kurnool cum_tests
# Kurnool test_per_million
# Kurnool daily_cases_per_million
# Kurnool daily_tests_per_million
# Kurnool daily_tests_ma
# Kurnool daily_deceased_ma
# Kurnool cfr1_point
# Kurnool cfr2_point
# Kurnool cfr3_point
# Kurnool cfr3_l95
# Kurnool cfr3_u95
# Kurnool cfr3_l50
# Kurnool cfr3_u50
# Kurnool dbt_point
# Kurnool dbt_l95
# Kurnool dbt_u95
# Kurnool rt_point
# Kurnool rt_sd
# Kurnool rt_l95
# Kurnool rt_u95
# Kurnool rt_l50
# Kurnool rt_u50
# Kurnool t_end
# Prakasam dates
# Prakasam cum_positive_cases
# Prakasam cum_positivity_rate
# Prakasam daily_positive_cases
# Prakasam cum_recovered
# Prakasam daily_recovered
# Prakasam cum_deceased
# Prakasam daily_deceased
# Prakasam daily_positivity_rate
# Prakasam daily_positive_cases_ma
# Prakasam daily_positivity_rate_ma
# Prakasam daily_tests
# Prakasam cum_tests
# Prakasam test_per_million
# Prakasam daily_cases_per_million
# Prakasam daily_tests_per_million
# Prakasam daily_tests_ma
# Prakasam daily_deceased_ma
# Prakasam cfr1_point
# Prakasam cfr2_point
# Prakasam cfr3_point
# Prakasam cfr3_l95
# Prakasam cfr3_u95
# Prakasam cfr3_l50
# Prakasam cfr3_u50
# Prakasam dbt_point
# Prakasam dbt_l95
# Prakasam dbt_u95
# Prakasam rt_point
# Prakasam rt_sd
# Prakasam rt_l95
# Prakasam rt_u95
# Prakasam rt_l50
# Prakasam rt_u50
# Prakasam t_end
# Srikakulam dates
# Srikakulam cum_positive_cases
# Srikakulam cum_positivity_rate
# Srikakulam daily_positive_cases
# Srikakulam cum_recovered
# Srikakulam daily_recovered
# Srikakulam cum_deceased
# Srikakulam daily_deceased
# Srikakulam daily_positivity_rate
# Srikakulam daily_positive_cases_ma
# Srikakulam daily_positivity_rate_ma
# Srikakulam daily_tests
# Srikakulam cum_tests
# Srikakulam test_per_million
# Srikakulam daily_cases_per_million
# Srikakulam daily_tests_per_million
# Srikakulam daily_tests_ma
# Srikakulam daily_deceased_ma
# Srikakulam cfr1_point
# Srikakulam cfr2_point
# Srikakulam cfr3_point
# Srikakulam cfr3_l95
# Srikakulam cfr3_u95
# Srikakulam cfr3_l50
# Srikakulam cfr3_u50
# Srikakulam dbt_point
# Srikakulam dbt_l95
# Srikakulam dbt_u95
# Srikakulam rt_point
# Srikakulam rt_sd
# Srikakulam rt_l95
# Srikakulam rt_u95
# Srikakulam rt_l50
# Srikakulam rt_u50
# Srikakulam t_end
# Visakhapatnam dates
# Visakhapatnam cum_positive_cases
# Visakhapatnam cum_positivity_rate
# Visakhapatnam daily_positive_cases
# Visakhapatnam cum_recovered
# Visakhapatnam daily_recovered
# Visakhapatnam cum_deceased
# Visakhapatnam daily_deceased
# Visakhapatnam daily_positivity_rate
# Visakhapatnam daily_positive_cases_ma
# Visakhapatnam daily_positivity_rate_ma
# Visakhapatnam daily_tests
# Visakhapatnam cum_tests
# Visakhapatnam test_per_million
# Visakhapatnam daily_cases_per_million
# Visakhapatnam daily_tests_per_million
# Visakhapatnam daily_tests_ma
# Visakhapatnam daily_deceased_ma
# Visakhapatnam cfr1_point
# Visakhapatnam cfr2_point
# Visakhapatnam cfr3_point
# Visakhapatnam cfr3_l95
# Visakhapatnam cfr3_u95
# Visakhapatnam cfr3_l50
# Visakhapatnam cfr3_u50
# Visakhapatnam dbt_point
# Visakhapatnam dbt_l95
# Visakhapatnam dbt_u95
# Visakhapatnam rt_point
# Visakhapatnam rt_sd
# Visakhapatnam rt_l95
# Visakhapatnam rt_u95
# Visakhapatnam rt_l50
# Visakhapatnam rt_u50
# Visakhapatnam t_end
# Vizianagaram dates
# Vizianagaram cum_positive_cases
# Vizianagaram cum_positivity_rate
# Vizianagaram daily_positive_cases
# Vizianagaram cum_recovered
# Vizianagaram daily_recovered
# Vizianagaram cum_deceased
# Vizianagaram daily_deceased
# Vizianagaram daily_positivity_rate
# Vizianagaram daily_positive_cases_ma
# Vizianagaram daily_positivity_rate_ma
# Vizianagaram daily_tests
# Vizianagaram cum_tests
# Vizianagaram test_per_million
# Vizianagaram daily_cases_per_million
# Vizianagaram daily_tests_per_million
# Vizianagaram daily_tests_ma
# Vizianagaram daily_deceased_ma
# Vizianagaram cfr1_point
# Vizianagaram cfr2_point
# Vizianagaram cfr3_point
# Vizianagaram cfr3_l95
# Vizianagaram cfr3_u95
# Vizianagaram cfr3_l50
# Vizianagaram cfr3_u50
# Vizianagaram dbt_point
# Vizianagaram dbt_l95
# Vizianagaram dbt_u95
# Vizianagaram rt_point
# Vizianagaram rt_sd
# Vizianagaram rt_l95
# Vizianagaram rt_u95
# Vizianagaram rt_l50
# Vizianagaram rt_u50
# Vizianagaram t_end
# West Godavari dates
# West Godavari cum_positive_cases
# West Godavari cum_positivity_rate
# West Godavari daily_positive_cases
# West Godavari cum_recovered
# West Godavari daily_recovered
# West Godavari cum_deceased
# West Godavari daily_deceased
# West Godavari daily_positivity_rate
# West Godavari daily_positive_cases_ma
# West Godavari daily_positivity_rate_ma
# West Godavari daily_tests
# West Godavari cum_tests
# West Godavari test_per_million
# West Godavari daily_cases_per_million
# West Godavari daily_tests_per_million
# West Godavari daily_tests_ma
# West Godavari daily_deceased_ma
# West Godavari cfr1_point
# West Godavari cfr2_point
# West Godavari cfr3_point
# West Godavari cfr3_l95
# West Godavari cfr3_u95
# West Godavari cfr3_l50
# West Godavari cfr3_u50
# West Godavari dbt_point
# West Godavari dbt_l95
# West Godavari dbt_u95
# West Godavari rt_point
# West Godavari rt_sd
# West Godavari rt_l95
# West Godavari rt_u95
# West Godavari rt_l50
# West Godavari rt_u50
# West Godavari t_end
# Kamrup Metropolitan dates
# Kamrup Metropolitan cum_positive_cases
# Kamrup Metropolitan cum_positivity_rate
# Kamrup Metropolitan daily_positive_cases
# Kamrup Metropolitan cum_recovered
# Kamrup Metropolitan daily_recovered
# Kamrup Metropolitan cum_deceased
# Kamrup Metropolitan daily_deceased
# Kamrup Metropolitan daily_positivity_rate
# Kamrup Metropolitan daily_positive_cases_ma
# Kamrup Metropolitan daily_positivity_rate_ma
# Kamrup Metropolitan daily_tests
# Kamrup Metropolitan cum_tests
# Kamrup Metropolitan test_per_million
# Kamrup Metropolitan daily_cases_per_million
# Kamrup Metropolitan daily_tests_per_million
# Kamrup Metropolitan daily_tests_ma
# Kamrup Metropolitan daily_deceased_ma
# Kamrup Metropolitan cfr1_point
# Kamrup Metropolitan cfr2_point
# Kamrup Metropolitan cfr3_point
# Kamrup Metropolitan cfr3_l95
# Kamrup Metropolitan cfr3_u95
# Kamrup Metropolitan cfr3_l50
# Kamrup Metropolitan cfr3_u50
# Kamrup Metropolitan dbt_point
# Kamrup Metropolitan dbt_l95
# Kamrup Metropolitan dbt_u95
# Kamrup Metropolitan rt_point
# Kamrup Metropolitan rt_sd
# Kamrup Metropolitan rt_l95
# Kamrup Metropolitan rt_u95
# Kamrup Metropolitan rt_l50
# Kamrup Metropolitan rt_u50
# Kamrup Metropolitan t_end
# Begusarai dates
# Begusarai cum_positive_cases
# Begusarai cum_positivity_rate
# Begusarai daily_positive_cases
# Begusarai cum_recovered
# Begusarai daily_recovered
# Begusarai cum_deceased
# Begusarai daily_deceased
# Begusarai daily_positivity_rate
# Begusarai daily_positive_cases_ma
# Begusarai daily_positivity_rate_ma
# Begusarai daily_tests
# Begusarai cum_tests
# Begusarai test_per_million
# Begusarai daily_cases_per_million
# Begusarai daily_tests_per_million
# Begusarai daily_tests_ma
# Begusarai daily_deceased_ma
# Begusarai cfr1_point
# Begusarai cfr2_point
# Begusarai cfr3_point
# Begusarai cfr3_l95
# Begusarai cfr3_u95
# Begusarai cfr3_l50
# Begusarai cfr3_u50
# Begusarai dbt_point
# Begusarai dbt_l95
# Begusarai dbt_u95
# Begusarai rt_point
# Begusarai rt_sd
# Begusarai rt_l95
# Begusarai rt_u95
# Begusarai rt_l50
# Begusarai rt_u50
# Begusarai t_end
# Patna dates
# Patna cum_positive_cases
# Patna cum_positivity_rate
# Patna daily_positive_cases
# Patna cum_recovered
# Patna daily_recovered
# Patna cum_deceased
# Patna daily_deceased
# Patna daily_positivity_rate
# Patna daily_positive_cases_ma
# Patna daily_positivity_rate_ma
# Patna daily_tests
# Patna cum_tests
# Patna test_per_million
# Patna daily_cases_per_million
# Patna daily_tests_per_million
# Patna daily_tests_ma
# Patna daily_deceased_ma
# Patna cfr1_point
# Patna cfr2_point
# Patna cfr3_point
# Patna cfr3_l95
# Patna cfr3_u95
# Patna cfr3_l50
# Patna cfr3_u50
# Patna dbt_point
# Patna dbt_l95
# Patna dbt_u95
# Patna rt_point
# Patna rt_sd
# Patna rt_l95
# Patna rt_u95
# Patna rt_l50
# Patna rt_u50
# Patna t_end
# Ahmedabad dates
# Ahmedabad cum_positive_cases
# Ahmedabad cum_positivity_rate
# Ahmedabad daily_positive_cases
# Ahmedabad cum_recovered
# Ahmedabad daily_recovered
# Ahmedabad cum_deceased
# Ahmedabad daily_deceased
# Ahmedabad daily_positivity_rate
# Ahmedabad daily_positive_cases_ma
# Ahmedabad daily_positivity_rate_ma
# Ahmedabad daily_tests
# Ahmedabad cum_tests
# Ahmedabad test_per_million
# Ahmedabad daily_cases_per_million
# Ahmedabad daily_tests_per_million
# Ahmedabad daily_tests_ma
# Ahmedabad daily_deceased_ma
# Ahmedabad cfr1_point
# Ahmedabad cfr2_point
# Ahmedabad cfr3_point
# Ahmedabad cfr3_l95
# Ahmedabad cfr3_u95
# Ahmedabad cfr3_l50
# Ahmedabad cfr3_u50
# Ahmedabad dbt_point
# Ahmedabad dbt_l95
# Ahmedabad dbt_u95
# Ahmedabad rt_point
# Ahmedabad rt_sd
# Ahmedabad rt_l95
# Ahmedabad rt_u95
# Ahmedabad rt_l50
# Ahmedabad rt_u50
# Ahmedabad t_end
# Rajkot dates
# Rajkot cum_positive_cases
# Rajkot cum_positivity_rate
# Rajkot daily_positive_cases
# Rajkot cum_recovered
# Rajkot daily_recovered
# Rajkot cum_deceased
# Rajkot daily_deceased
# Rajkot daily_positivity_rate
# Rajkot daily_positive_cases_ma
# Rajkot daily_positivity_rate_ma
# Rajkot daily_tests
# Rajkot cum_tests
# Rajkot test_per_million
# Rajkot daily_cases_per_million
# Rajkot daily_tests_per_million
# Rajkot daily_tests_ma
# Rajkot daily_deceased_ma
# Rajkot cfr1_point
# Rajkot cfr2_point
# Rajkot cfr3_point
# Rajkot cfr3_l95
# Rajkot cfr3_u95
# Rajkot cfr3_l50
# Rajkot cfr3_u50
# Rajkot dbt_point
# Rajkot dbt_l95
# Rajkot dbt_u95
# Rajkot rt_point
# Rajkot rt_sd
# Rajkot rt_l95
# Rajkot rt_u95
# Rajkot rt_l50
# Rajkot rt_u50
# Rajkot t_end
# Surat dates
# Surat cum_positive_cases
# Surat cum_positivity_rate
# Surat daily_positive_cases
# Surat cum_recovered
# Surat daily_recovered
# Surat cum_deceased
# Surat daily_deceased
# Surat daily_positivity_rate
# Surat daily_positive_cases_ma
# Surat daily_positivity_rate_ma
# Surat daily_tests
# Surat cum_tests
# Surat test_per_million
# Surat daily_cases_per_million
# Surat daily_tests_per_million
# Surat daily_tests_ma
# Surat daily_deceased_ma
# Surat cfr1_point
# Surat cfr2_point
# Surat cfr3_point
# Surat cfr3_l95
# Surat cfr3_u95
# Surat cfr3_l50
# Surat cfr3_u50
# Surat dbt_point
# Surat dbt_l95
# Surat dbt_u95
# Surat rt_point
# Surat rt_sd
# Surat rt_l95
# Surat rt_u95
# Surat rt_l50
# Surat rt_u50
# Surat t_end
# Vadodara dates
# Vadodara cum_positive_cases
# Vadodara cum_positivity_rate
# Vadodara daily_positive_cases
# Vadodara cum_recovered
# Vadodara daily_recovered
# Vadodara cum_deceased
# Vadodara daily_deceased
# Vadodara daily_positivity_rate
# Vadodara daily_positive_cases_ma
# Vadodara daily_positivity_rate_ma
# Vadodara daily_tests
# Vadodara cum_tests
# Vadodara test_per_million
# Vadodara daily_cases_per_million
# Vadodara daily_tests_per_million
# Vadodara daily_tests_ma
# Vadodara daily_deceased_ma
# Vadodara cfr1_point
# Vadodara cfr2_point
# Vadodara cfr3_point
# Vadodara cfr3_l95
# Vadodara cfr3_u95
# Vadodara cfr3_l50
# Vadodara cfr3_u50
# Vadodara dbt_point
# Vadodara dbt_l95
# Vadodara dbt_u95
# Vadodara rt_point
# Vadodara rt_sd
# Vadodara rt_l95
# Vadodara rt_u95
# Vadodara rt_l50
# Vadodara rt_u50
# Vadodara t_end
# Faridabad dates
# Faridabad cum_positive_cases
# Faridabad cum_positivity_rate
# Faridabad daily_positive_cases
# Faridabad cum_recovered
# Faridabad daily_recovered
# Faridabad cum_deceased
# Faridabad daily_deceased
# Faridabad daily_positivity_rate
# Faridabad daily_positive_cases_ma
# Faridabad daily_positivity_rate_ma
# Faridabad daily_tests
# Faridabad cum_tests
# Faridabad test_per_million
# Faridabad daily_cases_per_million
# Faridabad daily_tests_per_million
# Faridabad daily_tests_ma
# Faridabad daily_deceased_ma
# Faridabad cfr1_point
# Faridabad cfr2_point
# Faridabad cfr3_point
# Faridabad cfr3_l95
# Faridabad cfr3_u95
# Faridabad cfr3_l50
# Faridabad cfr3_u50
# Faridabad dbt_point
# Faridabad dbt_l95
# Faridabad dbt_u95
# Faridabad rt_point
# Faridabad rt_sd
# Faridabad rt_l95
# Faridabad rt_u95
# Faridabad rt_l50
# Faridabad rt_u50
# Faridabad t_end
# Gurugram dates
# Gurugram cum_positive_cases
# Gurugram cum_positivity_rate
# Gurugram daily_positive_cases
# Gurugram cum_recovered
# Gurugram daily_recovered
# Gurugram cum_deceased
# Gurugram daily_deceased
# Gurugram daily_positivity_rate
# Gurugram daily_positive_cases_ma
# Gurugram daily_positivity_rate_ma
# Gurugram daily_tests
# Gurugram cum_tests
# Gurugram test_per_million
# Gurugram daily_cases_per_million
# Gurugram daily_tests_per_million
# Gurugram daily_tests_ma
# Gurugram daily_deceased_ma
# Gurugram cfr1_point
# Gurugram cfr2_point
# Gurugram cfr3_point
# Gurugram cfr3_l95
# Gurugram cfr3_u95
# Gurugram cfr3_l50
# Gurugram cfr3_u50
# Gurugram dbt_point
# Gurugram dbt_l95
# Gurugram dbt_u95
# Gurugram rt_point
# Gurugram rt_sd
# Gurugram rt_l95
# Gurugram rt_u95
# Gurugram rt_l50
# Gurugram rt_u50
# Gurugram t_end
# Bengaluru Urban dates
# Bengaluru Urban cum_positive_cases
# Bengaluru Urban cum_positivity_rate
# Bengaluru Urban daily_positive_cases
# Bengaluru Urban cum_recovered
# Bengaluru Urban daily_recovered
# Bengaluru Urban cum_deceased
# Bengaluru Urban daily_deceased
# Bengaluru Urban daily_positivity_rate
# Bengaluru Urban daily_positive_cases_ma
# Bengaluru Urban daily_positivity_rate_ma
# Bengaluru Urban daily_tests
# Bengaluru Urban cum_tests
# Bengaluru Urban test_per_million
# Bengaluru Urban daily_cases_per_million
# Bengaluru Urban daily_tests_per_million
# Bengaluru Urban daily_tests_ma
# Bengaluru Urban daily_deceased_ma
# Bengaluru Urban cfr1_point
# Bengaluru Urban cfr2_point
# Bengaluru Urban cfr3_point
# Bengaluru Urban cfr3_l95
# Bengaluru Urban cfr3_u95
# Bengaluru Urban cfr3_l50
# Bengaluru Urban cfr3_u50
# Bengaluru Urban dbt_point
# Bengaluru Urban dbt_l95
# Bengaluru Urban dbt_u95
# Bengaluru Urban rt_point
# Bengaluru Urban rt_sd
# Bengaluru Urban rt_l95
# Bengaluru Urban rt_u95
# Bengaluru Urban rt_l50
# Bengaluru Urban rt_u50
# Bengaluru Urban t_end
# Aurangabad dates
# Aurangabad cum_positive_cases
# Aurangabad cum_positivity_rate
# Aurangabad daily_positive_cases
# Aurangabad cum_recovered
# Aurangabad daily_recovered
# Aurangabad cum_deceased
# Aurangabad daily_deceased
# Aurangabad daily_positivity_rate
# Aurangabad daily_positive_cases_ma
# Aurangabad daily_positivity_rate_ma
# Aurangabad daily_tests
# Aurangabad cum_tests
# Aurangabad test_per_million
# Aurangabad daily_cases_per_million
# Aurangabad daily_tests_per_million
# Aurangabad daily_tests_ma
# Aurangabad daily_deceased_ma
# Aurangabad cfr1_point
# Aurangabad cfr2_point
# Aurangabad cfr3_point
# Aurangabad cfr3_l95
# Aurangabad cfr3_u95
# Aurangabad cfr3_l50
# Aurangabad cfr3_u50
# Aurangabad dbt_point
# Aurangabad dbt_l95
# Aurangabad dbt_u95
# Aurangabad rt_point
# Aurangabad rt_sd
# Aurangabad rt_l95
# Aurangabad rt_u95
# Aurangabad rt_l50
# Aurangabad rt_u50
# Aurangabad t_end
# Jalgaon dates
# Jalgaon cum_positive_cases
# Jalgaon cum_positivity_rate
# Jalgaon daily_positive_cases
# Jalgaon cum_recovered
# Jalgaon daily_recovered
# Jalgaon cum_deceased
# Jalgaon daily_deceased
# Jalgaon daily_positivity_rate
# Jalgaon daily_positive_cases_ma
# Jalgaon daily_positivity_rate_ma
# Jalgaon daily_tests
# Jalgaon cum_tests
# Jalgaon test_per_million
# Jalgaon daily_cases_per_million
# Jalgaon daily_tests_per_million
# Jalgaon daily_tests_ma
# Jalgaon daily_deceased_ma
# Jalgaon cfr1_point
# Jalgaon cfr2_point
# Jalgaon cfr3_point
# Jalgaon cfr3_l95
# Jalgaon cfr3_u95
# Jalgaon cfr3_l50
# Jalgaon cfr3_u50
# Jalgaon dbt_point
# Jalgaon dbt_l95
# Jalgaon dbt_u95
# Jalgaon rt_point
# Jalgaon rt_sd
# Jalgaon rt_l95
# Jalgaon rt_u95
# Jalgaon rt_l50
# Jalgaon rt_u50
# Jalgaon t_end
# Kolhapur dates
# Kolhapur cum_positive_cases
# Kolhapur cum_positivity_rate
# Kolhapur daily_positive_cases
# Kolhapur cum_recovered
# Kolhapur daily_recovered
# Kolhapur cum_deceased
# Kolhapur daily_deceased
# Kolhapur daily_positivity_rate
# Kolhapur daily_positive_cases_ma
# Kolhapur daily_positivity_rate_ma
# Kolhapur daily_tests
# Kolhapur cum_tests
# Kolhapur test_per_million
# Kolhapur daily_cases_per_million
# Kolhapur daily_tests_per_million
# Kolhapur daily_tests_ma
# Kolhapur daily_deceased_ma
# Kolhapur cfr1_point
# Kolhapur cfr2_point
# Kolhapur cfr3_point
# Kolhapur cfr3_l95
# Kolhapur cfr3_u95
# Kolhapur cfr3_l50
# Kolhapur cfr3_u50
# Kolhapur dbt_point
# Kolhapur dbt_l95
# Kolhapur dbt_u95
# Kolhapur rt_point
# Kolhapur rt_sd
# Kolhapur rt_l95
# Kolhapur rt_u95
# Kolhapur rt_l50
# Kolhapur rt_u50
# Kolhapur t_end
# Mumbai dates
# Mumbai cum_positive_cases
# Mumbai cum_positivity_rate
# Mumbai daily_positive_cases
# Mumbai cum_recovered
# Mumbai daily_recovered
# Mumbai cum_deceased
# Mumbai daily_deceased
# Mumbai daily_positivity_rate
# Mumbai daily_positive_cases_ma
# Mumbai daily_positivity_rate_ma
# Mumbai daily_tests
# Mumbai cum_tests
# Mumbai test_per_million
# Mumbai daily_cases_per_million
# Mumbai daily_tests_per_million
# Mumbai daily_tests_ma
# Mumbai daily_deceased_ma
# Mumbai cfr1_point
# Mumbai cfr2_point
# Mumbai cfr3_point
# Mumbai cfr3_l95
# Mumbai cfr3_u95
# Mumbai cfr3_l50
# Mumbai cfr3_u50
# Mumbai dbt_point
# Mumbai dbt_l95
# Mumbai dbt_u95
# Mumbai rt_point
# Mumbai rt_sd
# Mumbai rt_l95
# Mumbai rt_u95
# Mumbai rt_l50
# Mumbai rt_u50
# Mumbai t_end
# Nagpur dates
# Nagpur cum_positive_cases
# Nagpur cum_positivity_rate
# Nagpur daily_positive_cases
# Nagpur cum_recovered
# Nagpur daily_recovered
# Nagpur cum_deceased
# Nagpur daily_deceased
# Nagpur daily_positivity_rate
# Nagpur daily_positive_cases_ma
# Nagpur daily_positivity_rate_ma
# Nagpur daily_tests
# Nagpur cum_tests
# Nagpur test_per_million
# Nagpur daily_cases_per_million
# Nagpur daily_tests_per_million
# Nagpur daily_tests_ma
# Nagpur daily_deceased_ma
# Nagpur cfr1_point
# Nagpur cfr2_point
# Nagpur cfr3_point
# Nagpur cfr3_l95
# Nagpur cfr3_u95
# Nagpur cfr3_l50
# Nagpur cfr3_u50
# Nagpur dbt_point
# Nagpur dbt_l95
# Nagpur dbt_u95
# Nagpur rt_point
# Nagpur rt_sd
# Nagpur rt_l95
# Nagpur rt_u95
# Nagpur rt_l50
# Nagpur rt_u50
# Nagpur t_end
# Nashik dates
# Nashik cum_positive_cases
# Nashik cum_positivity_rate
# Nashik daily_positive_cases
# Nashik cum_recovered
# Nashik daily_recovered
# Nashik cum_deceased
# Nashik daily_deceased
# Nashik daily_positivity_rate
# Nashik daily_positive_cases_ma
# Nashik daily_positivity_rate_ma
# Nashik daily_tests
# Nashik cum_tests
# Nashik test_per_million
# Nashik daily_cases_per_million
# Nashik daily_tests_per_million
# Nashik daily_tests_ma
# Nashik daily_deceased_ma
# Nashik cfr1_point
# Nashik cfr2_point
# Nashik cfr3_point
# Nashik cfr3_l95
# Nashik cfr3_u95
# Nashik cfr3_l50
# Nashik cfr3_u50
# Nashik dbt_point
# Nashik dbt_l95
# Nashik dbt_u95
# Nashik rt_point
# Nashik rt_sd
# Nashik rt_l95
# Nashik rt_u95
# Nashik rt_l50
# Nashik rt_u50
# Nashik t_end
# Palghar dates
# Palghar cum_positive_cases
# Palghar cum_positivity_rate
# Palghar daily_positive_cases
# Palghar cum_recovered
# Palghar daily_recovered
# Palghar cum_deceased
# Palghar daily_deceased
# Palghar daily_positivity_rate
# Palghar daily_positive_cases_ma
# Palghar daily_positivity_rate_ma
# Palghar daily_tests
# Palghar cum_tests
# Palghar test_per_million
# Palghar daily_cases_per_million
# Palghar daily_tests_per_million
# Palghar daily_tests_ma
# Palghar daily_deceased_ma
# Palghar cfr1_point
# Palghar cfr2_point
# Palghar cfr3_point
# Palghar cfr3_l95
# Palghar cfr3_u95
# Palghar cfr3_l50
# Palghar cfr3_u50
# Palghar dbt_point
# Palghar dbt_l95
# Palghar dbt_u95
# Palghar rt_point
# Palghar rt_sd
# Palghar rt_l95
# Palghar rt_u95
# Palghar rt_l50
# Palghar rt_u50
# Palghar t_end
# Pune dates
# Pune cum_positive_cases
# Pune cum_positivity_rate
# Pune daily_positive_cases
# Pune cum_recovered
# Pune daily_recovered
# Pune cum_deceased
# Pune daily_deceased
# Pune daily_positivity_rate
# Pune daily_positive_cases_ma
# Pune daily_positivity_rate_ma
# Pune daily_tests
# Pune cum_tests
# Pune test_per_million
# Pune daily_cases_per_million
# Pune daily_tests_per_million
# Pune daily_tests_ma
# Pune daily_deceased_ma
# Pune cfr1_point
# Pune cfr2_point
# Pune cfr3_point
# Pune cfr3_l95
# Pune cfr3_u95
# Pune cfr3_l50
# Pune cfr3_u50
# Pune dbt_point
# Pune dbt_l95
# Pune dbt_u95
# Pune rt_point
# Pune rt_sd
# Pune rt_l95
# Pune rt_u95
# Pune rt_l50
# Pune rt_u50
# Pune t_end
# Raigad dates
# Raigad cum_positive_cases
# Raigad cum_positivity_rate
# Raigad daily_positive_cases
# Raigad cum_recovered
# Raigad daily_recovered
# Raigad cum_deceased
# Raigad daily_deceased
# Raigad daily_positivity_rate
# Raigad daily_positive_cases_ma
# Raigad daily_positivity_rate_ma
# Raigad daily_tests
# Raigad cum_tests
# Raigad test_per_million
# Raigad daily_cases_per_million
# Raigad daily_tests_per_million
# Raigad daily_tests_ma
# Raigad daily_deceased_ma
# Raigad cfr1_point
# Raigad cfr2_point
# Raigad cfr3_point
# Raigad cfr3_l95
# Raigad cfr3_u95
# Raigad cfr3_l50
# Raigad cfr3_u50
# Raigad dbt_point
# Raigad dbt_l95
# Raigad dbt_u95
# Raigad rt_point
# Raigad rt_sd
# Raigad rt_l95
# Raigad rt_u95
# Raigad rt_l50
# Raigad rt_u50
# Raigad t_end
# Solapur dates
# Solapur cum_positive_cases
# Solapur cum_positivity_rate
# Solapur daily_positive_cases
# Solapur cum_recovered
# Solapur daily_recovered
# Solapur cum_deceased
# Solapur daily_deceased
# Solapur daily_positivity_rate
# Solapur daily_positive_cases_ma
# Solapur daily_positivity_rate_ma
# Solapur daily_tests
# Solapur cum_tests
# Solapur test_per_million
# Solapur daily_cases_per_million
# Solapur daily_tests_per_million
# Solapur daily_tests_ma
# Solapur daily_deceased_ma
# Solapur cfr1_point
# Solapur cfr2_point
# Solapur cfr3_point
# Solapur cfr3_l95
# Solapur cfr3_u95
# Solapur cfr3_l50
# Solapur cfr3_u50
# Solapur dbt_point
# Solapur dbt_l95
# Solapur dbt_u95
# Solapur rt_point
# Solapur rt_sd
# Solapur rt_l95
# Solapur rt_u95
# Solapur rt_l50
# Solapur rt_u50
# Solapur t_end
# Thane dates
# Thane cum_positive_cases
# Thane cum_positivity_rate
# Thane daily_positive_cases
# Thane cum_recovered
# Thane daily_recovered
# Thane cum_deceased
# Thane daily_deceased
# Thane daily_positivity_rate
# Thane daily_positive_cases_ma
# Thane daily_positivity_rate_ma
# Thane daily_tests
# Thane cum_tests
# Thane test_per_million
# Thane daily_cases_per_million
# Thane daily_tests_per_million
# Thane daily_tests_ma
# Thane daily_deceased_ma
# Thane cfr1_point
# Thane cfr2_point
# Thane cfr3_point
# Thane cfr3_l95
# Thane cfr3_u95
# Thane cfr3_l50
# Thane cfr3_u50
# Thane dbt_point
# Thane dbt_l95
# Thane dbt_u95
# Thane rt_point
# Thane rt_sd
# Thane rt_l95
# Thane rt_u95
# Thane rt_l50
# Thane rt_u50
# Thane t_end
# Bhopal dates
# Bhopal cum_positive_cases
# Bhopal cum_positivity_rate
# Bhopal daily_positive_cases
# Bhopal cum_recovered
# Bhopal daily_recovered
# Bhopal cum_deceased
# Bhopal daily_deceased
# Bhopal daily_positivity_rate
# Bhopal daily_positive_cases_ma
# Bhopal daily_positivity_rate_ma
# Bhopal daily_tests
# Bhopal cum_tests
# Bhopal test_per_million
# Bhopal daily_cases_per_million
# Bhopal daily_tests_per_million
# Bhopal daily_tests_ma
# Bhopal daily_deceased_ma
# Bhopal cfr1_point
# Bhopal cfr2_point
# Bhopal cfr3_point
# Bhopal cfr3_l95
# Bhopal cfr3_u95
# Bhopal cfr3_l50
# Bhopal cfr3_u50
# Bhopal dbt_point
# Bhopal dbt_l95
# Bhopal dbt_u95
# Bhopal rt_point
# Bhopal rt_sd
# Bhopal rt_l95
# Bhopal rt_u95
# Bhopal rt_l50
# Bhopal rt_u50
# Bhopal t_end
# Indore dates
# Indore cum_positive_cases
# Indore cum_positivity_rate
# Indore daily_positive_cases
# Indore cum_recovered
# Indore daily_recovered
# Indore cum_deceased
# Indore daily_deceased
# Indore daily_positivity_rate
# Indore daily_positive_cases_ma
# Indore daily_positivity_rate_ma
# Indore daily_tests
# Indore cum_tests
# Indore test_per_million
# Indore daily_cases_per_million
# Indore daily_tests_per_million
# Indore daily_tests_ma
# Indore daily_deceased_ma
# Indore cfr1_point
# Indore cfr2_point
# Indore cfr3_point
# Indore cfr3_l95
# Indore cfr3_u95
# Indore cfr3_l50
# Indore cfr3_u50
# Indore dbt_point
# Indore dbt_l95
# Indore dbt_u95
# Indore rt_point
# Indore rt_sd
# Indore rt_l95
# Indore rt_u95
# Indore rt_l50
# Indore rt_u50
# Indore t_end
# Ganjam dates
# Ganjam cum_positive_cases
# Ganjam cum_positivity_rate
# Ganjam daily_positive_cases
# Ganjam cum_recovered
# Ganjam daily_recovered
# Ganjam cum_deceased
# Ganjam daily_deceased
# Ganjam daily_positivity_rate
# Ganjam daily_positive_cases_ma
# Ganjam daily_positivity_rate_ma
# Ganjam daily_tests
# Ganjam cum_tests
# Ganjam test_per_million
# Ganjam daily_cases_per_million
# Ganjam daily_tests_per_million
# Ganjam daily_tests_ma
# Ganjam daily_deceased_ma
# Ganjam cfr1_point
# Ganjam cfr2_point
# Ganjam cfr3_point
# Ganjam cfr3_l95
# Ganjam cfr3_u95
# Ganjam cfr3_l50
# Ganjam cfr3_u50
# Ganjam dbt_point
# Ganjam dbt_l95
# Ganjam dbt_u95
# Ganjam rt_point
# Ganjam rt_sd
# Ganjam rt_l95
# Ganjam rt_u95
# Ganjam rt_l50
# Ganjam rt_u50
# Ganjam t_end
# Ludhiana dates
# Ludhiana cum_positive_cases
# Ludhiana cum_positivity_rate
# Ludhiana daily_positive_cases
# Ludhiana cum_recovered
# Ludhiana daily_recovered
# Ludhiana cum_deceased
# Ludhiana daily_deceased
# Ludhiana daily_positivity_rate
# Ludhiana daily_positive_cases_ma
# Ludhiana daily_positivity_rate_ma
# Ludhiana daily_tests
# Ludhiana cum_tests
# Ludhiana test_per_million
# Ludhiana daily_cases_per_million
# Ludhiana daily_tests_per_million
# Ludhiana daily_tests_ma
# Ludhiana daily_deceased_ma
# Ludhiana cfr1_point
# Ludhiana cfr2_point
# Ludhiana cfr3_point
# Ludhiana cfr3_l95
# Ludhiana cfr3_u95
# Ludhiana cfr3_l50
# Ludhiana cfr3_u50
# Ludhiana dbt_point
# Ludhiana dbt_l95
# Ludhiana dbt_u95
# Ludhiana rt_point
# Ludhiana rt_sd
# Ludhiana rt_l95
# Ludhiana rt_u95
# Ludhiana rt_l50
# Ludhiana rt_u50
# Ludhiana t_end
# Hyderabad dates
# Hyderabad cum_positive_cases
# Hyderabad cum_positivity_rate
# Hyderabad daily_positive_cases
# Hyderabad cum_recovered
# Hyderabad daily_recovered
# Hyderabad cum_deceased
# Hyderabad daily_deceased
# Hyderabad daily_positivity_rate
# Hyderabad daily_positive_cases_ma
# Hyderabad daily_positivity_rate_ma
# Hyderabad daily_tests
# Hyderabad cum_tests
# Hyderabad test_per_million
# Hyderabad daily_cases_per_million
# Hyderabad daily_tests_per_million
# Hyderabad daily_tests_ma
# Hyderabad daily_deceased_ma
# Hyderabad cfr1_point
# Hyderabad cfr2_point
# Hyderabad cfr3_point
# Hyderabad cfr3_l95
# Hyderabad cfr3_u95
# Hyderabad cfr3_l50
# Hyderabad cfr3_u50
# Hyderabad dbt_point
# Hyderabad dbt_l95
# Hyderabad dbt_u95
# Hyderabad rt_point
# Hyderabad rt_sd
# Hyderabad rt_l95
# Hyderabad rt_u95
# Hyderabad rt_l50
# Hyderabad rt_u50
# Hyderabad t_end
# Medchal Malkajgiri dates
# Medchal Malkajgiri cum_positive_cases
# Medchal Malkajgiri cum_positivity_rate
# Medchal Malkajgiri daily_positive_cases
# Medchal Malkajgiri cum_recovered
# Medchal Malkajgiri daily_recovered
# Medchal Malkajgiri cum_deceased
# Medchal Malkajgiri daily_deceased
# Medchal Malkajgiri daily_positivity_rate
# Medchal Malkajgiri daily_positive_cases_ma
# Medchal Malkajgiri daily_positivity_rate_ma
# Medchal Malkajgiri daily_tests
# Medchal Malkajgiri cum_tests
# Medchal Malkajgiri test_per_million
# Medchal Malkajgiri daily_cases_per_million
# Medchal Malkajgiri daily_tests_per_million
# Medchal Malkajgiri daily_tests_ma
# Medchal Malkajgiri daily_deceased_ma
# Medchal Malkajgiri cfr1_point
# Medchal Malkajgiri cfr2_point
# Medchal Malkajgiri cfr3_point
# Medchal Malkajgiri cfr3_l95
# Medchal Malkajgiri cfr3_u95
# Medchal Malkajgiri cfr3_l50
# Medchal Malkajgiri cfr3_u50
# Medchal Malkajgiri dbt_point
# Medchal Malkajgiri dbt_l95
# Medchal Malkajgiri dbt_u95
# Medchal Malkajgiri rt_point
# Medchal Malkajgiri rt_sd
# Medchal Malkajgiri rt_l95
# Medchal Malkajgiri rt_u95
# Medchal Malkajgiri rt_l50
# Medchal Malkajgiri rt_u50
# Medchal Malkajgiri t_end
# Ranga Reddy dates
# Ranga Reddy cum_positive_cases
# Ranga Reddy cum_positivity_rate
# Ranga Reddy daily_positive_cases
# Ranga Reddy cum_recovered
# Ranga Reddy daily_recovered
# Ranga Reddy cum_deceased
# Ranga Reddy daily_deceased
# Ranga Reddy daily_positivity_rate
# Ranga Reddy daily_positive_cases_ma
# Ranga Reddy daily_positivity_rate_ma
# Ranga Reddy daily_tests
# Ranga Reddy cum_tests
# Ranga Reddy test_per_million
# Ranga Reddy daily_cases_per_million
# Ranga Reddy daily_tests_per_million
# Ranga Reddy daily_tests_ma
# Ranga Reddy daily_deceased_ma
# Ranga Reddy cfr1_point
# Ranga Reddy cfr2_point
# Ranga Reddy cfr3_point
# Ranga Reddy cfr3_l95
# Ranga Reddy cfr3_u95
# Ranga Reddy cfr3_l50
# Ranga Reddy cfr3_u50
# Ranga Reddy dbt_point
# Ranga Reddy dbt_l95
# Ranga Reddy dbt_u95
# Ranga Reddy rt_point
# Ranga Reddy rt_sd
# Ranga Reddy rt_l95
# Ranga Reddy rt_u95
# Ranga Reddy rt_l50
# Ranga Reddy rt_u50
# Ranga Reddy t_end
# Chengalpattu dates
# Chengalpattu cum_positive_cases
# Chengalpattu cum_positivity_rate
# Chengalpattu daily_positive_cases
# Chengalpattu cum_recovered
# Chengalpattu daily_recovered
# Chengalpattu cum_deceased
# Chengalpattu daily_deceased
# Chengalpattu daily_positivity_rate
# Chengalpattu daily_positive_cases_ma
# Chengalpattu daily_positivity_rate_ma
# Chengalpattu daily_tests
# Chengalpattu cum_tests
# Chengalpattu test_per_million
# Chengalpattu daily_cases_per_million
# Chengalpattu daily_tests_per_million
# Chengalpattu daily_tests_ma
# Chengalpattu daily_deceased_ma
# Chengalpattu cfr1_point
# Chengalpattu cfr2_point
# Chengalpattu cfr3_point
# Chengalpattu cfr3_l95
# Chengalpattu cfr3_u95
# Chengalpattu cfr3_l50
# Chengalpattu cfr3_u50
# Chengalpattu dbt_point
# Chengalpattu dbt_l95
# Chengalpattu dbt_u95
# Chengalpattu rt_point
# Chengalpattu rt_sd
# Chengalpattu rt_l95
# Chengalpattu rt_u95
# Chengalpattu rt_l50
# Chengalpattu rt_u50
# Chengalpattu t_end
# Chennai dates
# Chennai cum_positive_cases
# Chennai cum_positivity_rate
# Chennai daily_positive_cases
# Chennai cum_recovered
# Chennai daily_recovered
# Chennai cum_deceased
# Chennai daily_deceased
# Chennai daily_positivity_rate
# Chennai daily_positive_cases_ma
# Chennai daily_positivity_rate_ma
# Chennai daily_tests
# Chennai cum_tests
# Chennai test_per_million
# Chennai daily_cases_per_million
# Chennai daily_tests_per_million
# Chennai daily_tests_ma
# Chennai daily_deceased_ma
# Chennai cfr1_point
# Chennai cfr2_point
# Chennai cfr3_point
# Chennai cfr3_l95
# Chennai cfr3_u95
# Chennai cfr3_l50
# Chennai cfr3_u50
# Chennai dbt_point
# Chennai dbt_l95
# Chennai dbt_u95
# Chennai rt_point
# Chennai rt_sd
# Chennai rt_l95
# Chennai rt_u95
# Chennai rt_l50
# Chennai rt_u50
# Chennai t_end
# Kancheepuram dates
# Kancheepuram cum_positive_cases
# Kancheepuram cum_positivity_rate
# Kancheepuram daily_positive_cases
# Kancheepuram cum_recovered
# Kancheepuram daily_recovered
# Kancheepuram cum_deceased
# Kancheepuram daily_deceased
# Kancheepuram daily_positivity_rate
# Kancheepuram daily_positive_cases_ma
# Kancheepuram daily_positivity_rate_ma
# Kancheepuram daily_tests
# Kancheepuram cum_tests
# Kancheepuram test_per_million
# Kancheepuram daily_cases_per_million
# Kancheepuram daily_tests_per_million
# Kancheepuram daily_tests_ma
# Kancheepuram daily_deceased_ma
# Kancheepuram cfr1_point
# Kancheepuram cfr2_point
# Kancheepuram cfr3_point
# Kancheepuram cfr3_l95
# Kancheepuram cfr3_u95
# Kancheepuram cfr3_l50
# Kancheepuram cfr3_u50
# Kancheepuram dbt_point
# Kancheepuram dbt_l95
# Kancheepuram dbt_u95
# Kancheepuram rt_point
# Kancheepuram rt_sd
# Kancheepuram rt_l95
# Kancheepuram rt_u95
# Kancheepuram rt_l50
# Kancheepuram rt_u50
# Kancheepuram t_end
# Madurai dates
# Madurai cum_positive_cases
# Madurai cum_positivity_rate
# Madurai daily_positive_cases
# Madurai cum_recovered
# Madurai daily_recovered
# Madurai cum_deceased
# Madurai daily_deceased
# Madurai daily_positivity_rate
# Madurai daily_positive_cases_ma
# Madurai daily_positivity_rate_ma
# Madurai daily_tests
# Madurai cum_tests
# Madurai test_per_million
# Madurai daily_cases_per_million
# Madurai daily_tests_per_million
# Madurai daily_tests_ma
# Madurai daily_deceased_ma
# Madurai cfr1_point
# Madurai cfr2_point
# Madurai cfr3_point
# Madurai cfr3_l95
# Madurai cfr3_u95
# Madurai cfr3_l50
# Madurai cfr3_u50
# Madurai dbt_point
# Madurai dbt_l95
# Madurai dbt_u95
# Madurai rt_point
# Madurai rt_sd
# Madurai rt_l95
# Madurai rt_u95
# Madurai rt_l50
# Madurai rt_u50
# Madurai t_end
# Thiruvallur dates
# Thiruvallur cum_positive_cases
# Thiruvallur cum_positivity_rate
# Thiruvallur daily_positive_cases
# Thiruvallur cum_recovered
# Thiruvallur daily_recovered
# Thiruvallur cum_deceased
# Thiruvallur daily_deceased
# Thiruvallur daily_positivity_rate
# Thiruvallur daily_positive_cases_ma
# Thiruvallur daily_positivity_rate_ma
# Thiruvallur daily_tests
# Thiruvallur cum_tests
# Thiruvallur test_per_million
# Thiruvallur daily_cases_per_million
# Thiruvallur daily_tests_per_million
# Thiruvallur daily_tests_ma
# Thiruvallur daily_deceased_ma
# Thiruvallur cfr1_point
# Thiruvallur cfr2_point
# Thiruvallur cfr3_point
# Thiruvallur cfr3_l95
# Thiruvallur cfr3_u95
# Thiruvallur cfr3_l50
# Thiruvallur cfr3_u50
# Thiruvallur dbt_point
# Thiruvallur dbt_l95
# Thiruvallur dbt_u95
# Thiruvallur rt_point
# Thiruvallur rt_sd
# Thiruvallur rt_l95
# Thiruvallur rt_u95
# Thiruvallur rt_l50
# Thiruvallur rt_u50
# Thiruvallur t_end
# Tiruvannamalai dates
# Tiruvannamalai cum_positive_cases
# Tiruvannamalai cum_positivity_rate
# Tiruvannamalai daily_positive_cases
# Tiruvannamalai cum_recovered
# Tiruvannamalai daily_recovered
# Tiruvannamalai cum_deceased
# Tiruvannamalai daily_deceased
# Tiruvannamalai daily_positivity_rate
# Tiruvannamalai daily_positive_cases_ma
# Tiruvannamalai daily_positivity_rate_ma
# Tiruvannamalai daily_tests
# Tiruvannamalai cum_tests
# Tiruvannamalai test_per_million
# Tiruvannamalai daily_cases_per_million
# Tiruvannamalai daily_tests_per_million
# Tiruvannamalai daily_tests_ma
# Tiruvannamalai daily_deceased_ma
# Tiruvannamalai cfr1_point
# Tiruvannamalai cfr2_point
# Tiruvannamalai cfr3_point
# Tiruvannamalai cfr3_l95
# Tiruvannamalai cfr3_u95
# Tiruvannamalai cfr3_l50
# Tiruvannamalai cfr3_u50
# Tiruvannamalai dbt_point
# Tiruvannamalai dbt_l95
# Tiruvannamalai dbt_u95
# Tiruvannamalai rt_point
# Tiruvannamalai rt_sd
# Tiruvannamalai rt_l95
# Tiruvannamalai rt_u95
# Tiruvannamalai rt_l50
# Tiruvannamalai rt_u50
# Tiruvannamalai t_end
# Vellore dates
# Vellore cum_positive_cases
# Vellore cum_positivity_rate
# Vellore daily_positive_cases
# Vellore cum_recovered
# Vellore daily_recovered
# Vellore cum_deceased
# Vellore daily_deceased
# Vellore daily_positivity_rate
# Vellore daily_positive_cases_ma
# Vellore daily_positivity_rate_ma
# Vellore daily_tests
# Vellore cum_tests
# Vellore test_per_million
# Vellore daily_cases_per_million
# Vellore daily_tests_per_million
# Vellore daily_tests_ma
# Vellore daily_deceased_ma
# Vellore cfr1_point
# Vellore cfr2_point
# Vellore cfr3_point
# Vellore cfr3_l95
# Vellore cfr3_u95
# Vellore cfr3_l50
# Vellore cfr3_u50
# Vellore dbt_point
# Vellore dbt_l95
# Vellore dbt_u95
# Vellore rt_point
# Vellore rt_sd
# Vellore rt_l95
# Vellore rt_u95
# Vellore rt_l50
# Vellore rt_u50
# Vellore t_end
# Aligarh dates
# Aligarh cum_positive_cases
# Aligarh cum_positivity_rate
# Aligarh daily_positive_cases
# Aligarh cum_recovered
# Aligarh daily_recovered
# Aligarh cum_deceased
# Aligarh daily_deceased
# Aligarh daily_positivity_rate
# Aligarh daily_positive_cases_ma
# Aligarh daily_positivity_rate_ma
# Aligarh daily_tests
# Aligarh cum_tests
# Aligarh test_per_million
# Aligarh daily_cases_per_million
# Aligarh daily_tests_per_million
# Aligarh daily_tests_ma
# Aligarh daily_deceased_ma
# Aligarh cfr1_point
# Aligarh cfr2_point
# Aligarh cfr3_point
# Aligarh cfr3_l95
# Aligarh cfr3_u95
# Aligarh cfr3_l50
# Aligarh cfr3_u50
# Aligarh dbt_point
# Aligarh dbt_l95
# Aligarh dbt_u95
# Aligarh rt_point
# Aligarh rt_sd
# Aligarh rt_l95
# Aligarh rt_u95
# Aligarh rt_l50
# Aligarh rt_u50
# Aligarh t_end
# Bareilly dates
# Bareilly cum_positive_cases
# Bareilly cum_positivity_rate
# Bareilly daily_positive_cases
# Bareilly cum_recovered
# Bareilly daily_recovered
# Bareilly cum_deceased
# Bareilly daily_deceased
# Bareilly daily_positivity_rate
# Bareilly daily_positive_cases_ma
# Bareilly daily_positivity_rate_ma
# Bareilly daily_tests
# Bareilly cum_tests
# Bareilly test_per_million
# Bareilly daily_cases_per_million
# Bareilly daily_tests_per_million
# Bareilly daily_tests_ma
# Bareilly daily_deceased_ma
# Bareilly cfr1_point
# Bareilly cfr2_point
# Bareilly cfr3_point
# Bareilly cfr3_l95
# Bareilly cfr3_u95
# Bareilly cfr3_l50
# Bareilly cfr3_u50
# Bareilly dbt_point
# Bareilly dbt_l95
# Bareilly dbt_u95
# Bareilly rt_point
# Bareilly rt_sd
# Bareilly rt_l95
# Bareilly rt_u95
# Bareilly rt_l50
# Bareilly rt_u50
# Bareilly t_end
# Gautam Buddha Nagar dates
# Gautam Buddha Nagar cum_positive_cases
# Gautam Buddha Nagar cum_positivity_rate
# Gautam Buddha Nagar daily_positive_cases
# Gautam Buddha Nagar cum_recovered
# Gautam Buddha Nagar daily_recovered
# Gautam Buddha Nagar cum_deceased
# Gautam Buddha Nagar daily_deceased
# Gautam Buddha Nagar daily_positivity_rate
# Gautam Buddha Nagar daily_positive_cases_ma
# Gautam Buddha Nagar daily_positivity_rate_ma
# Gautam Buddha Nagar daily_tests
# Gautam Buddha Nagar cum_tests
# Gautam Buddha Nagar test_per_million
# Gautam Buddha Nagar daily_cases_per_million
# Gautam Buddha Nagar daily_tests_per_million
# Gautam Buddha Nagar daily_tests_ma
# Gautam Buddha Nagar daily_deceased_ma
# Gautam Buddha Nagar cfr1_point
# Gautam Buddha Nagar cfr2_point
# Gautam Buddha Nagar cfr3_point
# Gautam Buddha Nagar cfr3_l95
# Gautam Buddha Nagar cfr3_u95
# Gautam Buddha Nagar cfr3_l50
# Gautam Buddha Nagar cfr3_u50
# Gautam Buddha Nagar dbt_point
# Gautam Buddha Nagar dbt_l95
# Gautam Buddha Nagar dbt_u95
# Gautam Buddha Nagar rt_point
# Gautam Buddha Nagar rt_sd
# Gautam Buddha Nagar rt_l95
# Gautam Buddha Nagar rt_u95
# Gautam Buddha Nagar rt_l50
# Gautam Buddha Nagar rt_u50
# Gautam Buddha Nagar t_end
# Ghaziabad dates
# Ghaziabad cum_positive_cases
# Ghaziabad cum_positivity_rate
# Ghaziabad daily_positive_cases
# Ghaziabad cum_recovered
# Ghaziabad daily_recovered
# Ghaziabad cum_deceased
# Ghaziabad daily_deceased
# Ghaziabad daily_positivity_rate
# Ghaziabad daily_positive_cases_ma
# Ghaziabad daily_positivity_rate_ma
# Ghaziabad daily_tests
# Ghaziabad cum_tests
# Ghaziabad test_per_million
# Ghaziabad daily_cases_per_million
# Ghaziabad daily_tests_per_million
# Ghaziabad daily_tests_ma
# Ghaziabad daily_deceased_ma
# Ghaziabad cfr1_point
# Ghaziabad cfr2_point
# Ghaziabad cfr3_point
# Ghaziabad cfr3_l95
# Ghaziabad cfr3_u95
# Ghaziabad cfr3_l50
# Ghaziabad cfr3_u50
# Ghaziabad dbt_point
# Ghaziabad dbt_l95
# Ghaziabad dbt_u95
# Ghaziabad rt_point
# Ghaziabad rt_sd
# Ghaziabad rt_l95
# Ghaziabad rt_u95
# Ghaziabad rt_l50
# Ghaziabad rt_u50
# Ghaziabad t_end
# Kanpur Nagar dates
# Kanpur Nagar cum_positive_cases
# Kanpur Nagar cum_positivity_rate
# Kanpur Nagar daily_positive_cases
# Kanpur Nagar cum_recovered
# Kanpur Nagar daily_recovered
# Kanpur Nagar cum_deceased
# Kanpur Nagar daily_deceased
# Kanpur Nagar daily_positivity_rate
# Kanpur Nagar daily_positive_cases_ma
# Kanpur Nagar daily_positivity_rate_ma
# Kanpur Nagar daily_tests
# Kanpur Nagar cum_tests
# Kanpur Nagar test_per_million
# Kanpur Nagar daily_cases_per_million
# Kanpur Nagar daily_tests_per_million
# Kanpur Nagar daily_tests_ma
# Kanpur Nagar daily_deceased_ma
# Kanpur Nagar cfr1_point
# Kanpur Nagar cfr2_point
# Kanpur Nagar cfr3_point
# Kanpur Nagar cfr3_l95
# Kanpur Nagar cfr3_u95
# Kanpur Nagar cfr3_l50
# Kanpur Nagar cfr3_u50
# Kanpur Nagar dbt_point
# Kanpur Nagar dbt_l95
# Kanpur Nagar dbt_u95
# Kanpur Nagar rt_point
# Kanpur Nagar rt_sd
# Kanpur Nagar rt_l95
# Kanpur Nagar rt_u95
# Kanpur Nagar rt_l50
# Kanpur Nagar rt_u50
# Kanpur Nagar t_end
# Lucknow dates
# Lucknow cum_positive_cases
# Lucknow cum_positivity_rate
# Lucknow daily_positive_cases
# Lucknow cum_recovered
# Lucknow daily_recovered
# Lucknow cum_deceased
# Lucknow daily_deceased
# Lucknow daily_positivity_rate
# Lucknow daily_positive_cases_ma
# Lucknow daily_positivity_rate_ma
# Lucknow daily_tests
# Lucknow cum_tests
# Lucknow test_per_million
# Lucknow daily_cases_per_million
# Lucknow daily_tests_per_million
# Lucknow daily_tests_ma
# Lucknow daily_deceased_ma
# Lucknow cfr1_point
# Lucknow cfr2_point
# Lucknow cfr3_point
# Lucknow cfr3_l95
# Lucknow cfr3_u95
# Lucknow cfr3_l50
# Lucknow cfr3_u50
# Lucknow dbt_point
# Lucknow dbt_l95
# Lucknow dbt_u95
# Lucknow rt_point
# Lucknow rt_sd
# Lucknow rt_l95
# Lucknow rt_u95
# Lucknow rt_l50
# Lucknow rt_u50
# Lucknow t_end
# Varanasi dates
# Varanasi cum_positive_cases
# Varanasi cum_positivity_rate
# Varanasi daily_positive_cases
# Varanasi cum_recovered
# Varanasi daily_recovered
# Varanasi cum_deceased
# Varanasi daily_deceased
# Varanasi daily_positivity_rate
# Varanasi daily_positive_cases_ma
# Varanasi daily_positivity_rate_ma
# Varanasi daily_tests
# Varanasi cum_tests
# Varanasi test_per_million
# Varanasi daily_cases_per_million
# Varanasi daily_tests_per_million
# Varanasi daily_tests_ma
# Varanasi daily_deceased_ma
# Varanasi cfr1_point
# Varanasi cfr2_point
# Varanasi cfr3_point
# Varanasi cfr3_l95
# Varanasi cfr3_u95
# Varanasi cfr3_l50
# Varanasi cfr3_u50
# Varanasi dbt_point
# Varanasi dbt_l95
# Varanasi dbt_u95
# Varanasi rt_point
# Varanasi rt_sd
# Varanasi rt_l95
# Varanasi rt_u95
# Varanasi rt_l50
# Varanasi rt_u50
# Varanasi t_end
# Kolkata dates
# Kolkata cum_positive_cases
# Kolkata cum_positivity_rate
# Kolkata daily_positive_cases
# Kolkata cum_recovered
# Kolkata daily_recovered
# Kolkata cum_deceased
# Kolkata daily_deceased
# Kolkata daily_positivity_rate
# Kolkata daily_positive_cases_ma
# Kolkata daily_positivity_rate_ma
# Kolkata daily_tests
# Kolkata cum_tests
# Kolkata test_per_million
# Kolkata daily_cases_per_million
# Kolkata daily_tests_per_million
# Kolkata daily_tests_ma
# Kolkata daily_deceased_ma
# Kolkata cfr1_point
# Kolkata cfr2_point
# Kolkata cfr3_point
# Kolkata cfr3_l95
# Kolkata cfr3_u95
# Kolkata cfr3_l50
# Kolkata cfr3_u50
# Kolkata dbt_point
# Kolkata dbt_l95
# Kolkata dbt_u95
# Kolkata rt_point
# Kolkata rt_sd
# Kolkata rt_l95
# Kolkata rt_u95
# Kolkata rt_l50
# Kolkata rt_u50
# Kolkata t_end
# North 24 Parganas dates
# North 24 Parganas cum_positive_cases
# North 24 Parganas cum_positivity_rate
# North 24 Parganas daily_positive_cases
# North 24 Parganas cum_recovered
# North 24 Parganas daily_recovered
# North 24 Parganas cum_deceased
# North 24 Parganas daily_deceased
# North 24 Parganas daily_positivity_rate
# North 24 Parganas daily_positive_cases_ma
# North 24 Parganas daily_positivity_rate_ma
# North 24 Parganas daily_tests
# North 24 Parganas cum_tests
# North 24 Parganas test_per_million
# North 24 Parganas daily_cases_per_million
# North 24 Parganas daily_tests_per_million
# North 24 Parganas daily_tests_ma
# North 24 Parganas daily_deceased_ma
# North 24 Parganas cfr1_point
# North 24 Parganas cfr2_point
# North 24 Parganas cfr3_point
# North 24 Parganas cfr3_l95
# North 24 Parganas cfr3_u95
# North 24 Parganas cfr3_l50
# North 24 Parganas cfr3_u50
# North 24 Parganas dbt_point
# North 24 Parganas dbt_l95
# North 24 Parganas dbt_u95
# North 24 Parganas rt_point
# North 24 Parganas rt_sd
# North 24 Parganas rt_l95
# North 24 Parganas rt_u95
# North 24 Parganas rt_l50
# North 24 Parganas rt_u50
# North 24 Parganas t_end

# %%
complete[complete['state']=='Ahmedabad']
# Out:
#          state       dates cum_positive_cases cum_positivity_rate  \
# 0    Ahmedabad  2020-01-30
# 1    Ahmedabad  2020-01-31
# 2    Ahmedabad  2020-02-01
# 3    Ahmedabad  2020-02-02
# 4    Ahmedabad  2020-02-03
# ..         ...         ...                ...                 ...
# 203  Ahmedabad  2020-08-20              29662             5.40128
# 204  Ahmedabad  2020-08-21              29841             5.25797
# 205  Ahmedabad  2020-08-22              30020             5.09773
# 206  Ahmedabad  2020-08-23              30197              5.0007
# 207  Ahmedabad  2020-08-24              30362              4.8748
#
#     daily_positive_cases cum_recovered daily_recovered cum_deceased  \
# 0
# 1
# 2
# 3
# 4
# ..                   ...           ...             ...          ...
# 203                  172         24589             167         1674
# 204                  179         24756             167         1677
# 205                  179         24932             176         1680
# 206                  177         25104             172         1685
# 207                  165         25268             164         1688
#
#     daily_deceased daily_positivity_rate  ... dbt_point  dbt_l95  dbt_u95  \
# 0                                         ...
# 1                                         ...
# 2                                         ...
# 3                                         ...
# 4                                         ...
# ..             ...                   ...  ...       ...      ...      ...
# 203              4              0.789969  ...   124.003  121.742  126.264
# 204              3              0.974309  ...   123.673  120.545  126.802
# 205              3              0.838329  ...   122.482  116.931  128.033
# 206              5               1.18268  ...   120.879  114.099  127.659
# 207              3              0.869336  ...   119.062  113.644  124.481
#
#     rt_point    rt_sd    rt_l95   rt_u95   rt_l50   rt_u50  t_end
# 0    2.60123  2.00426  0.210298  7.79594  6.48085  6.48085      8
# 1    2.61414  2.02938  0.245801  7.80682  6.61716  6.61716      9
# 2    2.59845  1.97022  0.246894  7.67477   6.4844   6.4844     10
# 3    2.59727  1.99294  0.228588  7.76563   6.5568   6.5568     11
# 4    2.63489  2.01855  0.247104  7.71694   6.6253   6.6253     12
# ..       ...      ...       ...      ...      ...      ...    ...
# 203
# 204
# 205
# 206
# 207
#
# [208 rows x 36 columns]

# %%
complete.to_csv('complete_districts.csv',index=False)

# %%
complete_shifted.to_csv('allmetrics_districts.csv',index=False)

# %%
states_indented = json.dumps(states, indent = 4)
with open("covidtoday_dist.json", "w") as outfile: 
    outfile.write(states_indented)

# %%
states_indented = json.dumps(states_shifted, indent = 4)
with open("allmetrics_districts.json", "w") as outfile: 
    outfile.write(states_indented)

# %%
# Out:
# ['2020-02-06',
#  '2020-02-07',
#  '2020-02-08',
#  '2020-02-09',
#  '2020-02-10',
#  '2020-02-11',
#  '2020-02-12',
#  '2020-02-13',
#  '2020-02-14',
#  '2020-02-15',
#  '2020-02-16',
#  '2020-02-17',
#  '2020-02-18',
#  '2020-02-19',
#  '2020-02-20',
#  '2020-02-21',
#  '2020-02-22',
#  '2020-02-23',
#  '2020-02-24',
#  '2020-02-25',
#  '2020-02-26',
#  '2020-02-27',
#  '2020-02-28',
#  '2020-02-29',
#  '2020-03-01',
#  '2020-03-02',
#  '2020-03-03',
#  '2020-03-04',
#  '2020-03-05',
#  '2020-03-06',
#  '2020-03-07',
#  '2020-03-08',
#  '2020-03-09',
#  '2020-03-10',
#  '2020-03-11',
#  '2020-03-12',
#  '2020-03-13',
#  '2020-03-14',
#  '2020-03-15',
#  '2020-03-16',
#  '2020-03-17',
#  '2020-03-18',
#  '2020-03-19',
#  '2020-03-20',
#  '2020-03-21',
#  '2020-03-22',
#  '2020-03-23',
#  '2020-03-24',
#  '2020-03-25',
#  '2020-03-26',
#  '2020-03-27',
#  '2020-03-28',
#  '2020-03-29',
#  '2020-03-30',
#  '2020-03-31',
#  '2020-04-01',
#  '2020-04-02',
#  '2020-04-03',
#  '2020-04-04',
#  '2020-04-05',
#  '2020-04-06',
#  '2020-04-07',
#  '2020-04-08',
#  '2020-04-09',
#  '2020-04-10',
#  '2020-04-11',
#  '2020-04-12',
#  '2020-04-13',
#  '2020-04-14',
#  '2020-04-15',
#  '2020-04-16',
#  '2020-04-17',
#  '2020-04-18',
#  '2020-04-19',
#  '2020-04-20',
#  '2020-04-21',
#  '2020-04-22',
#  '2020-04-23',
#  '2020-04-24',
#  '2020-04-25',
#  '2020-04-26',
#  '2020-04-27',
#  '2020-04-28',
#  '2020-04-29',
#  '2020-04-30',
#  '2020-05-01',
#  '2020-05-02',
#  '2020-05-03',
#  '2020-05-04',
#  '2020-05-05',
#  '2020-05-06',
#  '2020-05-07',
#  '2020-05-08',
#  '2020-05-09',
#  '2020-05-10',
#  '2020-05-11',
#  '2020-05-12',
#  '2020-05-13',
#  '2020-05-14',
#  '2020-05-15',
#  '2020-05-16',
#  '2020-05-17',
#  '2020-05-18',
#  '2020-05-19',
#  '2020-05-20',
#  '2020-05-21',
#  '2020-05-22',
#  '2020-05-23',
#  '2020-05-24',
#  '2020-05-25',
#  '2020-05-26',
#  '2020-05-27',
#  '2020-05-28',
#  '2020-05-29',
#  '2020-05-30',
#  '2020-05-31',
#  '2020-06-01',
#  '2020-06-02',
#  '2020-06-03',
#  '2020-06-04',
#  '2020-06-05',
#  '2020-06-06',
#  '2020-06-07',
#  '2020-06-08',
#  '2020-06-09',
#  '2020-06-10',
#  '2020-06-11',
#  '2020-06-12',
#  '2020-06-13',
#  '2020-06-14',
#  '2020-06-15',
#  '2020-06-16',
#  '2020-06-17',
#  '2020-06-18',
#  '2020-06-19',
#  '2020-06-20',
#  '2020-06-21',
#  '2020-06-22',
#  '2020-06-23',
#  '2020-06-24',
#  '2020-06-25',
#  '2020-06-26',
#  '2020-06-27',
#  '2020-06-28',
#  '2020-06-29',
#  '2020-06-30',
#  '2020-07-01',
#  '2020-07-02',
#  '2020-07-03',
#  '2020-07-04',
#  '2020-07-05',
#  '2020-07-06',
#  '2020-07-07',
#  '2020-07-08',
#  '2020-07-09',
#  '2020-07-10',
#  '2020-07-11',
#  '2020-07-12',
#  '2020-07-13',
#  '2020-07-14',
#  '2020-07-15',
#  '2020-07-16',
#  '2020-07-17',
#  '2020-07-18',
#  '2020-07-19',
#  '2020-07-20',
#  '2020-07-21',
#  '2020-07-22',
#  '2020-07-23',
#  '2020-07-24',
#  '2020-07-25',
#  '2020-07-26',
#  '2020-07-27',
#  '2020-07-28',
#  '2020-07-29',
#  '2020-07-30',
#  '2020-07-31',
#  '2020-08-01',
#  '2020-08-02',
#  '2020-08-03',
#  '2020-08-04',
#  '2020-08-05',
#  '2020-08-06',
#  '2020-08-07',
#  '2020-08-08',
#  '2020-08-09',
#  '2020-08-10',
#  '2020-08-11',
#  '2020-08-12',
#  '2020-08-13',
#  '2020-08-14',
#  '2020-08-15',
#  '2020-08-16',
#  '2020-08-17',
#  '2020-08-18',
#  '2020-08-19',
#  '2020-08-20',
#  '2020-08-21',
#  '2020-08-22',
#  '2020-08-23']
