# %%
#!pip install wget
#!pip install urllib3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from subprocess import call
from scipy.stats.distributions import gamma,lognorm
import json 
import wget
import os
import os.path
from datetime import datetime
import pytz 
from collections import OrderedDict
#from google.colab import drive
import math

from datetime import datetime,timedelta
from urllib.request import urlopen
import collections
import copy
#os.chdir('/content/gdrive/My Drive')
#drive.mount('/content/gdrive')

# %%
if os.path.exists("test.json"):
  os.remove("test.json")
wget.download('https://api.covid19india.org/v4/data-all.json', os.path.join(os.getcwd(),"test.json"))
# Out:
# 100% [........................................................................] 38962709 / 38962709
# 'C:\\Users\\patel\\Desktop\\Covid_Today\\backend\\district_data\\test.json'

# %%
def convert(dat): 
    return datetime.strptime(dat, '%Y-%m-%d').strftime('%d %B')

# %%
dataset=pd.read_csv('population_districts.csv')
population=pd.DataFrame()
population["District"]=dataset['District']
population["Population"]=dataset['Population']
population = population.set_index('District')
population
# Out:
#                    Population
# District
# Anantapur             4081148
# Chittoor              4174064
# East Godavari         5154296
# Guntur                4887813
# Kurnool               4053463
# ...                       ...
# Lucknow               4589838
# Varanasi              3676841
# Prayagraj             5954391
# Kolkata               4496694
# North 24 Parganas    10009781
#
# [74 rows x 1 columns]

# %%
d={}
for i in dataset['State_Code'].unique():
    d[i] = [dataset['District'][j] for j in dataset[dataset['State_Code']==i].index]

# %%
state_id = d
x=datetime.now(pytz.timezone('Asia/Kolkata')).date()
dd=pd.date_range(start="2020-01-30",end=x)
dates=[]
for i in range(len(dd)):
  dates.append((str(dd[i])[:10]))
#dates
dates1=[]
for w in range (len(dates)):
  if len(dates[w]):
    dates1.append(convert(dates[w]))

# %%
{
  "MH":["Mumbai", "Thane", "Pune", "Palghar", "Aurangabad"],
  "TN":["Chennai", "Chengalpattu"],
  "KA":["Bengaluru Urban"],
  "GJ":["Ahmedabad", "Surat"],
  "WB":["Kolkata"],
  "HR":["Gurugram"],
  "TG":["Hyderabad"],
}
# Out:
# {'MH': ['Mumbai', 'Thane', 'Pune', 'Palghar', 'Aurangabad'],
#  'TN': ['Chennai', 'Chengalpattu'],
#  'KA': ['Bengaluru Urban'],
#  'GJ': ['Ahmedabad', 'Surat'],
#  'WB': ['Kolkata'],
#  'HR': ['Gurugram'],
#  'TG': ['Hyderabad']}

# %%
'''
from datetime import timedelta
start=datetime.now()
x1=datetime.now(pytz.timezone('Asia/Kolkata')).date()
#x1 = datetime.today()
#y1 = timedelta(days=7)
y1=[]
x1=str(x1)[:10]
for i in range(7,0,-1):
  y1.append(str(datetime.today()-timedelta(days=i))[:10])
#print(y1)
##y1=str(y1)[:10]
t=y1
t
'''
def dates_gen(periods=7):
  t = pd.Series(pd.date_range(end = datetime.now(pytz.timezone('Asia/Kolkata'))-timedelta(1), periods = periods)).dt.strftime('%Y-%m-%d').tolist()

  return t

# %%
t = dates_gen()

# %% [markdown]
# # Positivity Rate (All metrics)

# %% [markdown]
# ## From the begining

# %%
start=datetime.now()
states={}
csv_dates=[]
csv_states=[]
csv_total_cases=[]
csv_cum_recovered=[]
csv_daily_recovered=[]
csv_cum_deceased=[]
csv_daily_deceased=[]
csv_positivity_rate_cumulative=[]
csv_daily_positive_cases=[]
csv_daily_positivity_rate=[]
csv_daily_positive_cases_ma=[]
csv_daily_positivity_rate_ma=[]
csv_test_per_million=[]
csv_daily_tested=[]
csv_cum_tested=[]

csv_daily_case_per_million = []
csv_daily_test_per_million = []
csv_daily_test_ma = []
csv_daily_deceased_ma = []

test=json.load(open('test.json'))


for j in state_id.keys():
  for k in state_id[j]:   
    test_per_million = ['']*len(dates)
    pos_cum = ['']*len(dates)
    pos_rate_cum = ['']*len(dates)
    daily_pos = ['']*len(dates)
    daily_pos_ma = ['']*len(dates)
    daily_tested = ['']*len(dates)
    daily_pos_rate = ['']*len(dates)
    daily_pos_rate_ma = ['']*len(dates)
    tested_cum = ['']*len(dates)
    tested_daily = ['']*len(dates)
    deceased_cum = ['']*len(dates)
    daily_deceased = ['']*len(dates)
    recovered_cum = ['']*len(dates)
    daily_recovered = ['']*len(dates)


    daily_case_per_million = ['']*len(dates)
    daily_test_per_million = ['']*len(dates)
    daily_test_ma = ['']*len(dates)
    daily_deceased_ma = ['']*len(dates)
    
    for i in range(len(dates)):
      
      if dates[i] in test.keys():
          temp=test[dates[i]] 
          if j in temp.keys():
            
            if 'districts' in temp[j].keys():
          
              if k in temp[j]['districts']:
               
                if 'total' in temp[j]['districts'][k].keys():
                  
                  if 'confirmed' in temp[j]['districts'][k]['total'].keys():
                  
                    pos_cum[i]=temp[j]['districts'][k]['total']['confirmed']

                  if 'tested' in temp[j]['districts'][k]['total'].keys():
                    tested_cum[i]=abs(temp[j]['districts'][k]['total']['tested'])
                    test_per_million[i]=temp[j]['districts'][k]['total']['tested']*1000000/int(population["Population"][k])
                      
                  if 'deceased' in temp[j]['districts'][k]['total'].keys():
                    deceased_cum[i]=temp[j]['districts'][k]['total']['deceased']
                  
                  if 'recovered' in temp[j]['districts'][k]['total'].keys():
                    recovered_cum[i]=temp[j]['districts'][k]['total']['recovered']
                  
                  if len(str(pos_cum[i])) and len(str(tested_cum[i])):
                    pos_rate_cum[i]= pos_cum[i]*100/tested_cum[i]


                if 'delta' in temp[j]['districts'][k].keys():
                  if 'confirmed' in temp[j]['districts'][k]['delta'].keys():
                    daily_pos[i]=temp[j]['districts'][k]['delta']['confirmed']
                    try:
                      daily_case_per_million[i] =temp[j]['delta']['confirmed']*1000000/int(population["Population"][k])   #New
                    except:
                      daily_case_per_million[i]= ''
                  if 'tested' in temp[j]['districts'][k]['delta'].keys():
                    daily_tested[i]=abs(temp[j]['districts'][k]['delta']['tested'])
                    try:
                      daily_test_per_million[i] = temp[j]['delta']['tested']*1000000/int(population["Population"][k])    #New
                    except:
                      daily_test_per_million[i] = ''
                  if 'deceased' in temp[j]['districts'][k]['delta'].keys():
                    daily_deceased[i]=temp[j]['districts'][k]['delta']['deceased']
                  
                  if 'recovered' in temp[j]['districts'][k]['delta'].keys():
                    daily_recovered[i]=temp[j]['districts'][k]['delta']['recovered']
                  
                  if len(str(daily_pos[i])) and len(str(daily_tested[i])):
                    daily_pos_rate[i]=int(daily_pos[i])*100/int(daily_tested[i])

      

    for w in range(7,len(daily_pos)):
                  sum1=0
                  sum2=0
                  for s in range(7):
                    if (len(str(daily_pos[w-s]))!=0 and len(str(daily_tested[w-s]))!=0):
                      sum1+=int(daily_pos[w-s])
                      sum2+=int(daily_tested[w-s])
                  if (sum2!=0):
                    daily_pos_rate_ma[w]=sum1*100/abs(sum2)
                
    for w in range(7,len(daily_pos)):
                  sum1=0
                  count=0
                  for s in range(7):
                    if (len(str(daily_pos[w-s]))!=0):
                      sum1+=int(daily_pos[w-s])
                      count+=1
                  if count!=0:
                    daily_pos_ma[w]=sum1/count

 
    for w in range(7,len(daily_tested)):
      sum1=0
      count=0
      for s in range(7):
        if (len(str(daily_tested[w-s]))!=0):
          sum1+=int(daily_tested[w-s])
        
          count+=1
      if count!=0:
        daily_test_ma[w]=sum1/count
        

    for w in range(7,len(daily_deceased)):
      sum1=0
      count=0
      for s in range(7):
        if (len(str(daily_deceased[w-s]))!=0):
          sum1+=int(daily_deceased[w-s])
          count+=1
      if count!=0:
        daily_deceased_ma[w]=sum1/count



    #print(daily_pos_rate[-15:],k)

    for i in range(len(dates)-1):
                  csv_dates.append(dates1[i])
                  csv_states.append(k)
                  csv_total_cases.append(pos_cum[i])
                  csv_positivity_rate_cumulative.append(pos_rate_cum[i])
                  csv_daily_positive_cases.append(daily_pos[i])
                  csv_cum_recovered.append(recovered_cum[i])
                  csv_daily_recovered.append(daily_recovered[i])
                  csv_cum_deceased.append(deceased_cum[i])
                  csv_daily_deceased.append(daily_deceased[i])
                  csv_daily_positivity_rate.append(daily_pos_rate[i])
                  csv_daily_positive_cases_ma.append(daily_pos_ma[i])
                  csv_daily_positivity_rate_ma.append(daily_pos_rate_ma[i])
                  csv_daily_tested.append(daily_tested[i])
                  csv_cum_tested.append(tested_cum[i])
                  csv_test_per_million.append(test_per_million[i])

                 
                  csv_daily_case_per_million.append(daily_case_per_million[i])
                  csv_daily_test_per_million.append(daily_test_per_million[i])
                  csv_daily_test_ma.append(daily_test_ma[i])
                  csv_daily_deceased_ma.append(daily_deceased_ma[i])
      
    states[k]={
                                  'dates':dates1[:-1],
                                  'cum_positive_cases':pos_cum[:-1],
                                  'cum_positivity_rate':pos_rate_cum[:-1],
                                  'daily_positive_cases':daily_pos[:-1],
                                  'cum_recovered':recovered_cum[:-1],
                                  'daily_recovered':daily_recovered[:-1],
                                  'cum_deceased':deceased_cum[:-1],
                                  'daily_deceased':daily_deceased[:-1],
                                  'daily_positivity_rate':daily_pos_rate[:-1],
                                  'daily_positive_cases_ma': daily_pos_ma[:-1],
                                  'daily_positivity_rate_ma':daily_pos_rate_ma[:-1] , 
                                  'daily_tests': daily_tested[:-1],
                                  'cum_tests': tested_cum[:-1],
                                  'test_per_million':test_per_million[:-1],
                                  'daily_cases_per_million':daily_case_per_million[:-1],
                                  'daily_tests_per_million':daily_test_per_million[:-1],
                                  'daily_tests_ma':daily_test_ma[:-1],
                                  'daily_deceased_ma':daily_deceased_ma[:-1]
                            }
end=datetime.now()
print(end-start)
# Out:
# 0:00:01.183308

# %%
dates1
# Out:
# ['30 January',
#  '31 January',
#  '01 February',
#  '02 February',
#  '03 February',
#  '04 February',
#  '05 February',
#  '06 February',
#  '07 February',
#  '08 February',
#  '09 February',
#  '10 February',
#  '11 February',
#  '12 February',
#  '13 February',
#  '14 February',
#  '15 February',
#  '16 February',
#  '17 February',
#  '18 February',
#  '19 February',
#  '20 February',
#  '21 February',
#  '22 February',
#  '23 February',
#  '24 February',
#  '25 February',
#  '26 February',
#  '27 February',
#  '28 February',
#  '29 February',
#  '01 March',
#  '02 March',
#  '03 March',
#  '04 March',
#  '05 March',
#  '06 March',
#  '07 March',
#  '08 March',
#  '09 March',
#  '10 March',
#  '11 March',
#  '12 March',
#  '13 March',
#  '14 March',
#  '15 March',
#  '16 March',
#  '17 March',
#  '18 March',
#  '19 March',
#  '20 March',
#  '21 March',
#  '22 March',
#  '23 March',
#  '24 March',
#  '25 March',
#  '26 March',
#  '27 March',
#  '28 March',
#  '29 March',
#  '30 March',
#  '31 March',
#  '01 April',
#  '02 April',
#  '03 April',
#  '04 April',
#  '05 April',
#  '06 April',
#  '07 April',
#  '08 April',
#  '09 April',
#  '10 April',
#  '11 April',
#  '12 April',
#  '13 April',
#  '14 April',
#  '15 April',
#  '16 April',
#  '17 April',
#  '18 April',
#  '19 April',
#  '20 April',
#  '21 April',
#  '22 April',
#  '23 April',
#  '24 April',
#  '25 April',
#  '26 April',
#  '27 April',
#  '28 April',
#  '29 April',
#  '30 April',
#  '01 May',
#  '02 May',
#  '03 May',
#  '04 May',
#  '05 May',
#  '06 May',
#  '07 May',
#  '08 May',
#  '09 May',
#  '10 May',
#  '11 May',
#  '12 May',
#  '13 May',
#  '14 May',
#  '15 May',
#  '16 May',
#  '17 May',
#  '18 May',
#  '19 May',
#  '20 May',
#  '21 May',
#  '22 May',
#  '23 May',
#  '24 May',
#  '25 May',
#  '26 May',
#  '27 May',
#  '28 May',
#  '29 May',
#  '30 May',
#  '31 May',
#  '01 June',
#  '02 June',
#  '03 June',
#  '04 June',
#  '05 June',
#  '06 June',
#  '07 June',
#  '08 June',
#  '09 June',
#  '10 June',
#  '11 June',
#  '12 June',
#  '13 June',
#  '14 June',
#  '15 June',
#  '16 June',
#  '17 June',
#  '18 June',
#  '19 June',
#  '20 June',
#  '21 June',
#  '22 June',
#  '23 June',
#  '24 June',
#  '25 June',
#  '26 June',
#  '27 June',
#  '28 June',
#  '29 June',
#  '30 June',
#  '01 July',
#  '02 July',
#  '03 July',
#  '04 July',
#  '05 July',
#  '06 July',
#  '07 July',
#  '08 July',
#  '09 July',
#  '10 July',
#  '11 July',
#  '12 July',
#  '13 July',
#  '14 July',
#  '15 July',
#  '16 July',
#  '17 July',
#  '18 July',
#  '19 July',
#  '20 July',
#  '21 July',
#  '22 July',
#  '23 July',
#  '24 July',
#  '25 July',
#  '26 July',
#  '27 July',
#  '28 July',
#  '29 July',
#  '30 July',
#  '31 July',
#  '01 August',
#  '02 August',
#  '03 August',
#  '04 August',
#  '05 August',
#  '06 August',
#  '07 August',
#  '08 August',
#  '09 August',
#  '10 August',
#  '11 August',
#  '12 August',
#  '13 August',
#  '14 August',
#  '15 August',
#  '16 August',
#  '17 August',
#  '18 August',
#  '19 August',
#  '20 August',
#  '21 August',
#  '22 August',
#  '23 August',
#  '24 August',
#  '25 August',
#  '26 August',
#  '27 August',
#  '28 August',
#  '29 August',
#  '30 August',
#  '31 August',
#  '01 September',
#  '02 September',
#  '03 September',
#  '04 September',
#  '05 September',
#  '06 September',
#  '07 September',
#  '08 September',
#  '09 September',
#  '10 September',
#  '11 September',
#  '12 September',
#  '13 September',
#  '14 September',
#  '15 September',
#  '16 September',
#  '17 September',
#  '18 September',
#  '19 September',
#  '20 September',
#  '21 September',
#  '22 September',
#  '23 September',
#  '24 September',
#  '25 September',
#  '26 September',
#  '27 September',
#  '28 September',
#  '29 September',
#  '30 September',
#  '01 October',
#  '02 October',
#  '03 October']

# %% [markdown]
# ## Append Method

# %%
'''
csv_dates=[]
csv_states=[]
csv_total_cases=[]
csv_cum_recovered=[]
csv_daily_recovered=[]
csv_cum_deceased=[]
csv_daily_deceased=[]
csv_positivity_rate_cumulative=[]
csv_daily_positive_cases=[]
csv_daily_positivity_rate=[]
csv_daily_positive_cases_ma=[]
csv_daily_positivity_rate_ma=[]
csv_test_per_million=[]
csv_daily_tested=[]
csv_cum_tested=[]

#New
csv_daily_case_per_million = []
csv_daily_test_per_million = []
csv_daily_test_ma = []
csv_daily_deceased_ma = []

temp1 = json.load(open('positivity_Rate_dist.json'))

test_json_url = 'https://api.covid19india.org/v3/data-all.json'
test_json = json.loads(urlopen(test_json_url).read())
test= test_json


for x in t:
  temp = test[x]
  
  states={}
  for j in state_id.keys():
    for k in state_id[j]:
    
      test_per_million = temp1[k]['test_per_million']
      pos_cum = temp1[k]['cum_positive_cases']
      pos_rate_cum = temp1[k]['cum_positivity_rate']
      daily_pos = temp1[k]['daily_positive_cases']
      daily_pos_ma = temp1[k]['daily_positive_cases_ma']
      daily_pos_rate = temp1[k]['daily_positivity_rate']
      daily_pos_rate_ma = temp1[k]['daily_positivity_rate_ma']
      tested_cum = temp1[k]['cum_tests']
      daily_tested = temp1[k]['daily_tests']
      deceased_cum = temp1[k]['cum_deceased']
      daily_deceased = temp1[k]['daily_deceased']
      recovered_cum = temp1[k]['cum_recovered']
      daily_recovered = temp1[k]['daily_recovered'] 

      #New added
      daily_case_per_million  = temp1[k]['daily_cases_per_million']
      daily_test_per_million  = temp1[k]['daily_tests_per_million']
      daily_test_ma  = temp1[k]['daily_tests_ma']
      daily_deceased_ma  = temp1[k]['daily_deceased_ma']
      
      dates=temp1[k]['dates']
      if convert(x) not in dates :
        print(1)
        dates.append(convert(x))
        test_per_million.append('')
        pos_cum.append('')
        pos_rate_cum.append('')
        daily_pos.append('')
        daily_pos_ma.append('')
        daily_pos_rate.append('')
        daily_pos_rate_ma.append('')
        tested_cum.append('')
        daily_tested.append('')
        deceased_cum.append('')
        daily_deceased.append('')
        recovered_cum.append('')
        daily_recovered.append('')
        i=len(dates)-1

      for l in range(len(dates)):
        if convert(x)==dates[l]:
          i=l
          break
      
      if dates[i] in test.keys():
          temp=test[dates[i]] #New
          # Previoustemp=json.load(open('test.json'))[dates[i]]
          if j in temp.keys():
            if 'districts' in temp[j].keys():
              if k in temp1.keys():
                  if 'total' in temp[j]['districts'][k].keys():
                    if 'confirmed' in temp[j]['districts'][k]['total'].keys():
                      pos_cum[i]=temp[j]['districts'][k]['total']['confirmed']

                    if 'tested' in temp[j]['districts'][k]['total'].keys():
                      tested_cum[i]=abs(temp[j]['districts'][k]['total']['tested'])
                      test_per_million[i]=temp[j]['districts'][k]['total']['tested']*1000000/int(population["Population"][k])
                        
                    if 'deceased' in temp[j]['districts'][k]['total'].keys():
                      deceased_cum[i]=temp[j]['districts'][k]['total']['deceased']
                    
                    if 'recovered' in temp[j]['districts'][k]['total'].keys():
                      recovered_cum[i]=temp[j]['districts'][k]['total']['recovered']
                    
                    if len(str(pos_cum[i])) and len(str(tested_cum[i])):
                      pos_rate_cum[i]= pos_cum[i]*100/tested_cum[i]

                  if 'delta' in temp[j].keys():
                    if 'confirmed' in temp[j]['districts'][k]['delta'].keys():
                      daily_pos[i]=temp[j]['districts'][k]['delta']['confirmed']
                      try:
                        daily_case_per_million[i] =temp[j]['delta']['confirmed']*1000000/int(population["Population"][k])   #New
                      except:
                        daily_case_per_million[i]= ''

                    if 'tested' in temp[j]['districts'][k]['delta'].keys():
                      daily_tested[i]=abs(temp[j]['districts'][k]['delta']['tested'])
                      try:
                        daily_test_per_million[i] = temp[j]['delta']['tested']*1000000/int(population["Population"][k])    #New
                      except:
                        daily_test_per_million[i] = ''

                    if 'deceased' in temp[j]['districts'][k]['delta'].keys():
                      daily_deceased[i]=temp[j]['districts'][k]['delta']['deceased']
                    
                    if 'recovered' in temp[j]['districts'][k]['delta'].keys():
                      daily_recovered[i]=temp[j]['districts'][k]['delta']['recovered']
                    
                    if len(str(daily_pos[i])) and len(str(daily_tested[i])):
                      daily_pos_rate[i]=int(daily_pos[i])*100/int(daily_tested[i])

      for w in range(7,len(daily_pos)):
        sum1=0
        sum2=0
        for s in range(7):
          if (len(str(daily_pos[w-s]))!=0 and len(str(daily_tested[w-s]))!=0):
            sum1+=int(daily_pos[w-s])
            sum2+=int(daily_tested[w-s])
        if (sum2!=0):
          daily_pos_rate_ma[w]=sum1*100/abs(sum2)
      
      for w in range(7,len(daily_pos)):
        sum1=0
        count=0
        for s in range(7):
          if (len(str(daily_pos[w-s]))!=0):
            sum1+=int(daily_pos[w-s])
            count+=1
        if count!=0:
          daily_pos_ma[w]=sum1/count

      #New
      for w in range(7,len(daily_tested)):
        sum1=0
        count=0
        for s in range(7):
          if (len(str(daily_tested[w-s]))!=0):
            sum1+=int(daily_tested[w-s])
          
            count+=1
        if count!=0:
          daily_test_ma[w]=sum1/count
          
      #New
      for w in range(7,len(daily_deceased)):
        sum1=0
        count=0
        for s in range(7):
          if (len(str(daily_deceased[w-s]))!=0):
            sum1+=int(daily_deceased[w-s])
            count+=1
        if count!=0:
          daily_deceased_ma[w]=sum1/count


      st=k
      for i in range(len(dates)):
          
          csv_dates.append(dates[i])
          csv_states.append(st)
          csv_total_cases.append(pos_cum[i])
          csv_positivity_rate_cumulative.append(pos_rate_cum[i])
          csv_daily_positive_cases.append(daily_pos[i])
          csv_cum_recovered.append(recovered_cum[i])
          csv_daily_recovered.append(daily_recovered[i])
          csv_cum_deceased.append(deceased_cum[i])
          csv_daily_deceased.append(daily_deceased[i])
          csv_daily_positivity_rate.append(daily_pos_rate[i])
          csv_daily_positive_cases_ma.append(daily_pos_ma[i])
          csv_daily_positivity_rate_ma.append(daily_pos_rate_ma[i])
          csv_daily_tested.append(daily_tested[i])
          csv_cum_tested.append(tested_cum[i])
          csv_test_per_million.append(test_per_million[i])
          
          #New
          csv_daily_case_per_million.append(daily_case_per_million[i])
          csv_daily_test_per_million.append(daily_test_per_million[i])
          csv_daily_test_ma.append(daily_test_ma[i])
          csv_daily_deceased_ma.append(daily_deceased_ma[i])
      #print(st)
      
      states[st]={
                      'dates':dates,
                      'cum_positive_cases':pos_cum,
                      'cum_positivity_rate':pos_rate_cum,
                      'daily_positive_cases':daily_pos,
                      'cum_recovered':recovered_cum,
                      'daily_recovered':daily_recovered,
                      'cum_deceased':deceased_cum,
                      'daily_deceased':daily_deceased,
                      'daily_positivity_rate':daily_pos_rate,
                      'daily_positive_cases_ma': daily_pos_ma,
                      'daily_positivity_rate_ma':daily_pos_rate_ma , 
                      'daily_tests': daily_tested,
                      'cum_tests': tested_cum,
                      'test_per_million':test_per_million,   

                      #New
                      'daily_cases_per_million':daily_case_per_million,
                      'daily_tests_per_million':daily_test_per_million,
                      'daily_tests_ma':daily_test_ma,
                      'daily_deceased_ma':daily_deceased_ma 
                }

    

states['datetime']=str(datetime.now(pytz.timezone('Asia/Kolkata')))
with open('positivity_Rate_dist.json', 'w') as outfile:
    json.dump(states, outfile,indent=4)'''
# Out:
# '\ncsv_dates=[]\ncsv_states=[]\ncsv_total_cases=[]\ncsv_cum_recovered=[]\ncsv_daily_recovered=[]\ncsv_cum_deceased=[]\ncsv_daily_deceased=[]\ncsv_positivity_rate_cumulative=[]\ncsv_daily_positive_cases=[]\ncsv_daily_positivity_rate=[]\ncsv_daily_positive_cases_ma=[]\ncsv_daily_positivity_rate_ma=[]\ncsv_test_per_million=[]\ncsv_daily_tested=[]\ncsv_cum_tested=[]\n\n#New\ncsv_daily_case_per_million = []\ncsv_daily_test_per_million = []\ncsv_daily_test_ma = []\ncsv_daily_deceased_ma = []\n\ntemp1 = json.load(open(\'positivity_Rate_dist.json\'))\n\ntest_json_url = \'https://api.covid19india.org/v3/data-all.json\'\ntest_json = json.loads(urlopen(test_json_url).read())\ntest= test_json\n\n\nfor x in t:\n  temp = test[x]\n  \n  states={}\n  for j in state_id.keys():\n    for k in state_id[j]:\n    \n      test_per_million = temp1[k][\'test_per_million\']\n      pos_cum = temp1[k][\'cum_positive_cases\']\n      pos_rate_cum = temp1[k][\'cum_positivity_rate\']\n      daily_pos = temp1[k][\'daily_positive_cases\']\n      daily_pos_ma = temp1[k][\'daily_positive_cases_ma\']\n      daily_pos_rate = temp1[k][\'daily_positivity_rate\']\n      daily_pos_rate_ma = temp1[k][\'daily_positivity_rate_ma\']\n      tested_cum = temp1[k][\'cum_tests\']\n      daily_tested = temp1[k][\'daily_tests\']\n      deceased_cum = temp1[k][\'cum_deceased\']\n      daily_deceased = temp1[k][\'daily_deceased\']\n      recovered_cum = temp1[k][\'cum_recovered\']\n      daily_recovered = temp1[k][\'daily_recovered\'] \n\n      #New added\n      daily_case_per_million  = temp1[k][\'daily_cases_per_million\']\n      daily_test_per_million  = temp1[k][\'daily_tests_per_million\']\n      daily_test_ma  = temp1[k][\'daily_tests_ma\']\n      daily_deceased_ma  = temp1[k][\'daily_deceased_ma\']\n      \n      dates=temp1[k][\'dates\']\n      if convert(x) not in dates :\n        print(1)\n        dates.append(convert(x))\n        test_per_million.append(\'\')\n        pos_cum.append(\'\')\n        pos_rate_cum.append(\'\')\n        daily_pos.append(\'\')\n        daily_pos_ma.append(\'\')\n        daily_pos_rate.append(\'\')\n        daily_pos_rate_ma.append(\'\')\n        tested_cum.append(\'\')\n        daily_tested.append(\'\')\n        deceased_cum.append(\'\')\n        daily_deceased.append(\'\')\n        recovered_cum.append(\'\')\n        daily_recovered.append(\'\')\n        i=len(dates)-1\n\n      for l in range(len(dates)):\n        if convert(x)==dates[l]:\n          i=l\n          break\n      \n      if dates[i] in test.keys():\n          temp=test[dates[i]] #New\n          # Previoustemp=json.load(open(\'test.json\'))[dates[i]]\n          if j in temp.keys():\n            if \'districts\' in temp[j].keys():\n              if k in temp1.keys():\n                  if \'total\' in temp[j][\'districts\'][k].keys():\n                    if \'confirmed\' in temp[j][\'districts\'][k][\'total\'].keys():\n                      pos_cum[i]=temp[j][\'districts\'][k][\'total\'][\'confirmed\']\n\n                    if \'tested\' in temp[j][\'districts\'][k][\'total\'].keys():\n                      tested_cum[i]=abs(temp[j][\'districts\'][k][\'total\'][\'tested\'])\n                      test_per_million[i]=temp[j][\'districts\'][k][\'total\'][\'tested\']*1000000/int(population["Population"][k])\n                        \n                    if \'deceased\' in temp[j][\'districts\'][k][\'total\'].keys():\n                      deceased_cum[i]=temp[j][\'districts\'][k][\'total\'][\'deceased\']\n                    \n                    if \'recovered\' in temp[j][\'districts\'][k][\'total\'].keys():\n                      recovered_cum[i]=temp[j][\'districts\'][k][\'total\'][\'recovered\']\n                    \n                    if len(str(pos_cum[i])) and len(str(tested_cum[i])):\n                      pos_rate_cum[i]= pos_cum[i]*100/tested_cum[i]\n\n                  if \'delta\' in temp[j].keys():\n                    if \'confirmed\' in temp[j][\'districts\'][k] ...

# %%
states['datetime']=str(datetime.now(pytz.timezone('Asia/Kolkata')))
with open('positivity_Rate_dist.json', 'w') as outfile:
    json.dump(states, outfile,indent=4)

# %%
n_states=0
for i in state_id.values():
  for k in i:
    n_states+=1

n_dates = len(list(test.keys()))

rows = n_states*n_dates

# %%
rows/36
# Out:
# 450.1666666666667

# %%
csv_dates[-1]
# Out:
# '02 October'

# %%
df=pd.DataFrame()

df['dates']=csv_dates[:rows]
df['state']=csv_states[:rows]
df['cum_positive_cases']=csv_total_cases[:rows]
df['cum_positivity_rate']=csv_positivity_rate_cumulative[:rows]
df['cum_recovered']=csv_cum_recovered[:rows]
df['daily_recovered']:csv_daily_recovered[:rows]
df['cum_deceased']=csv_cum_deceased[:rows]
df['daily_deceased']:daily_deceased[:rows]
df['daily_positive_cases']=csv_daily_positive_cases[:rows]
df['daily_positivity_rate']=csv_daily_positivity_rate[:rows]
df['daily_positive_cases_ma']=csv_daily_positive_cases_ma[:rows]
df['daily_positivity_rate_ma']=    csv_daily_positivity_rate_ma[:rows]
df['daily_tests']=csv_daily_tested[:rows]
df['cum_tested']=csv_cum_tested[:rows]
df['test_per_million']=csv_test_per_million[:rows]

#New
df['daily_cases_per_million'] = csv_daily_case_per_million[:rows]
df['daily_tests_per_million'] = csv_daily_test_per_million[:rows]
df['daily_tests_ma'] = csv_daily_test_ma[:rows]
df['daily_deceased_ma'] = csv_daily_deceased_ma[:rows]

df.to_csv('positivity_Rate_dist.csv',index=False)

# %%
df_to_concat = copy.deepcopy(df)

# %%
data_recovered = pd.DataFrame()
districts=[]
data_deceased = pd.DataFrame()
data_confirmed = pd.DataFrame()
for s in state_id.keys():
    st=state_id[s]
    districts+=st
    print(st)
    for k in st:
      data_confirmed[k] = np.array(states[k]['daily_positive_cases'])
      data_deceased[k] = np.array(states[k]['daily_deceased'])
      data_recovered[k] = np.array(states[k]['daily_recovered'])
# Out:
# ['Anantapur', 'Chittoor', 'East Godavari', 'Guntur', 'Kurnool', 'Prakasam', 'Srikakulam', 'Visakhapatnam', 'Vizianagaram', 'West Godavari', 'S.P.S. Nellore', 'Y.S.R. Kadapa']
# ['Begusarai', 'Patna']
# ['Raipur']
# ['Ahmedabad', 'Rajkot', 'Surat', 'Vadodara']
# ['Faridabad', 'Gurugram']
# ['East Singhbhum', 'Koderma', 'Ranchi', 'Ramgarh', 'West Singhbhum']
# ['Bengaluru Urban', 'Ballari', 'Mysuru', 'Belagavi', 'Chitradurga', 'Tumakuru']
# ['Thiruvananthapuram']
# ['Aurangabad', 'Jalgaon', 'Kolhapur', 'Mumbai', 'Nagpur', 'Nashik', 'Palghar', 'Pune', 'Raigad', 'Solapur', 'Thane', 'Satara', 'Sangli', 'Ahmednagar', 'Nanded']
# ['Bhopal', 'Indore']
# ['Ganjam', 'Khordha']
# ['Ludhiana', 'S.A.S. Nagar', 'Jalandhar']
# ['Jaipur']
# ['Chengalpattu', 'Chennai', 'Kancheepuram', 'Madurai', 'Thiruvallur', 'Tiruvannamalai', 'Vellore', 'Coimbatore']
# ['Aligarh', 'Bareilly', 'Gautam Buddha Nagar', 'Ghaziabad', 'Kanpur Nagar', 'Lucknow', 'Varanasi', 'Prayagraj']
# ['Kolkata', 'North 24 Parganas']

# %% [markdown]
# # CFR

# %%
def n2z(x):
    x[np.logical_or(np.isnan(x),np.isinf(x))] = 0
    return x

# %%
len(dates)
# Out:
# 248

# %%
data_recovered = data_recovered.replace(r'^\s*$', np.NaN, regex=True).fillna(0)
data_recovered = data_recovered.astype(np.int32)
data_confirmed = data_confirmed.replace(r'^\s*$', np.NaN, regex=True).fillna(0)
data_confirmed = data_confirmed.astype(np.int32)
data_deceased = data_deceased.replace(r'^\s*$', np.NaN, regex=True).fillna(0)
data_deceased = data_deceased.astype(np.int32)
data_deceased['date'] = dates[:-1]
data_recovered['date'] = dates[:-1]
data_confirmed['date'] = dates[:-1]

# %%
json_data={}
cfr = pd.DataFrame()
final=pd.DataFrame()
plt.figure(1, figsize=(15, 7))
for st in districts:
    print("cfr() -- Working : ",st)
    
    state=st
    boots = 100
    conf = []
    for n in range(boots):
        #print("Iteration: ",n+1,end='\r')
        if n  == boots//4:
          print("Progress : 25%")
        if n  == boots//2:
          print("Progress : 50%")
        if n  == (boots*3)//4:
          print("Progress : 75%")  
        if n  == boots-1:
          print("Progress : 100%")

        dataset = np.copy(data_confirmed[state].values)
        mean = 13.0+(20.9-8.7)/4*np.random.normal()
        sd = 12.7+(26.0-6.4)/4*np.random.normal()
        phi = np.sqrt(sd**2 + mean**2)
        mu = np.log(mean**2/phi)
        sigma = np.sqrt(np.log(phi**2/mean**2))
        L = lognorm(s=sigma,scale=np.exp(mu))
        for i in range(len(dataset)-1,-1,-1):
            send_forward = np.round(L.rvs(np.max([dataset[i],0])))
            send_forward = send_forward[i+send_forward<len(dataset)]
            dataset[i] = 0
            for j in np.unique(np.int32(send_forward)):
                dataset[i+j] += np.sum(send_forward==j)
        conf.append(dataset)
    CFR = np.cumsum(data_deceased[state].values)/np.cumsum(conf,axis=1)
    col_mean = np.nanmean(CFR, axis=0)
    inds = np.where(np.isnan(CFR))
    CFR[inds] = np.take(col_mean, inds[1])
    #temp1=list(pd.Series(dates).dt.strftime('%m-%d-%Y'))
    #print(temp1[0])
    temp={}
    temp = {
        'dates':dates1[:-1],
        'cfr1_point':list(n2z(100*np.cumsum(data_deceased[state].values)/np.cumsum(data_confirmed[state].values))),
        'cfr2_point':list(n2z(100*np.cumsum(data_deceased[state].values)/(np.cumsum(data_deceased[state].values)+np.cumsum(data_recovered[state].values)))),
        'cfr3_point':list(n2z(100*np.median(CFR,axis=0))),
        'cfr3_l95':list(n2z(100*np.quantile(CFR,0.025,axis=0))),
        'cfr3_u95':list(n2z(100*np.quantile(CFR,0.975,axis=0))),
        'cfr3_l50':list(n2z(100*np.quantile(CFR,0.25,axis=0))),
        'cfr3_u50':list(n2z(100*np.quantile(CFR,0.75,axis=0))),
        }
    a=st
    #print(a)
    states[state].update(temp)
    json_data[state] = temp
    cfr_state=pd.DataFrame()
    cfr_state['state']=([str(a)]*(len(dates)))[:-1]   #Reminder this method has to change when append method is implemented
    cfr_state['dates']=dates1[:-1]                     #Remove [1:] when append method
    cfr_state['cfr1_point']=(list(100*n2z(np.cumsum(data_deceased[state].values)/np.cumsum(data_confirmed[state].values))))
    cfr_state['cfr2_point']=(list(100*n2z(np.cumsum(data_deceased[state].values)/(np.cumsum(data_deceased[state].values)+np.cumsum(data_recovered[state].values)))))
    cfr_state['cfr3_point']=(list(100*n2z(np.median(CFR,axis=0))))
    cfr_state['cfr3_l95']=(list(100*n2z(np.quantile(CFR,0.025,axis=0))))
    cfr_state['cfr3_u95']=(list(100*n2z(np.quantile(CFR,0.975,axis=0))))
    cfr_state['cfr3_l50']=(list(100*n2z(np.quantile(CFR,0.25,axis=0))))
    cfr_state['cfr3_u50']=(list(100*n2z(np.quantile(CFR,0.75,axis=0))))
    cfr=pd.concat([cfr, cfr_state])
      
    plt.plot(temp['cfr3_point'],label=state)
    plt.legend()
    plt.ylim(0,10)
# Out:
# cfr() -- Working :  Anantapur
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Chittoor
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  East Godavari
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Guntur
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Kurnool
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Prakasam
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Srikakulam
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Visakhapatnam
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Vizianagaram
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  West Godavari
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  SPS Nellore
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  YSR Kadapa
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Kamrup Metropolitan
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Begusarai
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Patna
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Ahmedabad
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Rajkot
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Surat
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Vadodara
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Faridabad
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Gurugram
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Bengaluru Urban
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Ballari
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Mysuru
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Belagavi
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Aurangabad
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Jalgaon
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Kolhapur
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Mumbai
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Nagpur
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Nashik
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Palghar
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Pune
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
#  Raigad
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Solapur
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Thane
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Bhopal
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Indore
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Ganjam
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Ludhiana
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# cfr() -- Working :  Hyderabad
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Medchal Malkajgiri
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Ranga Reddy
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Chengalpattu
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Chennai
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# cfr() -- Working :  Kancheepuram
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Madurai
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Thiruvallur
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Tiruvannamalai
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Vellore
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Aligarh
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Bareilly
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Gautam Buddha Nagar
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Ghaziabad
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# cfr() -- Working :  Kanpur Nagar
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Lucknow
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Varanasi
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Prayagraj
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Kolkata
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  North 24 Parganas
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:61: RuntimeWarning: invalid value encountered in true_divide

# %%
cfr.to_csv('cfr_district.csv',index=False)
from datetime import datetime
json_data['datetime']=str(datetime.now())

# %%
json_data_indented = json.dumps(json_data, indent = 4)
with open("cfr_district.json", "w") as outfile: 
    outfile.write(json_data_indented)

# %% [markdown]
# # Doubling Rate

# %%
def calc_doublingtimes(x):
    vals = []
    for i in range(x.shape[0]):
        for j in range(i+1,x.shape[0]):
            if len(str(x[j])) and len(str(x[i])):
                vals.append(np.log(2)*(j-i)/np.log(int(x[j])/int(x[i])))
    return np.mean(vals),np.mean(vals)-1.96*np.std(vals),np.mean(vals)+1.96*np.std(vals)

# %%
start=datetime.now()
x=datetime.now(pytz.timezone('Asia/Kolkata')).date()
dd=pd.date_range(start="2020-01-30",end=x)
dd = dd [:-1]
datess=[]
for i in range(len(dd)):
  datess.append((str(dd[i])[:10]))

# %%
stt=states

# %%
dates1 = dates[:-1]
json_data={}
test=json.load(open('test.json'))
for j in state_id.keys():
    cumul=['']*len(dates)
    #st=state_id[j]
    for st in state_id[j]:
        #print(st)
        cumul=states[st]['cum_positive_cases']
        cumul_cases=np.array(cumul)
        dbt = np.zeros((3,cumul_cases.shape[0]))
        for i in range(cumul_cases.shape[0]):
            dbt[:,i] = calc_doublingtimes(cumul_cases[i-7:i])
        #st=state_id[j]
        #temp={}
        temp1 = {'dates':dates1,'dbt_point':pd.Series((list(dbt[0,:]))).replace([np.inf, -np.inf], np.nan).fillna('').tolist(),'dbt_l95':pd.Series((list(dbt[1,:]))).replace([np.inf, -np.inf], np.nan).fillna('').tolist(),'dbt_u95':pd.Series((list(dbt[2,:]))).replace([np.inf, -np.inf], np.nan).fillna('').tolist()}
        states[st].update(temp1)
        json_data[st] = temp1
# Out:
# c:\users\patel\appdata\local\programs\python\python38-32\lib\site-packages\numpy\core\fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\users\patel\appdata\local\programs\python\python38-32\lib\site-packages\numpy\core\_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# c:\users\patel\appdata\local\programs\python\python38-32\lib\site-packages\numpy\core\_methods.py:233: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# c:\users\patel\appdata\local\programs\python\python38-32\lib\site-packages\numpy\core\_methods.py:194: RuntimeWarning: invalid value encountered in true_divide
#   arrmean = um.true_divide(
# c:\users\patel\appdata\local\programs\python\python38-32\lib\site-packages\numpy\core\_methods.py:226: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# <ipython-input-23-dd5858f39099>:6: RuntimeWarning: divide by zero encountered in double_scalars
#   vals.append(np.log(2)*(j-i)/np.log(int(x[j])/int(x[i])))
# c:\users\patel\appdata\local\programs\python\python38-32\lib\site-packages\numpy\core\_methods.py:202: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)

# %%
json_data_indented = json.dumps(json_data, indent = 4)
with open("doubling_rate_dist.json", "w") as outfile: 
    outfile.write(json_data_indented)

# %% [markdown]
# # RT

# %%
rt_json = {}

rt = pd.DataFrame()
# plt.figure(1, figsize=(15, 7))
for j in state_id.keys():
  for st in state_id[j]:
    state=st
    print("Working : ",state)
    
    temp = pd.DataFrame()
    #temp["active"] = data_confirmed[state]
    temp["active"] = np.array(data_confirmed[state]).clip(0).tolist()

    temp.to_csv('confirmed.csv')
    call(['RScript.exe','scripts/Rt_analysis_newGT_TJ.R'])
    
    values = {
            'rt_point':[],
            'rt_sd':[],
            'rt_l95':[],
            'rt_u95':[],
            'rt_l50':[],
            'rt_u50':[],
            't_end':[]
            }

    for df in [pd.read_csv('rt_temp/'+temp) for temp in os.listdir('rt_temp/')]:
        values['rt_point'].append(df['Mean(R)'])
        values['rt_sd'].append(df['Std(R)'])
        values['rt_l95'].append(df['Quantile.0.025(R)'])
        values['rt_u95'].append(df['Quantile.0.975(R)'])
        values['rt_l50'].append(df['Quantile.0.25(R)'])
        values['rt_u50'].append(df['Quantile.0.75(R)'])
        values['t_end'].append(df['t_end']-1)
    for i in values:
        values[i] = np.median(values[i],axis=0)
    values['dates'] = list(data_confirmed['date'][values['t_end']-1])
    rt_state=pd.DataFrame()
    rt_state['state']=[str(state)]*len(values['dates'])
    rt_state['dates']= values['dates']
    rt_state['rt_point'] = values['rt_point']
    rt_state['rt_sd'] = values['rt_sd']    
    rt_state['rt_l95'] = values['rt_l95']    
    rt_state['rt_u95'] = values['rt_u95']    
    rt_state['rt_l50'] = values['rt_l50']
    rt_state['rt_u50'] = values['rt_u50']
    rt=pd.concat([rt, rt_state])
  
    rt_json[st] = values
    
    plt.plot(range(len(values['rt_point'])),values['rt_point'],label=state)
    plt.fill_between(range(len(values['rt_point'])),values['rt_l95'],values['rt_u95'],alpha=0.5)
    plt.ylim(0,4)
    plt.legend()
    plt.show()
# Out:
# Working :  Anantapur
# Working :  Chittoor
# Working :  East Godavari
# Working :  Guntur
# Working :  Kurnool
# Working :  Prakasam
# Working :  Srikakulam
# Working :  Visakhapatnam
# Working :  Vizianagaram
# Working :  West Godavari
# Working :  S.P.S. Nellore
# Working :  Y.S.R. Kadapa
# Working :  Begusarai
# Working :  Patna
# Working :  Raipur
# Working :  Ahmedabad
# Working :  Rajkot
# Working :  Surat
# Working :  Vadodara
# Working :  Faridabad
# Working :  Gurugram
# Working :  East Singhbhum
# Working :  Koderma
# Working :  Ranchi
# Working :  Ramgarh
# Working :  West Singhbhum
# Working :  Bengaluru Urban
# Working :  Ballari
# Working :  Mysuru
# Working :  Belagavi
# Working :  Chitradurga
# Working :  Tumakuru
# Working :  Thiruvananthapuram
# Working :  Aurangabad
# Working :  Jalgaon
# Working :  Kolhapur
# Working :  Mumbai
# Working :  Nagpur
# Working :  Nashik
# Working :  Palghar
# Working :  Pune
# Working :  Raigad
# Working :  Solapur
# Working :  Thane
# Working :  Satara
# Working :  Sangli
# Working :  Ahmednagar
# Working :  Nanded
# Working :  Bhopal
# Working :  Indore
# Working :  Ganjam
# Working :  Khordha
# Working :  Ludhiana
# Working :  S.A.S. Nagar
# Working :  Jalandhar
# Working :  Jaipur
# Working :  Chengalpattu
# Working :  Chennai
# Working :  Kancheepuram
# Working :  Madurai
# Working :  Thiruvallur
# Working :  Tiruvannamalai
# Working :  Vellore
# Working :  Coimbatore
# Working :  Aligarh
# Working :  Bareilly
# Working :  Gautam Buddha Nagar
# Working :  Ghaziabad
# Working :  Kanpur Nagar
# Working :  Lucknow
# Working :  Varanasi
# Working :  Prayagraj
# Working :  Kolkata
# Working :  North 24 Parganas

# %%
for st in state_id.keys():
    dist = state_id[st]
    for district in dist:
        states[district].update(rt_json[district])

# %%
rt.to_csv('rt.csv',index=False)

# %% [markdown]
# ## Rt shifting

# %%
def shift_rt_metrics(dict,key,days):
  values_shifted = collections.deque(dict[key])
  values_shifted.rotate(-1*days)

  new_val = list(values_shifted)

  size = len(dict['dates'])
  
  for i in range(days):
    new_val[size-1-i]=''

  return new_val

# %%
rt_json_shifted = copy.deepcopy(rt_json)
days = 2
for sta in state_id.keys():
    for st in state_id[sta]:
        rt_json_shifted[st]['rt_point'] = shift_rt_metrics(rt_json[st],'rt_point',days)
        rt_json_shifted[st]['rt_sd'] = shift_rt_metrics(rt_json[st],'rt_sd',days)
        rt_json_shifted[st]['rt_l95'] = shift_rt_metrics(rt_json[st],'rt_l95',days)
        rt_json_shifted[st]['rt_u95'] = shift_rt_metrics(rt_json[st],'rt_u95',days)
        rt_json_shifted[st]['rt_l50'] = shift_rt_metrics(rt_json[st],'rt_l50',days)
        rt_json_shifted[st]['rt_u50'] = shift_rt_metrics(rt_json[st],'rt_u50',days)
        rt_json_shifted[st]['t_end'] = shift_rt_metrics(rt_json[st],'t_end',days)

# %%
for st in state_id.keys():
    dist = state_id[st]
    leng = len(dates[:-1])
    
    #states[state]['dates'] =  temp1['India']['dates']
    for state in dist:
        for keys in list(rt_json_shifted[state].keys())[:-1]:
            if len(rt_json_shifted[state][keys])<leng:
                rt_json_shifted[state][keys].extend(['' for i in range(leng-len(rt_json_shifted[state][keys]))]) 
                
        rt_json_shifted[state]['dates'] = dates[:-1]

# %%
states_shifted = copy.deepcopy(states)

for sta in state_id.keys():
    for st in state_id[sta]:
        states_shifted[st].update(rt_json_shifted[st])

# %%
for sta in state_id.keys():
    for state in state_id[sta]:
        for key in rt_json[state].keys():
          try:
            rt_json[state][key]=rt_json[state][key].tolist()
          except:
            pass

# %%
for sta in state_id.keys():
    for state in state_id[sta]:
        for key in states[state].keys():
          try:
            states[state][key]=states[state][key].tolist()
          except:
            pass

# %%
for st in state_id.keys():
    dist = state_id[st]
        
    leng = len(dates[:-1])

        #states[state]['dates'] =  temp1['India']['dates']
    for state in dist:
        for keys in list(states[state].keys())[1:]:
            if len(states[state][keys])<leng:
                states[state][keys].extend(['' for i in range(leng-len(states[state][keys]))])

# %%
for st in state_id.keys():
    dist = state_id[st]
    leng = len(dates[:-1])
    
    #states[state]['dates'] =  temp1['India']['dates']
    for state in dist:
         for keys in list(states_shifted[state].keys())[1:]:
            if len(states_shifted[state][keys])<leng:
                states_shifted[state][keys].extend(['' for i in range(leng-len(states_shifted[state][keys]))])

# %%
for sta in state_id.keys():
    for st in state_id[sta]:
        states[st]['dates'] = dates[:-1]
        states_shifted[st]['dates'] = dates[:-1]

# %% [markdown]
# ## Rt changes for review

# %%
with open('rt_shifted.json', 'w') as outfile:
  json.dump(rt_json_shifted, outfile,indent=4)

# %%
with open('rt.json', 'w') as outfile:
  json.dump(rt_json, outfile,indent=4)

# %%
'''
df_list = [df,cfr,rt]
all_dataframes = pd.concat(df_list)
all_dataframes.to_csv('complete_districts_all_metrics.csv',index=False)'''
# Out:
# "\ndf_list = [df,cfr,rt]\nall_dataframes = pd.concat(df_list)\nall_dataframes.to_csv('complete_districts_all_metrics.csv',index=False)"

# %%
len(dates)
# Out:
# 248

# %%
rt_graph = copy.deepcopy(rt_json_shifted)

de =10

for s in state_id.keys():
    for st in state_id[s]:
        for k in rt_json_shifted[st].keys():
            rt_graph[st][k] = rt_json_shifted[st][k][:-10]

# %%
with open('rt_graph.json', 'w') as outfile:
  json.dump(rt_graph, outfile,indent=4)

# %% [markdown]
# # Complete

# %%
cols=list(states['Mumbai'].keys())
q=['state']
complete=pd.DataFrame(columns=q+cols)
keys=list(states.keys())[:-1]
for i in keys:
  temp=pd.DataFrame()
  d=len(states['Mumbai']['dates'])

  temp['state']=[str(i)]*d
  
  for j in cols:
    print(i,j)
    temp[j]=list(states[i][j])[:d]
  complete = pd.concat([complete,temp])
# Out:
# Anantapur dates
# Anantapur cum_positive_cases
# Anantapur cum_positivity_rate
# Anantapur daily_positive_cases
# Anantapur cum_recovered
# Anantapur daily_recovered
# Anantapur cum_deceased
# Anantapur daily_deceased
# Anantapur daily_positivity_rate
# Anantapur daily_positive_cases_ma
# Anantapur daily_positivity_rate_ma
# Anantapur daily_tests
# Anantapur cum_tests
# Anantapur test_per_million
# Anantapur daily_cases_per_million
# Anantapur daily_tests_per_million
# Anantapur daily_tests_ma
# Anantapur daily_deceased_ma
# Anantapur dbt_point
# Anantapur dbt_l95
# Anantapur dbt_u95
# Anantapur rt_point
# Anantapur rt_sd
# Anantapur rt_l95
# Anantapur rt_u95
# Anantapur rt_l50
# Anantapur rt_u50
# Anantapur t_end
# Chittoor dates
# Chittoor cum_positive_cases
# Chittoor cum_positivity_rate
# Chittoor daily_positive_cases
# Chittoor cum_recovered
# Chittoor daily_recovered
# Chittoor cum_deceased
# Chittoor daily_deceased
# Chittoor daily_positivity_rate
# Chittoor daily_positive_cases_ma
# Chittoor daily_positivity_rate_ma
# Chittoor daily_tests
# Chittoor cum_tests
# Chittoor test_per_million
# Chittoor daily_cases_per_million
# Chittoor daily_tests_per_million
# Chittoor daily_tests_ma
# Chittoor daily_deceased_ma
# Chittoor dbt_point
# Chittoor dbt_l95
# Chittoor dbt_u95
# Chittoor rt_point
# Chittoor rt_sd
# Chittoor rt_l95
# Chittoor rt_u95
# Chittoor rt_l50
# Chittoor rt_u50
# Chittoor t_end
# East Godavari dates
# East Godavari cum_positive_cases
# East Godavari cum_positivity_rate
# East Godavari daily_positive_cases
# East Godavari cum_recovered
# East Godavari daily_recovered
# East Godavari cum_deceased
# East Godavari daily_deceased
# East Godavari daily_positivity_rate
# East Godavari daily_positive_cases_ma
# East Godavari daily_positivity_rate_ma
# East Godavari daily_tests
# East Godavari cum_tests
# East Godavari test_per_million
# East Godavari daily_cases_per_million
# East Godavari daily_tests_per_million
# East Godavari daily_tests_ma
# East Godavari daily_deceased_ma
# East Godavari dbt_point
# East Godavari dbt_l95
# East Godavari dbt_u95
# East Godavari rt_point
# East Godavari rt_sd
# East Godavari rt_l95
# East Godavari rt_u95
# East Godavari rt_l50
# East Godavari rt_u50
# East Godavari t_end
# Guntur dates
# Guntur cum_positive_cases
# Guntur cum_positivity_rate
# Guntur daily_positive_cases
# Guntur cum_recovered
# Guntur daily_recovered
# Guntur cum_deceased
# Guntur daily_deceased
# Guntur daily_positivity_rate
# Guntur daily_positive_cases_ma
# Guntur daily_positivity_rate_ma
# Guntur daily_tests
# Guntur cum_tests
# Guntur test_per_million
# Guntur daily_cases_per_million
# Guntur daily_tests_per_million
# Guntur daily_tests_ma
# Guntur daily_deceased_ma
# Guntur dbt_point
# Guntur dbt_l95
# Guntur dbt_u95
# Guntur rt_point
# Guntur rt_sd
# Guntur rt_l95
# Guntur rt_u95
# Guntur rt_l50
# Guntur rt_u50
# Guntur t_end
# Kurnool dates
# Kurnool cum_positive_cases
# Kurnool cum_positivity_rate
# Kurnool daily_positive_cases
# Kurnool cum_recovered
# Kurnool daily_recovered
# Kurnool cum_deceased
# Kurnool daily_deceased
# Kurnool daily_positivity_rate
# Kurnool daily_positive_cases_ma
# Kurnool daily_positivity_rate_ma
# Kurnool daily_tests
# Kurnool cum_tests
# Kurnool test_per_million
# Kurnool daily_cases_per_million
# Kurnool daily_tests_per_million
# Kurnool daily_tests_ma
# Kurnool daily_deceased_ma
# Kurnool dbt_point
# Kurnool dbt_l95
# Kurnool dbt_u95
# Kurnool rt_point
# Kurnool rt_sd
# Kurnool rt_l95
# Kurnool rt_u95
# Kurnool rt_l50
# Kurnool rt_u50
# Kurnool t_end
# Prakasam dates
# Prakasam cum_positive_cases
# Prakasam cum_positivity_rate
# Prakasam daily_positive_cases
# Prakasam cum_recovered
# Prakasam daily_recovered
# Prakasam cum_deceased
# Prakasam daily_deceased
# Prakasam daily_positivity_rate
# Prakasam daily_positive_cases_ma
# Prakasam daily_positivity_rate_ma
# Prakasam daily_tests
# Prakasam cum_tests
# Prakasam test_per_million
# Prakasam daily_cases_per_million
# Prakasam daily_tests_per_million
# Prakasam daily_tests_ma
# Prakasam daily_deceased_ma
# Prakasam dbt_point
# Prakasam dbt_l95
# Prakasam dbt_u95
# Prakasam rt_point
# Prakasam rt_sd
# Prakasam rt_l95
# Prakasam rt_u95
# Prakasam rt_l50
# Prakasam rt_u50
# Prakasam t_end
# Srikakulam dates
# Srikakulam cum_positive_cases
# Srikakulam cum_positivity_rate
# Srikakulam daily_positive_cases
# Srikakulam cum_recovered
# Srikakulam daily_recovered
# Srikakulam cum_deceased
# Srikakulam daily_deceased
# Srikakulam daily_positivity_rate
# Srikakulam daily_positive_cases_ma
# Srikakulam daily_positivity_rate_ma
# Srikakulam daily_tests
# Srikakulam cum_tests
# Srikakulam test_per_million
# Srikakulam daily_cases_per_million
# Srikakulam daily_tests_per_million
# Srikakulam daily_tests_ma
# Srikakulam daily_deceased_ma
# Srikakulam dbt_point
# Srikakulam dbt_l95
# Srikakulam dbt_u95
# Srikakulam rt_point
# Srikakulam rt_sd
# Srikakulam rt_l95
# Srikakulam rt_u95
# Srikakulam rt_l50
# Srikakulam rt_u50
# Srikakulam t_end
# Visakhapatnam dates
# Visakhapatnam cum_positive_cases
# Visakhapatnam cum_positivity_rate
# Visakhapatnam daily_positive_cases
# Visakhapatnam cum_recovered
# Visakhapatnam daily_recovered
# Visakhapatnam cum_deceased
# Visakhapatnam daily_deceased
# Visakhapatnam daily_positivity_rate
# Visakhapatnam daily_positive_cases_ma
# Visakhapatnam daily_positivity_rate_ma
# Visakhapatnam daily_tests
# Visakhapatnam cum_tests
# Visakhapatnam test_per_million
# Visakhapatnam daily_cases_per_million
# Visakhapatnam daily_tests_per_million
# Visakhapatnam daily_tests_ma
# Visakhapatnam daily_deceased_ma
# Visakhapatnam dbt_point
# Visakhapatnam dbt_l95
# Visakhapatnam dbt_u95
# Visakhapatnam rt_point
# Visakhapatnam rt_sd
# Visakhapatnam rt_l95
# Visakhapatnam rt_u95
# Visakhapatnam rt_l50
# Visakhapatnam rt_u50
# Visakhapatnam t_end
# Vizianagaram dates
# Vizianagaram cum_positive_cases
# Vizianagaram cum_positivity_rate
# Vizianagaram daily_positive_cases
# Vizianagaram cum_recovered
# Vizianagaram daily_recovered
# Vizianagaram cum_deceased
# Vizianagaram daily_deceased
# Vizianagaram daily_positivity_rate
# Vizianagaram daily_positive_cases_ma
# Vizianagaram daily_positivity_rate_ma
# Vizianagaram daily_tests
# Vizianagaram cum_tests
# Vizianagaram test_per_million
# Vizianagaram daily_cases_per_million
# Vizianagaram daily_tests_per_million
# Vizianagaram daily_tests_ma
# Vizianagaram daily_deceased_ma
# Vizianagaram dbt_point
# Vizianagaram dbt_l95
# Vizianagaram dbt_u95
# Vizianagaram rt_point
# Vizianagaram rt_sd
# Vizianagaram rt_l95
# Vizianagaram rt_u95
# Vizianagaram rt_l50
# Vizianagaram rt_u50
# Vizianagaram t_end
# West Godavari dates
# West Godavari cum_positive_cases
# West Godavari cum_positivity_rate
# West Godavari daily_positive_cases
# West Godavari cum_recovered
# West Godavari daily_recovered
# West Godavari cum_deceased
# West Godavari daily_deceased
# West Godavari daily_positivity_rate
# West Godavari daily_positive_cases_ma
# West Godavari daily_positivity_rate_ma
# West Godavari daily_tests
# West Godavari cum_tests
# West Godavari test_per_million
# West Godavari daily_cases_per_million
# West Godavari daily_tests_per_million
# West Godavari daily_tests_ma
# West Godavari daily_deceased_ma
# West Godavari dbt_point
# West Godavari dbt_l95
# West Godavari dbt_u95
# West Godavari rt_point
# West Godavari rt_sd
# West Godavari rt_l95
# West Godavari rt_u95
# West Godavari rt_l50
# West Godavari rt_u50
# West Godavari t_end
# S.P.S. Nellore dates
# S.P.S. Nellore cum_positive_cases
# S.P.S. Nellore cum_positivity_rate
# S.P.S. Nellore daily_positive_cases
# S.P.S. Nellore cum_recovered
# S.P.S. Nellore daily_recovered
# S.P.S. Nellore cum_deceased
# S.P.S. Nellore daily_deceased
# S.P.S. Nellore daily_positivity_rate
# S.P.S. Nellore daily_positive_cases_ma
# S.P.S. Nellore daily_positivity_rate_ma
# S.P.S. Nellore daily_tests
# S.P.S. Nellore cum_tests
# S.P.S. Nellore test_per_million
# S.P.S. Nellore daily_cases_per_million
# S.P.S. Nellore daily_tests_per_million
# S.P.S. Nellore daily_tests_ma
# S.P.S. Nellore daily_deceased_ma
# S.P.S. Nellore dbt_point
# S.P.S. Nellore dbt_l95
# S.P.S. Nellore dbt_u95
# S.P.S. Nellore rt_point
# S.P.S. Nellore rt_sd
# S.P.S. Nellore rt_l95
# S.P.S. Nellore rt_u95
# S.P.S. Nellore rt_l50
# S.P.S. Nellore rt_u50
# S.P.S. Nellore t_end
# Y.S.R. Kadapa dates
# Y.S.R. Kadapa cum_positive_cases
# Y.S.R. Kadapa cum_positivity_rate
# Y.S.R. Kadapa daily_positive_cases
# Y.S.R. Kadapa cum_recovered
# Y.S.R. Kadapa daily_recovered
# Y.S.R. Kadapa cum_deceased
# Y.S.R. Kadapa daily_deceased
# Y.S.R. Kadapa daily_positivity_rate
# Y.S.R. Kadapa daily_positive_cases_ma
# Y.S.R. Kadapa daily_positivity_rate_ma
# Y.S.R. Kadapa daily_tests
# Y.S.R. Kadapa cum_tests
# Y.S.R. Kadapa test_per_million
# Y.S.R. Kadapa daily_cases_per_million
# Y.S.R. Kadapa daily_tests_per_million
# Y.S.R. Kadapa daily_tests_ma
# Y.S.R. Kadapa daily_deceased_ma
# Y.S.R. Kadapa dbt_point
# Y.S.R. Kadapa dbt_l95
# Y.S.R. Kadapa dbt_u95
# Y.S.R. Kadapa rt_point
# Y.S.R. Kadapa rt_sd
# Y.S.R. Kadapa rt_l95
# Y.S.R. Kadapa rt_u95
# Y.S.R. Kadapa rt_l50
# Y.S.R. Kadapa rt_u50
# Y.S.R. Kadapa t_end
# Begusarai dates
# Begusarai cum_positive_cases
# Begusarai cum_positivity_rate
# Begusarai daily_positive_cases
# Begusarai cum_recovered
# Begusarai daily_recovered
# Begusarai cum_deceased
# Begusarai daily_deceased
# Begusarai daily_positivity_rate
# Begusarai daily_positive_cases_ma
# Begusarai daily_positivity_rate_ma
# Begusarai daily_tests
# Begusarai cum_tests
# Begusarai test_per_million
# Begusarai daily_cases_per_million
# Begusarai daily_tests_per_million
# Begusarai daily_tests_ma
# Begusarai daily_deceased_ma
# Begusarai dbt_point
# Begusarai dbt_l95
# Begusarai dbt_u95
# Begusarai rt_point
# Begusarai rt_sd
# Begusarai rt_l95
# Begusarai rt_u95
# Begusarai rt_l50
# Begusarai rt_u50
# Begusarai t_end
# Patna dates
# Patna cum_positive_cases
# Patna cum_positivity_rate
# Patna daily_positive_cases
# Patna cum_recovered
# Patna daily_recovered
# Patna cum_deceased
# Patna daily_deceased
# Patna daily_positivity_rate
# Patna daily_positive_cases_ma
# Patna daily_positivity_rate_ma
# Patna daily_tests
# Patna cum_tests
# Patna test_per_million
# Patna daily_cases_per_million
# Patna daily_tests_per_million
# Patna daily_tests_ma
# Patna daily_deceased_ma
# Patna dbt_point
# Patna dbt_l95
# Patna dbt_u95
# Patna rt_point
# Patna rt_sd
# Patna rt_l95
# Patna rt_u95
# Patna rt_l50
# Patna rt_u50
# Patna t_end
# Raipur dates
# Raipur cum_positive_cases
# Raipur cum_positivity_rate
# Raipur daily_positive_cases
# Raipur cum_recovered
# Raipur daily_recovered
# Raipur cum_deceased
# Raipur daily_deceased
# Raipur daily_positivity_rate
# Raipur daily_positive_cases_ma
# Raipur daily_positivity_rate_ma
# Raipur daily_tests
# Raipur cum_tests
# Raipur test_per_million
# Raipur daily_cases_per_million
# Raipur daily_tests_per_million
# Raipur daily_tests_ma
# Raipur daily_deceased_ma
# Raipur dbt_point
# Raipur dbt_l95
# Raipur dbt_u95
# Raipur rt_point
# Raipur rt_sd
# Raipur rt_l95
# Raipur rt_u95
# Raipur rt_l50
# Raipur rt_u50
# Raipur t_end
# Ahmedabad dates
# Ahmedabad cum_positive_cases
# Ahmedabad cum_positivity_rate
# Ahmedabad daily_positive_cases
# Ahmedabad cum_recovered
# Ahmedabad daily_recovered
# Ahmedabad cum_deceased
# Ahmedabad daily_deceased
# Ahmedabad daily_positivity_rate
# Ahmedabad daily_positive_cases_ma
# Ahmedabad daily_positivity_rate_ma
# Ahmedabad daily_tests
# Ahmedabad cum_tests
# Ahmedabad test_per_million
# Ahmedabad daily_cases_per_million
# Ahmedabad daily_tests_per_million
# Ahmedabad daily_tests_ma
# Ahmedabad daily_deceased_ma
# Ahmedabad dbt_point
# Ahmedabad dbt_l95
# Ahmedabad dbt_u95
# Ahmedabad rt_point
# Ahmedabad rt_sd
# Ahmedabad rt_l95
# Ahmedabad rt_u95
# Ahmedabad rt_l50
# Ahmedabad rt_u50
# Ahmedabad t_end
# Rajkot dates
# Rajkot cum_positive_cases
# Rajkot cum_positivity_rate
# Rajkot daily_positive_cases
# Rajkot cum_recovered
# Rajkot daily_recovered
# Rajkot cum_deceased
# Rajkot daily_deceased
# Rajkot daily_positivity_rate
# Rajkot daily_positive_cases_ma
# Rajkot daily_positivity_rate_ma
# Rajkot daily_tests
# Rajkot cum_tests
# Rajkot test_per_million
# Rajkot daily_cases_per_million
# Rajkot daily_tests_per_million
# Rajkot daily_tests_ma
# Rajkot daily_deceased_ma
# Rajkot dbt_point
# Rajkot dbt_l95
# Rajkot dbt_u95
# Rajkot rt_point
# Rajkot rt_sd
# Rajkot rt_l95
# Rajkot rt_u95
# Rajkot rt_l50
# Rajkot rt_u50
# Rajkot t_end
# Surat dates
# Surat cum_positive_cases
# Surat cum_positivity_rate
# Surat daily_positive_cases
# Surat cum_recovered
# Surat daily_recovered
# Surat cum_deceased
# Surat daily_deceased
# Surat daily_positivity_rate
# Surat daily_positive_cases_ma
# Surat daily_positivity_rate_ma
# Surat daily_tests
# Surat cum_tests
# Surat test_per_million
# Surat daily_cases_per_million
# Surat daily_tests_per_million
# Surat daily_tests_ma
# Surat daily_deceased_ma
# Surat dbt_point
# Surat dbt_l95
# Surat dbt_u95
# Surat rt_point
# Surat rt_sd
# Surat rt_l95
# Surat rt_u95
# Surat rt_l50
# Surat rt_u50
# Surat t_end
# Vadodara dates
# Vadodara cum_positive_cases
# Vadodara cum_positivity_rate
# Vadodara daily_positive_cases
# Vadodara cum_recovered
# Vadodara daily_recovered
# Vadodara cum_deceased
# Vadodara daily_deceased
# Vadodara daily_positivity_rate
# Vadodara daily_positive_cases_ma
# Vadodara daily_positivity_rate_ma
# Vadodara daily_tests
# Vadodara cum_tests
# Vadodara test_per_million
# Vadodara daily_cases_per_million
# Vadodara daily_tests_per_million
# Vadodara daily_tests_ma
# Vadodara daily_deceased_ma
# Vadodara dbt_point
# Vadodara dbt_l95
# Vadodara dbt_u95
# Vadodara rt_point
# Vadodara rt_sd
# Vadodara rt_l95
# Vadodara rt_u95
# Vadodara rt_l50
# Vadodara rt_u50
# Vadodara t_end
# Faridabad dates
# Faridabad cum_positive_cases
# Faridabad cum_positivity_rate
# Faridabad daily_positive_cases
# Faridabad cum_recovered
# Faridabad daily_recovered
# Faridabad cum_deceased
# Faridabad daily_deceased
# Faridabad daily_positivity_rate
# Faridabad daily_positive_cases_ma
# Faridabad daily_positivity_rate_ma
# Faridabad daily_tests
# Faridabad cum_tests
# Faridabad test_per_million
# Faridabad daily_cases_per_million
# Faridabad daily_tests_per_million
# Faridabad daily_tests_ma
# Faridabad daily_deceased_ma
# Faridabad dbt_point
# Faridabad dbt_l95
# Faridabad dbt_u95
# Faridabad rt_point
# Faridabad rt_sd
# Faridabad rt_l95
# Faridabad rt_u95
# Faridabad rt_l50
# Faridabad rt_u50
# Faridabad t_end
# Gurugram dates
# Gurugram cum_positive_cases
# Gurugram cum_positivity_rate
# Gurugram daily_positive_cases
# Gurugram cum_recovered
# Gurugram daily_recovered
# Gurugram cum_deceased
# Gurugram daily_deceased
# Gurugram daily_positivity_rate
# Gurugram daily_positive_cases_ma
# Gurugram daily_positivity_rate_ma
# Gurugram daily_tests
# Gurugram cum_tests
# Gurugram test_per_million
# Gurugram daily_cases_per_million
# Gurugram daily_tests_per_million
# Gurugram daily_tests_ma
# Gurugram daily_deceased_ma
# Gurugram dbt_point
# Gurugram dbt_l95
# Gurugram dbt_u95
# Gurugram rt_point
# Gurugram rt_sd
# Gurugram rt_l95
# Gurugram rt_u95
# Gurugram rt_l50
# Gurugram rt_u50
# Gurugram t_end
# East Singhbhum dates
# East Singhbhum cum_positive_cases
# East Singhbhum cum_positivity_rate
# East Singhbhum daily_positive_cases
# East Singhbhum cum_recovered
# East Singhbhum daily_recovered
# East Singhbhum cum_deceased
# East Singhbhum daily_deceased
# East Singhbhum daily_positivity_rate
# East Singhbhum daily_positive_cases_ma
# East Singhbhum daily_positivity_rate_ma
# East Singhbhum daily_tests
# East Singhbhum cum_tests
# East Singhbhum test_per_million
# East Singhbhum daily_cases_per_million
# East Singhbhum daily_tests_per_million
# East Singhbhum daily_tests_ma
# East Singhbhum daily_deceased_ma
# East Singhbhum dbt_point
# East Singhbhum dbt_l95
# East Singhbhum dbt_u95
# East Singhbhum rt_point
# East Singhbhum rt_sd
# East Singhbhum rt_l95
# East Singhbhum rt_u95
# East Singhbhum rt_l50
# East Singhbhum rt_u50
# East Singhbhum t_end
# Koderma dates
# Koderma cum_positive_cases
# Koderma cum_positivity_rate
# Koderma daily_positive_cases
# Koderma cum_recovered
# Koderma daily_recovered
# Koderma cum_deceased
# Koderma daily_deceased
# Koderma daily_positivity_rate
# Koderma daily_positive_cases_ma
# Koderma daily_positivity_rate_ma
# Koderma daily_tests
# Koderma cum_tests
# Koderma test_per_million
# Koderma daily_cases_per_million
# Koderma daily_tests_per_million
# Koderma daily_tests_ma
# Koderma daily_deceased_ma
# Koderma dbt_point
# Koderma dbt_l95
# Koderma dbt_u95
# Koderma rt_point
# Koderma rt_sd
# Koderma rt_l95
# Koderma rt_u95
# Koderma rt_l50
# Koderma rt_u50
# Koderma t_end
# Ranchi dates
# Ranchi cum_positive_cases
# Ranchi cum_positivity_rate
# Ranchi daily_positive_cases
# Ranchi cum_recovered
# Ranchi daily_recovered
# Ranchi cum_deceased
# Ranchi daily_deceased
# Ranchi daily_positivity_rate
# Ranchi daily_positive_cases_ma
# Ranchi daily_positivity_rate_ma
# Ranchi daily_tests
# Ranchi cum_tests
# Ranchi test_per_million
# Ranchi daily_cases_per_million
# Ranchi daily_tests_per_million
# Ranchi daily_tests_ma
# Ranchi daily_deceased_ma
# Ranchi dbt_point
# Ranchi dbt_l95
# Ranchi dbt_u95
# Ranchi rt_point
# Ranchi rt_sd
# Ranchi rt_l95
# Ranchi rt_u95
# Ranchi rt_l50
# Ranchi rt_u50
# Ranchi t_end
# Ramgarh dates
# Ramgarh cum_positive_cases
# Ramgarh cum_positivity_rate
# Ramgarh daily_positive_cases
# Ramgarh cum_recovered
# Ramgarh daily_recovered
# Ramgarh cum_deceased
# Ramgarh daily_deceased
# Ramgarh daily_positivity_rate
# Ramgarh daily_positive_cases_ma
# Ramgarh daily_positivity_rate_ma
# Ramgarh daily_tests
# Ramgarh cum_tests
# Ramgarh test_per_million
# Ramgarh daily_cases_per_million
# Ramgarh daily_tests_per_million
# Ramgarh daily_tests_ma
# Ramgarh daily_deceased_ma
# Ramgarh dbt_point
# Ramgarh dbt_l95
# Ramgarh dbt_u95
# Ramgarh rt_point
# Ramgarh rt_sd
# Ramgarh rt_l95
# Ramgarh rt_u95
# Ramgarh rt_l50
# Ramgarh rt_u50
# Ramgarh t_end
# West Singhbhum dates
# West Singhbhum cum_positive_cases
# West Singhbhum cum_positivity_rate
# West Singhbhum daily_positive_cases
# West Singhbhum cum_recovered
# West Singhbhum daily_recovered
# West Singhbhum cum_deceased
# West Singhbhum daily_deceased
# West Singhbhum daily_positivity_rate
# West Singhbhum daily_positive_cases_ma
# West Singhbhum daily_positivity_rate_ma
# West Singhbhum daily_tests
# West Singhbhum cum_tests
# West Singhbhum test_per_million
# West Singhbhum daily_cases_per_million
# West Singhbhum daily_tests_per_million
# West Singhbhum daily_tests_ma
# West Singhbhum daily_deceased_ma
# West Singhbhum dbt_point
# West Singhbhum dbt_l95
# West Singhbhum dbt_u95
# West Singhbhum rt_point
# West Singhbhum rt_sd
# West Singhbhum rt_l95
# West Singhbhum rt_u95
# West Singhbhum rt_l50
# West Singhbhum rt_u50
# West Singhbhum t_end
# Bengaluru Urban dates
# Bengaluru Urban cum_positive_cases
# Bengaluru Urban cum_positivity_rate
# Bengaluru Urban daily_positive_cases
# Bengaluru Urban cum_recovered
# Bengaluru Urban daily_recovered
# Bengaluru Urban cum_deceased
# Bengaluru Urban daily_deceased
# Bengaluru Urban daily_positivity_rate
# Bengaluru Urban daily_positive_cases_ma
# Bengaluru Urban daily_positivity_rate_ma
# Bengaluru Urban daily_tests
# Bengaluru Urban cum_tests
# Bengaluru Urban test_per_million
# Bengaluru Urban daily_cases_per_million
# Bengaluru Urban daily_tests_per_million
# Bengaluru Urban daily_tests_ma
# Bengaluru Urban daily_deceased_ma
# Bengaluru Urban dbt_point
# Bengaluru Urban dbt_l95
# Bengaluru Urban dbt_u95
# Bengaluru Urban rt_point
# Bengaluru Urban rt_sd
# Bengaluru Urban rt_l95
# Bengaluru Urban rt_u95
# Bengaluru Urban rt_l50
# Bengaluru Urban rt_u50
# Bengaluru Urban t_end
# Ballari dates
# Ballari cum_positive_cases
# Ballari cum_positivity_rate
# Ballari daily_positive_cases
# Ballari cum_recovered
# Ballari daily_recovered
# Ballari cum_deceased
# Ballari daily_deceased
# Ballari daily_positivity_rate
# Ballari daily_positive_cases_ma
# Ballari daily_positivity_rate_ma
# Ballari daily_tests
# Ballari cum_tests
# Ballari test_per_million
# Ballari daily_cases_per_million
# Ballari daily_tests_per_million
# Ballari daily_tests_ma
# Ballari daily_deceased_ma
# Ballari dbt_point
# Ballari dbt_l95
# Ballari dbt_u95
# Ballari rt_point
# Ballari rt_sd
# Ballari rt_l95
# Ballari rt_u95
# Ballari rt_l50
# Ballari rt_u50
# Ballari t_end
# Mysuru dates
# Mysuru cum_positive_cases
# Mysuru cum_positivity_rate
# Mysuru daily_positive_cases
# Mysuru cum_recovered
# Mysuru daily_recovered
# Mysuru cum_deceased
# Mysuru daily_deceased
# Mysuru daily_positivity_rate
# Mysuru daily_positive_cases_ma
# Mysuru daily_positivity_rate_ma
# Mysuru daily_tests
# Mysuru cum_tests
# Mysuru test_per_million
# Mysuru daily_cases_per_million
# Mysuru daily_tests_per_million
# Mysuru daily_tests_ma
# Mysuru daily_deceased_ma
# Mysuru dbt_point
# Mysuru dbt_l95
# Mysuru dbt_u95
# Mysuru rt_point
# Mysuru rt_sd
# Mysuru rt_l95
# Mysuru rt_u95
# Mysuru rt_l50
# Mysuru rt_u50
# Mysuru t_end
# Belagavi dates
# Belagavi cum_positive_cases
# Belagavi cum_positivity_rate
# Belagavi daily_positive_cases
# Belagavi cum_recovered
# Belagavi daily_recovered
# Belagavi cum_deceased
# Belagavi daily_deceased
# Belagavi daily_positivity_rate
# Belagavi daily_positive_cases_ma
# Belagavi daily_positivity_rate_ma
# Belagavi daily_tests
# Belagavi cum_tests
# Belagavi test_per_million
# Belagavi daily_cases_per_million
# Belagavi daily_tests_per_million
# Belagavi daily_tests_ma
# Belagavi daily_deceased_ma
# Belagavi dbt_point
# Belagavi dbt_l95
# Belagavi dbt_u95
# Belagavi rt_point
# Belagavi rt_sd
# Belagavi rt_l95
# Belagavi rt_u95
# Belagavi rt_l50
# Belagavi rt_u50
# Belagavi t_end
# Chitradurga dates
# Chitradurga cum_positive_cases
# Chitradurga cum_positivity_rate
# Chitradurga daily_positive_cases
# Chitradurga cum_recovered
# Chitradurga daily_recovered
# Chitradurga cum_deceased
# Chitradurga daily_deceased
# Chitradurga daily_positivity_rate
# Chitradurga daily_positive_cases_ma
# Chitradurga daily_positivity_rate_ma
# Chitradurga daily_tests
# Chitradurga cum_tests
# Chitradurga test_per_million
# Chitradurga daily_cases_per_million
# Chitradurga daily_tests_per_million
# Chitradurga daily_tests_ma
# Chitradurga daily_deceased_ma
# Chitradurga dbt_point
# Chitradurga dbt_l95
# Chitradurga dbt_u95
# Chitradurga rt_point
# Chitradurga rt_sd
# Chitradurga rt_l95
# Chitradurga rt_u95
# Chitradurga rt_l50
# Chitradurga rt_u50
# Chitradurga t_end
# Tumakuru dates
# Tumakuru cum_positive_cases
# Tumakuru cum_positivity_rate
# Tumakuru daily_positive_cases
# Tumakuru cum_recovered
# Tumakuru daily_recovered
# Tumakuru cum_deceased
# Tumakuru daily_deceased
# Tumakuru daily_positivity_rate
# Tumakuru daily_positive_cases_ma
# Tumakuru daily_positivity_rate_ma
# Tumakuru daily_tests
# Tumakuru cum_tests
# Tumakuru test_per_million
# Tumakuru daily_cases_per_million
# Tumakuru daily_tests_per_million
# Tumakuru daily_tests_ma
# Tumakuru daily_deceased_ma
# Tumakuru dbt_point
# Tumakuru dbt_l95
# Tumakuru dbt_u95
# Tumakuru rt_point
# Tumakuru rt_sd
# Tumakuru rt_l95
# Tumakuru rt_u95
# Tumakuru rt_l50
# Tumakuru rt_u50
# Tumakuru t_end
# Thiruvananthapuram dates
# Thiruvananthapuram cum_positive_cases
# Thiruvananthapuram cum_positivity_rate
# Thiruvananthapuram daily_positive_cases
# Thiruvananthapuram cum_recovered
# Thiruvananthapuram daily_recovered
# Thiruvananthapuram cum_deceased
# Thiruvananthapuram daily_deceased
# Thiruvananthapuram daily_positivity_rate
# Thiruvananthapuram daily_positive_cases_ma
# Thiruvananthapuram daily_positivity_rate_ma
# Thiruvananthapuram daily_tests
# Thiruvananthapuram cum_tests
# Thiruvananthapuram test_per_million
# Thiruvananthapuram daily_cases_per_million
# Thiruvananthapuram daily_tests_per_million
# Thiruvananthapuram daily_tests_ma
# Thiruvananthapuram daily_deceased_ma
# Thiruvananthapuram dbt_point
# Thiruvananthapuram dbt_l95
# Thiruvananthapuram dbt_u95
# Thiruvananthapuram rt_point
# Thiruvananthapuram rt_sd
# Thiruvananthapuram rt_l95
# Thiruvananthapuram rt_u95
# Thiruvananthapuram rt_l50
# Thiruvananthapuram rt_u50
# Thiruvananthapuram t_end
# Aurangabad dates
# Aurangabad cum_positive_cases
# Aurangabad cum_positivity_rate
# Aurangabad daily_positive_cases
# Aurangabad cum_recovered
# Aurangabad daily_recovered
# Aurangabad cum_deceased
# Aurangabad daily_deceased
# Aurangabad daily_positivity_rate
# Aurangabad daily_positive_cases_ma
# Aurangabad daily_positivity_rate_ma
# Aurangabad daily_tests
# Aurangabad cum_tests
# Aurangabad test_per_million
# Aurangabad daily_cases_per_million
# Aurangabad daily_tests_per_million
# Aurangabad daily_tests_ma
# Aurangabad daily_deceased_ma
# Aurangabad dbt_point
# Aurangabad dbt_l95
# Aurangabad dbt_u95
# Aurangabad rt_point
# Aurangabad rt_sd
# Aurangabad rt_l95
# Aurangabad rt_u95
# Aurangabad rt_l50
# Aurangabad rt_u50
# Aurangabad t_end
# Jalgaon dates
# Jalgaon cum_positive_cases
# Jalgaon cum_positivity_rate
# Jalgaon daily_positive_cases
# Jalgaon cum_recovered
# Jalgaon daily_recovered
# Jalgaon cum_deceased
# Jalgaon daily_deceased
# Jalgaon daily_positivity_rate
# Jalgaon daily_positive_cases_ma
# Jalgaon daily_positivity_rate_ma
# Jalgaon daily_tests
# Jalgaon cum_tests
# Jalgaon test_per_million
# Jalgaon daily_cases_per_million
# Jalgaon daily_tests_per_million
# Jalgaon daily_tests_ma
# Jalgaon daily_deceased_ma
# Jalgaon dbt_point
# Jalgaon dbt_l95
# Jalgaon dbt_u95
# Jalgaon rt_point
# Jalgaon rt_sd
# Jalgaon rt_l95
# Jalgaon rt_u95
# Jalgaon rt_l50
# Jalgaon rt_u50
# Jalgaon t_end
# Kolhapur dates
# Kolhapur cum_positive_cases
# Kolhapur cum_positivity_rate
# Kolhapur daily_positive_cases
# Kolhapur cum_recovered
# Kolhapur daily_recovered
# Kolhapur cum_deceased
# Kolhapur daily_deceased
# Kolhapur daily_positivity_rate
# Kolhapur daily_positive_cases_ma
# Kolhapur daily_positivity_rate_ma
# Kolhapur daily_tests
# Kolhapur cum_tests
# Kolhapur test_per_million
# Kolhapur daily_cases_per_million
# Kolhapur daily_tests_per_million
# Kolhapur daily_tests_ma
# Kolhapur daily_deceased_ma
# Kolhapur dbt_point
# Kolhapur dbt_l95
# Kolhapur dbt_u95
# Kolhapur rt_point
# Kolhapur rt_sd
# Kolhapur rt_l95
# Kolhapur rt_u95
# Kolhapur rt_l50
# Kolhapur rt_u50
# Kolhapur t_end
# Mumbai dates
# Mumbai cum_positive_cases
# Mumbai cum_positivity_rate
# Mumbai daily_positive_cases
# Mumbai cum_recovered
# Mumbai daily_recovered
# Mumbai cum_deceased
# Mumbai daily_deceased
# Mumbai daily_positivity_rate
# Mumbai daily_positive_cases_ma
# Mumbai daily_positivity_rate_ma
# Mumbai daily_tests
# Mumbai cum_tests
# Mumbai test_per_million
# Mumbai daily_cases_per_million
# Mumbai daily_tests_per_million
# Mumbai daily_tests_ma
# Mumbai daily_deceased_ma
# Mumbai dbt_point
# Mumbai dbt_l95
# Mumbai dbt_u95
# Mumbai rt_point
# Mumbai rt_sd
# Mumbai rt_l95
# Mumbai rt_u95
# Mumbai rt_l50
# Mumbai rt_u50
# Mumbai t_end
# Nagpur dates
# Nagpur cum_positive_cases
# Nagpur cum_positivity_rate
# Nagpur daily_positive_cases
# Nagpur cum_recovered
# Nagpur daily_recovered
# Nagpur cum_deceased
# Nagpur daily_deceased
# Nagpur daily_positivity_rate
# Nagpur daily_positive_cases_ma
# Nagpur daily_positivity_rate_ma
# Nagpur daily_tests
# Nagpur cum_tests
# Nagpur test_per_million
# Nagpur daily_cases_per_million
# Nagpur daily_tests_per_million
# Nagpur daily_tests_ma
# Nagpur daily_deceased_ma
# Nagpur dbt_point
# Nagpur dbt_l95
# Nagpur dbt_u95
# Nagpur rt_point
# Nagpur rt_sd
# Nagpur rt_l95
# Nagpur rt_u95
# Nagpur rt_l50
# Nagpur rt_u50
# Nagpur t_end
# Nashik dates
# Nashik cum_positive_cases
# Nashik cum_positivity_rate
# Nashik daily_positive_cases
# Nashik cum_recovered
# Nashik daily_recovered
# Nashik cum_deceased
# Nashik daily_deceased
# Nashik daily_positivity_rate
# Nashik daily_positive_cases_ma
# Nashik daily_positivity_rate_ma
# Nashik daily_tests
# Nashik cum_tests
# Nashik test_per_million
# Nashik daily_cases_per_million
# Nashik daily_tests_per_million
# Nashik daily_tests_ma
# Nashik daily_deceased_ma
# Nashik dbt_point
# Nashik dbt_l95
# Nashik dbt_u95
# Nashik rt_point
# Nashik rt_sd
# Nashik rt_l95
# Nashik rt_u95
# Nashik rt_l50
# Nashik rt_u50
# Nashik t_end
# Palghar dates
# Palghar cum_positive_cases
# Palghar cum_positivity_rate
# Palghar daily_positive_cases
# Palghar cum_recovered
# Palghar daily_recovered
# Palghar cum_deceased
# Palghar daily_deceased
# Palghar daily_positivity_rate
# Palghar daily_positive_cases_ma
# Palghar daily_positivity_rate_ma
# Palghar daily_tests
# Palghar cum_tests
# Palghar test_per_million
# Palghar daily_cases_per_million
# Palghar daily_tests_per_million
# Palghar daily_tests_ma
# Palghar daily_deceased_ma
# Palghar dbt_point
# Palghar dbt_l95
# Palghar dbt_u95
# Palghar rt_point
# Palghar rt_sd
# Palghar rt_l95
# Palghar rt_u95
# Palghar rt_l50
# Palghar rt_u50
# Palghar t_end
# Pune dates
# Pune cum_positive_cases
# Pune cum_positivity_rate
# Pune daily_positive_cases
# Pune cum_recovered
# Pune daily_recovered
# Pune cum_deceased
# Pune daily_deceased
# Pune daily_positivity_rate
# Pune daily_positive_cases_ma
# Pune daily_positivity_rate_ma
# Pune daily_tests
# Pune cum_tests
# Pune test_per_million
# Pune daily_cases_per_million
# Pune daily_tests_per_million
# Pune daily_tests_ma
# Pune daily_deceased_ma
# Pune dbt_point
# Pune dbt_l95
# Pune dbt_u95
# Pune rt_point
# Pune rt_sd
# Pune rt_l95
# Pune rt_u95
# Pune rt_l50
# Pune rt_u50
# Pune t_end
# Raigad dates
# Raigad cum_positive_cases
# Raigad cum_positivity_rate
# Raigad daily_positive_cases
# Raigad cum_recovered
# Raigad daily_recovered
# Raigad cum_deceased
# Raigad daily_deceased
# Raigad daily_positivity_rate
# Raigad daily_positive_cases_ma
# Raigad daily_positivity_rate_ma
# Raigad daily_tests
# Raigad cum_tests
# Raigad test_per_million
# Raigad daily_cases_per_million
# Raigad daily_tests_per_million
# Raigad daily_tests_ma
# Raigad daily_deceased_ma
# Raigad dbt_point
# Raigad dbt_l95
# Raigad dbt_u95
# Raigad rt_point
# Raigad rt_sd
# Raigad rt_l95
# Raigad rt_u95
# Raigad rt_l50
# Raigad rt_u50
# Raigad t_end
# Solapur dates
# Solapur cum_positive_cases
# Solapur cum_positivity_rate
# Solapur daily_positive_cases
# Solapur cum_recovered
# Solapur daily_recovered
# Solapur cum_deceased
# Solapur daily_deceased
# Solapur daily_positivity_rate
# Solapur daily_positive_cases_ma
# Solapur daily_positivity_rate_ma
# Solapur daily_tests
# Solapur cum_tests
# Solapur test_per_million
# Solapur daily_cases_per_million
# Solapur daily_tests_per_million
# Solapur daily_tests_ma
# Solapur daily_deceased_ma
# Solapur dbt_point
# Solapur dbt_l95
# Solapur dbt_u95
# Solapur rt_point
# Solapur rt_sd
# Solapur rt_l95
# Solapur rt_u95
# Solapur rt_l50
# Solapur rt_u50
# Solapur t_end
# Thane dates
# Thane cum_positive_cases
# Thane cum_positivity_rate
# Thane daily_positive_cases
# Thane cum_recovered
# Thane daily_recovered
# Thane cum_deceased
# Thane daily_deceased
# Thane daily_positivity_rate
# Thane daily_positive_cases_ma
# Thane daily_positivity_rate_ma
# Thane daily_tests
# Thane cum_tests
# Thane test_per_million
# Thane daily_cases_per_million
# Thane daily_tests_per_million
# Thane daily_tests_ma
# Thane daily_deceased_ma
# Thane dbt_point
# Thane dbt_l95
# Thane dbt_u95
# Thane rt_point
# Thane rt_sd
# Thane rt_l95
# Thane rt_u95
# Thane rt_l50
# Thane rt_u50
# Thane t_end
# Satara dates
# Satara cum_positive_cases
# Satara cum_positivity_rate
# Satara daily_positive_cases
# Satara cum_recovered
# Satara daily_recovered
# Satara cum_deceased
# Satara daily_deceased
# Satara daily_positivity_rate
# Satara daily_positive_cases_ma
# Satara daily_positivity_rate_ma
# Satara daily_tests
# Satara cum_tests
# Satara test_per_million
# Satara daily_cases_per_million
# Satara daily_tests_per_million
# Satara daily_tests_ma
# Satara daily_deceased_ma
# Satara dbt_point
# Satara dbt_l95
# Satara dbt_u95
# Satara rt_point
# Satara rt_sd
# Satara rt_l95
# Satara rt_u95
# Satara rt_l50
# Satara rt_u50
# Satara t_end
# Sangli dates
# Sangli cum_positive_cases
# Sangli cum_positivity_rate
# Sangli daily_positive_cases
# Sangli cum_recovered
# Sangli daily_recovered
# Sangli cum_deceased
# Sangli daily_deceased
# Sangli daily_positivity_rate
# Sangli daily_positive_cases_ma
# Sangli daily_positivity_rate_ma
# Sangli daily_tests
# Sangli cum_tests
# Sangli test_per_million
# Sangli daily_cases_per_million
# Sangli daily_tests_per_million
# Sangli daily_tests_ma
# Sangli daily_deceased_ma
# Sangli dbt_point
# Sangli dbt_l95
# Sangli dbt_u95
# Sangli rt_point
# Sangli rt_sd
# Sangli rt_l95
# Sangli rt_u95
# Sangli rt_l50
# Sangli rt_u50
# Sangli t_end
# Ahmednagar dates
# Ahmednagar cum_positive_cases
# Ahmednagar cum_positivity_rate
# Ahmednagar daily_positive_cases
# Ahmednagar cum_recovered
# Ahmednagar daily_recovered
# Ahmednagar cum_deceased
# Ahmednagar daily_deceased
# Ahmednagar daily_positivity_rate
# Ahmednagar daily_positive_cases_ma
# Ahmednagar daily_positivity_rate_ma
# Ahmednagar daily_tests
# Ahmednagar cum_tests
# Ahmednagar test_per_million
# Ahmednagar daily_cases_per_million
# Ahmednagar daily_tests_per_million
# Ahmednagar daily_tests_ma
# Ahmednagar daily_deceased_ma
# Ahmednagar dbt_point
# Ahmednagar dbt_l95
# Ahmednagar dbt_u95
# Ahmednagar rt_point
# Ahmednagar rt_sd
# Ahmednagar rt_l95
# Ahmednagar rt_u95
# Ahmednagar rt_l50
# Ahmednagar rt_u50
# Ahmednagar t_end
# Nanded dates
# Nanded cum_positive_cases
# Nanded cum_positivity_rate
# Nanded daily_positive_cases
# Nanded cum_recovered
# Nanded daily_recovered
# Nanded cum_deceased
# Nanded daily_deceased
# Nanded daily_positivity_rate
# Nanded daily_positive_cases_ma
# Nanded daily_positivity_rate_ma
# Nanded daily_tests
# Nanded cum_tests
# Nanded test_per_million
# Nanded daily_cases_per_million
# Nanded daily_tests_per_million
# Nanded daily_tests_ma
# Nanded daily_deceased_ma
# Nanded dbt_point
# Nanded dbt_l95
# Nanded dbt_u95
# Nanded rt_point
# Nanded rt_sd
# Nanded rt_l95
# Nanded rt_u95
# Nanded rt_l50
# Nanded rt_u50
# Nanded t_end
# Bhopal dates
# Bhopal cum_positive_cases
# Bhopal cum_positivity_rate
# Bhopal daily_positive_cases
# Bhopal cum_recovered
# Bhopal daily_recovered
# Bhopal cum_deceased
# Bhopal daily_deceased
# Bhopal daily_positivity_rate
# Bhopal daily_positive_cases_ma
# Bhopal daily_positivity_rate_ma
# Bhopal daily_tests
# Bhopal cum_tests
# Bhopal test_per_million
# Bhopal daily_cases_per_million
# Bhopal daily_tests_per_million
# Bhopal daily_tests_ma
# Bhopal daily_deceased_ma
# Bhopal dbt_point
# Bhopal dbt_l95
# Bhopal dbt_u95
# Bhopal rt_point
# Bhopal rt_sd
# Bhopal rt_l95
# Bhopal rt_u95
# Bhopal rt_l50
# Bhopal rt_u50
# Bhopal t_end
# Indore dates
# Indore cum_positive_cases
# Indore cum_positivity_rate
# Indore daily_positive_cases
# Indore cum_recovered
# Indore daily_recovered
# Indore cum_deceased
# Indore daily_deceased
# Indore daily_positivity_rate
# Indore daily_positive_cases_ma
# Indore daily_positivity_rate_ma
# Indore daily_tests
# Indore cum_tests
# Indore test_per_million
# Indore daily_cases_per_million
# Indore daily_tests_per_million
# Indore daily_tests_ma
# Indore daily_deceased_ma
# Indore dbt_point
# Indore dbt_l95
# Indore dbt_u95
# Indore rt_point
# Indore rt_sd
# Indore rt_l95
# Indore rt_u95
# Indore rt_l50
# Indore rt_u50
# Indore t_end
# Ganjam dates
# Ganjam cum_positive_cases
# Ganjam cum_positivity_rate
# Ganjam daily_positive_cases
# Ganjam cum_recovered
# Ganjam daily_recovered
# Ganjam cum_deceased
# Ganjam daily_deceased
# Ganjam daily_positivity_rate
# Ganjam daily_positive_cases_ma
# Ganjam daily_positivity_rate_ma
# Ganjam daily_tests
# Ganjam cum_tests
# Ganjam test_per_million
# Ganjam daily_cases_per_million
# Ganjam daily_tests_per_million
# Ganjam daily_tests_ma
# Ganjam daily_deceased_ma
# Ganjam dbt_point
# Ganjam dbt_l95
# Ganjam dbt_u95
# Ganjam rt_point
# Ganjam rt_sd
# Ganjam rt_l95
# Ganjam rt_u95
# Ganjam rt_l50
# Ganjam rt_u50
# Ganjam t_end
# Khordha dates
# Khordha cum_positive_cases
# Khordha cum_positivity_rate
# Khordha daily_positive_cases
# Khordha cum_recovered
# Khordha daily_recovered
# Khordha cum_deceased
# Khordha daily_deceased
# Khordha daily_positivity_rate
# Khordha daily_positive_cases_ma
# Khordha daily_positivity_rate_ma
# Khordha daily_tests
# Khordha cum_tests
# Khordha test_per_million
# Khordha daily_cases_per_million
# Khordha daily_tests_per_million
# Khordha daily_tests_ma
# Khordha daily_deceased_ma
# Khordha dbt_point
# Khordha dbt_l95
# Khordha dbt_u95
# Khordha rt_point
# Khordha rt_sd
# Khordha rt_l95
# Khordha rt_u95
# Khordha rt_l50
# Khordha rt_u50
# Khordha t_end
# Ludhiana dates
# Ludhiana cum_positive_cases
# Ludhiana cum_positivity_rate
# Ludhiana daily_positive_cases
# Ludhiana cum_recovered
# Ludhiana daily_recovered
# Ludhiana cum_deceased
# Ludhiana daily_deceased
# Ludhiana daily_positivity_rate
# Ludhiana daily_positive_cases_ma
# Ludhiana daily_positivity_rate_ma
# Ludhiana daily_tests
# Ludhiana cum_tests
# Ludhiana test_per_million
# Ludhiana daily_cases_per_million
# Ludhiana daily_tests_per_million
# Ludhiana daily_tests_ma
# Ludhiana daily_deceased_ma
# Ludhiana dbt_point
# Ludhiana dbt_l95
# Ludhiana dbt_u95
# Ludhiana rt_point
# Ludhiana rt_sd
# Ludhiana rt_l95
# Ludhiana rt_u95
# Ludhiana rt_l50
# Ludhiana rt_u50
# Ludhiana t_end
# S.A.S. Nagar dates
# S.A.S. Nagar cum_positive_cases
# S.A.S. Nagar cum_positivity_rate
# S.A.S. Nagar daily_positive_cases
# S.A.S. Nagar cum_recovered
# S.A.S. Nagar daily_recovered
# S.A.S. Nagar cum_deceased
# S.A.S. Nagar daily_deceased
# S.A.S. Nagar daily_positivity_rate
# S.A.S. Nagar daily_positive_cases_ma
# S.A.S. Nagar daily_positivity_rate_ma
# S.A.S. Nagar daily_tests
# S.A.S. Nagar cum_tests
# S.A.S. Nagar test_per_million
# S.A.S. Nagar daily_cases_per_million
# S.A.S. Nagar daily_tests_per_million
# S.A.S. Nagar daily_tests_ma
# S.A.S. Nagar daily_deceased_ma
# S.A.S. Nagar dbt_point
# S.A.S. Nagar dbt_l95
# S.A.S. Nagar dbt_u95
# S.A.S. Nagar rt_point
# S.A.S. Nagar rt_sd
# S.A.S. Nagar rt_l95
# S.A.S. Nagar rt_u95
# S.A.S. Nagar rt_l50
# S.A.S. Nagar rt_u50
# S.A.S. Nagar t_end
# Jalandhar dates
# Jalandhar cum_positive_cases
# Jalandhar cum_positivity_rate
# Jalandhar daily_positive_cases
# Jalandhar cum_recovered
# Jalandhar daily_recovered
# Jalandhar cum_deceased
# Jalandhar daily_deceased
# Jalandhar daily_positivity_rate
# Jalandhar daily_positive_cases_ma
# Jalandhar daily_positivity_rate_ma
# Jalandhar daily_tests
# Jalandhar cum_tests
# Jalandhar test_per_million
# Jalandhar daily_cases_per_million
# Jalandhar daily_tests_per_million
# Jalandhar daily_tests_ma
# Jalandhar daily_deceased_ma
# Jalandhar dbt_point
# Jalandhar dbt_l95
# Jalandhar dbt_u95
# Jalandhar rt_point
# Jalandhar rt_sd
# Jalandhar rt_l95
# Jalandhar rt_u95
# Jalandhar rt_l50
# Jalandhar rt_u50
# Jalandhar t_end
# Jaipur dates
# Jaipur cum_positive_cases
# Jaipur cum_positivity_rate
# Jaipur daily_positive_cases
# Jaipur cum_recovered
# Jaipur daily_recovered
# Jaipur cum_deceased
# Jaipur daily_deceased
# Jaipur daily_positivity_rate
# Jaipur daily_positive_cases_ma
# Jaipur daily_positivity_rate_ma
# Jaipur daily_tests
# Jaipur cum_tests
# Jaipur test_per_million
# Jaipur daily_cases_per_million
# Jaipur daily_tests_per_million
# Jaipur daily_tests_ma
# Jaipur daily_deceased_ma
# Jaipur dbt_point
# Jaipur dbt_l95
# Jaipur dbt_u95
# Jaipur rt_point
# Jaipur rt_sd
# Jaipur rt_l95
# Jaipur rt_u95
# Jaipur rt_l50
# Jaipur rt_u50
# Jaipur t_end
# Chengalpattu dates
# Chengalpattu cum_positive_cases
# Chengalpattu cum_positivity_rate
# Chengalpattu daily_positive_cases
# Chengalpattu cum_recovered
# Chengalpattu daily_recovered
# Chengalpattu cum_deceased
# Chengalpattu daily_deceased
# Chengalpattu daily_positivity_rate
# Chengalpattu daily_positive_cases_ma
# Chengalpattu daily_positivity_rate_ma
# Chengalpattu daily_tests
# Chengalpattu cum_tests
# Chengalpattu test_per_million
# Chengalpattu daily_cases_per_million
# Chengalpattu daily_tests_per_million
# Chengalpattu daily_tests_ma
# Chengalpattu daily_deceased_ma
# Chengalpattu dbt_point
# Chengalpattu dbt_l95
# Chengalpattu dbt_u95
# Chengalpattu rt_point
# Chengalpattu rt_sd
# Chengalpattu rt_l95
# Chengalpattu rt_u95
# Chengalpattu rt_l50
# Chengalpattu rt_u50
# Chengalpattu t_end
# Chennai dates
# Chennai cum_positive_cases
# Chennai cum_positivity_rate
# Chennai daily_positive_cases
# Chennai cum_recovered
# Chennai daily_recovered
# Chennai cum_deceased
# Chennai daily_deceased
# Chennai daily_positivity_rate
# Chennai daily_positive_cases_ma
# Chennai daily_positivity_rate_ma
# Chennai daily_tests
# Chennai cum_tests
# Chennai test_per_million
# Chennai daily_cases_per_million
# Chennai daily_tests_per_million
# Chennai daily_tests_ma
# Chennai daily_deceased_ma
# Chennai dbt_point
# Chennai dbt_l95
# Chennai dbt_u95
# Chennai rt_point
# Chennai rt_sd
# Chennai rt_l95
# Chennai rt_u95
# Chennai rt_l50
# Chennai rt_u50
# Chennai t_end
# Kancheepuram dates
# Kancheepuram cum_positive_cases
# Kancheepuram cum_positivity_rate
# Kancheepuram daily_positive_cases
# Kancheepuram cum_recovered
# Kancheepuram daily_recovered
# Kancheepuram cum_deceased
# Kancheepuram daily_deceased
# Kancheepuram daily_positivity_rate
# Kancheepuram daily_positive_cases_ma
# Kancheepuram daily_positivity_rate_ma
# Kancheepuram daily_tests
# Kancheepuram cum_tests
# Kancheepuram test_per_million
# Kancheepuram daily_cases_per_million
# Kancheepuram daily_tests_per_million
# Kancheepuram daily_tests_ma
# Kancheepuram daily_deceased_ma
# Kancheepuram dbt_point
# Kancheepuram dbt_l95
# Kancheepuram dbt_u95
# Kancheepuram rt_point
# Kancheepuram rt_sd
# Kancheepuram rt_l95
# Kancheepuram rt_u95
# Kancheepuram rt_l50
# Kancheepuram rt_u50
# Kancheepuram t_end
# Madurai dates
# Madurai cum_positive_cases
# Madurai cum_positivity_rate
# Madurai daily_positive_cases
# Madurai cum_recovered
# Madurai daily_recovered
# Madurai cum_deceased
# Madurai daily_deceased
# Madurai daily_positivity_rate
# Madurai daily_positive_cases_ma
# Madurai daily_positivity_rate_ma
# Madurai daily_tests
# Madurai cum_tests
# Madurai test_per_million
# Madurai daily_cases_per_million
# Madurai daily_tests_per_million
# Madurai daily_tests_ma
# Madurai daily_deceased_ma
# Madurai dbt_point
# Madurai dbt_l95
# Madurai dbt_u95
# Madurai rt_point
# Madurai rt_sd
# Madurai rt_l95
# Madurai rt_u95
# Madurai rt_l50
# Madurai rt_u50
# Madurai t_end
# Thiruvallur dates
# Thiruvallur cum_positive_cases
# Thiruvallur cum_positivity_rate
# Thiruvallur daily_positive_cases
# Thiruvallur cum_recovered
# Thiruvallur daily_recovered
# Thiruvallur cum_deceased
# Thiruvallur daily_deceased
# Thiruvallur daily_positivity_rate
# Thiruvallur daily_positive_cases_ma
# Thiruvallur daily_positivity_rate_ma
# Thiruvallur daily_tests
# Thiruvallur cum_tests
# Thiruvallur test_per_million
# Thiruvallur daily_cases_per_million
# Thiruvallur daily_tests_per_million
# Thiruvallur daily_tests_ma
# Thiruvallur daily_deceased_ma
# Thiruvallur dbt_point
# Thiruvallur dbt_l95
# Thiruvallur dbt_u95
# Thiruvallur rt_point
# Thiruvallur rt_sd
# Thiruvallur rt_l95
# Thiruvallur rt_u95
# Thiruvallur rt_l50
# Thiruvallur rt_u50
# Thiruvallur t_end
# Tiruvannamalai dates
# Tiruvannamalai cum_positive_cases
# Tiruvannamalai cum_positivity_rate
# Tiruvannamalai daily_positive_cases
# Tiruvannamalai cum_recovered
# Tiruvannamalai daily_recovered
# Tiruvannamalai cum_deceased
# Tiruvannamalai daily_deceased
# Tiruvannamalai daily_positivity_rate
# Tiruvannamalai daily_positive_cases_ma
# Tiruvannamalai daily_positivity_rate_ma
# Tiruvannamalai daily_tests
# Tiruvannamalai cum_tests
# Tiruvannamalai test_per_million
# Tiruvannamalai daily_cases_per_million
# Tiruvannamalai daily_tests_per_million
# Tiruvannamalai daily_tests_ma
# Tiruvannamalai daily_deceased_ma
# Tiruvannamalai dbt_point
# Tiruvannamalai dbt_l95
# Tiruvannamalai dbt_u95
# Tiruvannamalai rt_point
# Tiruvannamalai rt_sd
# Tiruvannamalai rt_l95
# Tiruvannamalai rt_u95
# Tiruvannamalai rt_l50
# Tiruvannamalai rt_u50
# Tiruvannamalai t_end
# Vellore dates
# Vellore cum_positive_cases
# Vellore cum_positivity_rate
# Vellore daily_positive_cases
# Vellore cum_recovered
# Vellore daily_recovered
# Vellore cum_deceased
# Vellore daily_deceased
# Vellore daily_positivity_rate
# Vellore daily_positive_cases_ma
# Vellore daily_positivity_rate_ma
# Vellore daily_tests
# Vellore cum_tests
# Vellore test_per_million
# Vellore daily_cases_per_million
# Vellore daily_tests_per_million
# Vellore daily_tests_ma
# Vellore daily_deceased_ma
# Vellore dbt_point
# Vellore dbt_l95
# Vellore dbt_u95
# Vellore rt_point
# Vellore rt_sd
# Vellore rt_l95
# Vellore rt_u95
# Vellore rt_l50
# Vellore rt_u50
# Vellore t_end
# Coimbatore dates
# Coimbatore cum_positive_cases
# Coimbatore cum_positivity_rate
# Coimbatore daily_positive_cases
# Coimbatore cum_recovered
# Coimbatore daily_recovered
# Coimbatore cum_deceased
# Coimbatore daily_deceased
# Coimbatore daily_positivity_rate
# Coimbatore daily_positive_cases_ma
# Coimbatore daily_positivity_rate_ma
# Coimbatore daily_tests
# Coimbatore cum_tests
# Coimbatore test_per_million
# Coimbatore daily_cases_per_million
# Coimbatore daily_tests_per_million
# Coimbatore daily_tests_ma
# Coimbatore daily_deceased_ma
# Coimbatore dbt_point
# Coimbatore dbt_l95
# Coimbatore dbt_u95
# Coimbatore rt_point
# Coimbatore rt_sd
# Coimbatore rt_l95
# Coimbatore rt_u95
# Coimbatore rt_l50
# Coimbatore rt_u50
# Coimbatore t_end
# Aligarh dates
# Aligarh cum_positive_cases
# Aligarh cum_positivity_rate
# Aligarh daily_positive_cases
# Aligarh cum_recovered
# Aligarh daily_recovered
# Aligarh cum_deceased
# Aligarh daily_deceased
# Aligarh daily_positivity_rate
# Aligarh daily_positive_cases_ma
# Aligarh daily_positivity_rate_ma
# Aligarh daily_tests
# Aligarh cum_tests
# Aligarh test_per_million
# Aligarh daily_cases_per_million
# Aligarh daily_tests_per_million
# Aligarh daily_tests_ma
# Aligarh daily_deceased_ma
# Aligarh dbt_point
# Aligarh dbt_l95
# Aligarh dbt_u95
# Aligarh rt_point
# Aligarh rt_sd
# Aligarh rt_l95
# Aligarh rt_u95
# Aligarh rt_l50
# Aligarh rt_u50
# Aligarh t_end
# Bareilly dates
# Bareilly cum_positive_cases
# Bareilly cum_positivity_rate
# Bareilly daily_positive_cases
# Bareilly cum_recovered
# Bareilly daily_recovered
# Bareilly cum_deceased
# Bareilly daily_deceased
# Bareilly daily_positivity_rate
# Bareilly daily_positive_cases_ma
# Bareilly daily_positivity_rate_ma
# Bareilly daily_tests
# Bareilly cum_tests
# Bareilly test_per_million
# Bareilly daily_cases_per_million
# Bareilly daily_tests_per_million
# Bareilly daily_tests_ma
# Bareilly daily_deceased_ma
# Bareilly dbt_point
# Bareilly dbt_l95
# Bareilly dbt_u95
# Bareilly rt_point
# Bareilly rt_sd
# Bareilly rt_l95
# Bareilly rt_u95
# Bareilly rt_l50
# Bareilly rt_u50
# Bareilly t_end
# Gautam Buddha Nagar dates
# Gautam Buddha Nagar cum_positive_cases
# Gautam Buddha Nagar cum_positivity_rate
# Gautam Buddha Nagar daily_positive_cases
# Gautam Buddha Nagar cum_recovered
# Gautam Buddha Nagar daily_recovered
# Gautam Buddha Nagar cum_deceased
# Gautam Buddha Nagar daily_deceased
# Gautam Buddha Nagar daily_positivity_rate
# Gautam Buddha Nagar daily_positive_cases_ma
# Gautam Buddha Nagar daily_positivity_rate_ma
# Gautam Buddha Nagar daily_tests
# Gautam Buddha Nagar cum_tests
# Gautam Buddha Nagar test_per_million
# Gautam Buddha Nagar daily_cases_per_million
# Gautam Buddha Nagar daily_tests_per_million
# Gautam Buddha Nagar daily_tests_ma
# Gautam Buddha Nagar daily_deceased_ma
# Gautam Buddha Nagar dbt_point
# Gautam Buddha Nagar dbt_l95
# Gautam Buddha Nagar dbt_u95
# Gautam Buddha Nagar rt_point
# Gautam Buddha Nagar rt_sd
# Gautam Buddha Nagar rt_l95
# Gautam Buddha Nagar rt_u95
# Gautam Buddha Nagar rt_l50
# Gautam Buddha Nagar rt_u50
# Gautam Buddha Nagar t_end
# Ghaziabad dates
# Ghaziabad cum_positive_cases
# Ghaziabad cum_positivity_rate
# Ghaziabad daily_positive_cases
# Ghaziabad cum_recovered
# Ghaziabad daily_recovered
# Ghaziabad cum_deceased
# Ghaziabad daily_deceased
# Ghaziabad daily_positivity_rate
# Ghaziabad daily_positive_cases_ma
# Ghaziabad daily_positivity_rate_ma
# Ghaziabad daily_tests
# Ghaziabad cum_tests
# Ghaziabad test_per_million
# Ghaziabad daily_cases_per_million
# Ghaziabad daily_tests_per_million
# Ghaziabad daily_tests_ma
# Ghaziabad daily_deceased_ma
# Ghaziabad dbt_point
# Ghaziabad dbt_l95
# Ghaziabad dbt_u95
# Ghaziabad rt_point
# Ghaziabad rt_sd
# Ghaziabad rt_l95
# Ghaziabad rt_u95
# Ghaziabad rt_l50
# Ghaziabad rt_u50
# Ghaziabad t_end
# Kanpur Nagar dates
# Kanpur Nagar cum_positive_cases
# Kanpur Nagar cum_positivity_rate
# Kanpur Nagar daily_positive_cases
# Kanpur Nagar cum_recovered
# Kanpur Nagar daily_recovered
# Kanpur Nagar cum_deceased
# Kanpur Nagar daily_deceased
# Kanpur Nagar daily_positivity_rate
# Kanpur Nagar daily_positive_cases_ma
# Kanpur Nagar daily_positivity_rate_ma
# Kanpur Nagar daily_tests
# Kanpur Nagar cum_tests
# Kanpur Nagar test_per_million
# Kanpur Nagar daily_cases_per_million
# Kanpur Nagar daily_tests_per_million
# Kanpur Nagar daily_tests_ma
# Kanpur Nagar daily_deceased_ma
# Kanpur Nagar dbt_point
# Kanpur Nagar dbt_l95
# Kanpur Nagar dbt_u95
# Kanpur Nagar rt_point
# Kanpur Nagar rt_sd
# Kanpur Nagar rt_l95
# Kanpur Nagar rt_u95
# Kanpur Nagar rt_l50
# Kanpur Nagar rt_u50
# Kanpur Nagar t_end
# Lucknow dates
# Lucknow cum_positive_cases
# Lucknow cum_positivity_rate
# Lucknow daily_positive_cases
# Lucknow cum_recovered
# Lucknow daily_recovered
# Lucknow cum_deceased
# Lucknow daily_deceased
# Lucknow daily_positivity_rate
# Lucknow daily_positive_cases_ma
# Lucknow daily_positivity_rate_ma
# Lucknow daily_tests
# Lucknow cum_tests
# Lucknow test_per_million
# Lucknow daily_cases_per_million
# Lucknow daily_tests_per_million
# Lucknow daily_tests_ma
# Lucknow daily_deceased_ma
# Lucknow dbt_point
# Lucknow dbt_l95
# Lucknow dbt_u95
# Lucknow rt_point
# Lucknow rt_sd
# Lucknow rt_l95
# Lucknow rt_u95
# Lucknow rt_l50
# Lucknow rt_u50
# Lucknow t_end
# Varanasi dates
# Varanasi cum_positive_cases
# Varanasi cum_positivity_rate
# Varanasi daily_positive_cases
# Varanasi cum_recovered
# Varanasi daily_recovered
# Varanasi cum_deceased
# Varanasi daily_deceased
# Varanasi daily_positivity_rate
# Varanasi daily_positive_cases_ma
# Varanasi daily_positivity_rate_ma
# Varanasi daily_tests
# Varanasi cum_tests
# Varanasi test_per_million
# Varanasi daily_cases_per_million
# Varanasi daily_tests_per_million
# Varanasi daily_tests_ma
# Varanasi daily_deceased_ma
# Varanasi dbt_point
# Varanasi dbt_l95
# Varanasi dbt_u95
# Varanasi rt_point
# Varanasi rt_sd
# Varanasi rt_l95
# Varanasi rt_u95
# Varanasi rt_l50
# Varanasi rt_u50
# Varanasi t_end
# Prayagraj dates
# Prayagraj cum_positive_cases
# Prayagraj cum_positivity_rate
# Prayagraj daily_positive_cases
# Prayagraj cum_recovered
# Prayagraj daily_recovered
# Prayagraj cum_deceased
# Prayagraj daily_deceased
# Prayagraj daily_positivity_rate
# Prayagraj daily_positive_cases_ma
# Prayagraj daily_positivity_rate_ma
# Prayagraj daily_tests
# Prayagraj cum_tests
# Prayagraj test_per_million
# Prayagraj daily_cases_per_million
# Prayagraj daily_tests_per_million
# Prayagraj daily_tests_ma
# Prayagraj daily_deceased_ma
# Prayagraj dbt_point
# Prayagraj dbt_l95
# Prayagraj dbt_u95
# Prayagraj rt_point
# Prayagraj rt_sd
# Prayagraj rt_l95
# Prayagraj rt_u95
# Prayagraj rt_l50
# Prayagraj rt_u50
# Prayagraj t_end
# Kolkata dates
# Kolkata cum_positive_cases
# Kolkata cum_positivity_rate
# Kolkata daily_positive_cases
# Kolkata cum_recovered
# Kolkata daily_recovered
# Kolkata cum_deceased
# Kolkata daily_deceased
# Kolkata daily_positivity_rate
# Kolkata daily_positive_cases_ma
# Kolkata daily_positivity_rate_ma
# Kolkata daily_tests
# Kolkata cum_tests
# Kolkata test_per_million
# Kolkata daily_cases_per_million
# Kolkata daily_tests_per_million
# Kolkata daily_tests_ma
# Kolkata daily_deceased_ma
# Kolkata dbt_point
# Kolkata dbt_l95
# Kolkata dbt_u95
# Kolkata rt_point
# Kolkata rt_sd
# Kolkata rt_l95
# Kolkata rt_u95
# Kolkata rt_l50
# Kolkata rt_u50
# Kolkata t_end
# North 24 Parganas dates
# North 24 Parganas cum_positive_cases
# North 24 Parganas cum_positivity_rate
# North 24 Parganas daily_positive_cases
# North 24 Parganas cum_recovered
# North 24 Parganas daily_recovered
# North 24 Parganas cum_deceased
# North 24 Parganas daily_deceased
# North 24 Parganas daily_positivity_rate
# North 24 Parganas daily_positive_cases_ma
# North 24 Parganas daily_positivity_rate_ma
# North 24 Parganas daily_tests
# North 24 Parganas cum_tests
# North 24 Parganas test_per_million
# North 24 Parganas daily_cases_per_million
# North 24 Parganas daily_tests_per_million
# North 24 Parganas daily_tests_ma
# North 24 Parganas daily_deceased_ma
# North 24 Parganas dbt_point
# North 24 Parganas dbt_l95
# North 24 Parganas dbt_u95
# North 24 Parganas rt_point
# North 24 Parganas rt_sd
# North 24 Parganas rt_l95
# North 24 Parganas rt_u95
# North 24 Parganas rt_l50
# North 24 Parganas rt_u50
# North 24 Parganas t_end

# %%
cols=list(states_shifted['Mumbai'].keys())
q=['state']

complete_shifted=pd.DataFrame(columns=q+cols)

keys=list(states_shifted.keys())[:-1]

for i in keys:
  temp=pd.DataFrame()
  d=len(states_shifted['Mumbai']['dates'])
  temp['state']=[str(i)]*d
  
  for j in cols:
    print(i,j)
    temp[j]=list(states_shifted[i][j])
  
  complete_shifted = pd.concat([complete_shifted,temp])
# Out:
# Anantapur dates
# Anantapur cum_positive_cases
# Anantapur cum_positivity_rate
# Anantapur daily_positive_cases
# Anantapur cum_recovered
# Anantapur daily_recovered
# Anantapur cum_deceased
# Anantapur daily_deceased
# Anantapur daily_positivity_rate
# Anantapur daily_positive_cases_ma
# Anantapur daily_positivity_rate_ma
# Anantapur daily_tests
# Anantapur cum_tests
# Anantapur test_per_million
# Anantapur daily_cases_per_million
# Anantapur daily_tests_per_million
# Anantapur daily_tests_ma
# Anantapur daily_deceased_ma
# Anantapur dbt_point
# Anantapur dbt_l95
# Anantapur dbt_u95
# Anantapur rt_point
# Anantapur rt_sd
# Anantapur rt_l95
# Anantapur rt_u95
# Anantapur rt_l50
# Anantapur rt_u50
# Anantapur t_end
# Chittoor dates
# Chittoor cum_positive_cases
# Chittoor cum_positivity_rate
# Chittoor daily_positive_cases
# Chittoor cum_recovered
# Chittoor daily_recovered
# Chittoor cum_deceased
# Chittoor daily_deceased
# Chittoor daily_positivity_rate
# Chittoor daily_positive_cases_ma
# Chittoor daily_positivity_rate_ma
# Chittoor daily_tests
# Chittoor cum_tests
# Chittoor test_per_million
# Chittoor daily_cases_per_million
# Chittoor daily_tests_per_million
# Chittoor daily_tests_ma
# Chittoor daily_deceased_ma
# Chittoor dbt_point
# Chittoor dbt_l95
# Chittoor dbt_u95
# Chittoor rt_point
# Chittoor rt_sd
# Chittoor rt_l95
# Chittoor rt_u95
# Chittoor rt_l50
# Chittoor rt_u50
# Chittoor t_end
# East Godavari dates
# East Godavari cum_positive_cases
# East Godavari cum_positivity_rate
# East Godavari daily_positive_cases
# East Godavari cum_recovered
# East Godavari daily_recovered
# East Godavari cum_deceased
# East Godavari daily_deceased
# East Godavari daily_positivity_rate
# East Godavari daily_positive_cases_ma
# East Godavari daily_positivity_rate_ma
# East Godavari daily_tests
# East Godavari cum_tests
# East Godavari test_per_million
# East Godavari daily_cases_per_million
# East Godavari daily_tests_per_million
# East Godavari daily_tests_ma
# East Godavari daily_deceased_ma
# East Godavari dbt_point
# East Godavari dbt_l95
# East Godavari dbt_u95
# East Godavari rt_point
# East Godavari rt_sd
# East Godavari rt_l95
# East Godavari rt_u95
# East Godavari rt_l50
# East Godavari rt_u50
# East Godavari t_end
# Guntur dates
# Guntur cum_positive_cases
# Guntur cum_positivity_rate
# Guntur daily_positive_cases
# Guntur cum_recovered
# Guntur daily_recovered
# Guntur cum_deceased
# Guntur daily_deceased
# Guntur daily_positivity_rate
# Guntur daily_positive_cases_ma
# Guntur daily_positivity_rate_ma
# Guntur daily_tests
# Guntur cum_tests
# Guntur test_per_million
# Guntur daily_cases_per_million
# Guntur daily_tests_per_million
# Guntur daily_tests_ma
# Guntur daily_deceased_ma
# Guntur dbt_point
# Guntur dbt_l95
# Guntur dbt_u95
# Guntur rt_point
# Guntur rt_sd
# Guntur rt_l95
# Guntur rt_u95
# Guntur rt_l50
# Guntur rt_u50
# Guntur t_end
# Kurnool dates
# Kurnool cum_positive_cases
# Kurnool cum_positivity_rate
# Kurnool daily_positive_cases
# Kurnool cum_recovered
# Kurnool daily_recovered
# Kurnool cum_deceased
# Kurnool daily_deceased
# Kurnool daily_positivity_rate
# Kurnool daily_positive_cases_ma
# Kurnool daily_positivity_rate_ma
# Kurnool daily_tests
# Kurnool cum_tests
# Kurnool test_per_million
# Kurnool daily_cases_per_million
# Kurnool daily_tests_per_million
# Kurnool daily_tests_ma
# Kurnool daily_deceased_ma
# Kurnool dbt_point
# Kurnool dbt_l95
# Kurnool dbt_u95
# Kurnool rt_point
# Kurnool rt_sd
# Kurnool rt_l95
# Kurnool rt_u95
# Kurnool rt_l50
# Kurnool rt_u50
# Kurnool t_end
# Prakasam dates
# Prakasam cum_positive_cases
# Prakasam cum_positivity_rate
# Prakasam daily_positive_cases
# Prakasam cum_recovered
# Prakasam daily_recovered
# Prakasam cum_deceased
# Prakasam daily_deceased
# Prakasam daily_positivity_rate
# Prakasam daily_positive_cases_ma
# Prakasam daily_positivity_rate_ma
# Prakasam daily_tests
# Prakasam cum_tests
# Prakasam test_per_million
# Prakasam daily_cases_per_million
# Prakasam daily_tests_per_million
# Prakasam daily_tests_ma
# Prakasam daily_deceased_ma
# Prakasam dbt_point
# Prakasam dbt_l95
# Prakasam dbt_u95
# Prakasam rt_point
# Prakasam rt_sd
# Prakasam rt_l95
# Prakasam rt_u95
# Prakasam rt_l50
# Prakasam rt_u50
# Prakasam t_end
# Srikakulam dates
# Srikakulam cum_positive_cases
# Srikakulam cum_positivity_rate
# Srikakulam daily_positive_cases
# Srikakulam cum_recovered
# Srikakulam daily_recovered
# Srikakulam cum_deceased
# Srikakulam daily_deceased
# Srikakulam daily_positivity_rate
# Srikakulam daily_positive_cases_ma
# Srikakulam daily_positivity_rate_ma
# Srikakulam daily_tests
# Srikakulam cum_tests
# Srikakulam test_per_million
# Srikakulam daily_cases_per_million
# Srikakulam daily_tests_per_million
# Srikakulam daily_tests_ma
# Srikakulam daily_deceased_ma
# Srikakulam dbt_point
# Srikakulam dbt_l95
# Srikakulam dbt_u95
# Srikakulam rt_point
# Srikakulam rt_sd
# Srikakulam rt_l95
# Srikakulam rt_u95
# Srikakulam rt_l50
# Srikakulam rt_u50
# Srikakulam t_end
# Visakhapatnam dates
# Visakhapatnam cum_positive_cases
# Visakhapatnam cum_positivity_rate
# Visakhapatnam daily_positive_cases
# Visakhapatnam cum_recovered
# Visakhapatnam daily_recovered
# Visakhapatnam cum_deceased
# Visakhapatnam daily_deceased
# Visakhapatnam daily_positivity_rate
# Visakhapatnam daily_positive_cases_ma
# Visakhapatnam daily_positivity_rate_ma
# Visakhapatnam daily_tests
# Visakhapatnam cum_tests
# Visakhapatnam test_per_million
# Visakhapatnam daily_cases_per_million
# Visakhapatnam daily_tests_per_million
# Visakhapatnam daily_tests_ma
# Visakhapatnam daily_deceased_ma
# Visakhapatnam dbt_point
# Visakhapatnam dbt_l95
# Visakhapatnam dbt_u95
# Visakhapatnam rt_point
# Visakhapatnam rt_sd
# Visakhapatnam rt_l95
# Visakhapatnam rt_u95
# Visakhapatnam rt_l50
# Visakhapatnam rt_u50
# Visakhapatnam t_end
# Vizianagaram dates
# Vizianagaram cum_positive_cases
# Vizianagaram cum_positivity_rate
# Vizianagaram daily_positive_cases
# Vizianagaram cum_recovered
# Vizianagaram daily_recovered
# Vizianagaram cum_deceased
# Vizianagaram daily_deceased
# Vizianagaram daily_positivity_rate
# Vizianagaram daily_positive_cases_ma
# Vizianagaram daily_positivity_rate_ma
# Vizianagaram daily_tests
# Vizianagaram cum_tests
# Vizianagaram test_per_million
# Vizianagaram daily_cases_per_million
# Vizianagaram daily_tests_per_million
# Vizianagaram daily_tests_ma
# Vizianagaram daily_deceased_ma
# Vizianagaram dbt_point
# Vizianagaram dbt_l95
# Vizianagaram dbt_u95
# Vizianagaram rt_point
# Vizianagaram rt_sd
# Vizianagaram rt_l95
# Vizianagaram rt_u95
# Vizianagaram rt_l50
# Vizianagaram rt_u50
# Vizianagaram t_end
# West Godavari dates
# West Godavari cum_positive_cases
# West Godavari cum_positivity_rate
# West Godavari daily_positive_cases
# West Godavari cum_recovered
# West Godavari daily_recovered
# West Godavari cum_deceased
# West Godavari daily_deceased
# West Godavari daily_positivity_rate
# West Godavari daily_positive_cases_ma
# West Godavari daily_positivity_rate_ma
# West Godavari daily_tests
# West Godavari cum_tests
# West Godavari test_per_million
# West Godavari daily_cases_per_million
# West Godavari daily_tests_per_million
# West Godavari daily_tests_ma
# West Godavari daily_deceased_ma
# West Godavari dbt_point
# West Godavari dbt_l95
# West Godavari dbt_u95
# West Godavari rt_point
# West Godavari rt_sd
# West Godavari rt_l95
# West Godavari rt_u95
# West Godavari rt_l50
# West Godavari rt_u50
# West Godavari t_end
# S.P.S. Nellore dates
# S.P.S. Nellore cum_positive_cases
# S.P.S. Nellore cum_positivity_rate
# S.P.S. Nellore daily_positive_cases
# S.P.S. Nellore cum_recovered
# S.P.S. Nellore daily_recovered
# S.P.S. Nellore cum_deceased
# S.P.S. Nellore daily_deceased
# S.P.S. Nellore daily_positivity_rate
# S.P.S. Nellore daily_positive_cases_ma
# S.P.S. Nellore daily_positivity_rate_ma
# S.P.S. Nellore daily_tests
# S.P.S. Nellore cum_tests
# S.P.S. Nellore test_per_million
# S.P.S. Nellore daily_cases_per_million
# S.P.S. Nellore daily_tests_per_million
# S.P.S. Nellore daily_tests_ma
# S.P.S. Nellore daily_deceased_ma
# S.P.S. Nellore dbt_point
# S.P.S. Nellore dbt_l95
# S.P.S. Nellore dbt_u95
# S.P.S. Nellore rt_point
# S.P.S. Nellore rt_sd
# S.P.S. Nellore rt_l95
# S.P.S. Nellore rt_u95
# S.P.S. Nellore rt_l50
# S.P.S. Nellore rt_u50
# S.P.S. Nellore t_end
# Y.S.R. Kadapa dates
# Y.S.R. Kadapa cum_positive_cases
# Y.S.R. Kadapa cum_positivity_rate
# Y.S.R. Kadapa daily_positive_cases
# Y.S.R. Kadapa cum_recovered
# Y.S.R. Kadapa daily_recovered
# Y.S.R. Kadapa cum_deceased
# Y.S.R. Kadapa daily_deceased
# Y.S.R. Kadapa daily_positivity_rate
# Y.S.R. Kadapa daily_positive_cases_ma
# Y.S.R. Kadapa daily_positivity_rate_ma
# Y.S.R. Kadapa daily_tests
# Y.S.R. Kadapa cum_tests
# Y.S.R. Kadapa test_per_million
# Y.S.R. Kadapa daily_cases_per_million
# Y.S.R. Kadapa daily_tests_per_million
# Y.S.R. Kadapa daily_tests_ma
# Y.S.R. Kadapa daily_deceased_ma
# Y.S.R. Kadapa dbt_point
# Y.S.R. Kadapa dbt_l95
# Y.S.R. Kadapa dbt_u95
# Y.S.R. Kadapa rt_point
# Y.S.R. Kadapa rt_sd
# Y.S.R. Kadapa rt_l95
# Y.S.R. Kadapa rt_u95
# Y.S.R. Kadapa rt_l50
# Y.S.R. Kadapa rt_u50
# Y.S.R. Kadapa t_end
# Begusarai dates
# Begusarai cum_positive_cases
# Begusarai cum_positivity_rate
# Begusarai daily_positive_cases
# Begusarai cum_recovered
# Begusarai daily_recovered
# Begusarai cum_deceased
# Begusarai daily_deceased
# Begusarai daily_positivity_rate
# Begusarai daily_positive_cases_ma
# Begusarai daily_positivity_rate_ma
# Begusarai daily_tests
# Begusarai cum_tests
# Begusarai test_per_million
# Begusarai daily_cases_per_million
# Begusarai daily_tests_per_million
# Begusarai daily_tests_ma
# Begusarai daily_deceased_ma
# Begusarai dbt_point
# Begusarai dbt_l95
# Begusarai dbt_u95
# Begusarai rt_point
# Begusarai rt_sd
# Begusarai rt_l95
# Begusarai rt_u95
# Begusarai rt_l50
# Begusarai rt_u50
# Begusarai t_end
# Patna dates
# Patna cum_positive_cases
# Patna cum_positivity_rate
# Patna daily_positive_cases
# Patna cum_recovered
# Patna daily_recovered
# Patna cum_deceased
# Patna daily_deceased
# Patna daily_positivity_rate
# Patna daily_positive_cases_ma
# Patna daily_positivity_rate_ma
# Patna daily_tests
# Patna cum_tests
# Patna test_per_million
# Patna daily_cases_per_million
# Patna daily_tests_per_million
# Patna daily_tests_ma
# Patna daily_deceased_ma
# Patna dbt_point
# Patna dbt_l95
# Patna dbt_u95
# Patna rt_point
# Patna rt_sd
# Patna rt_l95
# Patna rt_u95
# Patna rt_l50
# Patna rt_u50
# Patna t_end
# Raipur dates
# Raipur cum_positive_cases
# Raipur cum_positivity_rate
# Raipur daily_positive_cases
# Raipur cum_recovered
# Raipur daily_recovered
# Raipur cum_deceased
# Raipur daily_deceased
# Raipur daily_positivity_rate
# Raipur daily_positive_cases_ma
# Raipur daily_positivity_rate_ma
# Raipur daily_tests
# Raipur cum_tests
# Raipur test_per_million
# Raipur daily_cases_per_million
# Raipur daily_tests_per_million
# Raipur daily_tests_ma
# Raipur daily_deceased_ma
# Raipur dbt_point
# Raipur dbt_l95
# Raipur dbt_u95
# Raipur rt_point
# Raipur rt_sd
# Raipur rt_l95
# Raipur rt_u95
# Raipur rt_l50
# Raipur rt_u50
# Raipur t_end
# Ahmedabad dates
# Ahmedabad cum_positive_cases
# Ahmedabad cum_positivity_rate
# Ahmedabad daily_positive_cases
# Ahmedabad cum_recovered
# Ahmedabad daily_recovered
# Ahmedabad cum_deceased
# Ahmedabad daily_deceased
# Ahmedabad daily_positivity_rate
# Ahmedabad daily_positive_cases_ma
# Ahmedabad daily_positivity_rate_ma
# Ahmedabad daily_tests
# Ahmedabad cum_tests
# Ahmedabad test_per_million
# Ahmedabad daily_cases_per_million
# Ahmedabad daily_tests_per_million
# Ahmedabad daily_tests_ma
# Ahmedabad daily_deceased_ma
# Ahmedabad dbt_point
# Ahmedabad dbt_l95
# Ahmedabad dbt_u95
# Ahmedabad rt_point
# Ahmedabad rt_sd
# Ahmedabad rt_l95
# Ahmedabad rt_u95
# Ahmedabad rt_l50
# Ahmedabad rt_u50
# Ahmedabad t_end
# Rajkot dates
# Rajkot cum_positive_cases
# Rajkot cum_positivity_rate
# Rajkot daily_positive_cases
# Rajkot cum_recovered
# Rajkot daily_recovered
# Rajkot cum_deceased
# Rajkot daily_deceased
# Rajkot daily_positivity_rate
# Rajkot daily_positive_cases_ma
# Rajkot daily_positivity_rate_ma
# Rajkot daily_tests
# Rajkot cum_tests
# Rajkot test_per_million
# Rajkot daily_cases_per_million
# Rajkot daily_tests_per_million
# Rajkot daily_tests_ma
# Rajkot daily_deceased_ma
# Rajkot dbt_point
# Rajkot dbt_l95
# Rajkot dbt_u95
# Rajkot rt_point
# Rajkot rt_sd
# Rajkot rt_l95
# Rajkot rt_u95
# Rajkot rt_l50
# Rajkot rt_u50
# Rajkot t_end
# Surat dates
# Surat cum_positive_cases
# Surat cum_positivity_rate
# Surat daily_positive_cases
# Surat cum_recovered
# Surat daily_recovered
# Surat cum_deceased
# Surat daily_deceased
# Surat daily_positivity_rate
# Surat daily_positive_cases_ma
# Surat daily_positivity_rate_ma
# Surat daily_tests
# Surat cum_tests
# Surat test_per_million
# Surat daily_cases_per_million
# Surat daily_tests_per_million
# Surat daily_tests_ma
# Surat daily_deceased_ma
# Surat dbt_point
# Surat dbt_l95
# Surat dbt_u95
# Surat rt_point
# Surat rt_sd
# Surat rt_l95
# Surat rt_u95
# Surat rt_l50
# Surat rt_u50
# Surat t_end
# Vadodara dates
# Vadodara cum_positive_cases
# Vadodara cum_positivity_rate
# Vadodara daily_positive_cases
# Vadodara cum_recovered
# Vadodara daily_recovered
# Vadodara cum_deceased
# Vadodara daily_deceased
# Vadodara daily_positivity_rate
# Vadodara daily_positive_cases_ma
# Vadodara daily_positivity_rate_ma
# Vadodara daily_tests
# Vadodara cum_tests
# Vadodara test_per_million
# Vadodara daily_cases_per_million
# Vadodara daily_tests_per_million
# Vadodara daily_tests_ma
# Vadodara daily_deceased_ma
# Vadodara dbt_point
# Vadodara dbt_l95
# Vadodara dbt_u95
# Vadodara rt_point
# Vadodara rt_sd
# Vadodara rt_l95
# Vadodara rt_u95
# Vadodara rt_l50
# Vadodara rt_u50
# Vadodara t_end
# Faridabad dates
# Faridabad cum_positive_cases
# Faridabad cum_positivity_rate
# Faridabad daily_positive_cases
# Faridabad cum_recovered
# Faridabad daily_recovered
# Faridabad cum_deceased
# Faridabad daily_deceased
# Faridabad daily_positivity_rate
# Faridabad daily_positive_cases_ma
# Faridabad daily_positivity_rate_ma
# Faridabad daily_tests
# Faridabad cum_tests
# Faridabad test_per_million
# Faridabad daily_cases_per_million
# Faridabad daily_tests_per_million
# Faridabad daily_tests_ma
# Faridabad daily_deceased_ma
# Faridabad dbt_point
# Faridabad dbt_l95
# Faridabad dbt_u95
# Faridabad rt_point
# Faridabad rt_sd
# Faridabad rt_l95
# Faridabad rt_u95
# Faridabad rt_l50
# Faridabad rt_u50
# Faridabad t_end
# Gurugram dates
# Gurugram cum_positive_cases
# Gurugram cum_positivity_rate
# Gurugram daily_positive_cases
# Gurugram cum_recovered
# Gurugram daily_recovered
# Gurugram cum_deceased
# Gurugram daily_deceased
# Gurugram daily_positivity_rate
# Gurugram daily_positive_cases_ma
# Gurugram daily_positivity_rate_ma
# Gurugram daily_tests
# Gurugram cum_tests
# Gurugram test_per_million
# Gurugram daily_cases_per_million
# Gurugram daily_tests_per_million
# Gurugram daily_tests_ma
# Gurugram daily_deceased_ma
# Gurugram dbt_point
# Gurugram dbt_l95
# Gurugram dbt_u95
# Gurugram rt_point
# Gurugram rt_sd
# Gurugram rt_l95
# Gurugram rt_u95
# Gurugram rt_l50
# Gurugram rt_u50
# Gurugram t_end
# East Singhbhum dates
# East Singhbhum cum_positive_cases
# East Singhbhum cum_positivity_rate
# East Singhbhum daily_positive_cases
# East Singhbhum cum_recovered
# East Singhbhum daily_recovered
# East Singhbhum cum_deceased
# East Singhbhum daily_deceased
# East Singhbhum daily_positivity_rate
# East Singhbhum daily_positive_cases_ma
# East Singhbhum daily_positivity_rate_ma
# East Singhbhum daily_tests
# East Singhbhum cum_tests
# East Singhbhum test_per_million
# East Singhbhum daily_cases_per_million
# East Singhbhum daily_tests_per_million
# East Singhbhum daily_tests_ma
# East Singhbhum daily_deceased_ma
# East Singhbhum dbt_point
# East Singhbhum dbt_l95
# East Singhbhum dbt_u95
# East Singhbhum rt_point
# East Singhbhum rt_sd
# East Singhbhum rt_l95
# East Singhbhum rt_u95
# East Singhbhum rt_l50
# East Singhbhum rt_u50
# East Singhbhum t_end
# Koderma dates
# Koderma cum_positive_cases
# Koderma cum_positivity_rate
# Koderma daily_positive_cases
# Koderma cum_recovered
# Koderma daily_recovered
# Koderma cum_deceased
# Koderma daily_deceased
# Koderma daily_positivity_rate
# Koderma daily_positive_cases_ma
# Koderma daily_positivity_rate_ma
# Koderma daily_tests
# Koderma cum_tests
# Koderma test_per_million
# Koderma daily_cases_per_million
# Koderma daily_tests_per_million
# Koderma daily_tests_ma
# Koderma daily_deceased_ma
# Koderma dbt_point
# Koderma dbt_l95
# Koderma dbt_u95
# Koderma rt_point
# Koderma rt_sd
# Koderma rt_l95
# Koderma rt_u95
# Koderma rt_l50
# Koderma rt_u50
# Koderma t_end
# Ranchi dates
# Ranchi cum_positive_cases
# Ranchi cum_positivity_rate
# Ranchi daily_positive_cases
# Ranchi cum_recovered
# Ranchi daily_recovered
# Ranchi cum_deceased
# Ranchi daily_deceased
# Ranchi daily_positivity_rate
# Ranchi daily_positive_cases_ma
# Ranchi daily_positivity_rate_ma
# Ranchi daily_tests
# Ranchi cum_tests
# Ranchi test_per_million
# Ranchi daily_cases_per_million
# Ranchi daily_tests_per_million
# Ranchi daily_tests_ma
# Ranchi daily_deceased_ma
# Ranchi dbt_point
# Ranchi dbt_l95
# Ranchi dbt_u95
# Ranchi rt_point
# Ranchi rt_sd
# Ranchi rt_l95
# Ranchi rt_u95
# Ranchi rt_l50
# Ranchi rt_u50
# Ranchi t_end
# Ramgarh dates
# Ramgarh cum_positive_cases
# Ramgarh cum_positivity_rate
# Ramgarh daily_positive_cases
# Ramgarh cum_recovered
# Ramgarh daily_recovered
# Ramgarh cum_deceased
# Ramgarh daily_deceased
# Ramgarh daily_positivity_rate
# Ramgarh daily_positive_cases_ma
# Ramgarh daily_positivity_rate_ma
# Ramgarh daily_tests
# Ramgarh cum_tests
# Ramgarh test_per_million
# Ramgarh daily_cases_per_million
# Ramgarh daily_tests_per_million
# Ramgarh daily_tests_ma
# Ramgarh daily_deceased_ma
# Ramgarh dbt_point
# Ramgarh dbt_l95
# Ramgarh dbt_u95
# Ramgarh rt_point
# Ramgarh rt_sd
# Ramgarh rt_l95
# Ramgarh rt_u95
# Ramgarh rt_l50
# Ramgarh rt_u50
# Ramgarh t_end
# West Singhbhum dates
# West Singhbhum cum_positive_cases
# West Singhbhum cum_positivity_rate
# West Singhbhum daily_positive_cases
# West Singhbhum cum_recovered
# West Singhbhum daily_recovered
# West Singhbhum cum_deceased
# West Singhbhum daily_deceased
# West Singhbhum daily_positivity_rate
# West Singhbhum daily_positive_cases_ma
# West Singhbhum daily_positivity_rate_ma
# West Singhbhum daily_tests
# West Singhbhum cum_tests
# West Singhbhum test_per_million
# West Singhbhum daily_cases_per_million
# West Singhbhum daily_tests_per_million
# West Singhbhum daily_tests_ma
# West Singhbhum daily_deceased_ma
# West Singhbhum dbt_point
# West Singhbhum dbt_l95
# West Singhbhum dbt_u95
# West Singhbhum rt_point
# West Singhbhum rt_sd
# West Singhbhum rt_l95
# West Singhbhum rt_u95
# West Singhbhum rt_l50
# West Singhbhum rt_u50
# West Singhbhum t_end
# Bengaluru Urban dates
# Bengaluru Urban cum_positive_cases
# Bengaluru Urban cum_positivity_rate
# Bengaluru Urban daily_positive_cases
# Bengaluru Urban cum_recovered
# Bengaluru Urban daily_recovered
# Bengaluru Urban cum_deceased
# Bengaluru Urban daily_deceased
# Bengaluru Urban daily_positivity_rate
# Bengaluru Urban daily_positive_cases_ma
# Bengaluru Urban daily_positivity_rate_ma
# Bengaluru Urban daily_tests
# Bengaluru Urban cum_tests
# Bengaluru Urban test_per_million
# Bengaluru Urban daily_cases_per_million
# Bengaluru Urban daily_tests_per_million
# Bengaluru Urban daily_tests_ma
# Bengaluru Urban daily_deceased_ma
# Bengaluru Urban dbt_point
# Bengaluru Urban dbt_l95
# Bengaluru Urban dbt_u95
# Bengaluru Urban rt_point
# Bengaluru Urban rt_sd
# Bengaluru Urban rt_l95
# Bengaluru Urban rt_u95
# Bengaluru Urban rt_l50
# Bengaluru Urban rt_u50
# Bengaluru Urban t_end
# Ballari dates
# Ballari cum_positive_cases
# Ballari cum_positivity_rate
# Ballari daily_positive_cases
# Ballari cum_recovered
# Ballari daily_recovered
# Ballari cum_deceased
# Ballari daily_deceased
# Ballari daily_positivity_rate
# Ballari daily_positive_cases_ma
# Ballari daily_positivity_rate_ma
# Ballari daily_tests
# Ballari cum_tests
# Ballari test_per_million
# Ballari daily_cases_per_million
# Ballari daily_tests_per_million
# Ballari daily_tests_ma
# Ballari daily_deceased_ma
# Ballari dbt_point
# Ballari dbt_l95
# Ballari dbt_u95
# Ballari rt_point
# Ballari rt_sd
# Ballari rt_l95
# Ballari rt_u95
# Ballari rt_l50
# Ballari rt_u50
# Ballari t_end
# Mysuru dates
# Mysuru cum_positive_cases
# Mysuru cum_positivity_rate
# Mysuru daily_positive_cases
# Mysuru cum_recovered
# Mysuru daily_recovered
# Mysuru cum_deceased
# Mysuru daily_deceased
# Mysuru daily_positivity_rate
# Mysuru daily_positive_cases_ma
# Mysuru daily_positivity_rate_ma
# Mysuru daily_tests
# Mysuru cum_tests
# Mysuru test_per_million
# Mysuru daily_cases_per_million
# Mysuru daily_tests_per_million
# Mysuru daily_tests_ma
# Mysuru daily_deceased_ma
# Mysuru dbt_point
# Mysuru dbt_l95
# Mysuru dbt_u95
# Mysuru rt_point
# Mysuru rt_sd
# Mysuru rt_l95
# Mysuru rt_u95
# Mysuru rt_l50
# Mysuru rt_u50
# Mysuru t_end
# Belagavi dates
# Belagavi cum_positive_cases
# Belagavi cum_positivity_rate
# Belagavi daily_positive_cases
# Belagavi cum_recovered
# Belagavi daily_recovered
# Belagavi cum_deceased
# Belagavi daily_deceased
# Belagavi daily_positivity_rate
# Belagavi daily_positive_cases_ma
# Belagavi daily_positivity_rate_ma
# Belagavi daily_tests
# Belagavi cum_tests
# Belagavi test_per_million
# Belagavi daily_cases_per_million
# Belagavi daily_tests_per_million
# Belagavi daily_tests_ma
# Belagavi daily_deceased_ma
# Belagavi dbt_point
# Belagavi dbt_l95
# Belagavi dbt_u95
# Belagavi rt_point
# Belagavi rt_sd
# Belagavi rt_l95
# Belagavi rt_u95
# Belagavi rt_l50
# Belagavi rt_u50
# Belagavi t_end
# Chitradurga dates
# Chitradurga cum_positive_cases
# Chitradurga cum_positivity_rate
# Chitradurga daily_positive_cases
# Chitradurga cum_recovered
# Chitradurga daily_recovered
# Chitradurga cum_deceased
# Chitradurga daily_deceased
# Chitradurga daily_positivity_rate
# Chitradurga daily_positive_cases_ma
# Chitradurga daily_positivity_rate_ma
# Chitradurga daily_tests
# Chitradurga cum_tests
# Chitradurga test_per_million
# Chitradurga daily_cases_per_million
# Chitradurga daily_tests_per_million
# Chitradurga daily_tests_ma
# Chitradurga daily_deceased_ma
# Chitradurga dbt_point
# Chitradurga dbt_l95
# Chitradurga dbt_u95
# Chitradurga rt_point
# Chitradurga rt_sd
# Chitradurga rt_l95
# Chitradurga rt_u95
# Chitradurga rt_l50
# Chitradurga rt_u50
# Chitradurga t_end
# Tumakuru dates
# Tumakuru cum_positive_cases
# Tumakuru cum_positivity_rate
# Tumakuru daily_positive_cases
# Tumakuru cum_recovered
# Tumakuru daily_recovered
# Tumakuru cum_deceased
# Tumakuru daily_deceased
# Tumakuru daily_positivity_rate
# Tumakuru daily_positive_cases_ma
# Tumakuru daily_positivity_rate_ma
# Tumakuru daily_tests
# Tumakuru cum_tests
# Tumakuru test_per_million
# Tumakuru daily_cases_per_million
# Tumakuru daily_tests_per_million
# Tumakuru daily_tests_ma
# Tumakuru daily_deceased_ma
# Tumakuru dbt_point
# Tumakuru dbt_l95
# Tumakuru dbt_u95
# Tumakuru rt_point
# Tumakuru rt_sd
# Tumakuru rt_l95
# Tumakuru rt_u95
# Tumakuru rt_l50
# Tumakuru rt_u50
# Tumakuru t_end
# Thiruvananthapuram dates
# Thiruvananthapuram cum_positive_cases
# Thiruvananthapuram cum_positivity_rate
# Thiruvananthapuram daily_positive_cases
# Thiruvananthapuram cum_recovered
# Thiruvananthapuram daily_recovered
# Thiruvananthapuram cum_deceased
# Thiruvananthapuram daily_deceased
# Thiruvananthapuram daily_positivity_rate
# Thiruvananthapuram daily_positive_cases_ma
# Thiruvananthapuram daily_positivity_rate_ma
# Thiruvananthapuram daily_tests
# Thiruvananthapuram cum_tests
# Thiruvananthapuram test_per_million
# Thiruvananthapuram daily_cases_per_million
# Thiruvananthapuram daily_tests_per_million
# Thiruvananthapuram daily_tests_ma
# Thiruvananthapuram daily_deceased_ma
# Thiruvananthapuram dbt_point
# Thiruvananthapuram dbt_l95
# Thiruvananthapuram dbt_u95
# Thiruvananthapuram rt_point
# Thiruvananthapuram rt_sd
# Thiruvananthapuram rt_l95
# Thiruvananthapuram rt_u95
# Thiruvananthapuram rt_l50
# Thiruvananthapuram rt_u50
# Thiruvananthapuram t_end
# Aurangabad dates
# Aurangabad cum_positive_cases
# Aurangabad cum_positivity_rate
# Aurangabad daily_positive_cases
# Aurangabad cum_recovered
# Aurangabad daily_recovered
# Aurangabad cum_deceased
# Aurangabad daily_deceased
# Aurangabad daily_positivity_rate
# Aurangabad daily_positive_cases_ma
# Aurangabad daily_positivity_rate_ma
# Aurangabad daily_tests
# Aurangabad cum_tests
# Aurangabad test_per_million
# Aurangabad daily_cases_per_million
# Aurangabad daily_tests_per_million
# Aurangabad daily_tests_ma
# Aurangabad daily_deceased_ma
# Aurangabad dbt_point
# Aurangabad dbt_l95
# Aurangabad dbt_u95
# Aurangabad rt_point
# Aurangabad rt_sd
# Aurangabad rt_l95
# Aurangabad rt_u95
# Aurangabad rt_l50
# Aurangabad rt_u50
# Aurangabad t_end
# Jalgaon dates
# Jalgaon cum_positive_cases
# Jalgaon cum_positivity_rate
# Jalgaon daily_positive_cases
# Jalgaon cum_recovered
# Jalgaon daily_recovered
# Jalgaon cum_deceased
# Jalgaon daily_deceased
# Jalgaon daily_positivity_rate
# Jalgaon daily_positive_cases_ma
# Jalgaon daily_positivity_rate_ma
# Jalgaon daily_tests
# Jalgaon cum_tests
# Jalgaon test_per_million
# Jalgaon daily_cases_per_million
# Jalgaon daily_tests_per_million
# Jalgaon daily_tests_ma
# Jalgaon daily_deceased_ma
# Jalgaon dbt_point
# Jalgaon dbt_l95
# Jalgaon dbt_u95
# Jalgaon rt_point
# Jalgaon rt_sd
# Jalgaon rt_l95
# Jalgaon rt_u95
# Jalgaon rt_l50
# Jalgaon rt_u50
# Jalgaon t_end
# Kolhapur dates
# Kolhapur cum_positive_cases
# Kolhapur cum_positivity_rate
# Kolhapur daily_positive_cases
# Kolhapur cum_recovered
# Kolhapur daily_recovered
# Kolhapur cum_deceased
# Kolhapur daily_deceased
# Kolhapur daily_positivity_rate
# Kolhapur daily_positive_cases_ma
# Kolhapur daily_positivity_rate_ma
# Kolhapur daily_tests
# Kolhapur cum_tests
# Kolhapur test_per_million
# Kolhapur daily_cases_per_million
# Kolhapur daily_tests_per_million
# Kolhapur daily_tests_ma
# Kolhapur daily_deceased_ma
# Kolhapur dbt_point
# Kolhapur dbt_l95
# Kolhapur dbt_u95
# Kolhapur rt_point
# Kolhapur rt_sd
# Kolhapur rt_l95
# Kolhapur rt_u95
# Kolhapur rt_l50
# Kolhapur rt_u50
# Kolhapur t_end
# Mumbai dates
# Mumbai cum_positive_cases
# Mumbai cum_positivity_rate
# Mumbai daily_positive_cases
# Mumbai cum_recovered
# Mumbai daily_recovered
# Mumbai cum_deceased
# Mumbai daily_deceased
# Mumbai daily_positivity_rate
# Mumbai daily_positive_cases_ma
# Mumbai daily_positivity_rate_ma
# Mumbai daily_tests
# Mumbai cum_tests
# Mumbai test_per_million
# Mumbai daily_cases_per_million
# Mumbai daily_tests_per_million
# Mumbai daily_tests_ma
# Mumbai daily_deceased_ma
# Mumbai dbt_point
# Mumbai dbt_l95
# Mumbai dbt_u95
# Mumbai rt_point
# Mumbai rt_sd
# Mumbai rt_l95
# Mumbai rt_u95
# Mumbai rt_l50
# Mumbai rt_u50
# Mumbai t_end
# Nagpur dates
# Nagpur cum_positive_cases
# Nagpur cum_positivity_rate
# Nagpur daily_positive_cases
# Nagpur cum_recovered
# Nagpur daily_recovered
# Nagpur cum_deceased
# Nagpur daily_deceased
# Nagpur daily_positivity_rate
# Nagpur daily_positive_cases_ma
# Nagpur daily_positivity_rate_ma
# Nagpur daily_tests
# Nagpur cum_tests
# Nagpur test_per_million
# Nagpur daily_cases_per_million
# Nagpur daily_tests_per_million
# Nagpur daily_tests_ma
# Nagpur daily_deceased_ma
# Nagpur dbt_point
# Nagpur dbt_l95
# Nagpur dbt_u95
# Nagpur rt_point
# Nagpur rt_sd
# Nagpur rt_l95
# Nagpur rt_u95
# Nagpur rt_l50
# Nagpur rt_u50
# Nagpur t_end
# Nashik dates
# Nashik cum_positive_cases
# Nashik cum_positivity_rate
# Nashik daily_positive_cases
# Nashik cum_recovered
# Nashik daily_recovered
# Nashik cum_deceased
# Nashik daily_deceased
# Nashik daily_positivity_rate
# Nashik daily_positive_cases_ma
# Nashik daily_positivity_rate_ma
# Nashik daily_tests
# Nashik cum_tests
# Nashik test_per_million
# Nashik daily_cases_per_million
# Nashik daily_tests_per_million
# Nashik daily_tests_ma
# Nashik daily_deceased_ma
# Nashik dbt_point
# Nashik dbt_l95
# Nashik dbt_u95
# Nashik rt_point
# Nashik rt_sd
# Nashik rt_l95
# Nashik rt_u95
# Nashik rt_l50
# Nashik rt_u50
# Nashik t_end
# Palghar dates
# Palghar cum_positive_cases
# Palghar cum_positivity_rate
# Palghar daily_positive_cases
# Palghar cum_recovered
# Palghar daily_recovered
# Palghar cum_deceased
# Palghar daily_deceased
# Palghar daily_positivity_rate
# Palghar daily_positive_cases_ma
# Palghar daily_positivity_rate_ma
# Palghar daily_tests
# Palghar cum_tests
# Palghar test_per_million
# Palghar daily_cases_per_million
# Palghar daily_tests_per_million
# Palghar daily_tests_ma
# Palghar daily_deceased_ma
# Palghar dbt_point
# Palghar dbt_l95
# Palghar dbt_u95
# Palghar rt_point
# Palghar rt_sd
# Palghar rt_l95
# Palghar rt_u95
# Palghar rt_l50
# Palghar rt_u50
# Palghar t_end
# Pune dates
# Pune cum_positive_cases
# Pune cum_positivity_rate
# Pune daily_positive_cases
# Pune cum_recovered
# Pune daily_recovered
# Pune cum_deceased
# Pune daily_deceased
# Pune daily_positivity_rate
# Pune daily_positive_cases_ma
# Pune daily_positivity_rate_ma
# Pune daily_tests
# Pune cum_tests
# Pune test_per_million
# Pune daily_cases_per_million
# Pune daily_tests_per_million
# Pune daily_tests_ma
# Pune daily_deceased_ma
# Pune dbt_point
# Pune dbt_l95
# Pune dbt_u95
# Pune rt_point
# Pune rt_sd
# Pune rt_l95
# Pune rt_u95
# Pune rt_l50
# Pune rt_u50
# Pune t_end
# Raigad dates
# Raigad cum_positive_cases
# Raigad cum_positivity_rate
# Raigad daily_positive_cases
# Raigad cum_recovered
# Raigad daily_recovered
# Raigad cum_deceased
# Raigad daily_deceased
# Raigad daily_positivity_rate
# Raigad daily_positive_cases_ma
# Raigad daily_positivity_rate_ma
# Raigad daily_tests
# Raigad cum_tests
# Raigad test_per_million
# Raigad daily_cases_per_million
# Raigad daily_tests_per_million
# Raigad daily_tests_ma
# Raigad daily_deceased_ma
# Raigad dbt_point
# Raigad dbt_l95
# Raigad dbt_u95
# Raigad rt_point
# Raigad rt_sd
# Raigad rt_l95
# Raigad rt_u95
# Raigad rt_l50
# Raigad rt_u50
# Raigad t_end
# Solapur dates
# Solapur cum_positive_cases
# Solapur cum_positivity_rate
# Solapur daily_positive_cases
# Solapur cum_recovered
# Solapur daily_recovered
# Solapur cum_deceased
# Solapur daily_deceased
# Solapur daily_positivity_rate
# Solapur daily_positive_cases_ma
# Solapur daily_positivity_rate_ma
# Solapur daily_tests
# Solapur cum_tests
# Solapur test_per_million
# Solapur daily_cases_per_million
# Solapur daily_tests_per_million
# Solapur daily_tests_ma
# Solapur daily_deceased_ma
# Solapur dbt_point
# Solapur dbt_l95
# Solapur dbt_u95
# Solapur rt_point
# Solapur rt_sd
# Solapur rt_l95
# Solapur rt_u95
# Solapur rt_l50
# Solapur rt_u50
# Solapur t_end
# Thane dates
# Thane cum_positive_cases
# Thane cum_positivity_rate
# Thane daily_positive_cases
# Thane cum_recovered
# Thane daily_recovered
# Thane cum_deceased
# Thane daily_deceased
# Thane daily_positivity_rate
# Thane daily_positive_cases_ma
# Thane daily_positivity_rate_ma
# Thane daily_tests
# Thane cum_tests
# Thane test_per_million
# Thane daily_cases_per_million
# Thane daily_tests_per_million
# Thane daily_tests_ma
# Thane daily_deceased_ma
# Thane dbt_point
# Thane dbt_l95
# Thane dbt_u95
# Thane rt_point
# Thane rt_sd
# Thane rt_l95
# Thane rt_u95
# Thane rt_l50
# Thane rt_u50
# Thane t_end
# Satara dates
# Satara cum_positive_cases
# Satara cum_positivity_rate
# Satara daily_positive_cases
# Satara cum_recovered
# Satara daily_recovered
# Satara cum_deceased
# Satara daily_deceased
# Satara daily_positivity_rate
# Satara daily_positive_cases_ma
# Satara daily_positivity_rate_ma
# Satara daily_tests
# Satara cum_tests
# Satara test_per_million
# Satara daily_cases_per_million
# Satara daily_tests_per_million
# Satara daily_tests_ma
# Satara daily_deceased_ma
# Satara dbt_point
# Satara dbt_l95
# Satara dbt_u95
# Satara rt_point
# Satara rt_sd
# Satara rt_l95
# Satara rt_u95
# Satara rt_l50
# Satara rt_u50
# Satara t_end
# Sangli dates
# Sangli cum_positive_cases
# Sangli cum_positivity_rate
# Sangli daily_positive_cases
# Sangli cum_recovered
# Sangli daily_recovered
# Sangli cum_deceased
# Sangli daily_deceased
# Sangli daily_positivity_rate
# Sangli daily_positive_cases_ma
# Sangli daily_positivity_rate_ma
# Sangli daily_tests
# Sangli cum_tests
# Sangli test_per_million
# Sangli daily_cases_per_million
# Sangli daily_tests_per_million
# Sangli daily_tests_ma
# Sangli daily_deceased_ma
# Sangli dbt_point
# Sangli dbt_l95
# Sangli dbt_u95
# Sangli rt_point
# Sangli rt_sd
# Sangli rt_l95
# Sangli rt_u95
# Sangli rt_l50
# Sangli rt_u50
# Sangli t_end
# Ahmednagar dates
# Ahmednagar cum_positive_cases
# Ahmednagar cum_positivity_rate
# Ahmednagar daily_positive_cases
# Ahmednagar cum_recovered
# Ahmednagar daily_recovered
# Ahmednagar cum_deceased
# Ahmednagar daily_deceased
# Ahmednagar daily_positivity_rate
# Ahmednagar daily_positive_cases_ma
# Ahmednagar daily_positivity_rate_ma
# Ahmednagar daily_tests
# Ahmednagar cum_tests
# Ahmednagar test_per_million
# Ahmednagar daily_cases_per_million
# Ahmednagar daily_tests_per_million
# Ahmednagar daily_tests_ma
# Ahmednagar daily_deceased_ma
# Ahmednagar dbt_point
# Ahmednagar dbt_l95
# Ahmednagar dbt_u95
# Ahmednagar rt_point
# Ahmednagar rt_sd
# Ahmednagar rt_l95
# Ahmednagar rt_u95
# Ahmednagar rt_l50
# Ahmednagar rt_u50
# Ahmednagar t_end
# Nanded dates
# Nanded cum_positive_cases
# Nanded cum_positivity_rate
# Nanded daily_positive_cases
# Nanded cum_recovered
# Nanded daily_recovered
# Nanded cum_deceased
# Nanded daily_deceased
# Nanded daily_positivity_rate
# Nanded daily_positive_cases_ma
# Nanded daily_positivity_rate_ma
# Nanded daily_tests
# Nanded cum_tests
# Nanded test_per_million
# Nanded daily_cases_per_million
# Nanded daily_tests_per_million
# Nanded daily_tests_ma
# Nanded daily_deceased_ma
# Nanded dbt_point
# Nanded dbt_l95
# Nanded dbt_u95
# Nanded rt_point
# Nanded rt_sd
# Nanded rt_l95
# Nanded rt_u95
# Nanded rt_l50
# Nanded rt_u50
# Nanded t_end
# Bhopal dates
# Bhopal cum_positive_cases
# Bhopal cum_positivity_rate
# Bhopal daily_positive_cases
# Bhopal cum_recovered
# Bhopal daily_recovered
# Bhopal cum_deceased
# Bhopal daily_deceased
# Bhopal daily_positivity_rate
# Bhopal daily_positive_cases_ma
# Bhopal daily_positivity_rate_ma
# Bhopal daily_tests
# Bhopal cum_tests
# Bhopal test_per_million
# Bhopal daily_cases_per_million
# Bhopal daily_tests_per_million
# Bhopal daily_tests_ma
# Bhopal daily_deceased_ma
# Bhopal dbt_point
# Bhopal dbt_l95
# Bhopal dbt_u95
# Bhopal rt_point
# Bhopal rt_sd
# Bhopal rt_l95
# Bhopal rt_u95
# Bhopal rt_l50
# Bhopal rt_u50
# Bhopal t_end
# Indore dates
# Indore cum_positive_cases
# Indore cum_positivity_rate
# Indore daily_positive_cases
# Indore cum_recovered
# Indore daily_recovered
# Indore cum_deceased
# Indore daily_deceased
# Indore daily_positivity_rate
# Indore daily_positive_cases_ma
# Indore daily_positivity_rate_ma
# Indore daily_tests
# Indore cum_tests
# Indore test_per_million
# Indore daily_cases_per_million
# Indore daily_tests_per_million
# Indore daily_tests_ma
# Indore daily_deceased_ma
# Indore dbt_point
# Indore dbt_l95
# Indore dbt_u95
# Indore rt_point
# Indore rt_sd
# Indore rt_l95
# Indore rt_u95
# Indore rt_l50
# Indore rt_u50
# Indore t_end
# Ganjam dates
# Ganjam cum_positive_cases
# Ganjam cum_positivity_rate
# Ganjam daily_positive_cases
# Ganjam cum_recovered
# Ganjam daily_recovered
# Ganjam cum_deceased
# Ganjam daily_deceased
# Ganjam daily_positivity_rate
# Ganjam daily_positive_cases_ma
# Ganjam daily_positivity_rate_ma
# Ganjam daily_tests
# Ganjam cum_tests
# Ganjam test_per_million
# Ganjam daily_cases_per_million
# Ganjam daily_tests_per_million
# Ganjam daily_tests_ma
# Ganjam daily_deceased_ma
# Ganjam dbt_point
# Ganjam dbt_l95
# Ganjam dbt_u95
# Ganjam rt_point
# Ganjam rt_sd
# Ganjam rt_l95
# Ganjam rt_u95
# Ganjam rt_l50
# Ganjam rt_u50
# Ganjam t_end
# Khordha dates
# Khordha cum_positive_cases
# Khordha cum_positivity_rate
# Khordha daily_positive_cases
# Khordha cum_recovered
# Khordha daily_recovered
# Khordha cum_deceased
# Khordha daily_deceased
# Khordha daily_positivity_rate
# Khordha daily_positive_cases_ma
# Khordha daily_positivity_rate_ma
# Khordha daily_tests
# Khordha cum_tests
# Khordha test_per_million
# Khordha daily_cases_per_million
# Khordha daily_tests_per_million
# Khordha daily_tests_ma
# Khordha daily_deceased_ma
# Khordha dbt_point
# Khordha dbt_l95
# Khordha dbt_u95
# Khordha rt_point
# Khordha rt_sd
# Khordha rt_l95
# Khordha rt_u95
# Khordha rt_l50
# Khordha rt_u50
# Khordha t_end
# Ludhiana dates
# Ludhiana cum_positive_cases
# Ludhiana cum_positivity_rate
# Ludhiana daily_positive_cases
# Ludhiana cum_recovered
# Ludhiana daily_recovered
# Ludhiana cum_deceased
# Ludhiana daily_deceased
# Ludhiana daily_positivity_rate
# Ludhiana daily_positive_cases_ma
# Ludhiana daily_positivity_rate_ma
# Ludhiana daily_tests
# Ludhiana cum_tests
# Ludhiana test_per_million
# Ludhiana daily_cases_per_million
# Ludhiana daily_tests_per_million
# Ludhiana daily_tests_ma
# Ludhiana daily_deceased_ma
# Ludhiana dbt_point
# Ludhiana dbt_l95
# Ludhiana dbt_u95
# Ludhiana rt_point
# Ludhiana rt_sd
# Ludhiana rt_l95
# Ludhiana rt_u95
# Ludhiana rt_l50
# Ludhiana rt_u50
# Ludhiana t_end
# S.A.S. Nagar dates
# S.A.S. Nagar cum_positive_cases
# S.A.S. Nagar cum_positivity_rate
# S.A.S. Nagar daily_positive_cases
# S.A.S. Nagar cum_recovered
# S.A.S. Nagar daily_recovered
# S.A.S. Nagar cum_deceased
# S.A.S. Nagar daily_deceased
# S.A.S. Nagar daily_positivity_rate
# S.A.S. Nagar daily_positive_cases_ma
# S.A.S. Nagar daily_positivity_rate_ma
# S.A.S. Nagar daily_tests
# S.A.S. Nagar cum_tests
# S.A.S. Nagar test_per_million
# S.A.S. Nagar daily_cases_per_million
# S.A.S. Nagar daily_tests_per_million
# S.A.S. Nagar daily_tests_ma
# S.A.S. Nagar daily_deceased_ma
# S.A.S. Nagar dbt_point
# S.A.S. Nagar dbt_l95
# S.A.S. Nagar dbt_u95
# S.A.S. Nagar rt_point
# S.A.S. Nagar rt_sd
# S.A.S. Nagar rt_l95
# S.A.S. Nagar rt_u95
# S.A.S. Nagar rt_l50
# S.A.S. Nagar rt_u50
# S.A.S. Nagar t_end
# Jalandhar dates
# Jalandhar cum_positive_cases
# Jalandhar cum_positivity_rate
# Jalandhar daily_positive_cases
# Jalandhar cum_recovered
# Jalandhar daily_recovered
# Jalandhar cum_deceased
# Jalandhar daily_deceased
# Jalandhar daily_positivity_rate
# Jalandhar daily_positive_cases_ma
# Jalandhar daily_positivity_rate_ma
# Jalandhar daily_tests
# Jalandhar cum_tests
# Jalandhar test_per_million
# Jalandhar daily_cases_per_million
# Jalandhar daily_tests_per_million
# Jalandhar daily_tests_ma
# Jalandhar daily_deceased_ma
# Jalandhar dbt_point
# Jalandhar dbt_l95
# Jalandhar dbt_u95
# Jalandhar rt_point
# Jalandhar rt_sd
# Jalandhar rt_l95
# Jalandhar rt_u95
# Jalandhar rt_l50
# Jalandhar rt_u50
# Jalandhar t_end
# Jaipur dates
# Jaipur cum_positive_cases
# Jaipur cum_positivity_rate
# Jaipur daily_positive_cases
# Jaipur cum_recovered
# Jaipur daily_recovered
# Jaipur cum_deceased
# Jaipur daily_deceased
# Jaipur daily_positivity_rate
# Jaipur daily_positive_cases_ma
# Jaipur daily_positivity_rate_ma
# Jaipur daily_tests
# Jaipur cum_tests
# Jaipur test_per_million
# Jaipur daily_cases_per_million
# Jaipur daily_tests_per_million
# Jaipur daily_tests_ma
# Jaipur daily_deceased_ma
# Jaipur dbt_point
# Jaipur dbt_l95
# Jaipur dbt_u95
# Jaipur rt_point
# Jaipur rt_sd
# Jaipur rt_l95
# Jaipur rt_u95
# Jaipur rt_l50
# Jaipur rt_u50
# Jaipur t_end
# Chengalpattu dates
# Chengalpattu cum_positive_cases
# Chengalpattu cum_positivity_rate
# Chengalpattu daily_positive_cases
# Chengalpattu cum_recovered
# Chengalpattu daily_recovered
# Chengalpattu cum_deceased
# Chengalpattu daily_deceased
# Chengalpattu daily_positivity_rate
# Chengalpattu daily_positive_cases_ma
# Chengalpattu daily_positivity_rate_ma
# Chengalpattu daily_tests
# Chengalpattu cum_tests
# Chengalpattu test_per_million
# Chengalpattu daily_cases_per_million
# Chengalpattu daily_tests_per_million
# Chengalpattu daily_tests_ma
# Chengalpattu daily_deceased_ma
# Chengalpattu dbt_point
# Chengalpattu dbt_l95
# Chengalpattu dbt_u95
# Chengalpattu rt_point
# Chengalpattu rt_sd
# Chengalpattu rt_l95
# Chengalpattu rt_u95
# Chengalpattu rt_l50
# Chengalpattu rt_u50
# Chengalpattu t_end
# Chennai dates
# Chennai cum_positive_cases
# Chennai cum_positivity_rate
# Chennai daily_positive_cases
# Chennai cum_recovered
# Chennai daily_recovered
# Chennai cum_deceased
# Chennai daily_deceased
# Chennai daily_positivity_rate
# Chennai daily_positive_cases_ma
# Chennai daily_positivity_rate_ma
# Chennai daily_tests
# Chennai cum_tests
# Chennai test_per_million
# Chennai daily_cases_per_million
# Chennai daily_tests_per_million
# Chennai daily_tests_ma
# Chennai daily_deceased_ma
# Chennai dbt_point
# Chennai dbt_l95
# Chennai dbt_u95
# Chennai rt_point
# Chennai rt_sd
# Chennai rt_l95
# Chennai rt_u95
# Chennai rt_l50
# Chennai rt_u50
# Chennai t_end
# Kancheepuram dates
# Kancheepuram cum_positive_cases
# Kancheepuram cum_positivity_rate
# Kancheepuram daily_positive_cases
# Kancheepuram cum_recovered
# Kancheepuram daily_recovered
# Kancheepuram cum_deceased
# Kancheepuram daily_deceased
# Kancheepuram daily_positivity_rate
# Kancheepuram daily_positive_cases_ma
# Kancheepuram daily_positivity_rate_ma
# Kancheepuram daily_tests
# Kancheepuram cum_tests
# Kancheepuram test_per_million
# Kancheepuram daily_cases_per_million
# Kancheepuram daily_tests_per_million
# Kancheepuram daily_tests_ma
# Kancheepuram daily_deceased_ma
# Kancheepuram dbt_point
# Kancheepuram dbt_l95
# Kancheepuram dbt_u95
# Kancheepuram rt_point
# Kancheepuram rt_sd
# Kancheepuram rt_l95
# Kancheepuram rt_u95
# Kancheepuram rt_l50
# Kancheepuram rt_u50
# Kancheepuram t_end
# Madurai dates
# Madurai cum_positive_cases
# Madurai cum_positivity_rate
# Madurai daily_positive_cases
# Madurai cum_recovered
# Madurai daily_recovered
# Madurai cum_deceased
# Madurai daily_deceased
# Madurai daily_positivity_rate
# Madurai daily_positive_cases_ma
# Madurai daily_positivity_rate_ma
# Madurai daily_tests
# Madurai cum_tests
# Madurai test_per_million
# Madurai daily_cases_per_million
# Madurai daily_tests_per_million
# Madurai daily_tests_ma
# Madurai daily_deceased_ma
# Madurai dbt_point
# Madurai dbt_l95
# Madurai dbt_u95
# Madurai rt_point
# Madurai rt_sd
# Madurai rt_l95
# Madurai rt_u95
# Madurai rt_l50
# Madurai rt_u50
# Madurai t_end
# Thiruvallur dates
# Thiruvallur cum_positive_cases
# Thiruvallur cum_positivity_rate
# Thiruvallur daily_positive_cases
# Thiruvallur cum_recovered
# Thiruvallur daily_recovered
# Thiruvallur cum_deceased
# Thiruvallur daily_deceased
# Thiruvallur daily_positivity_rate
# Thiruvallur daily_positive_cases_ma
# Thiruvallur daily_positivity_rate_ma
# Thiruvallur daily_tests
# Thiruvallur cum_tests
# Thiruvallur test_per_million
# Thiruvallur daily_cases_per_million
# Thiruvallur daily_tests_per_million
# Thiruvallur daily_tests_ma
# Thiruvallur daily_deceased_ma
# Thiruvallur dbt_point
# Thiruvallur dbt_l95
# Thiruvallur dbt_u95
# Thiruvallur rt_point
# Thiruvallur rt_sd
# Thiruvallur rt_l95
# Thiruvallur rt_u95
# Thiruvallur rt_l50
# Thiruvallur rt_u50
# Thiruvallur t_end
# Tiruvannamalai dates
# Tiruvannamalai cum_positive_cases
# Tiruvannamalai cum_positivity_rate
# Tiruvannamalai daily_positive_cases
# Tiruvannamalai cum_recovered
# Tiruvannamalai daily_recovered
# Tiruvannamalai cum_deceased
# Tiruvannamalai daily_deceased
# Tiruvannamalai daily_positivity_rate
# Tiruvannamalai daily_positive_cases_ma
# Tiruvannamalai daily_positivity_rate_ma
# Tiruvannamalai daily_tests
# Tiruvannamalai cum_tests
# Tiruvannamalai test_per_million
# Tiruvannamalai daily_cases_per_million
# Tiruvannamalai daily_tests_per_million
# Tiruvannamalai daily_tests_ma
# Tiruvannamalai daily_deceased_ma
# Tiruvannamalai dbt_point
# Tiruvannamalai dbt_l95
# Tiruvannamalai dbt_u95
# Tiruvannamalai rt_point
# Tiruvannamalai rt_sd
# Tiruvannamalai rt_l95
# Tiruvannamalai rt_u95
# Tiruvannamalai rt_l50
# Tiruvannamalai rt_u50
# Tiruvannamalai t_end
# Vellore dates
# Vellore cum_positive_cases
# Vellore cum_positivity_rate
# Vellore daily_positive_cases
# Vellore cum_recovered
# Vellore daily_recovered
# Vellore cum_deceased
# Vellore daily_deceased
# Vellore daily_positivity_rate
# Vellore daily_positive_cases_ma
# Vellore daily_positivity_rate_ma
# Vellore daily_tests
# Vellore cum_tests
# Vellore test_per_million
# Vellore daily_cases_per_million
# Vellore daily_tests_per_million
# Vellore daily_tests_ma
# Vellore daily_deceased_ma
# Vellore dbt_point
# Vellore dbt_l95
# Vellore dbt_u95
# Vellore rt_point
# Vellore rt_sd
# Vellore rt_l95
# Vellore rt_u95
# Vellore rt_l50
# Vellore rt_u50
# Vellore t_end
# Coimbatore dates
# Coimbatore cum_positive_cases
# Coimbatore cum_positivity_rate
# Coimbatore daily_positive_cases
# Coimbatore cum_recovered
# Coimbatore daily_recovered
# Coimbatore cum_deceased
# Coimbatore daily_deceased
# Coimbatore daily_positivity_rate
# Coimbatore daily_positive_cases_ma
# Coimbatore daily_positivity_rate_ma
# Coimbatore daily_tests
# Coimbatore cum_tests
# Coimbatore test_per_million
# Coimbatore daily_cases_per_million
# Coimbatore daily_tests_per_million
# Coimbatore daily_tests_ma
# Coimbatore daily_deceased_ma
# Coimbatore dbt_point
# Coimbatore dbt_l95
# Coimbatore dbt_u95
# Coimbatore rt_point
# Coimbatore rt_sd
# Coimbatore rt_l95
# Coimbatore rt_u95
# Coimbatore rt_l50
# Coimbatore rt_u50
# Coimbatore t_end
# Aligarh dates
# Aligarh cum_positive_cases
# Aligarh cum_positivity_rate
# Aligarh daily_positive_cases
# Aligarh cum_recovered
# Aligarh daily_recovered
# Aligarh cum_deceased
# Aligarh daily_deceased
# Aligarh daily_positivity_rate
# Aligarh daily_positive_cases_ma
# Aligarh daily_positivity_rate_ma
# Aligarh daily_tests
# Aligarh cum_tests
# Aligarh test_per_million
# Aligarh daily_cases_per_million
# Aligarh daily_tests_per_million
# Aligarh daily_tests_ma
# Aligarh daily_deceased_ma
# Aligarh dbt_point
# Aligarh dbt_l95
# Aligarh dbt_u95
# Aligarh rt_point
# Aligarh rt_sd
# Aligarh rt_l95
# Aligarh rt_u95
# Aligarh rt_l50
# Aligarh rt_u50
# Aligarh t_end
# Bareilly dates
# Bareilly cum_positive_cases
# Bareilly cum_positivity_rate
# Bareilly daily_positive_cases
# Bareilly cum_recovered
# Bareilly daily_recovered
# Bareilly cum_deceased
# Bareilly daily_deceased
# Bareilly daily_positivity_rate
# Bareilly daily_positive_cases_ma
# Bareilly daily_positivity_rate_ma
# Bareilly daily_tests
# Bareilly cum_tests
# Bareilly test_per_million
# Bareilly daily_cases_per_million
# Bareilly daily_tests_per_million
# Bareilly daily_tests_ma
# Bareilly daily_deceased_ma
# Bareilly dbt_point
# Bareilly dbt_l95
# Bareilly dbt_u95
# Bareilly rt_point
# Bareilly rt_sd
# Bareilly rt_l95
# Bareilly rt_u95
# Bareilly rt_l50
# Bareilly rt_u50
# Bareilly t_end
# Gautam Buddha Nagar dates
# Gautam Buddha Nagar cum_positive_cases
# Gautam Buddha Nagar cum_positivity_rate
# Gautam Buddha Nagar daily_positive_cases
# Gautam Buddha Nagar cum_recovered
# Gautam Buddha Nagar daily_recovered
# Gautam Buddha Nagar cum_deceased
# Gautam Buddha Nagar daily_deceased
# Gautam Buddha Nagar daily_positivity_rate
# Gautam Buddha Nagar daily_positive_cases_ma
# Gautam Buddha Nagar daily_positivity_rate_ma
# Gautam Buddha Nagar daily_tests
# Gautam Buddha Nagar cum_tests
# Gautam Buddha Nagar test_per_million
# Gautam Buddha Nagar daily_cases_per_million
# Gautam Buddha Nagar daily_tests_per_million
# Gautam Buddha Nagar daily_tests_ma
# Gautam Buddha Nagar daily_deceased_ma
# Gautam Buddha Nagar dbt_point
# Gautam Buddha Nagar dbt_l95
# Gautam Buddha Nagar dbt_u95
# Gautam Buddha Nagar rt_point
# Gautam Buddha Nagar rt_sd
# Gautam Buddha Nagar rt_l95
# Gautam Buddha Nagar rt_u95
# Gautam Buddha Nagar rt_l50
# Gautam Buddha Nagar rt_u50
# Gautam Buddha Nagar t_end
# Ghaziabad dates
# Ghaziabad cum_positive_cases
# Ghaziabad cum_positivity_rate
# Ghaziabad daily_positive_cases
# Ghaziabad cum_recovered
# Ghaziabad daily_recovered
# Ghaziabad cum_deceased
# Ghaziabad daily_deceased
# Ghaziabad daily_positivity_rate
# Ghaziabad daily_positive_cases_ma
# Ghaziabad daily_positivity_rate_ma
# Ghaziabad daily_tests
# Ghaziabad cum_tests
# Ghaziabad test_per_million
# Ghaziabad daily_cases_per_million
# Ghaziabad daily_tests_per_million
# Ghaziabad daily_tests_ma
# Ghaziabad daily_deceased_ma
# Ghaziabad dbt_point
# Ghaziabad dbt_l95
# Ghaziabad dbt_u95
# Ghaziabad rt_point
# Ghaziabad rt_sd
# Ghaziabad rt_l95
# Ghaziabad rt_u95
# Ghaziabad rt_l50
# Ghaziabad rt_u50
# Ghaziabad t_end
# Kanpur Nagar dates
# Kanpur Nagar cum_positive_cases
# Kanpur Nagar cum_positivity_rate
# Kanpur Nagar daily_positive_cases
# Kanpur Nagar cum_recovered
# Kanpur Nagar daily_recovered
# Kanpur Nagar cum_deceased
# Kanpur Nagar daily_deceased
# Kanpur Nagar daily_positivity_rate
# Kanpur Nagar daily_positive_cases_ma
# Kanpur Nagar daily_positivity_rate_ma
# Kanpur Nagar daily_tests
# Kanpur Nagar cum_tests
# Kanpur Nagar test_per_million
# Kanpur Nagar daily_cases_per_million
# Kanpur Nagar daily_tests_per_million
# Kanpur Nagar daily_tests_ma
# Kanpur Nagar daily_deceased_ma
# Kanpur Nagar dbt_point
# Kanpur Nagar dbt_l95
# Kanpur Nagar dbt_u95
# Kanpur Nagar rt_point
# Kanpur Nagar rt_sd
# Kanpur Nagar rt_l95
# Kanpur Nagar rt_u95
# Kanpur Nagar rt_l50
# Kanpur Nagar rt_u50
# Kanpur Nagar t_end
# Lucknow dates
# Lucknow cum_positive_cases
# Lucknow cum_positivity_rate
# Lucknow daily_positive_cases
# Lucknow cum_recovered
# Lucknow daily_recovered
# Lucknow cum_deceased
# Lucknow daily_deceased
# Lucknow daily_positivity_rate
# Lucknow daily_positive_cases_ma
# Lucknow daily_positivity_rate_ma
# Lucknow daily_tests
# Lucknow cum_tests
# Lucknow test_per_million
# Lucknow daily_cases_per_million
# Lucknow daily_tests_per_million
# Lucknow daily_tests_ma
# Lucknow daily_deceased_ma
# Lucknow dbt_point
# Lucknow dbt_l95
# Lucknow dbt_u95
# Lucknow rt_point
# Lucknow rt_sd
# Lucknow rt_l95
# Lucknow rt_u95
# Lucknow rt_l50
# Lucknow rt_u50
# Lucknow t_end
# Varanasi dates
# Varanasi cum_positive_cases
# Varanasi cum_positivity_rate
# Varanasi daily_positive_cases
# Varanasi cum_recovered
# Varanasi daily_recovered
# Varanasi cum_deceased
# Varanasi daily_deceased
# Varanasi daily_positivity_rate
# Varanasi daily_positive_cases_ma
# Varanasi daily_positivity_rate_ma
# Varanasi daily_tests
# Varanasi cum_tests
# Varanasi test_per_million
# Varanasi daily_cases_per_million
# Varanasi daily_tests_per_million
# Varanasi daily_tests_ma
# Varanasi daily_deceased_ma
# Varanasi dbt_point
# Varanasi dbt_l95
# Varanasi dbt_u95
# Varanasi rt_point
# Varanasi rt_sd
# Varanasi rt_l95
# Varanasi rt_u95
# Varanasi rt_l50
# Varanasi rt_u50
# Varanasi t_end
# Prayagraj dates
# Prayagraj cum_positive_cases
# Prayagraj cum_positivity_rate
# Prayagraj daily_positive_cases
# Prayagraj cum_recovered
# Prayagraj daily_recovered
# Prayagraj cum_deceased
# Prayagraj daily_deceased
# Prayagraj daily_positivity_rate
# Prayagraj daily_positive_cases_ma
# Prayagraj daily_positivity_rate_ma
# Prayagraj daily_tests
# Prayagraj cum_tests
# Prayagraj test_per_million
# Prayagraj daily_cases_per_million
# Prayagraj daily_tests_per_million
# Prayagraj daily_tests_ma
# Prayagraj daily_deceased_ma
# Prayagraj dbt_point
# Prayagraj dbt_l95
# Prayagraj dbt_u95
# Prayagraj rt_point
# Prayagraj rt_sd
# Prayagraj rt_l95
# Prayagraj rt_u95
# Prayagraj rt_l50
# Prayagraj rt_u50
# Prayagraj t_end
# Kolkata dates
# Kolkata cum_positive_cases
# Kolkata cum_positivity_rate
# Kolkata daily_positive_cases
# Kolkata cum_recovered
# Kolkata daily_recovered
# Kolkata cum_deceased
# Kolkata daily_deceased
# Kolkata daily_positivity_rate
# Kolkata daily_positive_cases_ma
# Kolkata daily_positivity_rate_ma
# Kolkata daily_tests
# Kolkata cum_tests
# Kolkata test_per_million
# Kolkata daily_cases_per_million
# Kolkata daily_tests_per_million
# Kolkata daily_tests_ma
# Kolkata daily_deceased_ma
# Kolkata dbt_point
# Kolkata dbt_l95
# Kolkata dbt_u95
# Kolkata rt_point
# Kolkata rt_sd
# Kolkata rt_l95
# Kolkata rt_u95
# Kolkata rt_l50
# Kolkata rt_u50
# Kolkata t_end
# North 24 Parganas dates
# North 24 Parganas cum_positive_cases
# North 24 Parganas cum_positivity_rate
# North 24 Parganas daily_positive_cases
# North 24 Parganas cum_recovered
# North 24 Parganas daily_recovered
# North 24 Parganas cum_deceased
# North 24 Parganas daily_deceased
# North 24 Parganas daily_positivity_rate
# North 24 Parganas daily_positive_cases_ma
# North 24 Parganas daily_positivity_rate_ma
# North 24 Parganas daily_tests
# North 24 Parganas cum_tests
# North 24 Parganas test_per_million
# North 24 Parganas daily_cases_per_million
# North 24 Parganas daily_tests_per_million
# North 24 Parganas daily_tests_ma
# North 24 Parganas daily_deceased_ma
# North 24 Parganas dbt_point
# North 24 Parganas dbt_l95
# North 24 Parganas dbt_u95
# North 24 Parganas rt_point
# North 24 Parganas rt_sd
# North 24 Parganas rt_l95
# North 24 Parganas rt_u95
# North 24 Parganas rt_l50
# North 24 Parganas rt_u50
# North 24 Parganas t_end

# %%
complete[complete['state']=='Ahmedabad']
# Out:
#          state       dates cum_positive_cases cum_positivity_rate  \
# 0    Ahmedabad  2020-01-30
# 1    Ahmedabad  2020-01-31
# 2    Ahmedabad  2020-02-01
# 3    Ahmedabad  2020-02-02
# 4    Ahmedabad  2020-02-03
# ..         ...         ...                ...                 ...
# 242  Ahmedabad  2020-09-28              36456             2.94809
# 243  Ahmedabad  2020-09-29              36651             2.93169
# 244  Ahmedabad  2020-09-30              36848             2.91695
# 245  Ahmedabad  2020-10-01              37041             2.90371
# 246  Ahmedabad  2020-10-02              37239             2.88963
#
#     daily_positive_cases cum_recovered daily_recovered cum_deceased  \
# 0
# 1
# 2
# 3
# 4
# ..                   ...           ...             ...          ...
# 242                  210         30345             210         1806
# 243                  195         30581             236         1809
# 244                  197         30848             267         1812
# 245                  193         31104             256         1815
# 246                  198         31362             258         1818
#
#     daily_deceased daily_positivity_rate  ... dbt_point  dbt_l95  dbt_u95  \
# 0                                         ...
# 1                                         ...
# 2                                         ...
# 3                                         ...
# 4                                         ...
# ..             ...                   ...  ...       ...      ...      ...
# 242              3               1.55325  ...   132.184  127.546  136.821
# 243              3               1.43689  ...   130.226  122.222  138.231
# 244              3               1.50715  ...   128.737  120.925   136.55
# 245              3               1.55582  ...   127.507  121.264  133.749
# 246              3               1.51515  ...   127.284  121.914  132.654
#
#     rt_point    rt_sd    rt_l95   rt_u95   rt_l50   rt_u50 t_end
# 0    2.55876  1.97705  0.233333  7.63484  1.10474  3.48554     8
# 1    2.58965  2.00192  0.239865  7.72281  1.13939  3.50743     9
# 2    2.58844  1.99907   0.23702  7.71036  1.13065  3.52322    10
# 3    2.60589   2.0066  0.248413  7.74599  1.13321  3.52476    11
# 4    2.59291  1.98858  0.235023   7.6389  1.14451  3.51551    12
# ..       ...      ...       ...      ...      ...      ...   ...
# 242
# 243
# 244
# 245
# 246
#
# [247 rows x 29 columns]

# %%
complete.to_csv('complete_districts.csv',index=False)

# %%
complete_shifted.to_csv('allmetrics_districts.csv',index=False)

# %%
states_indented = json.dumps(states, indent = 4)
with open("covidtoday_dist.json", "w") as outfile: 
    outfile.write(states_indented)

# %%
states_indented = json.dumps(states_shifted, indent = 4)
with open("allmetrics_districts.json", "w") as outfile: 
    outfile.write(states_indented)
