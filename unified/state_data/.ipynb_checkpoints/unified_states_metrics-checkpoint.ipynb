# %%
#!pip install wget
#!pip install urllib3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from subprocess import call
from scipy.stats.distributions import gamma,lognorm
import json 
import wget
import os
import os.path
from datetime import datetime,timedelta
import pytz 
from collections import OrderedDict

from urllib.request import urlopen
import copy
import collections

# %%
#!git clone https://github.com/CovidToday/backend

# %%
if os.path.exists("test.json"):
  os.remove("test.json")
wget.download('https://api.covid19india.org/v3/data-all.json', os.path.join(os.getcwd(),'test.json')) #os.path.join instead of concating string together
# Out:
# 100% [....................................................] 32594910 / 32594910
# 'C:\\Users\\asus\\Documents\\GitHub\\CovidToday_Website\\unified\\state_data\\test.json'

# %%
def convert(dat): 
    return datetime.strptime(dat, '%Y-%m-%d').strftime('%d %B')

# %%
json.load(open('test.json')).keys()
# Out:
# dict_keys(['2020-01-30', '2020-02-02', '2020-02-03', '2020-02-14', '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09', '2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13', '2020-03-14', '2020-03-15', '2020-03-16', '2020-03-17', '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-21', '2020-03-22', '2020-03-23', '2020-03-24', '2020-03-25', '2020-03-26', '2020-03-27', '2020-03-28', '2020-03-29', '2020-03-30', '2020-03-31', '2020-04-01', '2020-04-02', '2020-04-03', '2020-04-04', '2020-04-05', '2020-04-06', '2020-04-07', '2020-04-08', '2020-04-09', '2020-04-10', '2020-04-11', '2020-04-12', '2020-04-13', '2020-04-14', '2020-04-15', '2020-04-16', '2020-04-17', '2020-04-18', '2020-04-19', '2020-04-20', '2020-04-21', '2020-04-22', '2020-04-23', '2020-04-24', '2020-04-25', '2020-04-26', '2020-04-27', '2020-04-28', '2020-04-29', '2020-04-30', '2020-05-01', '2020-05-02', '2020-05-03', '2020-05-04', '2020-05-05', '2020-05-06', '2020-05-07', '2020-05-08', '2020-05-09', '2020-05-10', '2020-05-11', '2020-05-12', '2020-05-13', '2020-05-14', '2020-05-15', '2020-05-16', '2020-05-17', '2020-05-18', '2020-05-19', '2020-05-20', '2020-05-21', '2020-05-22', '2020-05-23', '2020-05-24', '2020-05-25', '2020-05-26', '2020-05-27', '2020-05-28', '2020-05-29', '2020-05-30', '2020-05-31', '2020-06-01', '2020-06-02', '2020-06-03', '2020-06-04', '2020-06-05', '2020-06-06', '2020-06-07', '2020-06-08', '2020-06-09', '2020-06-10', '2020-06-11', '2020-06-12', '2020-06-13', '2020-06-14', '2020-06-15', '2020-06-16', '2020-06-17', '2020-06-18', '2020-06-19', '2020-06-20', '2020-06-21', '2020-06-22', '2020-06-23', '2020-06-24', '2020-06-25', '2020-06-26', '2020-06-27', '2020-06-28', '2020-06-29', '2020-06-30', '2020-07-01', '2020-07-02', '2020-07-03', '2020-07-04', '2020-07-05', '2020-07-06', '2020-07-07', '2020-07-08', '2020-07-09', '2020-07-10', '2020-07-11', '2020-07-12', '2020-07-13', '2020-07-14', '2020-07-15', '2020-07-16', '2020-07-17', '2020-07-18', '2020-07-19', '2020-07-20', '2020-07-21', '2020-07-22', '2020-07-23', '2020-07-24', '2020-07-25', '2020-07-26', '2020-07-27', '2020-07-28', '2020-07-29', '2020-07-30', '2020-07-31', '2020-08-01', '2020-08-02', '2020-08-03', '2020-08-04', '2020-08-05', '2020-08-06', '2020-08-07', '2020-08-08', '2020-08-09', '2020-08-10', '2020-08-11', '2020-08-12', '2020-08-13', '2020-08-14', '2020-08-15', '2020-08-16', '2020-08-17', '2020-08-18', '2020-08-19', '2020-08-20', '2020-08-21', '2020-08-22', '2020-08-23'])

# %%
dt = '2020-05-30'
convert(dt)
# Out:
# '30 May'

# %%
# maybe helpful 

def split_date_json(pos_rate_json,state):
  td =  pd.DataFrame(pos_rate_json[state]['dates'])
  
  df = td.apply(lambda x: [x[0][:3],x[0][3:]],  result_type="expand",axis=1)
  df.columns=['date','month']
  return df

# %%
#dataset=pd.read_csv('https://raw.githubusercontent.com/CovidToday/backend/master/testing-and-cfr/population.csv')
dataset=pd.read_csv('population.csv')
population=pd.DataFrame()
population["State"]=dataset['State'][:37]
population["Population"]=dataset['Population'][:37]
population=population.set_index('State')

# %%
state_id = {
  "TT":"India",
  "MH":"Maharashtra",
  "TN":"Tamil Nadu",
  "DL":"Delhi",
  "GJ":"Gujarat",
  "RJ":"Rajasthan",
  "UP":"Uttar Pradesh",
  "MP":"Madhya Pradesh",
  "WB":"West Bengal",
  "KA":"Karnataka",
  "BR":"Bihar",
  "AP":"Andhra Pradesh",
  "HR":"Haryana",
  "TG":"Telangana",
  "JK":"Jammu and Kashmir",
  "OR":"Odisha",
  "PB":"Punjab",
  "AS":"Assam",
  "KL":"Kerala",
  "UT":"Uttarakhand",
  "JH":"Jharkhand",
  "CT":"Chhattisgarh",
  "TR":"Tripura",
  "HP":"Himachal Pradesh",
  "CH":"Chandigarh",
  "GA":"Goa",
  "MN":"Manipur",
  "NL":"Nagaland",
  "PY":"Puducherry",
  "LA":"Ladakh",
  "AR":"Arunachal Pradesh",
  "AN":"Andaman and Nicobar Islands",
  "ML":"Meghalaya",
  "MZ":"Mizoram",
  "DN":"Dadra and Nagar Haveli and Daman and Diu",
  "SK":"Sikkim",
}

# %%
#Changed

'''
from datetime import timedelta
start=datetime.now()
x1=datetime.now(pytz.timezone('Asia/Kolkata')).date()
#x1 = datetime.today()
#y1 = timedelta(days=7)
y1=[]
#x1=str(x1)[:10]
for i in range(7,0,-1):
  y1.append(str(datetime.today()-timedelta(days=i))[:10])
#print(y1)
##y1=str(y1)[:10]
t=y1
t
'''
def dates_gen(periods=7):
  t = pd.Series(pd.date_range(end = datetime.now(pytz.timezone('Asia/Kolkata'))-timedelta(1), periods = periods)).dt.strftime('%Y-%m-%d').tolist()

  return t

# %%
t=dates_gen()

# %%
from datetime import datetime
x=datetime.today()
dd=pd.date_range(start="2020-01-30",end=x)
dates=[]
for i in range(len(dd)):
  dates.append((str(dd[i])[:10]))
#dates
dates1=[]
for w in range (len(dates)):
  if len(dates[w]):
    dates1.append(convert(dates[w]))

# %%
dates[-1]
# Out:
# '2020-08-23'

# %% [markdown]
# # Positive Rate (All metrics)

# %% [markdown]
# ## GroundZero

# %%
'''
start=datetime.now()
states={}

csv_dates=[]
csv_states=[]
csv_total_cases=[]
csv_cum_recovered=[]
csv_daily_recovered=[]
csv_cum_deceased=[]
csv_daily_deceased=[]
csv_positivity_rate_cumulative=[]
csv_daily_positive_cases=[]
csv_daily_positivity_rate=[]
csv_daily_positive_cases_ma=[]
csv_daily_positivity_rate_ma=[]
csv_test_per_million=[]
csv_daily_tested=[]
csv_cum_tested=[]

csv_daily_case_per_million = []
csv_daily_test_per_million = []
csv_daily_test_ma = []
csv_daily_deceased_ma = []


test=json.load(open('test.json'))

for j in state_id.keys():
  print("Working : ",state_id[j])
  test_per_million=['']*len(dates)
  pos_cum=['']*len(dates)
  pos_rate_cum=['']*len(dates)
  daily_pos=['']*len(dates)
  daily_pos_ma=['']*len(dates)
  daily_tested=['']*len(dates)
  daily_pos_rate=['']*len(dates)
  daily_pos_rate_ma=['']*len(dates)
  tested_cum=['']*len(dates)
  tested_daily=['']*len(dates)
  deceased_cum=['']*len(dates)
  daily_deceased=['']*len(dates)
  recovered_cum=['']*len(dates)
  daily_recovered=['']*len(dates)    
  
  daily_case_per_million = ['']*len(dates)
  daily_test_per_million = ['']*len(dates)
  daily_test_ma = ['']*len(dates)
  daily_deceased_ma = ['']*len(dates)
    
  for i in range(len(dates)):
    if dates[i] in test.keys():
        temp=test[dates[i]]
    
        if j in temp.keys():
          if 'total' in temp[j].keys():
            if 'confirmed' in temp[j]['total'].keys():
              pos_cum[i]=temp[j]['total']['confirmed']

            if 'tested' in temp[j]['total'].keys():
              tested_cum[i]=abs(temp[j]['total']['tested'])
              test_per_million[i]=temp[j]['total']['tested']*1000000/int(population["Population"][state_id[j]])

            if 'deceased' in temp[j]['total'].keys():
              deceased_cum[i]=temp[j]['total']['deceased']

            if 'recovered' in temp[j]['total'].keys():
              recovered_cum[i]=temp[j]['total']['recovered']

            if len(str(pos_cum[i])) and len(str(tested_cum[i])):
              pos_rate_cum[i]= pos_cum[i]*100/tested_cum[i]

          if 'delta' in temp[j].keys():
            if 'confirmed' in temp[j]['delta'].keys():
              daily_pos[i]=temp[j]['delta']['confirmed']
              daily_case_per_million[i] =temp[j]['delta']['confirmed']*1000000/int(population["Population"][state_id[j]])   #New

            if 'tested' in temp[j]['delta'].keys():
              daily_tested[i]=abs(temp[j]['delta']['tested'])
              daily_test_per_million[i] = temp[j]['delta']['tested']*1000000/int(population["Population"][state_id[j]])    #New

            if 'deceased' in temp[j]['delta'].keys():
              daily_deceased[i]=temp[j]['delta']['deceased']

            if 'recovered' in temp[j]['delta'].keys():
              daily_recovered[i]=temp[j]['delta']['recovered']

            if len(str(daily_pos[i])) and len(str(daily_tested[i])):
              daily_pos_rate[i]=int(daily_pos[i])*100/int(daily_tested[i])

  for w in range(7,len(daily_pos)):
    sum1=0
    sum2=0
    for s in range(7):
      if (len(str(daily_pos[w-s]))!=0 and len(str(daily_tested[w-s]))!=0):
        sum1+=int(daily_pos[w-s])
        sum2+=int(daily_tested[w-s])
    if (sum2!=0):
      daily_pos_rate_ma[w]=sum1*100/abs(sum2)
  
  for w in range(7,len(daily_pos)):
    sum1=0
    count=0
    for s in range(7):
      if (len(str(daily_pos[w-s]))!=0):
        sum1+=int(daily_pos[w-s])
        count+=1
    if count!=0:
      daily_pos_ma[w]=sum1/count
    
  #New
    for w in range(7,len(daily_tested)):
      sum1=0
      count=0
      for s in range(7):
        if (len(str(daily_tested[w-s]))!=0):
          sum1+=int(daily_tested[w-s])
        
          count+=1
      if count!=0:
        daily_test_ma[w]=sum1/count
        
    #New
    for w in range(7,len(daily_deceased)):
      sum1=0
      count=0
      for s in range(7):
        if (len(str(daily_deceased[w-s]))!=0):
          sum1+=int(daily_deceased[w-s])
          count+=1
      if count!=0:
        daily_deceased_ma[w]=sum1/count

  st=state_id[j]

  for i in range(len(dates)-1):
    csv_dates.append(dates1[i])
    csv_states.append(st)
    csv_total_cases.append(pos_cum[i])
    csv_positivity_rate_cumulative.append(pos_rate_cum[i])
    csv_daily_positive_cases.append(daily_pos[i])
    csv_cum_recovered.append(recovered_cum[i])
    csv_daily_recovered.append(daily_recovered[i])
    csv_cum_deceased.append(deceased_cum[i])
    csv_daily_deceased.append(daily_deceased[i])
    csv_daily_positivity_rate.append(daily_pos_rate[i])
    csv_daily_positive_cases_ma.append(daily_pos_ma[i])
    csv_daily_positivity_rate_ma.append(daily_pos_rate_ma[i])
    csv_daily_tested.append(daily_tested[i])
    csv_cum_tested.append(tested_cum[i])
    csv_test_per_million.append(test_per_million[i])
    
    #New
    csv_daily_case_per_million.append(daily_case_per_million[i])
    csv_daily_test_per_million.append(daily_test_per_million[i])
    csv_daily_test_ma.append(daily_test_ma[i])
    csv_daily_deceased_ma.append(daily_deceased_ma[i])

  states[st]={
                    'dates':dates1[:-1],
                    'cum_positive_cases':pos_cum[:-1],
                    'cum_positivity_rate':pos_rate_cum[:-1],
                    'daily_positive_cases':daily_pos[:-1],
                    'cum_recovered':recovered_cum[:-1],
                    'daily_recovered':daily_recovered[:-1],
                    'cum_deceased':deceased_cum[:-1],
                    'daily_deceased':daily_deceased[:-1],
                    'daily_positivity_rate':daily_pos_rate[:-1],
                    'daily_positive_cases_ma': daily_pos_ma[:-1],
                    'daily_positivity_rate_ma':daily_pos_rate_ma[:-1] , 
                    'daily_tests': daily_tested[:-1],
                    'cum_tests': tested_cum[:-1],
                    'test_per_million':test_per_million[:-1],    
                    #New
                    'daily_cases_per_million':daily_case_per_million[:-1],
                    'daily_tests_per_million':daily_test_per_million[:-1],
                    'daily_tests_ma':daily_test_ma[:-1],
                    'daily_deceased_ma':daily_deceased_ma[:-1]

                   }
      
states['datetime']=str(datetime.now(pytz.timezone('Asia/Kolkata')))
with open('positivity_Rate_new.json', 'w') as outfile:
  json.dump(states, outfile,indent=4)
'''
# Out:
# '\nstart=datetime.now()\nstates={}\n\ncsv_dates=[]\ncsv_states=[]\ncsv_total_cases=[]\ncsv_cum_recovered=[]\ncsv_daily_recovered=[]\ncsv_cum_deceased=[]\ncsv_daily_deceased=[]\ncsv_positivity_rate_cumulative=[]\ncsv_daily_positive_cases=[]\ncsv_daily_positivity_rate=[]\ncsv_daily_positive_cases_ma=[]\ncsv_daily_positivity_rate_ma=[]\ncsv_test_per_million=[]\ncsv_daily_tested=[]\ncsv_cum_tested=[]\n\ncsv_daily_case_per_million = []\ncsv_daily_test_per_million = []\ncsv_daily_test_ma = []\ncsv_daily_deceased_ma = []\n\n\ntest=json.load(open(\'test.json\'))\n\nfor j in state_id.keys():\n  print("Working : ",state_id[j])\n  test_per_million=[\'\']*len(dates)\n  pos_cum=[\'\']*len(dates)\n  pos_rate_cum=[\'\']*len(dates)\n  daily_pos=[\'\']*len(dates)\n  daily_pos_ma=[\'\']*len(dates)\n  daily_tested=[\'\']*len(dates)\n  daily_pos_rate=[\'\']*len(dates)\n  daily_pos_rate_ma=[\'\']*len(dates)\n  tested_cum=[\'\']*len(dates)\n  tested_daily=[\'\']*len(dates)\n  deceased_cum=[\'\']*len(dates)\n  daily_deceased=[\'\']*len(dates)\n  recovered_cum=[\'\']*len(dates)\n  daily_recovered=[\'\']*len(dates)    \n  \n  daily_case_per_million = [\'\']*len(dates)\n  daily_test_per_million = [\'\']*len(dates)\n  daily_test_ma = [\'\']*len(dates)\n  daily_deceased_ma = [\'\']*len(dates)\n    \n  for i in range(len(dates)):\n    if dates[i] in test.keys():\n        temp=test[dates[i]]\n    \n        if j in temp.keys():\n          if \'total\' in temp[j].keys():\n            if \'confirmed\' in temp[j][\'total\'].keys():\n              pos_cum[i]=temp[j][\'total\'][\'confirmed\']\n\n            if \'tested\' in temp[j][\'total\'].keys():\n              tested_cum[i]=abs(temp[j][\'total\'][\'tested\'])\n              test_per_million[i]=temp[j][\'total\'][\'tested\']*1000000/int(population["Population"][state_id[j]])\n\n            if \'deceased\' in temp[j][\'total\'].keys():\n              deceased_cum[i]=temp[j][\'total\'][\'deceased\']\n\n            if \'recovered\' in temp[j][\'total\'].keys():\n              recovered_cum[i]=temp[j][\'total\'][\'recovered\']\n\n            if len(str(pos_cum[i])) and len(str(tested_cum[i])):\n              pos_rate_cum[i]= pos_cum[i]*100/tested_cum[i]\n\n          if \'delta\' in temp[j].keys():\n            if \'confirmed\' in temp[j][\'delta\'].keys():\n              daily_pos[i]=temp[j][\'delta\'][\'confirmed\']\n              daily_case_per_million[i] =temp[j][\'delta\'][\'confirmed\']*1000000/int(population["Population"][state_id[j]])   #New\n\n            if \'tested\' in temp[j][\'delta\'].keys():\n              daily_tested[i]=abs(temp[j][\'delta\'][\'tested\'])\n              daily_test_per_million[i] = temp[j][\'delta\'][\'tested\']*1000000/int(population["Population"][state_id[j]])    #New\n\n            if \'deceased\' in temp[j][\'delta\'].keys():\n              daily_deceased[i]=temp[j][\'delta\'][\'deceased\']\n\n            if \'recovered\' in temp[j][\'delta\'].keys():\n              daily_recovered[i]=temp[j][\'delta\'][\'recovered\']\n\n            if len(str(daily_pos[i])) and len(str(daily_tested[i])):\n              daily_pos_rate[i]=int(daily_pos[i])*100/int(daily_tested[i])\n\n  for w in range(7,len(daily_pos)):\n    sum1=0\n    sum2=0\n    for s in range(7):\n      if (len(str(daily_pos[w-s]))!=0 and len(str(daily_tested[w-s]))!=0):\n        sum1+=int(daily_pos[w-s])\n        sum2+=int(daily_tested[w-s])\n    if (sum2!=0):\n      daily_pos_rate_ma[w]=sum1*100/abs(sum2)\n  \n  for w in range(7,len(daily_pos)):\n    sum1=0\n    count=0\n    for s in range(7):\n      if (len(str(daily_pos[w-s]))!=0):\n        sum1+=int(daily_pos[w-s])\n        count+=1\n    if count!=0:\n      daily_pos_ma[w]=sum1/count\n    \n  #New\n    for w in range(7,len(daily_tested)):\n      sum1=0\n      count=0\n      for s in range(7):\n        if (len(str(daily_tested[w-s]))!=0):\n          sum1+=int(daily_tested[w-s])\n        \n          count+=1\n      if count!=0:\n        daily_test_ma[w]=sum1/count\n      ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-0603eb35dab9> in <module>
# ----> 1 len(csv_cum_tested)/36
#
# NameError: name 'csv_cum_tested' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-25c9c522d0a5> in <module>
# ----> 1 for k in states['India'].keys():
#       2     print(len(states['India'][k]))
#
# NameError: name 'states' is not defined

# %% [markdown]
# ## Append

# %%
csv_dates=[]
csv_states=[]
csv_total_cases=[]
csv_cum_recovered=[]
csv_daily_recovered=[]
csv_cum_deceased=[]
csv_daily_deceased=[]
csv_positivity_rate_cumulative=[]
csv_daily_positive_cases=[]
csv_daily_positivity_rate=[]
csv_daily_positive_cases_ma=[]
csv_daily_positivity_rate_ma=[]
csv_test_per_million=[]
csv_daily_tested=[]
csv_cum_tested=[]

#New
csv_daily_case_per_million = []
csv_daily_test_per_million = []
csv_daily_test_ma = []
csv_daily_deceased_ma = []
'''
#Proposed method

test_json_url = 'https://api.covid19india.org/v3/data-all.json'
test_json = json.loads(urlopen(test_json_url).read())

posrat_json_url = 'https://raw.githubusercontent.com/CovidToday/backend/master/testing-and-cfr/positivity_Rate.json'
posrat_json = json.loads(urlopen(posrat_json_url).read())


test =test_json
temp1 = posrat_json

'''
#Old method

#test_json_url = 'https://api.covid19india.org/v3/data-all.json'
#test_json = json.loads(urlopen(test_json_url).read())

#test = test_json
test = json.load(open('test.json'))
temp1 = json.load(open('positivity_Rate.json'))


for date in t:  
 
  states={}
  temp = test[date]
  

  for i,j in enumerate(state_id.keys()):
    k = state_id[j]
    #print('posrate() -- Working : ',state_id[j])

    test_per_million = temp1[k]['test_per_million']
    pos_cum = temp1[k]['cum_positive_cases']
    pos_rate_cum = temp1[k]['cum_positivity_rate']
    daily_pos = temp1[k]['daily_positive_cases']
    daily_pos_ma = temp1[k]['daily_positive_cases_ma']
    daily_pos_rate = temp1[k]['daily_positivity_rate']
    daily_pos_rate_ma = temp1[k]['daily_positivity_rate_ma']
    tested_cum = temp1[k]['cum_tests']
    daily_tested = temp1[k]['daily_tests']
    deceased_cum = temp1[k]['cum_deceased']
    daily_deceased = temp1[k]['daily_deceased']
    recovered_cum = temp1[k]['cum_recovered']
    daily_recovered = temp1[k]['daily_recovered'] 
    
    
    
    #New added
    daily_case_per_million  = temp1[k]['daily_cases_per_million']
    daily_test_per_million  = temp1[k]['daily_tests_per_million']
    daily_test_ma  = temp1[k]['daily_tests_ma']
    daily_deceased_ma  = temp1[k]['daily_deceased_ma']
  
    dates=temp1[k]['dates']

    if convert(date) not in dates :
      print(1)
      dates.append(convert(date))
      test_per_million.append('')
      pos_cum.append('')
      pos_rate_cum.append('')
      daily_pos.append('')
      daily_pos_ma.append('')
      daily_pos_rate.append('')
      daily_pos_rate_ma.append('')
      tested_cum.append('')
      daily_tested.append('')
      deceased_cum.append('')
      daily_deceased.append('')
      recovered_cum.append('')
      daily_recovered.append('')
      
      #New added
      print("Appends")
      daily_case_per_million.append('')
      daily_test_per_million.append('')
      daily_test_ma.append('')
      daily_deceased_ma.append('')

      i=len(dates)-1
      
    for l in range(len(dates)):
      if convert(date)==dates[l]:
        i=l
        break
    

    if k in temp1.keys():
        if 'total' in temp[j].keys():
          if 'confirmed' in temp[j]['total'].keys():
            pos_cum[i]=temp[j]['total']['confirmed']

          if 'tested' in temp[j]['total'].keys():
            tested_cum[i]=abs(temp[j]['total']['tested'])
            test_per_million[i]=temp[j]['total']['tested']*1000000/int(population["Population"][k])
              
          if 'deceased' in temp[j]['total'].keys():
            deceased_cum[i]=temp[j]['total']['deceased']
          
          if 'recovered' in temp[j]['total'].keys():
            recovered_cum[i]=temp[j]['total']['recovered']
          
          if len(str(pos_cum[i])) and len(str(tested_cum[i])):
            pos_rate_cum[i]= pos_cum[i]*100/tested_cum[i]

        if 'delta' in temp[j].keys():
          if 'confirmed' in temp[j]['delta'].keys():
            daily_pos[i]=temp[j]['delta']['confirmed']
            daily_case_per_million[i] =temp[j]['delta']['confirmed']*1000000/int(population["Population"][k])   #New

          if 'tested' in temp[j]['delta'].keys():
            daily_tested[i]=abs(temp[j]['delta']['tested'])
            daily_test_per_million[i] = temp[j]['delta']['tested']*1000000/int(population["Population"][k])    #New

          if 'deceased' in temp[j]['delta'].keys():
            daily_deceased[i]=temp[j]['delta']['deceased']
          
          if 'recovered' in temp[j]['delta'].keys():
            daily_recovered[i]=temp[j]['delta']['recovered']
          
          if len(str(daily_pos[i])) and len(str(daily_tested[i])):
            daily_pos_rate[i]=int(daily_pos[i])*100/int(daily_tested[i])
    
   
    for w in range(7,len(daily_pos)):
      sum1=0
      sum2=0
      for s in range(7):
        if (len(str(daily_pos[w-s]))!=0 and len(str(daily_tested[w-s]))!=0):
          sum1+=int(daily_pos[w-s])
          sum2+=int(daily_tested[w-s])
      if (sum2!=0):
        daily_pos_rate_ma[w]=sum1*100/abs(sum2)
    
    for w in range(7,len(daily_pos)):
      sum1=0
      count=0
      for s in range(7):
        if (len(str(daily_pos[w-s]))!=0):
          sum1+=int(daily_pos[w-s])
          count+=1
      if count!=0:
        daily_pos_ma[w]=sum1/count
  
    #New
    for w in range(7,len(daily_tested)):
      sum1=0
      count=0
      for s in range(7):
        if (len(str(daily_tested[w-s]))!=0):
          sum1+=int(daily_tested[w-s])
        
          count+=1
      if count!=0:
        daily_test_ma[w]=sum1/count
        
    #New
    for w in range(7,len(daily_deceased)):
      sum1=0
      count=0
      for s in range(7):
        if (len(str(daily_deceased[w-s]))!=0):
          sum1+=int(daily_deceased[w-s])
          count+=1
      if count!=0:
        daily_deceased_ma[w]=sum1/count
   
    
    #print(len)
    st=state_id[j]
    for i in range(len(dates)):
      '''
      if i  == len(dates)//4:
        print("Progress : 25%")
      if i  == len(dates)//2:
        print("Progress : 50%")
      if i  == (len(dates)*3)//4:
        print("Progress : 75%")  
      if i  == len(dates)-1:
        print("Progres : 100&")
      '''
      csv_dates.append(dates[i])
      csv_states.append(st)
      csv_total_cases.append(pos_cum[i])
      csv_positivity_rate_cumulative.append(pos_rate_cum[i])
      csv_daily_positive_cases.append(daily_pos[i])
      csv_cum_recovered.append(recovered_cum[i])
      csv_daily_recovered.append(daily_recovered[i])
      csv_cum_deceased.append(deceased_cum[i])
      csv_daily_deceased.append(daily_deceased[i])
      csv_daily_positivity_rate.append(daily_pos_rate[i])
      csv_daily_positive_cases_ma.append(daily_pos_ma[i])
      csv_daily_positivity_rate_ma.append(daily_pos_rate_ma[i])
      csv_daily_tested.append(daily_tested[i])
      csv_cum_tested.append(tested_cum[i])
      csv_test_per_million.append(test_per_million[i])

      #New
      csv_daily_case_per_million.append(daily_case_per_million[i])
      csv_daily_test_per_million.append(daily_test_per_million[i])
      csv_daily_test_ma.append(daily_test_ma[i])
      csv_daily_deceased_ma.append(daily_deceased_ma[i])
    
    #print(st)
    states[st]={
                    'dates':dates,
                    'cum_positive_cases':pos_cum,
                    'cum_positivity_rate':pos_rate_cum,
                    'daily_positive_cases':daily_pos,
                    'cum_recovered':recovered_cum,
                    'daily_recovered':daily_recovered,
                    'cum_deceased':deceased_cum,
                    'daily_deceased':daily_deceased,
                    'daily_positivity_rate':daily_pos_rate,
                    'daily_positive_cases_ma': daily_pos_ma,
                    'daily_positivity_rate_ma':daily_pos_rate_ma , 
                    'daily_tests': daily_tested,
                    'cum_tests': tested_cum,
                    'test_per_million':test_per_million,
                    #New
                    'daily_cases_per_million':daily_case_per_million,
                    'daily_tests_per_million':daily_test_per_million,
                    'daily_tests_ma':daily_test_ma,
                    'daily_deceased_ma':daily_deceased_ma

                   }
      
states['datetime']=str(datetime.now(pytz.timezone('Asia/Kolkata')))
with open('positivity_Rate.json', 'w') as outfile:
    json.dump(states, outfile,indent=4)

# %%
dates
# Out:
# ['30 January',
#  '31 January',
#  '01 February',
#  '02 February',
#  '03 February',
#  '04 February',
#  '05 February',
#  '06 February',
#  '07 February',
#  '08 February',
#  '09 February',
#  '10 February',
#  '11 February',
#  '12 February',
#  '13 February',
#  '14 February',
#  '15 February',
#  '16 February',
#  '17 February',
#  '18 February',
#  '19 February',
#  '20 February',
#  '21 February',
#  '22 February',
#  '23 February',
#  '24 February',
#  '25 February',
#  '26 February',
#  '27 February',
#  '28 February',
#  '29 February',
#  '01 March',
#  '02 March',
#  '03 March',
#  '04 March',
#  '05 March',
#  '06 March',
#  '07 March',
#  '08 March',
#  '09 March',
#  '10 March',
#  '11 March',
#  '12 March',
#  '13 March',
#  '14 March',
#  '15 March',
#  '16 March',
#  '17 March',
#  '18 March',
#  '19 March',
#  '20 March',
#  '21 March',
#  '22 March',
#  '23 March',
#  '24 March',
#  '25 March',
#  '26 March',
#  '27 March',
#  '28 March',
#  '29 March',
#  '30 March',
#  '31 March',
#  '01 April',
#  '02 April',
#  '03 April',
#  '04 April',
#  '05 April',
#  '06 April',
#  '07 April',
#  '08 April',
#  '09 April',
#  '10 April',
#  '11 April',
#  '12 April',
#  '13 April',
#  '14 April',
#  '15 April',
#  '16 April',
#  '17 April',
#  '18 April',
#  '19 April',
#  '20 April',
#  '21 April',
#  '22 April',
#  '23 April',
#  '24 April',
#  '25 April',
#  '26 April',
#  '27 April',
#  '28 April',
#  '29 April',
#  '30 April',
#  '01 May',
#  '02 May',
#  '03 May',
#  '04 May',
#  '05 May',
#  '06 May',
#  '07 May',
#  '08 May',
#  '09 May',
#  '10 May',
#  '11 May',
#  '12 May',
#  '13 May',
#  '14 May',
#  '15 May',
#  '16 May',
#  '17 May',
#  '18 May',
#  '19 May',
#  '20 May',
#  '21 May',
#  '22 May',
#  '23 May',
#  '24 May',
#  '25 May',
#  '26 May',
#  '27 May',
#  '28 May',
#  '29 May',
#  '30 May',
#  '31 May',
#  '01 June',
#  '02 June',
#  '03 June',
#  '04 June',
#  '05 June',
#  '06 June',
#  '07 June',
#  '08 June',
#  '09 June',
#  '10 June',
#  '11 June',
#  '12 June',
#  '13 June',
#  '14 June',
#  '15 June',
#  '16 June',
#  '17 June',
#  '18 June',
#  '19 June',
#  '20 June',
#  '21 June',
#  '22 June',
#  '23 June',
#  '24 June',
#  '25 June',
#  '26 June',
#  '27 June',
#  '28 June',
#  '29 June',
#  '30 June',
#  '01 July',
#  '02 July',
#  '03 July',
#  '04 July',
#  '05 July',
#  '06 July',
#  '07 July',
#  '08 July',
#  '09 July',
#  '10 July',
#  '11 July',
#  '12 July',
#  '13 July',
#  '14 July',
#  '15 July',
#  '16 July',
#  '17 July',
#  '18 July',
#  '19 July',
#  '20 July',
#  '21 July',
#  '22 July',
#  '23 July',
#  '24 July',
#  '25 July',
#  '26 July',
#  '27 July',
#  '28 July',
#  '29 July',
#  '30 July',
#  '31 July',
#  '01 August',
#  '02 August',
#  '03 August',
#  '04 August',
#  '05 August',
#  '06 August',
#  '07 August',
#  '08 August',
#  '09 August',
#  '10 August',
#  '11 August',
#  '12 August',
#  '13 August',
#  '14 August',
#  '15 August',
#  '16 August',
#  '17 August',
#  '18 August',
#  '19 August',
#  '20 August',
#  '21 August',
#  '22 August']

# %%
len(pos_cum)
# Out:
# 206

# %%
dates[-1]
# Out:
# '22 August'

# %%
csv_dates[-1]
# Out:
# '22 August'

# %%
n_states = len(state_id.keys())
n_dates = len(dates)

rows = n_states*n_dates

rows
# Out:
# 7416

# %% [markdown]
# # CSV

# %%
n_states = len(state_id.keys())
n_dates = len(dates)

rows = n_states*n_dates


df=pd.DataFrame()
df['dates']=csv_dates[:rows]
df['state']=csv_states[:rows]
df['cum_positive_cases']=csv_total_cases[:rows]
df['cum_positivity_rate']=csv_positivity_rate_cumulative[:rows]

df['cum_recovered']=csv_cum_recovered[:rows]
df['daily_recovered']:csv_daily_recovered[:rows]
df['cum_deceased']=csv_cum_deceased[:rows]
df['daily_deceased']=csv_daily_deceased[:rows]
df['daily_positive_cases']=csv_daily_positive_cases[:rows]
df['daily_positivity_rate']=csv_daily_positivity_rate[:rows]
df['daily_positive_cases_ma']=csv_daily_positive_cases_ma[:rows]
df['daily_positivity_rate_ma']=    csv_daily_positivity_rate_ma[:rows]
df['daily_tests']=csv_daily_tested[:rows]
df['cum_tested']=csv_cum_tested[:rows]
df['test_per_million']=csv_test_per_million[:rows]

#New
df['daily_cases_per_million'] = csv_daily_case_per_million[:rows]
df['daily_tests_per_million'] = csv_daily_test_per_million[:rows]
df['daily_tests_ma'] = csv_daily_test_ma[:rows]
df['daily_deceased_ma'] = csv_daily_deceased_ma[:rows]

df.to_csv('positivity_Rate_new.csv',index=False)

df_to_concat = copy.deepcopy(df)

# %%
df.columns
# Out:
# Index(['dates', 'state', 'cum_positive_cases', 'cum_positivity_rate',
#        'cum_recovered', 'cum_deceased', 'daily_deceased',
#        'daily_positive_cases', 'daily_positivity_rate',
#        'daily_positive_cases_ma', 'daily_positivity_rate_ma', 'daily_tests',
#        'cum_tested', 'test_per_million', 'daily_cases_per_million',
#        'daily_tests_per_million', 'daily_tests_ma', 'daily_deceased_ma'],
#       dtype='object')

# %%
df[df['state']=='India']
# Out:
#            dates  state cum_positive_cases cum_positivity_rate cum_recovered  \
# 0     30 January  India                  1
# 1     31 January  India
# 2    01 February  India
# 3    02 February  India                  2
# 4    03 February  India                  3
# ..           ...    ...                ...                 ...           ...
# 201    18 August  India            2766626             8.71576       2036703
# 202    19 August  India            2835822             8.68253       2096068
# 203    20 August  India            2904340             8.67816       2157941
# 204    21 August  India            2973369             8.62069       2220799
# 205    22 August  India            3043436             8.62353       2279900
#
#     cum_deceased daily_deceased daily_positive_cases daily_positivity_rate  \
# 0                                                  1
# 1
# 2
# 3                                                  1
# 4                                                  1
# ..           ...            ...                  ...                   ...
# 201        53015           1099                65024               8.11261
# 202        53994            979                69196               7.53383
# 203        54975            981                68518               8.50115
# 204        55928            953                69029               6.74219
# 205        56846            918                70067               8.74584
#
#     daily_positive_cases_ma daily_positivity_rate_ma daily_tests cum_tested  \
# 0
# 1
# 2
# 3
# 4
# ..                      ...                      ...         ...        ...
# 201                   62603                  7.65119      801518   31742782
# 202                 62907.3                  7.57194      918470   32661252
# 203                 63532.6                  7.70382      805985   33467237
# 204                   64021                  7.55986     1023836   34491073
# 205                 64889.7                  7.59259      801147   35292220
#
#     test_per_million daily_cases_per_million daily_tests_per_million  \
# 0                                0.000729203
# 1
# 2
# 3                                0.000729203
# 4                                0.000729203
# ..               ...                     ...                     ...
# 201          23146.9                 47.4157                 584.469
# 202          23816.7                 50.4579                 669.751
# 203          24404.4                 49.9635                 587.727
# 204            25151                 50.3361                 746.584
# 205          25735.2                 51.0931                 584.199
#
#     daily_tests_ma daily_deceased_ma
# 0
# 1
# 2
# 3
# 4
# ..             ...               ...
# 201         818212           975.429
# 202         830795           979.571
# 203         824689               976
# 204         846854           970.857
# 205         854645               966
#
# [206 rows x 18 columns]

# %% [markdown]
# # CFR

# %%
#dates = np.array([pd.to_datetime(i['date']) for i in filter(lambda v: v['status'] == 'Confirmed',json.load(open('states.json',))['states_daily'])])
#print(dates)
data_recovered = pd.DataFrame()
data_deceased = pd.DataFrame()
data_confirmed = pd.DataFrame()

for s in state_id.keys():
    st=state_id[s]
    data_confirmed[st] = np.array(states[st]['daily_positive_cases'])
    data_deceased[st] = np.array(states[st]['daily_deceased'])
    data_recovered[st] = np.array(states[st]['daily_recovered'])

# %%
def n2z(x):
    x[np.logical_or(np.isnan(x),np.isinf(x))] = 0
    return x

# %%
data_recovered = data_recovered.replace(r'^\s*$', np.NaN, regex=True).fillna(0)
data_recovered = data_recovered.astype(np.int32)
data_confirmed = data_confirmed.replace(r'^\s*$', np.NaN, regex=True).fillna(0)
data_confirmed = data_confirmed.astype(np.int32)
data_deceased = data_deceased.replace(r'^\s*$', np.NaN, regex=True).fillna(0)
data_deceased = data_deceased.astype(np.int32)
data_deceased['date'] = dates
data_recovered['date'] = dates
data_confirmed['date'] = dates

# %%
json_data={}
cfr = pd.DataFrame()
final=pd.DataFrame
plt.figure(1, figsize=(15, 7))
for st in state_id.keys():
    print("cfr() -- Working : ",state_id[st])

    state=state_id[st]
    boots = 100
    conf = []
    for n in range(boots):
        if n  == boots//4:
          print("Progress : 25%")
        if n  == boots//2:
          print("Progress : 50%")
        if n  == (boots*3)//4:
          print("Progress : 75%")  
        if n  == boots-1:
          print("Progress : 100%")

        dataset = np.copy(data_confirmed[state].values)
        mean = 13.0+(20.9-8.7)/4*np.random.normal()
        sd = 12.7+(26.0-6.4)/4*np.random.normal()
        phi = np.sqrt(sd**2 + mean**2)
        mu = np.log(mean**2/phi)
        sigma = np.sqrt(np.log(phi**2/mean**2))
        L = lognorm(s=sigma,scale=np.exp(mu))
        for i in range(len(dataset)-1,-1,-1):
            send_forward = np.round(L.rvs(np.max([dataset[i],0])))
            send_forward = send_forward[i+send_forward<len(dataset)]
            dataset[i] = 0
            for j in np.unique(np.int32(send_forward)):
                dataset[i+j] += np.sum(send_forward==j)
        conf.append(dataset)
    CFR = np.cumsum(data_deceased[state].values)/np.cumsum(conf,axis=1)
    col_mean = np.nanmean(CFR, axis=0)
    inds = np.where(np.isnan(CFR))
    CFR[inds] = np.take(col_mean, inds[1])
    #temp1=list(pd.Series(dates).dt.strftime('%m-%d-%Y'))
    #print(temp1[0])
    dates = states[state]['dates']
    temp = {
        'dates':dates,
        'cfr1_point':list(n2z(100*np.cumsum(data_deceased[state].values)/np.cumsum(data_confirmed[state].values))),
        'cfr2_point':list(n2z(100*np.cumsum(data_deceased[state].values)/(np.cumsum(data_deceased[state].values)+np.cumsum(data_recovered[state].values)))),
        'cfr3_point':list(n2z(100*np.median(CFR,axis=0))),
        'cfr3_l95':list(n2z(100*np.quantile(CFR,0.025,axis=0))),
        'cfr3_u95':list(n2z(100*np.quantile(CFR,0.975,axis=0))),
        'cfr3_l50':list(n2z(100*np.quantile(CFR,0.25,axis=0))),
        'cfr3_u50':list(n2z(100*np.quantile(CFR,0.75,axis=0))),
        }
    a=state_id[st]
    #print(a)
    states[state].update(temp)
    json_data[state] = temp
    cfr_state=pd.DataFrame()
    cfr_state['state']=[str(a)]*len(dates)
    cfr_state['dates']=dates
    cfr_state['cfr1_point']=(list(100*n2z(np.cumsum(data_deceased[state].values)/np.cumsum(data_confirmed[state].values))))
    cfr_state['cfr2_point']=(list(100*n2z(np.cumsum(data_deceased[state].values)/(np.cumsum(data_deceased[state].values)+np.cumsum(data_recovered[state].values)))))
    cfr_state['cfr3_point']=(list(100*n2z(np.median(CFR,axis=0))))
    cfr_state['cfr3_l95']=(list(100*n2z(np.quantile(CFR,0.025,axis=0))))
    cfr_state['cfr3_u95']=(list(100*n2z(np.quantile(CFR,0.975,axis=0))))
    cfr_state['cfr3_l50']=(list(100*n2z(np.quantile(CFR,0.25,axis=0))))
    cfr_state['cfr3_u50']=(list(100*n2z(np.quantile(CFR,0.75,axis=0))))
    cfr=pd.concat([cfr, cfr_state])
      
    plt.plot(temp['cfr3_point'],label=state)
plt.legend()
# Out:
# cfr() -- Working :  India
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# cfr() -- Working :  Maharashtra
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# cfr() -- Working :  Tamil Nadu
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# cfr() -- Working :  Delhi
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
#  Gujarat
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Rajasthan
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Uttar Pradesh
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
#  Madhya Pradesh
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  West Bengal
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Karnataka
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Bihar
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Andhra Pradesh
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# cfr() -- Working :  Haryana
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Telangana
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Jammu and Kashmir
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Odisha
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Punjab
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Assam
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Kerala
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Uttarakhand
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Jharkhand
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Chhattisgarh
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Tripura
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Himachal Pradesh
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Chandigarh
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Goa
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Manipur
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Nagaland
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Puducherry
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Ladakh
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Arunachal Pradesh
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Andaman and Nicobar Islands
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Meghalaya
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Mizoram
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: divide by zero encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Dadra and Nagar Haveli and Daman and Diu
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# cfr() -- Working :  Sikkim
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# Progress : 25%
# Progress : 50%
# Progress : 75%
# Progress : 100%
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: RuntimeWarning: Mean of empty slice
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:45: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning: invalid value encountered in true_divide
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide

# %%
cfr.to_csv('cfr.csv',index=False)
from datetime import datetime
json_data['datetime']=str(datetime.now(pytz.timezone('Asia/Kolkata')))

# %%
json_data_indented = json.dumps(json_data, indent = 4)
with open("cfr.json", "w") as outfile: 
    outfile.write(json_data_indented)

# %% [markdown]
# # Doubling Rate

# %%
def calc_doublingtimes(x):
    vals = []
    for i in range(x.shape[0]):
        for j in range(i+1,x.shape[0]):
            if len(str(x[j])) and len(str(x[i])):
                vals.append(np.log(2)*(j-i)/np.log(int(x[j])/int(x[i])))
    if not vals:
        return 0,0,0
    return np.median(vals),np.quantile(vals,0.025),np.quantile(vals,0.975)

# %%
start=datetime.now()
x=datetime.now(pytz.timezone('Asia/Kolkata')).date()
dd=pd.date_range(start="2020-01-30",end=x)
datess=[]
for i in range(len(dd)):
  datess.append((str(dd[i])[:10]))

# %%
dates1=[]
for w in range (len(dates)):
  if len(dates[w]):
    dates1.append(convert(datess[w]))

# %%
json_data={}

#test_json_url = 'https://api.covid19india.org/v3/data-all.json'
#test_json = json.loads(urlopen(test_json_url).read())
test= json.load(open('test.json'))

for j in state_id.keys():
    cumul=['']*len(dates)
    st=state_id[j]
    cumul=states[st]['cum_positive_cases']

    cumul_cases=np.array(cumul)
    dbt = np.zeros((3,cumul_cases.shape[0]))
    for i in range(cumul_cases.shape[0]):
        dbt[:,i] = calc_doublingtimes(cumul_cases[i-7:i])
    st=state_id[j]
    json_data[st] = {
            'dates':dates1,
            'dbt_point':pd.Series((list(dbt[0,:]))).fillna('').tolist(),
            'dbt_l95':pd.Series((list(dbt[1,:]))).fillna('').tolist(),
            'dbt_u95':pd.Series((list(dbt[2,:]))).fillna('').tolist()
            }
    states[st].update(json_data[st])
# Out:
# F:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: divide by zero encountered in double_scalars
#
# F:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3942: RuntimeWarning: invalid value encountered in multiply
#   x2 = take(ap, indices_above, axis=axis) * weights_above

# %% [markdown]
# # Rt Calculation

# %%
data_recovered = pd.DataFrame()
data_deceased = pd.DataFrame()
data_confirmed = pd.DataFrame()
for s in state_id.keys():
    st=state_id[s]
    data_confirmed[st] = np.array(states[st]['daily_positive_cases'])
    data_deceased[st] = np.array(states[st]['daily_deceased'])
    data_recovered[st] = np.array(states[st]['daily_recovered'])

# %%
data_recovered = data_recovered.replace(r'^\s*$', np.NaN, regex=True).fillna(0)
data_recovered = data_recovered.astype(np.int32)
data_confirmed = data_confirmed.replace(r'^\s*$', np.NaN, regex=True).fillna(0)
data_confirmed = data_confirmed.astype(np.int32)
data_deceased = data_deceased.replace(r'^\s*$', np.NaN, regex=True).fillna(0)
data_deceased = data_deceased.astype(np.int32)
data_deceased['date'] = dates
data_recovered['date'] = dates
data_confirmed['date'] = dates

# %%
rt_json = {}

rt = pd.DataFrame()
# plt.figure(1, figsize=(15, 7))
for st in list(state_id.keys()):
    state=state_id[st]
    print("Working : ",state)
    
    temp = pd.DataFrame()
    temp["active"] = np.array(data_confirmed[state]).clip(0).tolist()
    temp.to_csv('confirmed.csv')
    
    #os.system("Rscript.exe scripts/Rt_analysis_newGT_TJ.R")  #Changed
    call(['RScript.exe',"scripts/Rt_analysis_newGT_TJ.R"])
    
    values = {

            'rt_point':[],
            'rt_sd':[],
            'rt_l95':[],
            'rt_u95':[],
            'rt_l50':[],
            'rt_u50':[],
            't_end':[]
            }
    for df in [pd.read_csv('rt_temp/'+temp) for temp in os.listdir('rt_temp/')]:
        values['rt_point'].append(df['Mean(R)'])
        values['rt_sd'].append(df['Std(R)'])
        values['rt_l95'].append(df['Quantile.0.025(R)'])
        values['rt_u95'].append(df['Quantile.0.975(R)'])
        values['rt_l50'].append(df['Quantile.0.25(R)'])
        values['rt_u50'].append(df['Quantile.0.75(R)'])
        values['t_end'].append(df['t_end']-1)
    for i in values:
        values[i] = np.median(values[i],axis=0)
    values['dates'] = list(data_confirmed['date'][values['t_end']-1])
    rt_state=pd.DataFrame()
    rt_state['state']=[str(state)]*len(values['dates'])
    rt_state['dates']= values['dates']
    rt_state['rt_point'] = values['rt_point']
    rt_state['rt_sd'] = values['rt_sd']    
    rt_state['rt_l95'] = values['rt_l95']    
    rt_state['rt_u95'] = values['rt_u95']    
    rt_state['rt_l50'] = values['rt_l50']
    rt_state['rt_u50'] = values['rt_u50']
    rt=pd.concat([rt, rt_state])
    
    rt_json[st] = values
    plt.plot(range(len(values['rt_point'])),values['rt_point'],label=state)
    plt.fill_between(range(len(values['rt_point'])),values['rt_l95'],values['rt_u95'],alpha=0.5)
    plt.ylim(0,4)
    plt.legend()
    plt.show()
# Out:
# Working :  India
# Working :  Maharashtra
# Working :  Tamil Nadu
# Working :  Delhi
# Working :  Gujarat
# Working :  Rajasthan
# Working :  Uttar Pradesh
# Working :  Madhya Pradesh
# Working :  West Bengal
# Working :  Karnataka
# Working :  Bihar
# Working :  Andhra Pradesh
# Working :  Haryana
# Working :  Telangana
# Working :  Jammu and Kashmir
# Working :  Odisha
# Working :  Punjab
# Working :  Assam
# Working :  Kerala
# Working :  Uttarakhand
# Working :  Jharkhand
# Working :  Chhattisgarh
# Working :  Tripura
# Working :  Himachal Pradesh
# Working :  Chandigarh
# Working :  Goa
# Working :  Manipur
# Working :  Nagaland
# Working :  Puducherry
# Working :  Ladakh
# Working :  Arunachal Pradesh
# Working :  Andaman and Nicobar Islands
# Working :  Meghalaya
# Working :  Mizoram
# Working :  Dadra and Nagar Haveli and Daman and Diu
# Working :  Sikkim

# %%
for st in state_id.keys():
    state = state_id[st]
    states[state].update(rt_json[st])

# %%
rt.to_csv('rt.csv',index=False)

# %%
len(dates)
# Out:
# 206

# %%
states['Maharashtra'].keys()
# Out:
# dict_keys(['dates', 'cum_positive_cases', 'cum_positivity_rate', 'daily_positive_cases', 'cum_recovered', 'daily_recovered', 'cum_deceased', 'daily_deceased', 'daily_positivity_rate', 'daily_positive_cases_ma', 'daily_positivity_rate_ma', 'daily_tests', 'cum_tests', 'test_per_million', 'daily_cases_per_million', 'daily_tests_per_million', 'daily_tests_ma', 'daily_deceased_ma', 'cfr1_point', 'cfr2_point', 'cfr3_point', 'cfr3_l95', 'cfr3_u95', 'cfr3_l50', 'cfr3_u50', 'dbt_point', 'dbt_l95', 'dbt_u95', 'rt_point', 'rt_sd', 'rt_l95', 'rt_u95', 'rt_l50', 'rt_u50', 't_end'])

# %% [markdown]
# ##Rt Shifting

# %%
def shift_rt_metrics(dict,key,days=9):
  arr = copy.deepcopy(dict[key])
  values_shift = collections.deque(arr)
  values_shift.rotate(-1*days)

  new_val = list(values_shift)

  size = len(dict['dates'])
  
  for i in range(days):
    new_val[size-1-i]=''

  return new_val

# %%
rt_json_shifted = copy.deepcopy(rt_json)

for st in state_id.keys():
    
    rt_json_shifted[st]['rt_point'] = shift_rt_metrics(rt_json[st],'rt_point',2)
    rt_json_shifted[st]['rt_sd'] = shift_rt_metrics(rt_json[st],'rt_sd',2)
    rt_json_shifted[st]['rt_l95'] = shift_rt_metrics(rt_json[st],'rt_l95',2)
    rt_json_shifted[st]['rt_u95'] = shift_rt_metrics(rt_json[st],'rt_u95',2)
    rt_json_shifted[st]['rt_l50'] = shift_rt_metrics(rt_json[st],'rt_l50',2)
    rt_json_shifted[st]['rt_u50'] = shift_rt_metrics(rt_json[st],'rt_u50',2)
    rt_json_shifted[st]['t_end'] = shift_rt_metrics(rt_json[st],'t_end',2)

# %%
dates[-1]
# Out:
# '22 August'

# %%
for st in state_id.keys():
    state = state_id[st]
    leng = len(dates)
    
    #states[state]['dates'] =  temp1['India']['dates']
    for keys in list(rt_json_shifted[st].keys())[:-1]:
        if len(rt_json_shifted[st][keys])<leng:
            rt_json_shifted[st][keys].extend(['' for i in range(leng-len(rt_json_shifted[st][keys]))]) 
                
    rt_json_shifted[st]['dates'] = dates

# %%
states_shifted = copy.deepcopy(states)

for st in state_id.keys():
    state = state_id[st]
    states_shifted[state].update(rt_json_shifted[st])

# %%
for st in state_id.keys():
    for key in rt_json[st].keys():
      try:
        rt_json[st][key]=rt_json[st][key].tolist()
      except:
        pass

# %%
for st in state_id.keys():
    state = state_id[st]
    
    for key in states[state].keys():
      try:
        states[state][key]=states[state][key].tolist()
      except:
        pass

# %%
for st in state_id.keys():
    state = state_id[st]
    leng = len(temp1['India']['dates'])
    states[state]['dates'] =  temp1['India']['dates']
    
    for keys in list(states[state].keys())[1:]:
        if len(states[state][keys])<leng:
            states[state][keys].extend(['' for i in range(leng-len(states[state][keys]))])

# %%
for st in state_id.keys():
    state = state_id[st]
    leng = len(temp1['India']['dates'])
    states_shifted[state]['dates'] =  temp1['India']['dates']
    
    for keys in list(states_shifted[state].keys())[1:]:
        if len(states_shifted[state][keys])<leng:
            states_shifted[state][keys].extend(['' for i in range(leng-len(states_shifted[state][keys]))])

# %% [markdown]
# ## Rt changes for review

# %%
with open('rt_shifted.json', 'w') as outfile:
  json.dump(rt_json_shifted, outfile,indent=4)

# %%
with open('rt.json', 'w') as outfile:
  json.dump(rt_json, outfile,indent=4)

# %%
            
rt_graph = copy.deepcopy(rt_json_shifted)

de =10

for st in state_id.keys():
    
    for k in rt_json_shifted[st].keys():
            rt_graph[st][k] = rt_json_shifted[st][k][:-10]

# %%
with open('rt_graph.json', 'w') as outfile:
  json.dump(rt_graph, outfile,indent=4)

# %%
'''
vals = min(len(df_to_concat),len(cfr),len(rt))
one = df_to_concat.iloc[:vals]
two = cfr.iloc[:vals]
three = rt.iloc[:vals]
df_list = [one,two]
#df_list = [df_to_concat.iloc[:vals],cfr.iloc[:vals],rt.iloc[:vals]]
all_dataframes = pd.concat([two,three],axis=1)
all_dataframes.to_csv('allmetrics_state.csv',index=False)'''
# Out:
# "\nvals = min(len(df_to_concat),len(cfr),len(rt))\none = df_to_concat.iloc[:vals]\ntwo = cfr.iloc[:vals]\nthree = rt.iloc[:vals]\ndf_list = [one,two]\n#df_list = [df_to_concat.iloc[:vals],cfr.iloc[:vals],rt.iloc[:vals]]\nall_dataframes = pd.concat([two,three],axis=1)\nall_dataframes.to_csv('allmetrics_state.csv',index=False)"

# %% [markdown]
# #Pooling

# %%
print("No of days of data present: ",len(dates))
print("Data rows for state dict: ",len(states['India']['dbt_u95']))
print("No. of states : ",len(states.keys())-1)
# Out:
# No of days of data present:  206
# Data rows for state dict:  206
# No. of states :  36

# %%
print("Date updated : ",states['datetime'])
# Out:
# Date updated :  2020-08-23 14:13:08.672325+05:30

# %%
len(states['India']['dates'])
# Out:
# 206

# %%
cols=list(states['India'].keys())
q=['state']
complete=pd.DataFrame(columns=q+cols)
keys=list(states.keys())[:-1]

for i in keys:
  temp=pd.DataFrame()
  temp['state']=[str(i)]*len(states['India']['dates'])
  for j in cols:
    print(j)
    temp[j]=list(states[i][j])
  complete = pd.concat([complete,temp])
# Out:
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end
# dates
# cum_positive_cases
# cum_positivity_rate
# daily_positive_cases
# cum_recovered
# daily_recovered
# cum_deceased
# daily_deceased
# daily_positivity_rate
# daily_positive_cases_ma
# daily_positivity_rate_ma
# daily_tests
# cum_tests
# test_per_million
# daily_cases_per_million
# daily_tests_per_million
# daily_tests_ma
# daily_deceased_ma
# cfr1_point
# cfr2_point
# cfr3_point
# cfr3_l95
# cfr3_u95
# cfr3_l50
# cfr3_u50
# dbt_point
# dbt_l95
# dbt_u95
# rt_point
# rt_sd
# rt_l95
# rt_u95
# rt_l50
# rt_u50
# t_end

# %%
len(states_shifted['India']['dates'])
# Out:
# 206

# %%
cols=list(states_shifted['India'].keys())
q=['state']
complete_shifted=pd.DataFrame(columns=q+cols)
keys=list(states_shifted.keys())[:-1]

for i in keys:
  temp=pd.DataFrame()
  temp['state']=[str(i)]*len(states_shifted['India']['dates'])
  for j in cols:
    print(i,j)
    temp[j]=list(states_shifted[i][j])
  complete_shifted = pd.concat([complete_shifted,temp])
# Out:
# India dates
# India cum_positive_cases
# India cum_positivity_rate
# India daily_positive_cases
# India cum_recovered
# India daily_recovered
# India cum_deceased
# India daily_deceased
# India daily_positivity_rate
# India daily_positive_cases_ma
# India daily_positivity_rate_ma
# India daily_tests
# India cum_tests
# India test_per_million
# India daily_cases_per_million
# India daily_tests_per_million
# India daily_tests_ma
# India daily_deceased_ma
# India cfr1_point
# India cfr2_point
# India cfr3_point
# India cfr3_l95
# India cfr3_u95
# India cfr3_l50
# India cfr3_u50
# India dbt_point
# India dbt_l95
# India dbt_u95
# India rt_point
# India rt_sd
# India rt_l95
# India rt_u95
# India rt_l50
# India rt_u50
# India t_end
# Maharashtra dates
# Maharashtra cum_positive_cases
# Maharashtra cum_positivity_rate
# Maharashtra daily_positive_cases
# Maharashtra cum_recovered
# Maharashtra daily_recovered
# Maharashtra cum_deceased
# Maharashtra daily_deceased
# Maharashtra daily_positivity_rate
# Maharashtra daily_positive_cases_ma
# Maharashtra daily_positivity_rate_ma
# Maharashtra daily_tests
# Maharashtra cum_tests
# Maharashtra test_per_million
# Maharashtra daily_cases_per_million
# Maharashtra daily_tests_per_million
# Maharashtra daily_tests_ma
# Maharashtra daily_deceased_ma
# Maharashtra cfr1_point
# Maharashtra cfr2_point
# Maharashtra cfr3_point
# Maharashtra cfr3_l95
# Maharashtra cfr3_u95
# Maharashtra cfr3_l50
# Maharashtra cfr3_u50
# Maharashtra dbt_point
# Maharashtra dbt_l95
# Maharashtra dbt_u95
# Maharashtra rt_point
# Maharashtra rt_sd
# Maharashtra rt_l95
# Maharashtra rt_u95
# Maharashtra rt_l50
# Maharashtra rt_u50
# Maharashtra t_end
# Tamil Nadu dates
# Tamil Nadu cum_positive_cases
# Tamil Nadu cum_positivity_rate
# Tamil Nadu daily_positive_cases
# Tamil Nadu cum_recovered
# Tamil Nadu daily_recovered
# Tamil Nadu cum_deceased
# Tamil Nadu daily_deceased
# Tamil Nadu daily_positivity_rate
# Tamil Nadu daily_positive_cases_ma
# Tamil Nadu daily_positivity_rate_ma
# Tamil Nadu daily_tests
# Tamil Nadu cum_tests
# Tamil Nadu test_per_million
# Tamil Nadu daily_cases_per_million
# Tamil Nadu daily_tests_per_million
# Tamil Nadu daily_tests_ma
# Tamil Nadu daily_deceased_ma
# Tamil Nadu cfr1_point
# Tamil Nadu cfr2_point
# Tamil Nadu cfr3_point
# Tamil Nadu cfr3_l95
# Tamil Nadu cfr3_u95
# Tamil Nadu cfr3_l50
# Tamil Nadu cfr3_u50
# Tamil Nadu dbt_point
# Tamil Nadu dbt_l95
# Tamil Nadu dbt_u95
# Tamil Nadu rt_point
# Tamil Nadu rt_sd
# Tamil Nadu rt_l95
# Tamil Nadu rt_u95
# Tamil Nadu rt_l50
# Tamil Nadu rt_u50
# Tamil Nadu t_end
# Delhi dates
# Delhi cum_positive_cases
# Delhi cum_positivity_rate
# Delhi daily_positive_cases
# Delhi cum_recovered
# Delhi daily_recovered
# Delhi cum_deceased
# Delhi daily_deceased
# Delhi daily_positivity_rate
# Delhi daily_positive_cases_ma
# Delhi daily_positivity_rate_ma
# Delhi daily_tests
# Delhi cum_tests
# Delhi test_per_million
# Delhi daily_cases_per_million
# Delhi daily_tests_per_million
# Delhi daily_tests_ma
# Delhi daily_deceased_ma
# Delhi cfr1_point
# Delhi cfr2_point
# Delhi cfr3_point
# Delhi cfr3_l95
# Delhi cfr3_u95
# Delhi cfr3_l50
# Delhi cfr3_u50
# Delhi dbt_point
# Delhi dbt_l95
# Delhi dbt_u95
# Delhi rt_point
# Delhi rt_sd
# Delhi rt_l95
# Delhi rt_u95
# Delhi rt_l50
# Delhi rt_u50
# Delhi t_end
# Gujarat dates
# Gujarat cum_positive_cases
# Gujarat cum_positivity_rate
# Gujarat daily_positive_cases
# Gujarat cum_recovered
# Gujarat daily_recovered
# Gujarat cum_deceased
# Gujarat daily_deceased
# Gujarat daily_positivity_rate
# Gujarat daily_positive_cases_ma
# Gujarat daily_positivity_rate_ma
# Gujarat daily_tests
# Gujarat cum_tests
# Gujarat test_per_million
# Gujarat daily_cases_per_million
# Gujarat daily_tests_per_million
# Gujarat daily_tests_ma
# Gujarat daily_deceased_ma
# Gujarat cfr1_point
# Gujarat cfr2_point
# Gujarat cfr3_point
# Gujarat cfr3_l95
# Gujarat cfr3_u95
# Gujarat cfr3_l50
# Gujarat cfr3_u50
# Gujarat dbt_point
# Gujarat dbt_l95
# Gujarat dbt_u95
# Gujarat rt_point
# Gujarat rt_sd
# Gujarat rt_l95
# Gujarat rt_u95
# Gujarat rt_l50
# Gujarat rt_u50
# Gujarat t_end
# Rajasthan dates
# Rajasthan cum_positive_cases
# Rajasthan cum_positivity_rate
# Rajasthan daily_positive_cases
# Rajasthan cum_recovered
# Rajasthan daily_recovered
# Rajasthan cum_deceased
# Rajasthan daily_deceased
# Rajasthan daily_positivity_rate
# Rajasthan daily_positive_cases_ma
# Rajasthan daily_positivity_rate_ma
# Rajasthan daily_tests
# Rajasthan cum_tests
# Rajasthan test_per_million
# Rajasthan daily_cases_per_million
# Rajasthan daily_tests_per_million
# Rajasthan daily_tests_ma
# Rajasthan daily_deceased_ma
# Rajasthan cfr1_point
# Rajasthan cfr2_point
# Rajasthan cfr3_point
# Rajasthan cfr3_l95
# Rajasthan cfr3_u95
# Rajasthan cfr3_l50
# Rajasthan cfr3_u50
# Rajasthan dbt_point
# Rajasthan dbt_l95
# Rajasthan dbt_u95
# Rajasthan rt_point
# Rajasthan rt_sd
# Rajasthan rt_l95
# Rajasthan rt_u95
# Rajasthan rt_l50
# Rajasthan rt_u50
# Rajasthan t_end
# Uttar Pradesh dates
# Uttar Pradesh cum_positive_cases
# Uttar Pradesh cum_positivity_rate
# Uttar Pradesh daily_positive_cases
# Uttar Pradesh cum_recovered
# Uttar Pradesh daily_recovered
# Uttar Pradesh cum_deceased
# Uttar Pradesh daily_deceased
# Uttar Pradesh daily_positivity_rate
# Uttar Pradesh daily_positive_cases_ma
# Uttar Pradesh daily_positivity_rate_ma
# Uttar Pradesh daily_tests
# Uttar Pradesh cum_tests
# Uttar Pradesh test_per_million
# Uttar Pradesh daily_cases_per_million
# Uttar Pradesh daily_tests_per_million
# Uttar Pradesh daily_tests_ma
# Uttar Pradesh daily_deceased_ma
# Uttar Pradesh cfr1_point
# Uttar Pradesh cfr2_point
# Uttar Pradesh cfr3_point
# Uttar Pradesh cfr3_l95
# Uttar Pradesh cfr3_u95
# Uttar Pradesh cfr3_l50
# Uttar Pradesh cfr3_u50
# Uttar Pradesh dbt_point
# Uttar Pradesh dbt_l95
# Uttar Pradesh dbt_u95
# Uttar Pradesh rt_point
# Uttar Pradesh rt_sd
# Uttar Pradesh rt_l95
# Uttar Pradesh rt_u95
# Uttar Pradesh rt_l50
# Uttar Pradesh rt_u50
# Uttar Pradesh t_end
# Madhya Pradesh dates
# Madhya Pradesh cum_positive_cases
# Madhya Pradesh cum_positivity_rate
# Madhya Pradesh daily_positive_cases
# Madhya Pradesh cum_recovered
# Madhya Pradesh daily_recovered
# Madhya Pradesh cum_deceased
# Madhya Pradesh daily_deceased
# Madhya Pradesh daily_positivity_rate
# Madhya Pradesh daily_positive_cases_ma
# Madhya Pradesh daily_positivity_rate_ma
# Madhya Pradesh daily_tests
# Madhya Pradesh cum_tests
# Madhya Pradesh test_per_million
# Madhya Pradesh daily_cases_per_million
# Madhya Pradesh daily_tests_per_million
# Madhya Pradesh daily_tests_ma
# Madhya Pradesh daily_deceased_ma
# Madhya Pradesh cfr1_point
# Madhya Pradesh cfr2_point
# Madhya Pradesh cfr3_point
# Madhya Pradesh cfr3_l95
# Madhya Pradesh cfr3_u95
# Madhya Pradesh cfr3_l50
# Madhya Pradesh cfr3_u50
# Madhya Pradesh dbt_point
# Madhya Pradesh dbt_l95
# Madhya Pradesh dbt_u95
# Madhya Pradesh rt_point
# Madhya Pradesh rt_sd
# Madhya Pradesh rt_l95
# Madhya Pradesh rt_u95
# Madhya Pradesh rt_l50
# Madhya Pradesh rt_u50
# Madhya Pradesh t_end
# West Bengal dates
# West Bengal cum_positive_cases
# West Bengal cum_positivity_rate
# West Bengal daily_positive_cases
# West Bengal cum_recovered
# West Bengal daily_recovered
# West Bengal cum_deceased
# West Bengal daily_deceased
# West Bengal daily_positivity_rate
# West Bengal daily_positive_cases_ma
# West Bengal daily_positivity_rate_ma
# West Bengal daily_tests
# West Bengal cum_tests
# West Bengal test_per_million
# West Bengal daily_cases_per_million
# West Bengal daily_tests_per_million
# West Bengal daily_tests_ma
# West Bengal daily_deceased_ma
# West Bengal cfr1_point
# West Bengal cfr2_point
# West Bengal cfr3_point
# West Bengal cfr3_l95
# West Bengal cfr3_u95
# West Bengal cfr3_l50
# West Bengal cfr3_u50
# West Bengal dbt_point
# West Bengal dbt_l95
# West Bengal dbt_u95
# West Bengal rt_point
# West Bengal rt_sd
# West Bengal rt_l95
# West Bengal rt_u95
# West Bengal rt_l50
# West Bengal rt_u50
# West Bengal t_end
# Karnataka dates
# Karnataka cum_positive_cases
# Karnataka cum_positivity_rate
# Karnataka daily_positive_cases
# Karnataka cum_recovered
# Karnataka daily_recovered
# Karnataka cum_deceased
# Karnataka daily_deceased
# Karnataka daily_positivity_rate
# Karnataka daily_positive_cases_ma
# Karnataka daily_positivity_rate_ma
# Karnataka daily_tests
# Karnataka cum_tests
# Karnataka test_per_million
# Karnataka daily_cases_per_million
# Karnataka daily_tests_per_million
# Karnataka daily_tests_ma
# Karnataka daily_deceased_ma
# Karnataka cfr1_point
# Karnataka cfr2_point
# Karnataka cfr3_point
# Karnataka cfr3_l95
# Karnataka cfr3_u95
# Karnataka cfr3_l50
# Karnataka cfr3_u50
# Karnataka dbt_point
# Karnataka dbt_l95
# Karnataka dbt_u95
# Karnataka rt_point
# Karnataka rt_sd
# Karnataka rt_l95
# Karnataka rt_u95
# Karnataka rt_l50
# Karnataka rt_u50
# Karnataka t_end
# Bihar dates
# Bihar cum_positive_cases
# Bihar cum_positivity_rate
# Bihar daily_positive_cases
# Bihar cum_recovered
# Bihar daily_recovered
# Bihar cum_deceased
# Bihar daily_deceased
# Bihar daily_positivity_rate
# Bihar daily_positive_cases_ma
# Bihar daily_positivity_rate_ma
# Bihar daily_tests
# Bihar cum_tests
# Bihar test_per_million
# Bihar daily_cases_per_million
# Bihar daily_tests_per_million
# Bihar daily_tests_ma
# Bihar daily_deceased_ma
# Bihar cfr1_point
# Bihar cfr2_point
# Bihar cfr3_point
# Bihar cfr3_l95
# Bihar cfr3_u95
# Bihar cfr3_l50
# Bihar cfr3_u50
# Bihar dbt_point
# Bihar dbt_l95
# Bihar dbt_u95
# Bihar rt_point
# Bihar rt_sd
# Bihar rt_l95
# Bihar rt_u95
# Bihar rt_l50
# Bihar rt_u50
# Bihar t_end
# Andhra Pradesh dates
# Andhra Pradesh cum_positive_cases
# Andhra Pradesh cum_positivity_rate
# Andhra Pradesh daily_positive_cases
# Andhra Pradesh cum_recovered
# Andhra Pradesh daily_recovered
# Andhra Pradesh cum_deceased
# Andhra Pradesh daily_deceased
# Andhra Pradesh daily_positivity_rate
# Andhra Pradesh daily_positive_cases_ma
# Andhra Pradesh daily_positivity_rate_ma
# Andhra Pradesh daily_tests
# Andhra Pradesh cum_tests
# Andhra Pradesh test_per_million
# Andhra Pradesh daily_cases_per_million
# Andhra Pradesh daily_tests_per_million
# Andhra Pradesh daily_tests_ma
# Andhra Pradesh daily_deceased_ma
# Andhra Pradesh cfr1_point
# Andhra Pradesh cfr2_point
# Andhra Pradesh cfr3_point
# Andhra Pradesh cfr3_l95
# Andhra Pradesh cfr3_u95
# Andhra Pradesh cfr3_l50
# Andhra Pradesh cfr3_u50
# Andhra Pradesh dbt_point
# Andhra Pradesh dbt_l95
# Andhra Pradesh dbt_u95
# Andhra Pradesh rt_point
# Andhra Pradesh rt_sd
# Andhra Pradesh rt_l95
# Andhra Pradesh rt_u95
# Andhra Pradesh rt_l50
# Andhra Pradesh rt_u50
# Andhra Pradesh t_end
# Haryana dates
# Haryana cum_positive_cases
# Haryana cum_positivity_rate
# Haryana daily_positive_cases
# Haryana cum_recovered
# Haryana daily_recovered
# Haryana cum_deceased
# Haryana daily_deceased
# Haryana daily_positivity_rate
# Haryana daily_positive_cases_ma
# Haryana daily_positivity_rate_ma
# Haryana daily_tests
# Haryana cum_tests
# Haryana test_per_million
# Haryana daily_cases_per_million
# Haryana daily_tests_per_million
# Haryana daily_tests_ma
# Haryana daily_deceased_ma
# Haryana cfr1_point
# Haryana cfr2_point
# Haryana cfr3_point
# Haryana cfr3_l95
# Haryana cfr3_u95
# Haryana cfr3_l50
# Haryana cfr3_u50
# Haryana dbt_point
# Haryana dbt_l95
# Haryana dbt_u95
# Haryana rt_point
# Haryana rt_sd
# Haryana rt_l95
# Haryana rt_u95
# Haryana rt_l50
# Haryana rt_u50
# Haryana t_end
# Telangana dates
# Telangana cum_positive_cases
# Telangana cum_positivity_rate
# Telangana daily_positive_cases
# Telangana cum_recovered
# Telangana daily_recovered
# Telangana cum_deceased
# Telangana daily_deceased
# Telangana daily_positivity_rate
# Telangana daily_positive_cases_ma
# Telangana daily_positivity_rate_ma
# Telangana daily_tests
# Telangana cum_tests
# Telangana test_per_million
# Telangana daily_cases_per_million
# Telangana daily_tests_per_million
# Telangana daily_tests_ma
# Telangana daily_deceased_ma
# Telangana cfr1_point
# Telangana cfr2_point
# Telangana cfr3_point
# Telangana cfr3_l95
# Telangana cfr3_u95
# Telangana cfr3_l50
# Telangana cfr3_u50
# Telangana dbt_point
# Telangana dbt_l95
# Telangana dbt_u95
# Telangana rt_point
# Telangana rt_sd
# Telangana rt_l95
# Telangana rt_u95
# Telangana rt_l50
# Telangana rt_u50
# Telangana t_end
# Jammu and Kashmir dates
# Jammu and Kashmir cum_positive_cases
# Jammu and Kashmir cum_positivity_rate
# Jammu and Kashmir daily_positive_cases
# Jammu and Kashmir cum_recovered
# Jammu and Kashmir daily_recovered
# Jammu and Kashmir cum_deceased
# Jammu and Kashmir daily_deceased
# Jammu and Kashmir daily_positivity_rate
# Jammu and Kashmir daily_positive_cases_ma
# Jammu and Kashmir daily_positivity_rate_ma
# Jammu and Kashmir daily_tests
# Jammu and Kashmir cum_tests
# Jammu and Kashmir test_per_million
# Jammu and Kashmir daily_cases_per_million
# Jammu and Kashmir daily_tests_per_million
# Jammu and Kashmir daily_tests_ma
# Jammu and Kashmir daily_deceased_ma
# Jammu and Kashmir cfr1_point
# Jammu and Kashmir cfr2_point
# Jammu and Kashmir cfr3_point
# Jammu and Kashmir cfr3_l95
# Jammu and Kashmir cfr3_u95
# Jammu and Kashmir cfr3_l50
# Jammu and Kashmir cfr3_u50
# Jammu and Kashmir dbt_point
# Jammu and Kashmir dbt_l95
# Jammu and Kashmir dbt_u95
# Jammu and Kashmir rt_point
# Jammu and Kashmir rt_sd
# Jammu and Kashmir rt_l95
# Jammu and Kashmir rt_u95
# Jammu and Kashmir rt_l50
# Jammu and Kashmir rt_u50
# Jammu and Kashmir t_end
# Odisha dates
# Odisha cum_positive_cases
# Odisha cum_positivity_rate
# Odisha daily_positive_cases
# Odisha cum_recovered
# Odisha daily_recovered
# Odisha cum_deceased
# Odisha daily_deceased
# Odisha daily_positivity_rate
# Odisha daily_positive_cases_ma
# Odisha daily_positivity_rate_ma
# Odisha daily_tests
# Odisha cum_tests
# Odisha test_per_million
# Odisha daily_cases_per_million
# Odisha daily_tests_per_million
# Odisha daily_tests_ma
# Odisha daily_deceased_ma
# Odisha cfr1_point
# Odisha cfr2_point
# Odisha cfr3_point
# Odisha cfr3_l95
# Odisha cfr3_u95
# Odisha cfr3_l50
# Odisha cfr3_u50
# Odisha dbt_point
# Odisha dbt_l95
# Odisha dbt_u95
# Odisha rt_point
# Odisha rt_sd
# Odisha rt_l95
# Odisha rt_u95
# Odisha rt_l50
# Odisha rt_u50
# Odisha t_end
# Punjab dates
# Punjab cum_positive_cases
# Punjab cum_positivity_rate
# Punjab daily_positive_cases
# Punjab cum_recovered
# Punjab daily_recovered
# Punjab cum_deceased
# Punjab daily_deceased
# Punjab daily_positivity_rate
# Punjab daily_positive_cases_ma
# Punjab daily_positivity_rate_ma
# Punjab daily_tests
# Punjab cum_tests
# Punjab test_per_million
# Punjab daily_cases_per_million
# Punjab daily_tests_per_million
# Punjab daily_tests_ma
# Punjab daily_deceased_ma
# Punjab cfr1_point
# Punjab cfr2_point
# Punjab cfr3_point
# Punjab cfr3_l95
# Punjab cfr3_u95
# Punjab cfr3_l50
# Punjab cfr3_u50
# Punjab dbt_point
# Punjab dbt_l95
# Punjab dbt_u95
# Punjab rt_point
# Punjab rt_sd
# Punjab rt_l95
# Punjab rt_u95
# Punjab rt_l50
# Punjab rt_u50
# Punjab t_end
# Assam dates
# Assam cum_positive_cases
# Assam cum_positivity_rate
# Assam daily_positive_cases
# Assam cum_recovered
# Assam daily_recovered
# Assam cum_deceased
# Assam daily_deceased
# Assam daily_positivity_rate
# Assam daily_positive_cases_ma
# Assam daily_positivity_rate_ma
# Assam daily_tests
# Assam cum_tests
# Assam test_per_million
# Assam daily_cases_per_million
# Assam daily_tests_per_million
# Assam daily_tests_ma
# Assam daily_deceased_ma
# Assam cfr1_point
# Assam cfr2_point
# Assam cfr3_point
# Assam cfr3_l95
# Assam cfr3_u95
# Assam cfr3_l50
# Assam cfr3_u50
# Assam dbt_point
# Assam dbt_l95
# Assam dbt_u95
# Assam rt_point
# Assam rt_sd
# Assam rt_l95
# Assam rt_u95
# Assam rt_l50
# Assam rt_u50
# Assam t_end
# Kerala dates
# Kerala cum_positive_cases
# Kerala cum_positivity_rate
# Kerala daily_positive_cases
# Kerala cum_recovered
# Kerala daily_recovered
# Kerala cum_deceased
# Kerala daily_deceased
# Kerala daily_positivity_rate
# Kerala daily_positive_cases_ma
# Kerala daily_positivity_rate_ma
# Kerala daily_tests
# Kerala cum_tests
# Kerala test_per_million
# Kerala daily_cases_per_million
# Kerala daily_tests_per_million
# Kerala daily_tests_ma
# Kerala daily_deceased_ma
# Kerala cfr1_point
# Kerala cfr2_point
# Kerala cfr3_point
# Kerala cfr3_l95
# Kerala cfr3_u95
# Kerala cfr3_l50
# Kerala cfr3_u50
# Kerala dbt_point
# Kerala dbt_l95
# Kerala dbt_u95
# Kerala rt_point
# Kerala rt_sd
# Kerala rt_l95
# Kerala rt_u95
# Kerala rt_l50
# Kerala rt_u50
# Kerala t_end
# Uttarakhand dates
# Uttarakhand cum_positive_cases
# Uttarakhand cum_positivity_rate
# Uttarakhand daily_positive_cases
# Uttarakhand cum_recovered
# Uttarakhand daily_recovered
# Uttarakhand cum_deceased
# Uttarakhand daily_deceased
# Uttarakhand daily_positivity_rate
# Uttarakhand daily_positive_cases_ma
# Uttarakhand daily_positivity_rate_ma
# Uttarakhand daily_tests
# Uttarakhand cum_tests
# Uttarakhand test_per_million
# Uttarakhand daily_cases_per_million
# Uttarakhand daily_tests_per_million
# Uttarakhand daily_tests_ma
# Uttarakhand daily_deceased_ma
# Uttarakhand cfr1_point
# Uttarakhand cfr2_point
# Uttarakhand cfr3_point
# Uttarakhand cfr3_l95
# Uttarakhand cfr3_u95
# Uttarakhand cfr3_l50
# Uttarakhand cfr3_u50
# Uttarakhand dbt_point
# Uttarakhand dbt_l95
# Uttarakhand dbt_u95
# Uttarakhand rt_point
# Uttarakhand rt_sd
# Uttarakhand rt_l95
# Uttarakhand rt_u95
# Uttarakhand rt_l50
# Uttarakhand rt_u50
# Uttarakhand t_end
# Jharkhand dates
# Jharkhand cum_positive_cases
# Jharkhand cum_positivity_rate
# Jharkhand daily_positive_cases
# Jharkhand cum_recovered
# Jharkhand daily_recovered
# Jharkhand cum_deceased
# Jharkhand daily_deceased
# Jharkhand daily_positivity_rate
# Jharkhand daily_positive_cases_ma
# Jharkhand daily_positivity_rate_ma
# Jharkhand daily_tests
# Jharkhand cum_tests
# Jharkhand test_per_million
# Jharkhand daily_cases_per_million
# Jharkhand daily_tests_per_million
# Jharkhand daily_tests_ma
# Jharkhand daily_deceased_ma
# Jharkhand cfr1_point
# Jharkhand cfr2_point
# Jharkhand cfr3_point
# Jharkhand cfr3_l95
# Jharkhand cfr3_u95
# Jharkhand cfr3_l50
# Jharkhand cfr3_u50
# Jharkhand dbt_point
# Jharkhand dbt_l95
# Jharkhand dbt_u95
# Jharkhand rt_point
# Jharkhand rt_sd
# Jharkhand rt_l95
# Jharkhand rt_u95
# Jharkhand rt_l50
# Jharkhand rt_u50
# Jharkhand t_end
# Chhattisgarh dates
# Chhattisgarh cum_positive_cases
# Chhattisgarh cum_positivity_rate
# Chhattisgarh daily_positive_cases
# Chhattisgarh cum_recovered
# Chhattisgarh daily_recovered
# Chhattisgarh cum_deceased
# Chhattisgarh daily_deceased
# Chhattisgarh daily_positivity_rate
# Chhattisgarh daily_positive_cases_ma
# Chhattisgarh daily_positivity_rate_ma
# Chhattisgarh daily_tests
# Chhattisgarh cum_tests
# Chhattisgarh test_per_million
# Chhattisgarh daily_cases_per_million
# Chhattisgarh daily_tests_per_million
# Chhattisgarh daily_tests_ma
# Chhattisgarh daily_deceased_ma
# Chhattisgarh cfr1_point
# Chhattisgarh cfr2_point
# Chhattisgarh cfr3_point
# Chhattisgarh cfr3_l95
# Chhattisgarh cfr3_u95
# Chhattisgarh cfr3_l50
# Chhattisgarh cfr3_u50
# Chhattisgarh dbt_point
# Chhattisgarh dbt_l95
# Chhattisgarh dbt_u95
# Chhattisgarh rt_point
# Chhattisgarh rt_sd
# Chhattisgarh rt_l95
# Chhattisgarh rt_u95
# Chhattisgarh rt_l50
# Chhattisgarh rt_u50
# Chhattisgarh t_end
# Tripura dates
# Tripura cum_positive_cases
# Tripura cum_positivity_rate
# Tripura daily_positive_cases
# Tripura cum_recovered
# Tripura daily_recovered
# Tripura cum_deceased
# Tripura daily_deceased
# Tripura daily_positivity_rate
# Tripura daily_positive_cases_ma
# Tripura daily_positivity_rate_ma
# Tripura daily_tests
# Tripura cum_tests
# Tripura test_per_million
# Tripura daily_cases_per_million
# Tripura daily_tests_per_million
# Tripura daily_tests_ma
# Tripura daily_deceased_ma
# Tripura cfr1_point
# Tripura cfr2_point
# Tripura cfr3_point
# Tripura cfr3_l95
# Tripura cfr3_u95
# Tripura cfr3_l50
# Tripura cfr3_u50
# Tripura dbt_point
# Tripura dbt_l95
# Tripura dbt_u95
# Tripura rt_point
# Tripura rt_sd
# Tripura rt_l95
# Tripura rt_u95
# Tripura rt_l50
# Tripura rt_u50
# Tripura t_end
# Himachal Pradesh dates
# Himachal Pradesh cum_positive_cases
# Himachal Pradesh cum_positivity_rate
# Himachal Pradesh daily_positive_cases
# Himachal Pradesh cum_recovered
# Himachal Pradesh daily_recovered
# Himachal Pradesh cum_deceased
# Himachal Pradesh daily_deceased
# Himachal Pradesh daily_positivity_rate
# Himachal Pradesh daily_positive_cases_ma
# Himachal Pradesh daily_positivity_rate_ma
# Himachal Pradesh daily_tests
# Himachal Pradesh cum_tests
# Himachal Pradesh test_per_million
# Himachal Pradesh daily_cases_per_million
# Himachal Pradesh daily_tests_per_million
# Himachal Pradesh daily_tests_ma
# Himachal Pradesh daily_deceased_ma
# Himachal Pradesh cfr1_point
# Himachal Pradesh cfr2_point
# Himachal Pradesh cfr3_point
# Himachal Pradesh cfr3_l95
# Himachal Pradesh cfr3_u95
# Himachal Pradesh cfr3_l50
# Himachal Pradesh cfr3_u50
# Himachal Pradesh dbt_point
# Himachal Pradesh dbt_l95
# Himachal Pradesh dbt_u95
# Himachal Pradesh rt_point
# Himachal Pradesh rt_sd
# Himachal Pradesh rt_l95
# Himachal Pradesh rt_u95
# Himachal Pradesh rt_l50
# Himachal Pradesh rt_u50
# Himachal Pradesh t_end
# Chandigarh dates
# Chandigarh cum_positive_cases
# Chandigarh cum_positivity_rate
# Chandigarh daily_positive_cases
# Chandigarh cum_recovered
# Chandigarh daily_recovered
# Chandigarh cum_deceased
# Chandigarh daily_deceased
# Chandigarh daily_positivity_rate
# Chandigarh daily_positive_cases_ma
# Chandigarh daily_positivity_rate_ma
# Chandigarh daily_tests
# Chandigarh cum_tests
# Chandigarh test_per_million
# Chandigarh daily_cases_per_million
# Chandigarh daily_tests_per_million
# Chandigarh daily_tests_ma
# Chandigarh daily_deceased_ma
# Chandigarh cfr1_point
# Chandigarh cfr2_point
# Chandigarh cfr3_point
# Chandigarh cfr3_l95
# Chandigarh cfr3_u95
# Chandigarh cfr3_l50
# Chandigarh cfr3_u50
# Chandigarh dbt_point
# Chandigarh dbt_l95
# Chandigarh dbt_u95
# Chandigarh rt_point
# Chandigarh rt_sd
# Chandigarh rt_l95
# Chandigarh rt_u95
# Chandigarh rt_l50
# Chandigarh rt_u50
# Chandigarh t_end
# Goa dates
# Goa cum_positive_cases
# Goa cum_positivity_rate
# Goa daily_positive_cases
# Goa cum_recovered
# Goa daily_recovered
# Goa cum_deceased
# Goa daily_deceased
# Goa daily_positivity_rate
# Goa daily_positive_cases_ma
# Goa daily_positivity_rate_ma
# Goa daily_tests
# Goa cum_tests
# Goa test_per_million
# Goa daily_cases_per_million
# Goa daily_tests_per_million
# Goa daily_tests_ma
# Goa daily_deceased_ma
# Goa cfr1_point
# Goa cfr2_point
# Goa cfr3_point
# Goa cfr3_l95
# Goa cfr3_u95
# Goa cfr3_l50
# Goa cfr3_u50
# Goa dbt_point
# Goa dbt_l95
# Goa dbt_u95
# Goa rt_point
# Goa rt_sd
# Goa rt_l95
# Goa rt_u95
# Goa rt_l50
# Goa rt_u50
# Goa t_end
# Manipur dates
# Manipur cum_positive_cases
# Manipur cum_positivity_rate
# Manipur daily_positive_cases
# Manipur cum_recovered
# Manipur daily_recovered
# Manipur cum_deceased
# Manipur daily_deceased
# Manipur daily_positivity_rate
# Manipur daily_positive_cases_ma
# Manipur daily_positivity_rate_ma
# Manipur daily_tests
# Manipur cum_tests
# Manipur test_per_million
# Manipur daily_cases_per_million
# Manipur daily_tests_per_million
# Manipur daily_tests_ma
# Manipur daily_deceased_ma
# Manipur cfr1_point
# Manipur cfr2_point
# Manipur cfr3_point
# Manipur cfr3_l95
# Manipur cfr3_u95
# Manipur cfr3_l50
# Manipur cfr3_u50
# Manipur dbt_point
# Manipur dbt_l95
# Manipur dbt_u95
# Manipur rt_point
# Manipur rt_sd
# Manipur rt_l95
# Manipur rt_u95
# Manipur rt_l50
# Manipur rt_u50
# Manipur t_end
# Nagaland dates
# Nagaland cum_positive_cases
# Nagaland cum_positivity_rate
# Nagaland daily_positive_cases
# Nagaland cum_recovered
# Nagaland daily_recovered
# Nagaland cum_deceased
# Nagaland daily_deceased
# Nagaland daily_positivity_rate
# Nagaland daily_positive_cases_ma
# Nagaland daily_positivity_rate_ma
# Nagaland daily_tests
# Nagaland cum_tests
# Nagaland test_per_million
# Nagaland daily_cases_per_million
# Nagaland daily_tests_per_million
# Nagaland daily_tests_ma
# Nagaland daily_deceased_ma
# Nagaland cfr1_point
# Nagaland cfr2_point
# Nagaland cfr3_point
# Nagaland cfr3_l95
# Nagaland cfr3_u95
# Nagaland cfr3_l50
# Nagaland cfr3_u50
# Nagaland dbt_point
# Nagaland dbt_l95
# Nagaland dbt_u95
# Nagaland rt_point
# Nagaland rt_sd
# Nagaland rt_l95
# Nagaland rt_u95
# Nagaland rt_l50
# Nagaland rt_u50
# Nagaland t_end
# Puducherry dates
# Puducherry cum_positive_cases
# Puducherry cum_positivity_rate
# Puducherry daily_positive_cases
# Puducherry cum_recovered
# Puducherry daily_recovered
# Puducherry cum_deceased
# Puducherry daily_deceased
# Puducherry daily_positivity_rate
# Puducherry daily_positive_cases_ma
# Puducherry daily_positivity_rate_ma
# Puducherry daily_tests
# Puducherry cum_tests
# Puducherry test_per_million
# Puducherry daily_cases_per_million
# Puducherry daily_tests_per_million
# Puducherry daily_tests_ma
# Puducherry daily_deceased_ma
# Puducherry cfr1_point
# Puducherry cfr2_point
# Puducherry cfr3_point
# Puducherry cfr3_l95
# Puducherry cfr3_u95
# Puducherry cfr3_l50
# Puducherry cfr3_u50
# Puducherry dbt_point
# Puducherry dbt_l95
# Puducherry dbt_u95
# Puducherry rt_point
# Puducherry rt_sd
# Puducherry rt_l95
# Puducherry rt_u95
# Puducherry rt_l50
# Puducherry rt_u50
# Puducherry t_end
# Ladakh dates
# Ladakh cum_positive_cases
# Ladakh cum_positivity_rate
# Ladakh daily_positive_cases
# Ladakh cum_recovered
# Ladakh daily_recovered
# Ladakh cum_deceased
# Ladakh daily_deceased
# Ladakh daily_positivity_rate
# Ladakh daily_positive_cases_ma
# Ladakh daily_positivity_rate_ma
# Ladakh daily_tests
# Ladakh cum_tests
# Ladakh test_per_million
# Ladakh daily_cases_per_million
# Ladakh daily_tests_per_million
# Ladakh daily_tests_ma
# Ladakh daily_deceased_ma
# Ladakh cfr1_point
# Ladakh cfr2_point
# Ladakh cfr3_point
# Ladakh cfr3_l95
# Ladakh cfr3_u95
# Ladakh cfr3_l50
# Ladakh cfr3_u50
# Ladakh dbt_point
# Ladakh dbt_l95
# Ladakh dbt_u95
# Ladakh rt_point
# Ladakh rt_sd
# Ladakh rt_l95
# Ladakh rt_u95
# Ladakh rt_l50
# Ladakh rt_u50
# Ladakh t_end
# Arunachal Pradesh dates
# Arunachal Pradesh cum_positive_cases
# Arunachal Pradesh cum_positivity_rate
# Arunachal Pradesh daily_positive_cases
# Arunachal Pradesh cum_recovered
# Arunachal Pradesh daily_recovered
# Arunachal Pradesh cum_deceased
# Arunachal Pradesh daily_deceased
# Arunachal Pradesh daily_positivity_rate
# Arunachal Pradesh daily_positive_cases_ma
# Arunachal Pradesh daily_positivity_rate_ma
# Arunachal Pradesh daily_tests
# Arunachal Pradesh cum_tests
# Arunachal Pradesh test_per_million
# Arunachal Pradesh daily_cases_per_million
# Arunachal Pradesh daily_tests_per_million
# Arunachal Pradesh daily_tests_ma
# Arunachal Pradesh daily_deceased_ma
# Arunachal Pradesh cfr1_point
# Arunachal Pradesh cfr2_point
# Arunachal Pradesh cfr3_point
# Arunachal Pradesh cfr3_l95
# Arunachal Pradesh cfr3_u95
# Arunachal Pradesh cfr3_l50
# Arunachal Pradesh cfr3_u50
# Arunachal Pradesh dbt_point
# Arunachal Pradesh dbt_l95
# Arunachal Pradesh dbt_u95
# Arunachal Pradesh rt_point
# Arunachal Pradesh rt_sd
# Arunachal Pradesh rt_l95
# Arunachal Pradesh rt_u95
# Arunachal Pradesh rt_l50
# Arunachal Pradesh rt_u50
# Arunachal Pradesh t_end
# Andaman and Nicobar Islands dates
# Andaman and Nicobar Islands cum_positive_cases
# Andaman and Nicobar Islands cum_positivity_rate
# Andaman and Nicobar Islands daily_positive_cases
# Andaman and Nicobar Islands cum_recovered
# Andaman and Nicobar Islands daily_recovered
# Andaman and Nicobar Islands cum_deceased
# Andaman and Nicobar Islands daily_deceased
# Andaman and Nicobar Islands daily_positivity_rate
# Andaman and Nicobar Islands daily_positive_cases_ma
# Andaman and Nicobar Islands daily_positivity_rate_ma
# Andaman and Nicobar Islands daily_tests
# Andaman and Nicobar Islands cum_tests
# Andaman and Nicobar Islands test_per_million
# Andaman and Nicobar Islands daily_cases_per_million
# Andaman and Nicobar Islands daily_tests_per_million
# Andaman and Nicobar Islands daily_tests_ma
# Andaman and Nicobar Islands daily_deceased_ma
# Andaman and Nicobar Islands cfr1_point
# Andaman and Nicobar Islands cfr2_point
# Andaman and Nicobar Islands cfr3_point
# Andaman and Nicobar Islands cfr3_l95
# Andaman and Nicobar Islands cfr3_u95
# Andaman and Nicobar Islands cfr3_l50
# Andaman and Nicobar Islands cfr3_u50
# Andaman and Nicobar Islands dbt_point
# Andaman and Nicobar Islands dbt_l95
# Andaman and Nicobar Islands dbt_u95
# Andaman and Nicobar Islands rt_point
# Andaman and Nicobar Islands rt_sd
# Andaman and Nicobar Islands rt_l95
# Andaman and Nicobar Islands rt_u95
# Andaman and Nicobar Islands rt_l50
# Andaman and Nicobar Islands rt_u50
# Andaman and Nicobar Islands t_end
# Meghalaya dates
# Meghalaya cum_positive_cases
# Meghalaya cum_positivity_rate
# Meghalaya daily_positive_cases
# Meghalaya cum_recovered
# Meghalaya daily_recovered
# Meghalaya cum_deceased
# Meghalaya daily_deceased
# Meghalaya daily_positivity_rate
# Meghalaya daily_positive_cases_ma
# Meghalaya daily_positivity_rate_ma
# Meghalaya daily_tests
# Meghalaya cum_tests
# Meghalaya test_per_million
# Meghalaya daily_cases_per_million
# Meghalaya daily_tests_per_million
# Meghalaya daily_tests_ma
# Meghalaya daily_deceased_ma
# Meghalaya cfr1_point
# Meghalaya cfr2_point
# Meghalaya cfr3_point
# Meghalaya cfr3_l95
# Meghalaya cfr3_u95
# Meghalaya cfr3_l50
# Meghalaya cfr3_u50
# Meghalaya dbt_point
# Meghalaya dbt_l95
# Meghalaya dbt_u95
# Meghalaya rt_point
# Meghalaya rt_sd
# Meghalaya rt_l95
# Meghalaya rt_u95
# Meghalaya rt_l50
# Meghalaya rt_u50
# Meghalaya t_end
# Mizoram dates
# Mizoram cum_positive_cases
# Mizoram cum_positivity_rate
# Mizoram daily_positive_cases
# Mizoram cum_recovered
# Mizoram daily_recovered
# Mizoram cum_deceased
# Mizoram daily_deceased
# Mizoram daily_positivity_rate
# Mizoram daily_positive_cases_ma
# Mizoram daily_positivity_rate_ma
# Mizoram daily_tests
# Mizoram cum_tests
# Mizoram test_per_million
# Mizoram daily_cases_per_million
# Mizoram daily_tests_per_million
# Mizoram daily_tests_ma
# Mizoram daily_deceased_ma
# Mizoram cfr1_point
# Mizoram cfr2_point
# Mizoram cfr3_point
# Mizoram cfr3_l95
# Mizoram cfr3_u95
# Mizoram cfr3_l50
# Mizoram cfr3_u50
# Mizoram dbt_point
# Mizoram dbt_l95
# Mizoram dbt_u95
# Mizoram rt_point
# Mizoram rt_sd
# Mizoram rt_l95
# Mizoram rt_u95
# Mizoram rt_l50
# Mizoram rt_u50
# Mizoram t_end
# Dadra and Nagar Haveli and Daman and Diu dates
# Dadra and Nagar Haveli and Daman and Diu cum_positive_cases
# Dadra and Nagar Haveli and Daman and Diu cum_positivity_rate
# Dadra and Nagar Haveli and Daman and Diu daily_positive_cases
# Dadra and Nagar Haveli and Daman and Diu cum_recovered
# Dadra and Nagar Haveli and Daman and Diu daily_recovered
# Dadra and Nagar Haveli and Daman and Diu cum_deceased
# Dadra and Nagar Haveli and Daman and Diu daily_deceased
# Dadra and Nagar Haveli and Daman and Diu daily_positivity_rate
# Dadra and Nagar Haveli and Daman and Diu daily_positive_cases_ma
# Dadra and Nagar Haveli and Daman and Diu daily_positivity_rate_ma
# Dadra and Nagar Haveli and Daman and Diu daily_tests
# Dadra and Nagar Haveli and Daman and Diu cum_tests
# Dadra and Nagar Haveli and Daman and Diu test_per_million
# Dadra and Nagar Haveli and Daman and Diu daily_cases_per_million
# Dadra and Nagar Haveli and Daman and Diu daily_tests_per_million
# Dadra and Nagar Haveli and Daman and Diu daily_tests_ma
# Dadra and Nagar Haveli and Daman and Diu daily_deceased_ma
# Dadra and Nagar Haveli and Daman and Diu cfr1_point
# Dadra and Nagar Haveli and Daman and Diu cfr2_point
# Dadra and Nagar Haveli and Daman and Diu cfr3_point
# Dadra and Nagar Haveli and Daman and Diu cfr3_l95
# Dadra and Nagar Haveli and Daman and Diu cfr3_u95
# Dadra and Nagar Haveli and Daman and Diu cfr3_l50
# Dadra and Nagar Haveli and Daman and Diu cfr3_u50
# Dadra and Nagar Haveli and Daman and Diu dbt_point
# Dadra and Nagar Haveli and Daman and Diu dbt_l95
# Dadra and Nagar Haveli and Daman and Diu dbt_u95
# Dadra and Nagar Haveli and Daman and Diu rt_point
# Dadra and Nagar Haveli and Daman and Diu rt_sd
# Dadra and Nagar Haveli and Daman and Diu rt_l95
# Dadra and Nagar Haveli and Daman and Diu rt_u95
# Dadra and Nagar Haveli and Daman and Diu rt_l50
# Dadra and Nagar Haveli and Daman and Diu rt_u50
# Dadra and Nagar Haveli and Daman and Diu t_end
# Sikkim dates
# Sikkim cum_positive_cases
# Sikkim cum_positivity_rate
# Sikkim daily_positive_cases
# Sikkim cum_recovered
# Sikkim daily_recovered
# Sikkim cum_deceased
# Sikkim daily_deceased
# Sikkim daily_positivity_rate
# Sikkim daily_positive_cases_ma
# Sikkim daily_positivity_rate_ma
# Sikkim daily_tests
# Sikkim cum_tests
# Sikkim test_per_million
# Sikkim daily_cases_per_million
# Sikkim daily_tests_per_million
# Sikkim daily_tests_ma
# Sikkim daily_deceased_ma
# Sikkim cfr1_point
# Sikkim cfr2_point
# Sikkim cfr3_point
# Sikkim cfr3_l95
# Sikkim cfr3_u95
# Sikkim cfr3_l50
# Sikkim cfr3_u50
# Sikkim dbt_point
# Sikkim dbt_l95
# Sikkim dbt_u95
# Sikkim rt_point
# Sikkim rt_sd
# Sikkim rt_l95
# Sikkim rt_u95
# Sikkim rt_l50
# Sikkim rt_u50
# Sikkim t_end

# %%
complete_shifted.to_csv('allmetrics_states.csv',index=False)

# %%
complete.to_csv('com.csv',index=False)

# %%
json_data_indented = json.dumps(json_data, indent = 4)
with open("doubling_rate.json", "w") as outfile: 
    outfile.write(json_data_indented)

# %%
states_indented = json.dumps(states, indent = 4)
with open("covidtoday.json", "w") as outfile: 
    outfile.write(states_indented)

# %%
states_indented = json.dumps(states_shifted, indent = 4)
with open("allmetrics_states.json", "w") as outfile: 
    outfile.write(states_indented)

# %%
complete.columns
# Out:
# Index(['state', 'dates', 'cum_positive_cases', 'cum_positivity_rate',
#        'daily_positive_cases', 'cum_recovered', 'daily_recovered',
#        'cum_deceased', 'daily_deceased', 'daily_positivity_rate',
#        'daily_positive_cases_ma', 'daily_positivity_rate_ma', 'daily_tests',
#        'cum_tests', 'test_per_million', 'daily_cases_per_million',
#        'daily_tests_per_million', 'daily_tests_ma', 'daily_deceased_ma',
#        'cfr1_point', 'cfr2_point', 'cfr3_point', 'cfr3_l95', 'cfr3_u95',
#        'cfr3_l50', 'cfr3_u50', 'dbt_point', 'dbt_l95', 'dbt_u95', 'rt_point',
#        'rt_sd', 'rt_l95', 'rt_u95', 'rt_l50', 'rt_u50', 't_end'],
#       dtype='object')
